# %%
# Install system dependencies for Box2D and Video Recording
# !apt-get install -y swig ffmpeg xvfb
# Install Python libraries
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay

import gymnasium as gym
import os
import base64
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecMonitor, VecVideoRecorder
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML

# --- COLAB SETUP ---
# 1. Mount Google Drive
drive.mount('/content/drive')

# 2. Create Virtual Display (Required for video in Colab)
display = Display(visible=0, size=(1400, 900))
display.start()

# --- CONFIGURATION ---
EXPERIMENT_NAME = "basic_ppo_final"
ENV_ID = "BipedalWalker-v3"
TOTAL_TIMESTEPS = 2_000_000    # 2 Million Steps
NUM_CPU = 4                    # Colab usually gives 2-4 cores. 4 is a safe bet.
SEED = 42

# --- DIRECTORY SETUP (GOOGLE DRIVE) ---
# This saves everything to "My Drive/aisf_project/..."
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

def make_env(rank, seed=0):
    """
    Utility function for multiprocessed env.
    """
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (Steps: {TOTAL_TIMESTEPS}) ---")
    print(f"Saving data to: {base_path}")

    # 1. Create Multiprocessed Environment (FAST)
    env = SubprocVecEnv([make_env(i) for i in range(NUM_CPU)])

    # Wrap in VecMonitor to log the reward data for your graphs
    env = VecMonitor(env, log_dir)

    # 2. Setup Callback
    # Saves the best model found during training to Drive
    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=max(10000 // NUM_CPU, 1),
        deterministic=True,
        render=False
    )

    # 3. Create Model
    # "Untuned" - using default hyperparameters (matches "No clipping or penalty" baseline concept [cite: 557])
    # though SB3 defaults usually include some clipping.
    model = PPO("MlpPolicy", env, verbose=1, seed=SEED, tensorboard_log=log_dir)

    # 4. Train
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback)

    model.save(f"{model_dir}/final_model")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    # Try to load the best model (if EvalCallback saved one), otherwise final
    best_model_path = os.path.join(model_dir, "best_model.zip")
    if not os.path.exists(best_model_path):
        print("Best model not found, loading final model.")
        best_model_path = os.path.join(model_dir, "final_model.zip")

    model = PPO.load(best_model_path)

    # Use DummyVecEnv for video recording (simpler than Subproc)
    from stable_baselines3.common.vec_env import DummyVecEnv
    video_env = DummyVecEnv([lambda: gym.make(ENV_ID, render_mode="rgb_array")])

    # Record 1 episode or max 1600 steps
    video_env = VecVideoRecorder(
        video_env,
        video_dir,
        record_video_trigger=lambda x: x == 0, # Record immediately
        video_length=1600,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    # --- DISPLAY IN COLAB ---
    # Finds the video file we just made and displays it
    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        print(f"Video saved to: {mp4}")

        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 1 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 0s (4,784 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 117528 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 22.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cpu)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 80.3 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 16.4 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381979 sha256=37c3bac0304651ba23863f1707c4933ca06dac3f0145f593809e3c18041e12cd
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Starting Training: basic_ppo_final (Steps: 2000000) ---
# Saving data to: /content/drive/MyDrive/aisf_project
# Using cpu device
# Logging to /content/drive/MyDrive/aisf_project/logs/basic_ppo_final/PPO_1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Streaming output truncated to the last 5000 lines.
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.43        |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.00269    |
# |    std                  | 0.493       |
# |    value_loss           | 12.8        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    fps             | 812      |
# |    iterations      | 76       |
# |    time_elapsed    | 766      |
# |    total_timesteps | 622592   |
# ---------------------------------
# Eval num_timesteps=630000, episode_reward=156.89 +/- 141.93
# Episode length: 1214.40 +/- 531.14
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.21e+03    |
# |    mean_reward          | 157         |
# | time/                   |             |
# |    total_timesteps      | 630000      |
# | train/                  |             |
# |    approx_kl            | 0.021875907 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.84       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.08        |
# |    n_updates            | 760         |
# |    policy_gradient_loss | 0.00185     |
# |    std                  | 0.494       |
# |    value_loss           | 7.56        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 105      |
# | time/              |          |
# |    fps             | 809      |
# |    iterations      | 77       |
# |    time_elapsed    | 779      |
# |    total_timesteps | 630784   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.15e+03    |
# |    ep_rew_mean          | 109         |
# | time/                   |             |
# |    fps                  | 811         |
# |    iterations           | 78          |
# |    time_elapsed         | 787         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.013650048 |
# |    clip_fraction        | 0.134       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.81       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.23        |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.00399    |
# |    std                  | 0.489       |
# |    value_loss           | 14.8        |
# -----------------------------------------
# Eval num_timesteps=640000, episode_reward=40.36 +/- 133.84
# Episode length: 699.40 +/- 552.33
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 699         |
# |    mean_reward          | 40.4        |
# | time/                   |             |
# |    total_timesteps      | 640000      |
# | train/                  |             |
# |    approx_kl            | 0.015398761 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.79       |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.859       |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.00127    |
# |    std                  | 0.488       |
# |    value_loss           | 6.33        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    fps             | 811      |
# |    iterations      | 79       |
# |    time_elapsed    | 797      |
# |    total_timesteps | 647168   |
# ---------------------------------
# Eval num_timesteps=650000, episode_reward=145.67 +/- 150.19
# Episode length: 1106.20 +/- 572.90
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.11e+03   |
# |    mean_reward          | 146        |
# | time/                   |            |
# |    total_timesteps      | 650000     |
# | train/                  |            |
# |    approx_kl            | 0.02193941 |
# |    clip_fraction        | 0.225      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.923      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 1.21       |
# |    n_updates            | 790        |
# |    policy_gradient_loss | -0.00141   |
# |    std                  | 0.481      |
# |    value_loss           | 7.57       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    fps             | 808      |
# |    iterations      | 80       |
# |    time_elapsed    | 810      |
# |    total_timesteps | 655360   |
# ---------------------------------
# Eval num_timesteps=660000, episode_reward=145.21 +/- 121.97
# Episode length: 1328.00 +/- 459.32
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.33e+03    |
# |    mean_reward          | 145         |
# | time/                   |             |
# |    total_timesteps      | 660000      |
# | train/                  |             |
# |    approx_kl            | 0.020526892 |
# |    clip_fraction        | 0.229       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.7        |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.24        |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.00047    |
# |    std                  | 0.476       |
# |    value_loss           | 7.06        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    fps             | 807      |
# |    iterations      | 81       |
# |    time_elapsed    | 821      |
# |    total_timesteps | 663552   |
# ---------------------------------
# Eval num_timesteps=670000, episode_reward=-83.17 +/- 1.84
# Episode length: 106.60 +/- 4.59
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 107        |
# |    mean_reward          | -83.2      |
# | time/                   |            |
# |    total_timesteps      | 670000     |
# | train/                  |            |
# |    approx_kl            | 0.01602714 |
# |    clip_fraction        | 0.235      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.67      |
# |    explained_variance   | 0.444      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 4.41       |
# |    n_updates            | 810        |
# |    policy_gradient_loss | -0.00015   |
# |    std                  | 0.472      |
# |    value_loss           | 2.12       |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 113      |
# | time/              |          |
# |    fps             | 808      |
# |    iterations      | 82       |
# |    time_elapsed    | 830      |
# |    total_timesteps | 671744   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.16e+03    |
# |    ep_rew_mean          | 116         |
# | time/                   |             |
# |    fps                  | 810         |
# |    iterations           | 83          |
# |    time_elapsed         | 838         |
# |    total_timesteps      | 679936      |
# | train/                  |             |
# |    approx_kl            | 0.013951387 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.62       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.289       |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.00463    |
# |    std                  | 0.466       |
# |    value_loss           | 2.87        |
# -----------------------------------------
# Eval num_timesteps=680000, episode_reward=193.31 +/- 82.99
# Episode length: 1391.40 +/- 254.55
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.39e+03    |
# |    mean_reward          | 193         |
# | time/                   |             |
# |    total_timesteps      | 680000      |
# | train/                  |             |
# |    approx_kl            | 0.012198548 |
# |    clip_fraction        | 0.136       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.6        |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.24        |
# |    n_updates            | 830         |
# |    policy_gradient_loss | -0.00193    |
# |    std                  | 0.464       |
# |    value_loss           | 7.74        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    fps             | 808      |
# |    iterations      | 84       |
# |    time_elapsed    | 851      |
# |    total_timesteps | 688128   |
# ---------------------------------
# Eval num_timesteps=690000, episode_reward=206.21 +/- 126.67
# Episode length: 1399.00 +/- 332.35
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.4e+03     |
# |    mean_reward          | 206         |
# | time/                   |             |
# |    total_timesteps      | 690000      |
# | train/                  |             |
# |    approx_kl            | 0.012659337 |
# |    clip_fraction        | 0.129       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.58       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.51        |
# |    n_updates            | 840         |
# |    policy_gradient_loss | -0.00321    |
# |    std                  | 0.464       |
# |    value_loss           | 12.9        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    fps             | 807      |
# |    iterations      | 85       |
# |    time_elapsed    | 862      |
# |    total_timesteps | 696320   |
# ---------------------------------
# Eval num_timesteps=700000, episode_reward=193.14 +/- 107.84
# Episode length: 1282.40 +/- 320.96
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.28e+03    |
# |    mean_reward          | 193         |
# | time/                   |             |
# |    total_timesteps      | 700000      |
# | train/                  |             |
# |    approx_kl            | 0.016875291 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.57       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.203       |
# |    n_updates            | 850         |
# |    policy_gradient_loss | -0.000745   |
# |    std                  | 0.461       |
# |    value_loss           | 4.08        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 111      |
# | time/              |          |
# |    fps             | 805      |
# |    iterations      | 86       |
# |    time_elapsed    | 875      |
# |    total_timesteps | 704512   |
# ---------------------------------
# Eval num_timesteps=710000, episode_reward=211.88 +/- 132.65
# Episode length: 1316.40 +/- 498.68
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.32e+03    |
# |    mean_reward          | 212         |
# | time/                   |             |
# |    total_timesteps      | 710000      |
# | train/                  |             |
# |    approx_kl            | 0.015691154 |
# |    clip_fraction        | 0.19        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.55       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.11        |
# |    n_updates            | 860         |
# |    policy_gradient_loss | -0.00327    |
# |    std                  | 0.458       |
# |    value_loss           | 8.36        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    fps             | 802      |
# |    iterations      | 87       |
# |    time_elapsed    | 887      |
# |    total_timesteps | 712704   |
# ---------------------------------
# Eval num_timesteps=720000, episode_reward=134.36 +/- 178.30
# Episode length: 977.20 +/- 709.57
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 977         |
# |    mean_reward          | 134         |
# | time/                   |             |
# |    total_timesteps      | 720000      |
# | train/                  |             |
# |    approx_kl            | 0.017091725 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.53       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.371       |
# |    n_updates            | 870         |
# |    policy_gradient_loss | -0.000284   |
# |    std                  | 0.456       |
# |    value_loss           | 3.73        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    fps             | 802      |
# |    iterations      | 88       |
# |    time_elapsed    | 898      |
# |    total_timesteps | 720896   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.17e+03    |
# |    ep_rew_mean          | 122         |
# | time/                   |             |
# |    fps                  | 803         |
# |    iterations           | 89          |
# |    time_elapsed         | 906         |
# |    total_timesteps      | 729088      |
# | train/                  |             |
# |    approx_kl            | 0.013996538 |
# |    clip_fraction        | 0.172       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.73        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.54        |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.00249    |
# |    std                  | 0.452       |
# |    value_loss           | 14.9        |
# -----------------------------------------
# Eval num_timesteps=730000, episode_reward=152.29 +/- 149.80
# Episode length: 1080.20 +/- 561.48
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.08e+03    |
# |    mean_reward          | 152         |
# | time/                   |             |
# |    total_timesteps      | 730000      |
# | train/                  |             |
# |    approx_kl            | 0.016424052 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.47       |
# |    explained_variance   | 0.94        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.73        |
# |    n_updates            | 890         |
# |    policy_gradient_loss | -0.00275    |
# |    std                  | 0.449       |
# |    value_loss           | 5.17        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 125      |
# | time/              |          |
# |    fps             | 803      |
# |    iterations      | 90       |
# |    time_elapsed    | 918      |
# |    total_timesteps | 737280   |
# ---------------------------------
# Eval num_timesteps=740000, episode_reward=125.70 +/- 133.21
# Episode length: 1045.60 +/- 503.33
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.05e+03    |
# |    mean_reward          | 126         |
# | time/                   |             |
# |    total_timesteps      | 740000      |
# | train/                  |             |
# |    approx_kl            | 0.018378697 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.744       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.35        |
# |    n_updates            | 900         |
# |    policy_gradient_loss | 0.00093     |
# |    std                  | 0.449       |
# |    value_loss           | 3.55        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 129      |
# | time/              |          |
# |    fps             | 800      |
# |    iterations      | 91       |
# |    time_elapsed    | 930      |
# |    total_timesteps | 745472   |
# ---------------------------------
# Eval num_timesteps=750000, episode_reward=193.93 +/- 121.65
# Episode length: 1203.00 +/- 380.49
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.2e+03     |
# |    mean_reward          | 194         |
# | time/                   |             |
# |    total_timesteps      | 750000      |
# | train/                  |             |
# |    approx_kl            | 0.015415244 |
# |    clip_fraction        | 0.161       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.6        |
# |    n_updates            | 910         |
# |    policy_gradient_loss | -0.00163    |
# |    std                  | 0.449       |
# |    value_loss           | 8.96        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    fps             | 800      |
# |    iterations      | 92       |
# |    time_elapsed    | 941      |
# |    total_timesteps | 753664   |
# ---------------------------------
# Eval num_timesteps=760000, episode_reward=84.79 +/- 110.17
# Episode length: 905.40 +/- 373.64
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 905         |
# |    mean_reward          | 84.8        |
# | time/                   |             |
# |    total_timesteps      | 760000      |
# | train/                  |             |
# |    approx_kl            | 0.010821444 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.44       |
# |    explained_variance   | 0.939       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.88        |
# |    n_updates            | 920         |
# |    policy_gradient_loss | -0.00396    |
# |    std                  | 0.447       |
# |    value_loss           | 16.1        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 123      |
# | time/              |          |
# |    fps             | 800      |
# |    iterations      | 93       |
# |    time_elapsed    | 951      |
# |    total_timesteps | 761856   |
# ---------------------------------
# Eval num_timesteps=770000, episode_reward=253.00 +/- 60.41
# Episode length: 1414.20 +/- 99.98
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 1.41e+03  |
# |    mean_reward          | 253       |
# | time/                   |           |
# |    total_timesteps      | 770000    |
# | train/                  |           |
# |    approx_kl            | 0.0180001 |
# |    clip_fraction        | 0.245     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -2.43     |
# |    explained_variance   | 0.949     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.39      |
# |    n_updates            | 930       |
# |    policy_gradient_loss | 0.000396  |
# |    std                  | 0.447     |
# |    value_loss           | 7.44      |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 131      |
# | time/              |          |
# |    fps             | 798      |
# |    iterations      | 94       |
# |    time_elapsed    | 964      |
# |    total_timesteps | 770048   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.21e+03   |
# |    ep_rew_mean          | 139        |
# | time/                   |            |
# |    fps                  | 799        |
# |    iterations           | 95         |
# |    time_elapsed         | 973        |
# |    total_timesteps      | 778240     |
# | train/                  |            |
# |    approx_kl            | 0.02002576 |
# |    clip_fraction        | 0.253      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.44      |
# |    explained_variance   | 0.926      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.839      |
# |    n_updates            | 940        |
# |    policy_gradient_loss | 0.00142    |
# |    std                  | 0.447      |
# |    value_loss           | 3.56       |
# ----------------------------------------
# Eval num_timesteps=780000, episode_reward=114.79 +/- 93.19
# Episode length: 1016.80 +/- 333.99
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.02e+03    |
# |    mean_reward          | 115         |
# | time/                   |             |
# |    total_timesteps      | 780000      |
# | train/                  |             |
# |    approx_kl            | 0.016494025 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.46        |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.00278    |
# |    std                  | 0.44        |
# |    value_loss           | 7.21        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    fps             | 799      |
# |    iterations      | 96       |
# |    time_elapsed    | 983      |
# |    total_timesteps | 786432   |
# ---------------------------------
# Eval num_timesteps=790000, episode_reward=153.06 +/- 123.30
# Episode length: 1136.40 +/- 366.03
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.14e+03    |
# |    mean_reward          | 153         |
# | time/                   |             |
# |    total_timesteps      | 790000      |
# | train/                  |             |
# |    approx_kl            | 0.013440096 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.99        |
# |    n_updates            | 960         |
# |    policy_gradient_loss | -0.00245    |
# |    std                  | 0.436       |
# |    value_loss           | 14          |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 140      |
# | time/              |          |
# |    fps             | 798      |
# |    iterations      | 97       |
# |    time_elapsed    | 995      |
# |    total_timesteps | 794624   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=223.14 +/- 112.96
# Episode length: 1292.20 +/- 395.43
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.29e+03    |
# |    mean_reward          | 223         |
# | time/                   |             |
# |    total_timesteps      | 800000      |
# | train/                  |             |
# |    approx_kl            | 0.018857855 |
# |    clip_fraction        | 0.264       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.34       |
# |    explained_variance   | 0.46        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.332       |
# |    n_updates            | 970         |
# |    policy_gradient_loss | 0.00179     |
# |    std                  | 0.434       |
# |    value_loss           | 8.6         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 137      |
# | time/              |          |
# |    fps             | 796      |
# |    iterations      | 98       |
# |    time_elapsed    | 1007     |
# |    total_timesteps | 802816   |
# ---------------------------------
# Eval num_timesteps=810000, episode_reward=182.43 +/- 128.22
# Episode length: 1211.60 +/- 447.34
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.21e+03    |
# |    mean_reward          | 182         |
# | time/                   |             |
# |    total_timesteps      | 810000      |
# | train/                  |             |
# |    approx_kl            | 0.017759878 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.594       |
# |    n_updates            | 980         |
# |    policy_gradient_loss | -0.000955   |
# |    std                  | 0.432       |
# |    value_loss           | 7.78        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    fps             | 795      |
# |    iterations      | 99       |
# |    time_elapsed    | 1019     |
# |    total_timesteps | 811008   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.2e+03     |
# |    ep_rew_mean          | 144         |
# | time/                   |             |
# |    fps                  | 796         |
# |    iterations           | 100         |
# |    time_elapsed         | 1028        |
# |    total_timesteps      | 819200      |
# | train/                  |             |
# |    approx_kl            | 0.012577597 |
# |    clip_fraction        | 0.171       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.31       |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.59        |
# |    n_updates            | 990         |
# |    policy_gradient_loss | -0.00234    |
# |    std                  | 0.434       |
# |    value_loss           | 10.9        |
# -----------------------------------------
# Eval num_timesteps=820000, episode_reward=117.13 +/- 144.89
# Episode length: 1030.60 +/- 567.22
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.03e+03    |
# |    mean_reward          | 117         |
# | time/                   |             |
# |    total_timesteps      | 820000      |
# | train/                  |             |
# |    approx_kl            | 0.018342547 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.537       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.419       |
# |    n_updates            | 1000        |
# |    policy_gradient_loss | -0.00184    |
# |    std                  | 0.43        |
# |    value_loss           | 0.721       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    fps             | 794      |
# |    iterations      | 101      |
# |    time_elapsed    | 1041     |
# |    total_timesteps | 827392   |
# ---------------------------------
# Eval num_timesteps=830000, episode_reward=219.15 +/- 114.44
# Episode length: 1330.60 +/- 394.63
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.33e+03    |
# |    mean_reward          | 219         |
# | time/                   |             |
# |    total_timesteps      | 830000      |
# | train/                  |             |
# |    approx_kl            | 0.012287568 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.29       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.6         |
# |    n_updates            | 1010        |
# |    policy_gradient_loss | -0.00484    |
# |    std                  | 0.43        |
# |    value_loss           | 11.3        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    fps             | 791      |
# |    iterations      | 102      |
# |    time_elapsed    | 1055     |
# |    total_timesteps | 835584   |
# ---------------------------------
# Eval num_timesteps=840000, episode_reward=233.93 +/- 82.90
# Episode length: 1433.20 +/- 216.49
# --------------------------------------
# | eval/                   |          |
# |    mean_ep_length       | 1.43e+03 |
# |    mean_reward          | 234      |
# | time/                   |          |
# |    total_timesteps      | 840000   |
# | train/                  |          |
# |    approx_kl            | 0.014888 |
# |    clip_fraction        | 0.173    |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -2.27    |
# |    explained_variance   | 0.956    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 1.71     |
# |    n_updates            | 1020     |
# |    policy_gradient_loss | -0.00245 |
# |    std                  | 0.427    |
# |    value_loss           | 7.29     |
# --------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 143      |
# | time/              |          |
# |    fps             | 789      |
# |    iterations      | 103      |
# |    time_elapsed    | 1068     |
# |    total_timesteps | 843776   |
# ---------------------------------
# Eval num_timesteps=850000, episode_reward=234.31 +/- 91.87
# Episode length: 1353.40 +/- 198.71
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.35e+03    |
# |    mean_reward          | 234         |
# | time/                   |             |
# |    total_timesteps      | 850000      |
# | train/                  |             |
# |    approx_kl            | 0.018502753 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.27       |
# |    explained_variance   | 0.874       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.33        |
# |    n_updates            | 1030        |
# |    policy_gradient_loss | -0.000236   |
# |    std                  | 0.427       |
# |    value_loss           | 6.7         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 146      |
# | time/              |          |
# |    fps             | 787      |
# |    iterations      | 104      |
# |    time_elapsed    | 1081     |
# |    total_timesteps | 851968   |
# ---------------------------------
# Eval num_timesteps=860000, episode_reward=223.84 +/- 106.82
# Episode length: 1273.20 +/- 347.17
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.27e+03    |
# |    mean_reward          | 224         |
# | time/                   |             |
# |    total_timesteps      | 860000      |
# | train/                  |             |
# |    approx_kl            | 0.015352592 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.24       |
# |    explained_variance   | 0.558       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.326       |
# |    n_updates            | 1040        |
# |    policy_gradient_loss | 0.00031     |
# |    std                  | 0.423       |
# |    value_loss           | 1.06        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 141      |
# | time/              |          |
# |    fps             | 786      |
# |    iterations      | 105      |
# |    time_elapsed    | 1094     |
# |    total_timesteps | 860160   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.18e+03    |
# |    ep_rew_mean          | 142         |
# | time/                   |             |
# |    fps                  | 787         |
# |    iterations           | 106         |
# |    time_elapsed         | 1102        |
# |    total_timesteps      | 868352      |
# | train/                  |             |
# |    approx_kl            | 0.011400232 |
# |    clip_fraction        | 0.122       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.37        |
# |    n_updates            | 1050        |
# |    policy_gradient_loss | -0.00494    |
# |    std                  | 0.423       |
# |    value_loss           | 9.99        |
# -----------------------------------------
# Eval num_timesteps=870000, episode_reward=220.37 +/- 116.80
# Episode length: 1248.60 +/- 384.52
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.25e+03    |
# |    mean_reward          | 220         |
# | time/                   |             |
# |    total_timesteps      | 870000      |
# | train/                  |             |
# |    approx_kl            | 0.021111649 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.33        |
# |    n_updates            | 1060        |
# |    policy_gradient_loss | -0.00309    |
# |    std                  | 0.419       |
# |    value_loss           | 5.01        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    fps             | 786      |
# |    iterations      | 107      |
# |    time_elapsed    | 1114     |
# |    total_timesteps | 876544   |
# ---------------------------------
# Eval num_timesteps=880000, episode_reward=248.25 +/- 53.19
# Episode length: 1451.20 +/- 86.44
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.45e+03    |
# |    mean_reward          | 248         |
# | time/                   |             |
# |    total_timesteps      | 880000      |
# | train/                  |             |
# |    approx_kl            | 0.016976759 |
# |    clip_fraction        | 0.249       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.19       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.58        |
# |    n_updates            | 1070        |
# |    policy_gradient_loss | -0.000351   |
# |    std                  | 0.419       |
# |    value_loss           | 4.45        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    fps             | 784      |
# |    iterations      | 108      |
# |    time_elapsed    | 1127     |
# |    total_timesteps | 884736   |
# ---------------------------------
# Eval num_timesteps=890000, episode_reward=277.23 +/- 3.19
# Episode length: 1463.60 +/- 41.52
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.46e+03    |
# |    mean_reward          | 277         |
# | time/                   |             |
# |    total_timesteps      | 890000      |
# | train/                  |             |
# |    approx_kl            | 0.015718695 |
# |    clip_fraction        | 0.204       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.16       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.494       |
# |    n_updates            | 1080        |
# |    policy_gradient_loss | -0.00327    |
# |    std                  | 0.416       |
# |    value_loss           | 2.9         |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    fps             | 782      |
# |    iterations      | 109      |
# |    time_elapsed    | 1140     |
# |    total_timesteps | 892928   |
# ---------------------------------
# Eval num_timesteps=900000, episode_reward=235.73 +/- 95.39
# Episode length: 1234.00 +/- 219.58
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.23e+03    |
# |    mean_reward          | 236         |
# ...
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.422       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.246       |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00268    |
# |    std                  | 0.336       |
# |    value_loss           | 3.18        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 290      |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 235      |
# |    time_elapsed    | 2510     |
# |    total_timesteps | 1925120  |
# ---------------------------------
# Eval num_timesteps=1930000, episode_reward=294.99 +/- 1.12
# Episode length: 1024.60 +/- 17.37
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.02e+03    |
# |    mean_reward          | 295         |
# | time/                   |             |
# |    total_timesteps      | 1930000     |
# | train/                  |             |
# |    approx_kl            | 0.022130303 |
# |    clip_fraction        | 0.269       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.314       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.812       |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00566    |
# |    std                  | 0.339       |
# |    value_loss           | 5.98        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 236      |
# |    time_elapsed    | 2522     |
# |    total_timesteps | 1933312  |
# ---------------------------------
# Eval num_timesteps=1940000, episode_reward=295.06 +/- 1.11
# Episode length: 1012.00 +/- 12.05
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 295         |
# | time/                   |             |
# |    total_timesteps      | 1940000     |
# | train/                  |             |
# |    approx_kl            | 0.026113886 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.585       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.348       |
# |    n_updates            | 2360        |
# |    policy_gradient_loss | -0.00717    |
# |    std                  | 0.338       |
# |    value_loss           | 5.5         |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.07e+03 |
# |    ep_rew_mean     | 286      |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 237      |
# |    time_elapsed    | 2534     |
# |    total_timesteps | 1941504  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.06e+03   |
# |    ep_rew_mean          | 282        |
# | time/                   |            |
# |    fps                  | 766        |
# |    iterations           | 238        |
# |    time_elapsed         | 2543       |
# |    total_timesteps      | 1949696    |
# | train/                  |            |
# |    approx_kl            | 0.02725675 |
# |    clip_fraction        | 0.289      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.28      |
# |    explained_variance   | 0.324      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 2.37       |
# |    n_updates            | 2370       |
# |    policy_gradient_loss | -0.00561   |
# |    std                  | 0.337      |
# |    value_loss           | 7.25       |
# ----------------------------------------
# Eval num_timesteps=1950000, episode_reward=296.07 +/- 1.27
# Episode length: 1001.20 +/- 25.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1e+03       |
# |    mean_reward          | 296         |
# | time/                   |             |
# |    total_timesteps      | 1950000     |
# | train/                  |             |
# |    approx_kl            | 0.023137579 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.3        |
# |    explained_variance   | 0.837       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.64        |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00558    |
# |    std                  | 0.341       |
# |    value_loss           | 6.78        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | 282      |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 239      |
# |    time_elapsed    | 2554     |
# |    total_timesteps | 1957888  |
# ---------------------------------
# Eval num_timesteps=1960000, episode_reward=294.33 +/- 1.09
# Episode length: 1005.20 +/- 18.28
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 294         |
# | time/                   |             |
# |    total_timesteps      | 1960000     |
# | train/                  |             |
# |    approx_kl            | 0.024840038 |
# |    clip_fraction        | 0.296       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.31       |
# |    explained_variance   | 0.302       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.85        |
# |    n_updates            | 2390        |
# |    policy_gradient_loss | -0.00255    |
# |    std                  | 0.34        |
# |    value_loss           | 5.09        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 240      |
# |    time_elapsed    | 2566     |
# |    total_timesteps | 1966080  |
# ---------------------------------
# Eval num_timesteps=1970000, episode_reward=295.31 +/- 1.56
# Episode length: 1006.40 +/- 24.12
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.01e+03    |
# |    mean_reward          | 295         |
# | time/                   |             |
# |    total_timesteps      | 1970000     |
# | train/                  |             |
# |    approx_kl            | 0.023632197 |
# |    clip_fraction        | 0.271       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.29       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.964       |
# |    n_updates            | 2400        |
# |    policy_gradient_loss | -0.00318    |
# |    std                  | 0.338       |
# |    value_loss           | 8.12        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    fps             | 765      |
# |    iterations      | 241      |
# |    time_elapsed    | 2577     |
# |    total_timesteps | 1974272  |
# ---------------------------------
# Eval num_timesteps=1980000, episode_reward=296.02 +/- 0.59
# Episode length: 995.20 +/- 18.58
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 995         |
# |    mean_reward          | 296         |
# | time/                   |             |
# |    total_timesteps      | 1980000     |
# | train/                  |             |
# |    approx_kl            | 0.025645439 |
# |    clip_fraction        | 0.278       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.845       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 10.5        |
# |    n_updates            | 2410        |
# |    policy_gradient_loss | -0.00548    |
# |    std                  | 0.336       |
# |    value_loss           | 5.06        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    fps             | 765      |
# |    iterations      | 242      |
# |    time_elapsed    | 2589     |
# |    total_timesteps | 1982464  |
# ---------------------------------
# Eval num_timesteps=1990000, episode_reward=296.68 +/- 0.49
# Episode length: 974.40 +/- 6.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 974         |
# |    mean_reward          | 297         |
# | time/                   |             |
# |    total_timesteps      | 1990000     |
# | train/                  |             |
# |    approx_kl            | 0.023093691 |
# |    clip_fraction        | 0.283       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.26       |
# |    explained_variance   | 0.415       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 4.53        |
# |    n_updates            | 2420        |
# |    policy_gradient_loss | -0.000738   |
# |    std                  | 0.336       |
# |    value_loss           | 3.95        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | 269      |
# | time/              |          |
# |    fps             | 765      |
# |    iterations      | 243      |
# |    time_elapsed    | 2601     |
# |    total_timesteps | 1990656  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | 268         |
# | time/                   |             |
# |    fps                  | 766         |
# |    iterations           | 244         |
# |    time_elapsed         | 2609        |
# |    total_timesteps      | 1998848     |
# | train/                  |             |
# |    approx_kl            | 0.024621872 |
# |    clip_fraction        | 0.238       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.4         |
# |    n_updates            | 2430        |
# |    policy_gradient_loss | -0.00355    |
# |    std                  | 0.337       |
# |    value_loss           | 9.51        |
# -----------------------------------------
# Eval num_timesteps=2000000, episode_reward=240.90 +/- 107.17
# Episode length: 897.00 +/- 226.89
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 897         |
# |    mean_reward          | 241         |
# | time/                   |             |
# |    total_timesteps      | 2000000     |
# | train/                  |             |
# |    approx_kl            | 0.024351714 |
# |    clip_fraction        | 0.291       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.27       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 1.58        |
# |    n_updates            | 2440        |
# |    policy_gradient_loss | -0.00202    |
# |    std                  | 0.337       |
# |    value_loss           | 5.51        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.01e+03 |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    fps             | 766      |
# |    iterations      | 245      |
# |    time_elapsed    | 2620     |
# |    total_timesteps | 2007040  |
# ---------------------------------
# Training finished.
# --- Recording Video for basic_ppo_final ---
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/basic_ppo_final/basic_ppo_final_agent-step-0-to-step-1600.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/basic_ppo_final/basic_ppo_final_agent-step-0-to-step-1600.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/basic_ppo_final/basic_ppo_final_agent-step-0-to-step-1600.mp4
# Video saved to: /content/drive/MyDrive/aisf_project/videos/basic_ppo_final/basic_ppo_final_agent-step-0-to-step-1600.mp4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-321771646.py in <cell line: 0>()
#     135 if __name__ == "__main__":
#     136     train()
# --> 137     record_and_show_video()
#
# /tmp/ipython-input-321771646.py in record_and_show_video()
#     125         video_data = open(mp4, "rb").read()
#     126         b64 = base64.b64encode(video_data)
# --> 127         display(HTML(f'''
#     128         <video width="600" controls autoplay loop>
#     129             <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
#
# TypeError: 'Display' object is not callable

# %%
import gymnasium as gym
import os
import numpy as np
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecMonitor, VecVideoRecorder, VecNormalize
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive # Added for Drive saving
from typing import Callable
import base64
from IPython.display import HTML, display as ipy_display # Explicit import to be safe
from pyvirtualdisplay import Display

# --- COLAB SETUP ---
# 1. Mount Drive (CRITICAL for saving logs)
drive.mount('/content/drive')

# 2. Virtual Display (Renamed to avoid conflict)
virtual_display = Display(visible=0, size=(1400, 900))
virtual_display.start()

# --- CONFIGURATION ---
EXPERIMENT_NAME = "improved_ppo_v2"
ENV_ID = "BipedalWalker-v3"
TOTAL_TIMESTEPS = 2_000_000
NUM_CPU = 4
SEED = 42

# --- DIRECTORY SETUP (DRIVE) ---
# Saves directly to your Google Drive
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- IMPROVEMENT C: REWARD SHAPING (Wrapper) ---
class EncouragingWalkerWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)

    def reward(self, reward):
        # Scale reward to offset the torque penalty slightly
        return reward * 1.1

# --- IMPROVEMENT B: LEARNING RATE SCHEDULE ---
# Linearly anneal from initial_value to 0
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env(rank, seed=0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = EncouragingWalkerWrapper(env)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} ---")
    print(f"Saving to: {base_path}")

    # 1. Parallel Environments
    env = SubprocVecEnv([make_env(i) for i in range(NUM_CPU)])
    env = VecMonitor(env, log_dir)

    # --- IMPROVEMENT A: OBSERVATION NORMALIZATION ---
    # Standard practice for continuous control
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # 2. Callbacks
    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=max(20000 // NUM_CPU, 1),
        deterministic=True,
        render=False
    )

    # 3. Model with Literature Hyperparameters (Schulman et al. 2017)
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        # Architecture: 2 hidden layers of 64 units, Tanh activation
        policy_kwargs=dict(
            net_arch=[64, 64],
            activation_fn=nn.Tanh
        ),
        # PPO Hyperparameters
        learning_rate=linear_schedule(3e-4),
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.001,
        vf_coef=0.5,
        max_grad_norm=0.5,
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vecnormalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vecnormalize.pkl")

    if not os.path.exists(model_path):
        model_path = os.path.join(model_dir, "final_model.zip")

    # Recreate Environment
    env = gym.make(ENV_ID, render_mode="rgb_array")
    env = EncouragingWalkerWrapper(env)

    from stable_baselines3.common.vec_env import DummyVecEnv
    env = DummyVecEnv([lambda: env])

    # Load Stats
    env = VecNormalize.load(stats_path, env)
    env.training = False
    env.norm_reward = False

    model = PPO.load(model_path)

    # Record
    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=1600,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    # --- DISPLAY IN COLAB ---
    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# --- Starting Training: improved_ppo_v2 ---
# Saving to: /content/drive/MyDrive/aisf_project
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Streaming output truncated to the last 5000 lines.
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.23       |
# |    explained_variance   | 0.955       |
# |    learning_rate        | 0.000237    |
# |    loss                 | -0.00222    |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.0144     |
# |    std                  | 0.543       |
# |    value_loss           | 0.002       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | 209      |
# | time/              |          |
# |    fps             | 706      |
# |    iterations      | 52       |
# |    time_elapsed    | 602      |
# |    total_timesteps | 425984   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+03    |
# |    ep_rew_mean          | 217         |
# | time/                   |             |
# |    fps                  | 709         |
# |    iterations           | 53          |
# |    time_elapsed         | 612         |
# |    total_timesteps      | 434176      |
# | train/                  |             |
# |    approx_kl            | 0.016740885 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.18       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.000236    |
# |    loss                 | 0.013       |
# |    n_updates            | 520         |
# |    policy_gradient_loss | -0.0124     |
# |    std                  | 0.536       |
# |    value_loss           | 0.00776     |
# -----------------------------------------
# Eval num_timesteps=440000, episode_reward=315.68 +/- 3.54
# Episode length: 1582.20 +/- 11.96
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.58e+03    |
# |    mean_reward          | 316         |
# | time/                   |             |
# |    total_timesteps      | 440000      |
# | train/                  |             |
# |    approx_kl            | 0.016836798 |
# |    clip_fraction        | 0.181       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.13       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.000235    |
# |    loss                 | 0.0135      |
# |    n_updates            | 530         |
# |    policy_gradient_loss | -0.0147     |
# |    std                  | 0.529       |
# |    value_loss           | 0.00208     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | 218      |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 54       |
# |    time_elapsed    | 627      |
# |    total_timesteps | 442368   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.53e+03    |
# |    ep_rew_mean          | 224         |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 55          |
# |    time_elapsed         | 637         |
# |    total_timesteps      | 450560      |
# | train/                  |             |
# |    approx_kl            | 0.014696622 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.08       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.000234    |
# |    loss                 | -0.0326     |
# |    n_updates            | 540         |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.523       |
# |    value_loss           | 0.00232     |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.53e+03    |
# |    ep_rew_mean          | 228         |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 56          |
# |    time_elapsed         | 648         |
# |    total_timesteps      | 458752      |
# | train/                  |             |
# |    approx_kl            | 0.016746482 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.02       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.000232    |
# |    loss                 | -0.0325     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.516       |
# |    value_loss           | 0.00419     |
# -----------------------------------------
# Eval num_timesteps=460000, episode_reward=273.11 +/- 86.81
# Episode length: 1463.60 +/- 195.28
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.46e+03    |
# |    mean_reward          | 273         |
# | time/                   |             |
# |    total_timesteps      | 460000      |
# | train/                  |             |
# |    approx_kl            | 0.016230632 |
# |    clip_fraction        | 0.185       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.98       |
# |    explained_variance   | 0.833       |
# |    learning_rate        | 0.000231    |
# |    loss                 | 0.0204      |
# |    n_updates            | 560         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.51        |
# |    value_loss           | 0.0153      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | 231      |
# | time/              |          |
# |    fps             | 703      |
# |    iterations      | 57       |
# |    time_elapsed    | 663      |
# |    total_timesteps | 466944   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.53e+03    |
# |    ep_rew_mean          | 235         |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 58          |
# |    time_elapsed         | 673         |
# |    total_timesteps      | 475136      |
# | train/                  |             |
# |    approx_kl            | 0.017432958 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.95       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.00023     |
# |    loss                 | -0.0109     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.0107     |
# |    std                  | 0.507       |
# |    value_loss           | 0.0533      |
# -----------------------------------------
# Eval num_timesteps=480000, episode_reward=319.20 +/- 2.63
# Episode length: 1552.80 +/- 20.78
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.55e+03    |
# |    mean_reward          | 319         |
# | time/                   |             |
# |    total_timesteps      | 480000      |
# | train/                  |             |
# |    approx_kl            | 0.016631156 |
# |    clip_fraction        | 0.192       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.9        |
# |    explained_variance   | 0.865       |
# |    learning_rate        | 0.000229    |
# |    loss                 | 0.00239     |
# |    n_updates            | 580         |
# |    policy_gradient_loss | -0.0148     |
# |    std                  | 0.5         |
# |    value_loss           | 0.00257     |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 243      |
# | time/              |          |
# |    fps             | 700      |
# |    iterations      | 59       |
# |    time_elapsed    | 689      |
# |    total_timesteps | 483328   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.53e+03   |
# |    ep_rew_mean          | 242        |
# | time/                   |            |
# |    fps                  | 701        |
# |    iterations           | 60         |
# |    time_elapsed         | 700        |
# |    total_timesteps      | 491520     |
# | train/                  |            |
# |    approx_kl            | 0.01587688 |
# |    clip_fraction        | 0.2        |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.85      |
# |    explained_variance   | 0.862      |
# |    learning_rate        | 0.000228   |
# |    loss                 | -0.00239   |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.0141    |
# |    std                  | 0.494      |
# |    value_loss           | 0.00664    |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+03    |
# |    ep_rew_mean          | 248         |
# | time/                   |             |
# |    fps                  | 701         |
# |    iterations           | 61          |
# |    time_elapsed         | 711         |
# |    total_timesteps      | 499712      |
# | train/                  |             |
# |    approx_kl            | 0.015478681 |
# |    clip_fraction        | 0.176       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.82       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 0.000226    |
# |    loss                 | -0.0329     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.0103     |
# |    std                  | 0.49        |
# |    value_loss           | 0.0113      |
# -----------------------------------------
# Eval num_timesteps=500000, episode_reward=318.75 +/- 1.28
# Episode length: 1558.20 +/- 20.53
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.56e+03   |
# |    mean_reward          | 319        |
# | time/                   |            |
# |    total_timesteps      | 500000     |
# | train/                  |            |
# |    approx_kl            | 0.01730642 |
# |    clip_fraction        | 0.192      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.75      |
# |    explained_variance   | 0.929      |
# |    learning_rate        | 0.000225   |
# |    loss                 | -0.0106    |
# |    n_updates            | 610        |
# |    policy_gradient_loss | -0.013     |
# |    std                  | 0.481      |
# |    value_loss           | 0.00221    |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.55e+03 |
# |    ep_rew_mean     | 252      |
# | time/              |          |
# |    fps             | 695      |
# |    iterations      | 62       |
# |    time_elapsed    | 730      |
# |    total_timesteps | 507904   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.55e+03   |
# |    ep_rew_mean          | 253        |
# | time/                   |            |
# |    fps                  | 696        |
# |    iterations           | 63         |
# |    time_elapsed         | 740        |
# |    total_timesteps      | 516096     |
# | train/                  |            |
# |    approx_kl            | 0.01773101 |
# |    clip_fraction        | 0.202      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.7       |
# |    explained_variance   | 0.947      |
# |    learning_rate        | 0.000224   |
# |    loss                 | -0.0113    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0146    |
# |    std                  | 0.475      |
# |    value_loss           | 0.00247    |
# ----------------------------------------
# Eval num_timesteps=520000, episode_reward=322.70 +/- 3.91
# Episode length: 1533.60 +/- 34.65
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.53e+03   |
# |    mean_reward          | 323        |
# | time/                   |            |
# |    total_timesteps      | 520000     |
# | train/                  |            |
# |    approx_kl            | 0.01584366 |
# |    clip_fraction        | 0.178      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.68      |
# |    explained_variance   | 0.955      |
# |    learning_rate        | 0.000223   |
# |    loss                 | -0.0341    |
# |    n_updates            | 630        |
# |    policy_gradient_loss | -0.0154    |
# |    std                  | 0.475      |
# |    value_loss           | 0.00206    |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.55e+03 |
# |    ep_rew_mean     | 254      |
# | time/              |          |
# |    fps             | 692      |
# |    iterations      | 64       |
# |    time_elapsed    | 756      |
# |    total_timesteps | 524288   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.55e+03    |
# |    ep_rew_mean          | 255         |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 65          |
# |    time_elapsed         | 767         |
# |    total_timesteps      | 532480      |
# | train/                  |             |
# |    approx_kl            | 0.016776867 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.67       |
# |    explained_variance   | 0.787       |
# |    learning_rate        | 0.000221    |
# |    loss                 | -0.00762    |
# |    n_updates            | 640         |
# |    policy_gradient_loss | -0.0125     |
# |    std                  | 0.471       |
# |    value_loss           | 0.0086      |
# -----------------------------------------
# Eval num_timesteps=540000, episode_reward=322.18 +/- 1.12
# Episode length: 1539.80 +/- 19.53
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.54e+03    |
# |    mean_reward          | 322         |
# | time/                   |             |
# |    total_timesteps      | 540000      |
# | train/                  |             |
# |    approx_kl            | 0.017164955 |
# |    clip_fraction        | 0.188       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.61       |
# |    explained_variance   | 0.884       |
# |    learning_rate        | 0.00022     |
# |    loss                 | -0.00455    |
# |    n_updates            | 650         |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.465       |
# |    value_loss           | 0.00566     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.55e+03 |
# |    ep_rew_mean     | 260      |
# | time/              |          |
# |    fps             | 690      |
# |    iterations      | 66       |
# |    time_elapsed    | 783      |
# |    total_timesteps | 540672   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.55e+03    |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 67          |
# |    time_elapsed         | 793         |
# |    total_timesteps      | 548864      |
# | train/                  |             |
# |    approx_kl            | 0.016097385 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.56       |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.000219    |
# |    loss                 | -0.0416     |
# |    n_updates            | 660         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.46        |
# |    value_loss           | 0.00525     |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.55e+03   |
# |    ep_rew_mean          | 263        |
# | time/                   |            |
# |    fps                  | 693        |
# |    iterations           | 68         |
# |    time_elapsed         | 803        |
# |    total_timesteps      | 557056     |
# | train/                  |            |
# |    approx_kl            | 0.01787381 |
# |    clip_fraction        | 0.207      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.53      |
# |    explained_variance   | 0.757      |
# |    learning_rate        | 0.000218   |
# |    loss                 | -0.0187    |
# |    n_updates            | 670        |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 0.456      |
# |    value_loss           | 0.0139     |
# ----------------------------------------
# Eval num_timesteps=560000, episode_reward=297.84 +/- 50.65
# Episode length: 1503.00 +/- 12.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.5e+03     |
# |    mean_reward          | 298         |
# | time/                   |             |
# |    total_timesteps      | 560000      |
# | train/                  |             |
# |    approx_kl            | 0.016706338 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.51       |
# |    explained_variance   | 0.854       |
# |    learning_rate        | 0.000216    |
# |    loss                 | -0.0101     |
# |    n_updates            | 680         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.454       |
# |    value_loss           | 0.00754     |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 264      |
# | time/              |          |
# |    fps             | 690      |
# |    iterations      | 69       |
# |    time_elapsed    | 818      |
# |    total_timesteps | 565248   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+03    |
# |    ep_rew_mean          | 265         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 70          |
# |    time_elapsed         | 828         |
# |    total_timesteps      | 573440      |
# | train/                  |             |
# |    approx_kl            | 0.017288608 |
# |    clip_fraction        | 0.2         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.5        |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.000215    |
# |    loss                 | -0.0231     |
# |    n_updates            | 690         |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.452       |
# |    value_loss           | 0.0123      |
# -----------------------------------------
# Eval num_timesteps=580000, episode_reward=322.93 +/- 1.62
# Episode length: 1528.40 +/- 21.69
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.53e+03    |
# |    mean_reward          | 323         |
# | time/                   |             |
# |    total_timesteps      | 580000      |
# | train/                  |             |
# |    approx_kl            | 0.016101811 |
# |    clip_fraction        | 0.199       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.743       |
# |    learning_rate        | 0.000214    |
# |    loss                 | 0.0119      |
# |    n_updates            | 700         |
# |    policy_gradient_loss | -0.0115     |
# |    std                  | 0.446       |
# |    value_loss           | 0.0151      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | 261      |
# | time/              |          |
# |    fps             | 689      |
# |    iterations      | 71       |
# |    time_elapsed    | 843      |
# |    total_timesteps | 581632   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+03    |
# |    ep_rew_mean          | 261         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 72          |
# |    time_elapsed         | 853         |
# |    total_timesteps      | 589824      |
# | train/                  |             |
# |    approx_kl            | 0.017735539 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.45       |
# |    explained_variance   | 0.886       |
# |    learning_rate        | 0.000213    |
# |    loss                 | -0.016      |
# |    n_updates            | 710         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.447       |
# |    value_loss           | 0.037       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.52e+03    |
# |    ep_rew_mean          | 262         |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 73          |
# |    time_elapsed         | 863         |
# |    total_timesteps      | 598016      |
# | train/                  |             |
# |    approx_kl            | 0.018182626 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.42       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.000212    |
# |    loss                 | -0.0137     |
# |    n_updates            | 720         |
# |    policy_gradient_loss | -0.0128     |
# |    std                  | 0.443       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# Eval num_timesteps=600000, episode_reward=271.50 +/- 93.21
# Episode length: 1529.60 +/- 19.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.53e+03    |
# |    mean_reward          | 272         |
# | time/                   |             |
# |    total_timesteps      | 600000      |
# | train/                  |             |
# |    approx_kl            | 0.016178949 |
# |    clip_fraction        | 0.191       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.4        |
# |    explained_variance   | 0.66        |
# |    learning_rate        | 0.00021     |
# |    loss                 | -0.0156     |
# |    n_updates            | 730         |
# |    policy_gradient_loss | -0.00961    |
# |    std                  | 0.442       |
# |    value_loss           | 0.0192      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | 268      |
# | time/              |          |
# |    fps             | 689      |
# |    iterations      | 74       |
# |    time_elapsed    | 879      |
# |    total_timesteps | 606208   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.55e+03    |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 691         |
# |    iterations           | 75          |
# |    time_elapsed         | 888         |
# |    total_timesteps      | 614400      |
# | train/                  |             |
# |    approx_kl            | 0.016793229 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.39       |
# |    explained_variance   | 0.675       |
# |    learning_rate        | 0.000209    |
# |    loss                 | -0.00525    |
# |    n_updates            | 740         |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.44        |
# |    value_loss           | 0.0201      |
# -----------------------------------------
# Eval num_timesteps=620000, episode_reward=216.07 +/- 147.02
# Episode length: 1253.40 +/- 438.86
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.25e+03    |
# |    mean_reward          | 216         |
# | time/                   |             |
# |    total_timesteps      | 620000      |
# | train/                  |             |
# |    approx_kl            | 0.017009126 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.36       |
# |    explained_variance   | 0.733       |
# |    learning_rate        | 0.000208    |
# |    loss                 | 0.00788     |
# |    n_updates            | 750         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.436       |
# |    value_loss           | 0.0139      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 270      |
# | time/              |          |
# |    fps             | 689      |
# |    iterations      | 76       |
# |    time_elapsed    | 902      |
# |    total_timesteps | 622592   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.53e+03   |
# |    ep_rew_mean          | 268        |
# | time/                   |            |
# |    fps                  | 691        |
# |    iterations           | 77         |
# |    time_elapsed         | 912        |
# |    total_timesteps      | 630784     |
# | train/                  |            |
# |    approx_kl            | 0.01726915 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.31      |
# |    explained_variance   | 0.922      |
# |    learning_rate        | 0.000207   |
# |    loss                 | 0.0144     |
# |    n_updates            | 760        |
# |    policy_gradient_loss | -0.0146    |
# |    std                  | 0.432      |
# |    value_loss           | 0.0137     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.54e+03    |
# |    ep_rew_mean          | 271         |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 78          |
# |    time_elapsed         | 921         |
# |    total_timesteps      | 638976      |
# | train/                  |             |
# |    approx_kl            | 0.016228337 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.32       |
# |    explained_variance   | 0.898       |
# |    learning_rate        | 0.000205    |
# |    loss                 | -0.0151     |
# |    n_updates            | 770         |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.433       |
# |    value_loss           | 0.031       |
# -----------------------------------------
# Eval num_timesteps=640000, episode_reward=240.79 +/- 149.94
# Episode length: 1354.00 +/- 375.77
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.35e+03    |
# |    mean_reward          | 241         |
# | time/                   |             |
# |    total_timesteps      | 640000      |
# | train/                  |             |
# |    approx_kl            | 0.016469808 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.3        |
# |    explained_variance   | 0.944       |
# |    learning_rate        | 0.000204    |
# |    loss                 | -0.0141     |
# |    n_updates            | 780         |
# |    policy_gradient_loss | -0.0136     |
# |    std                  | 0.429       |
# |    value_loss           | 0.021       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 271      |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 79       |
# |    time_elapsed    | 935      |
# |    total_timesteps | 647168   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.53e+03   |
# |    ep_rew_mean          | 272        |
# | time/                   |            |
# |    fps                  | 693        |
# |    iterations           | 80         |
# |    time_elapsed         | 945        |
# |    total_timesteps      | 655360     |
# | train/                  |            |
# |    approx_kl            | 0.01896124 |
# |    clip_fraction        | 0.203      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.27      |
# |    explained_variance   | 0.731      |
# |    learning_rate        | 0.000203   |
# |    loss                 | -0.0084    |
# |    n_updates            | 790        |
# |    policy_gradient_loss | -0.0128    |
# |    std                  | 0.427      |
# |    value_loss           | 0.0148     |
# ----------------------------------------
# Eval num_timesteps=660000, episode_reward=319.72 +/- 2.28
# Episode length: 1505.20 +/- 30.77
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.51e+03    |
# |    mean_reward          | 320         |
# | time/                   |             |
# |    total_timesteps      | 660000      |
# | train/                  |             |
# |    approx_kl            | 0.016938034 |
# |    clip_fraction        | 0.198       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.25       |
# |    explained_variance   | 0.762       |
# |    learning_rate        | 0.000202    |
# |    loss                 | -0.0161     |
# |    n_updates            | 800         |
# |    policy_gradient_loss | -0.0145     |
# |    std                  | 0.424       |
# |    value_loss           | 0.013       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | 273      |
# | time/              |          |
# |    fps             | 690      |
# |    iterations      | 81       |
# |    time_elapsed    | 960      |
# |    total_timesteps | 663552   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.53e+03    |
# |    ep_rew_mean          | 275         |
# | time/                   |             |
# |    fps                  | 692         |
# |    iterations           | 82          |
# |    time_elapsed         | 970         |
# |    total_timesteps      | 671744      |
# | train/                  |             |
# |    approx_kl            | 0.016000692 |
# |    clip_fraction        | 0.193       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.22       |
# |    explained_variance   | 0.797       |
# |    learning_rate        | 0.0002      |
# |    loss                 | -0.0202     |
# |    n_updates            | 810         |
# |    policy_gradient_loss | -0.0142     |
# |    std                  | 0.422       |
# |    value_loss           | 0.011       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.53e+03    |
# |    ep_rew_mean          | 276         |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 83          |
# |    time_elapsed         | 980         |
# |    total_timesteps      | 679936      |
# | train/                  |             |
# |    approx_kl            | 0.017097779 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.2        |
# |    explained_variance   | 0.671       |
# |    learning_rate        | 0.000199    |
# |    loss                 | -0.0275     |
# |    n_updates            | 820         |
# |    policy_gradient_loss | -0.0123     |
# |    std                  | 0.42        |
# |    value_loss           | 0.0189      |
# -----------------------------------------
# Eval num_timesteps=680000, episode_reward=292.17 +/- 55.62
# Episode length: 1486.20 +/- 42.75
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.49e+03   |
# |    mean_reward          | 292        |
# | time/                   |            |
# |    total_timesteps      | 680000     |
# | train/                  |            |
# |    approx_kl            | 0.01872598 |
# |    clip_fraction        | 0.208      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.17      |
# |    explained_variance   | 0.641      |
# |    learning_rate        | 0.000198   |
# |    loss                 | 0.000498   |
# |    n_updates            | 830        |
# |    policy_gradient_loss | -0.0107    |
# |    std                  | 0.415      |
# |    value_loss           | 0.0241     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 84       |
# |    time_elapsed    | 995      |
# |    total_timesteps | 688128   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.53e+03   |
# |    ep_rew_mean          | 276        |
# | time/                   |            |
# |    fps                  | 692        |
# |    iterations           | 85         |
# |    time_elapsed         | 1005       |
# |    total_timesteps      | 696320     |
# | train/                  |            |
# |    approx_kl            | 0.01720699 |
# |    clip_fraction        | 0.206      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.14      |
# |    explained_variance   | 0.751      |
# |    learning_rate        | 0.000197   |
# |    loss                 | -0.0151    |
# |    n_updates            | 840        |
# |    policy_gradient_loss | -0.0126    |
# |    std                  | 0.413      |
# |    value_loss           | 0.0155     |
# ----------------------------------------
# Eval num_timesteps=700000, episode_reward=222.91 +/- 129.22
# Episode length: 1267.60 +/- 384.65
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.27e+03   |
# |    mean_reward          | 223        |
# | time/                   |            |
# |    total_timesteps      | 700000     |
# | train/                  |            |
# |    approx_kl            | 0.01913363 |
# |    clip_fraction        | 0.21       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.11      |
# |    explained_variance   | 0.752      |
# |    learning_rate        | 0.000196   |
# |    loss                 | -0.0369    |
# |    n_updates            | 850        |
# |    policy_gradient_loss | -0.0134    |
# |    std                  | 0.409      |
# |    value_loss           | 0.0157     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 86       |
# |    time_elapsed    | 1018     |
# |    total_timesteps | 704512   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.53e+03   |
# |    ep_rew_mean          | 277        |
# | time/                   |            |
# |    fps                  | 693        |
# |    iterations           | 87         |
# |    time_elapsed         | 1027       |
# |    total_timesteps      | 712704     |
# | train/                  |            |
# |    approx_kl            | 0.01695982 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.11      |
# |    explained_variance   | 0.862      |
# |    learning_rate        | 0.000194   |
# |    loss                 | -0.0402    |
# |    n_updates            | 860        |
# |    policy_gradient_loss | -0.0117    |
# |    std                  | 0.411      |
# |    value_loss           | 0.027      |
# ----------------------------------------
# Eval num_timesteps=720000, episode_reward=268.75 +/- 104.07
# Episode length: 1350.40 +/- 254.85
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.35e+03   |
# |    mean_reward          | 269        |
# | time/                   |            |
# |    total_timesteps      | 720000     |
# | train/                  |            |
# |    approx_kl            | 0.01823176 |
# |    clip_fraction        | 0.201      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.12      |
# |    explained_variance   | 0.807      |
# |    learning_rate        | 0.000193   |
# |    loss                 | -0.0154    |
# |    n_updates            | 870        |
# |    policy_gradient_loss | -0.0127    |
# |    std                  | 0.412      |
# |    value_loss           | 0.0122     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | 278      |
# | time/              |          |
# |    fps             | 691      |
# |    iterations      | 88       |
# |    time_elapsed    | 1042     |
# |    total_timesteps | 720896   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.53e+03    |
# |    ep_rew_mean          | 278         |
# | time/                   |             |
# |    fps                  | 693         |
# |    iterations           | 89          |
# |    time_elapsed         | 1051        |
# |    total_timesteps      | 729088      |
# | train/                  |             |
# |    approx_kl            | 0.017973417 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.13       |
# |    explained_variance   | 0.649       |
# |    learning_rate        | 0.000192    |
# |    loss                 | -0.0025     |
# |    n_updates            | 880         |
# |    policy_gradient_loss | -0.0122     |
# |    std                  | 0.413       |
# |    value_loss           | 0.0278      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.54e+03   |
# |    ep_rew_mean          | 281        |
# | time/                   |            |
# |    fps                  | 694        |
# |    iterations           | 90         |
# |    time_elapsed         | 1061       |
# |    total_timesteps      | 737280     |
# | train/                  |            |
# |    approx_kl            | 0.01457274 |
# |    clip_fraction        | 0.167      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.11      |
# |    explained_variance   | 0.839      |
# |    learning_rate        | 0.000191   |
# |    loss                 | -0.0333    |
# |    n_updates            | 890        |
# |    policy_gradient_loss | -0.0124    |
# |    std                  | 0.41       |
# |    value_loss           | 0.0176     |
# ----------------------------------------
# Eval num_timesteps=740000, episode_reward=259.67 +/- 113.26
# Episode length: 1350.20 +/- 318.62
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.35e+03    |
# |    mean_reward          | 260         |
# | time/                   |             |
# |    total_timesteps      | 740000      |
# | train/                  |             |
# |    approx_kl            | 0.017632563 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.08       |
# |    explained_variance   | 0.719       |
# |    learning_rate        | 0.000189    |
# |    loss                 | -0.00153    |
# |    n_updates            | 900         |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.407       |
# |    value_loss           | 0.018       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | 281      |
# | time/              |          |
# |    fps             | 693      |
# |    iterations      | 91       |
# |    time_elapsed    | 1074     |
# |    total_timesteps | 745472   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.52e+03   |
# |    ep_rew_mean          | 277        |
# | time/                   |            |
# |    fps                  | 695        |
# |    iterations           | 92         |
# |    time_elapsed         | 1084       |
# |    total_timesteps      | 753664     |
# | train/                  |            |
# |    approx_kl            | 0.01703415 |
# |    clip_fraction        | 0.189      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.05      |
# |    explained_variance   | 0.636      |
# |    learning_rate        | 0.000188   |
# |    loss                 | -0.014     |
# |    n_updates            | 910        |
# |    policy_gradient_loss | -0.011     |
# |    std                  | 0.403      |
# |    value_loss           | 0.025      |
# ----------------------------------------
# Eval num_timesteps=760000, episode_reward=254.13 +/- 137.27
# Episode length: 1251.20 +/- 426.21
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.25e+03   |
# |    mean_reward          | 254        |
# | time/                   |            |
# |    total_timesteps      | 760000     |
# | train/                  |            |
# |    approx_kl            | 0.01843936 |
# |    clip_fraction        | 0.195      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.04      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.000187   |
# |    loss                 | -0.0208    |
# |    n_updates            | 920        |
# |    policy_gradient_loss | -0.0147    |
# |    std                  | 0.403      |
# |    value_loss           | 0.0262     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | 277      |
# | time/              |          |
# |    fps             | 693      |
# |    iterations      | 93       |
# |    time_elapsed    | 1098     |
# |    total_timesteps | 761856   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 695         |
# |    iterations           | 94          |
# |    time_elapsed         | 1107        |
# |    total_timesteps      | 770048      |
# | train/                  |             |
# |    approx_kl            | 0.018567529 |
# |    clip_fraction        | 0.21        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.03       |
# |    explained_variance   | 0.647       |
# |    learning_rate        | 0.000186    |
# |    loss                 | -0.0425     |
# |    n_updates            | 930         |
# |    policy_gradient_loss | -0.0119     |
# |    std                  | 0.403       |
# |    value_loss           | 0.0292      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+03    |
# |    ep_rew_mean          | 273         |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 95          |
# |    time_elapsed         | 1117        |
# |    total_timesteps      | 778240      |
# | train/                  |             |
# |    approx_kl            | 0.018354978 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.02       |
# |    explained_variance   | 0.887       |
# |    learning_rate        | 0.000184    |
# |    loss                 | -0.0297     |
# |    n_updates            | 940         |
# |    policy_gradient_loss | -0.013      |
# |    std                  | 0.4         |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# Eval num_timesteps=780000, episode_reward=254.20 +/- 92.17
# Episode length: 1393.20 +/- 98.05
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.39e+03    |
# |    mean_reward          | 254         |
# | time/                   |             |
# |    total_timesteps      | 780000      |
# | train/                  |             |
# |    approx_kl            | 0.018610545 |
# |    clip_fraction        | 0.212       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.99       |
# |    explained_variance   | 0.348       |
# |    learning_rate        | 0.000183    |
# |    loss                 | 0.0219      |
# |    n_updates            | 950         |
# |    policy_gradient_loss | -0.0138     |
# |    std                  | 0.397       |
# |    value_loss           | 0.0562      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | 276      |
# | time/              |          |
# |    fps             | 695      |
# |    iterations      | 96       |
# |    time_elapsed    | 1131     |
# |    total_timesteps | 786432   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | 280         |
# | time/                   |             |
# |    fps                  | 696         |
# |    iterations           | 97          |
# |    time_elapsed         | 1140        |
# |    total_timesteps      | 794624      |
# | train/                  |             |
# |    approx_kl            | 0.018544447 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.98       |
# |    explained_variance   | 0.408       |
# |    learning_rate        | 0.000182    |
# ...
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.814       |
# |    learning_rate        | 1.74e-05    |
# |    loss                 | 0.0967      |
# |    n_updates            | 2300        |
# |    policy_gradient_loss | -0.00758    |
# |    std                  | 0.37        |
# |    value_loss           | 0.122       |
# -----------------------------------------
# Eval num_timesteps=1900000, episode_reward=344.22 +/- 1.69
# Episode length: 871.80 +/- 3.31
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 872         |
# |    mean_reward          | 344         |
# | time/                   |             |
# |    total_timesteps      | 1900000     |
# | train/                  |             |
# |    approx_kl            | 0.007444081 |
# |    clip_fraction        | 0.0675      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 1.61e-05    |
# |    loss                 | 0.0148      |
# |    n_updates            | 2310        |
# |    policy_gradient_loss | -0.00895    |
# |    std                  | 0.37        |
# |    value_loss           | 0.121       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 896      |
# |    ep_rew_mean     | 298      |
# | time/              |          |
# |    fps             | 714      |
# |    iterations      | 232      |
# |    time_elapsed    | 2661     |
# |    total_timesteps | 1900544  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | 301          |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 233          |
# |    time_elapsed         | 2670         |
# |    total_timesteps      | 1908736      |
# | train/                  |              |
# |    approx_kl            | 0.0073311655 |
# |    clip_fraction        | 0.0691       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.441        |
# |    learning_rate        | 1.49e-05     |
# |    loss                 | 0.084        |
# |    n_updates            | 2320         |
# |    policy_gradient_loss | -0.00877     |
# |    std                  | 0.37         |
# |    value_loss           | 0.192        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 902          |
# |    ep_rew_mean          | 301          |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 234          |
# |    time_elapsed         | 2680         |
# |    total_timesteps      | 1916928      |
# | train/                  |              |
# |    approx_kl            | 0.0062030824 |
# |    clip_fraction        | 0.0439       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.68        |
# |    explained_variance   | 0.329        |
# |    learning_rate        | 1.37e-05     |
# |    loss                 | 0.0117       |
# |    n_updates            | 2330         |
# |    policy_gradient_loss | -0.00709     |
# |    std                  | 0.37         |
# |    value_loss           | 0.0717       |
# ------------------------------------------
# Eval num_timesteps=1920000, episode_reward=343.08 +/- 0.50
# Episode length: 872.60 +/- 10.69
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 873         |
# |    mean_reward          | 343         |
# | time/                   |             |
# |    total_timesteps      | 1920000     |
# | train/                  |             |
# |    approx_kl            | 0.005915826 |
# |    clip_fraction        | 0.0404      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.68       |
# |    explained_variance   | 0.244       |
# |    learning_rate        | 1.25e-05    |
# |    loss                 | 0.0347      |
# |    n_updates            | 2340        |
# |    policy_gradient_loss | -0.00544    |
# |    std                  | 0.37        |
# |    value_loss           | 0.0734      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 893      |
# |    ep_rew_mean     | 300      |
# | time/              |          |
# |    fps             | 714      |
# |    iterations      | 235      |
# |    time_elapsed    | 2693     |
# |    total_timesteps | 1925120  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 890         |
# |    ep_rew_mean          | 297         |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 236         |
# |    time_elapsed         | 2702        |
# |    total_timesteps      | 1933312     |
# | train/                  |             |
# |    approx_kl            | 0.006350154 |
# |    clip_fraction        | 0.0412      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.788       |
# |    learning_rate        | 1.12e-05    |
# |    loss                 | -0.0113     |
# |    n_updates            | 2350        |
# |    policy_gradient_loss | -0.00654    |
# |    std                  | 0.37        |
# |    value_loss           | 0.137       |
# -----------------------------------------
# Eval num_timesteps=1940000, episode_reward=342.78 +/- 0.34
# Episode length: 868.00 +/- 9.78
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 868          |
# |    mean_reward          | 343          |
# | time/                   |              |
# |    total_timesteps      | 1940000      |
# | train/                  |              |
# |    approx_kl            | 0.0046633948 |
# |    clip_fraction        | 0.0259       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0204       |
# |    n_updates            | 2360         |
# |    policy_gradient_loss | -0.00599     |
# |    std                  | 0.37         |
# |    value_loss           | 0.0984       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 877      |
# |    ep_rew_mean     | 291      |
# | time/              |          |
# |    fps             | 714      |
# |    iterations      | 237      |
# |    time_elapsed    | 2716     |
# |    total_timesteps | 1941504  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 884         |
# |    ep_rew_mean          | 295         |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 238         |
# |    time_elapsed         | 2726        |
# |    total_timesteps      | 1949696     |
# | train/                  |             |
# |    approx_kl            | 0.005378768 |
# |    clip_fraction        | 0.0374      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 8.77e-06    |
# |    loss                 | 0.124       |
# |    n_updates            | 2370        |
# |    policy_gradient_loss | -0.00598    |
# |    std                  | 0.37        |
# |    value_loss           | 0.167       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 889         |
# |    ep_rew_mean          | 296         |
# | time/                   |             |
# |    fps                  | 715         |
# |    iterations           | 239         |
# |    time_elapsed         | 2736        |
# |    total_timesteps      | 1957888     |
# | train/                  |             |
# |    approx_kl            | 0.005677293 |
# |    clip_fraction        | 0.0339      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.69       |
# |    explained_variance   | 0.283       |
# |    learning_rate        | 7.55e-06    |
# |    loss                 | 0.0625      |
# |    n_updates            | 2380        |
# |    policy_gradient_loss | -0.00589    |
# |    std                  | 0.37        |
# |    value_loss           | 0.0778      |
# -----------------------------------------
# Eval num_timesteps=1960000, episode_reward=343.97 +/- 0.86
# Episode length: 863.40 +/- 12.31
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 863          |
# |    mean_reward          | 344          |
# | time/                   |              |
# |    total_timesteps      | 1960000      |
# | train/                  |              |
# |    approx_kl            | 0.0064034364 |
# |    clip_fraction        | 0.0391       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 6.32e-06     |
# |    loss                 | 0.206        |
# |    n_updates            | 2390         |
# |    policy_gradient_loss | -0.00592     |
# |    std                  | 0.37         |
# |    value_loss           | 0.167        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 897      |
# |    ep_rew_mean     | 299      |
# | time/              |          |
# |    fps             | 715      |
# |    iterations      | 240      |
# |    time_elapsed    | 2749     |
# |    total_timesteps | 1966080  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 896          |
# |    ep_rew_mean          | 298          |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 241          |
# |    time_elapsed         | 2758         |
# |    total_timesteps      | 1974272      |
# | train/                  |              |
# |    approx_kl            | 0.0035570413 |
# |    clip_fraction        | 0.00917      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.86         |
# |    learning_rate        | 5.09e-06     |
# |    loss                 | 0.00544      |
# |    n_updates            | 2400         |
# |    policy_gradient_loss | -0.00328     |
# |    std                  | 0.37         |
# |    value_loss           | 0.107        |
# ------------------------------------------
# Eval num_timesteps=1980000, episode_reward=343.45 +/- 0.58
# Episode length: 873.80 +/- 14.66
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 874          |
# |    mean_reward          | 343          |
# | time/                   |              |
# |    total_timesteps      | 1980000      |
# | train/                  |              |
# |    approx_kl            | 0.0047478015 |
# |    clip_fraction        | 0.0165       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.894        |
# |    learning_rate        | 3.86e-06     |
# |    loss                 | 0.0426       |
# |    n_updates            | 2410         |
# |    policy_gradient_loss | -0.00411     |
# |    std                  | 0.37         |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 908      |
# |    ep_rew_mean     | 306      |
# | time/              |          |
# |    fps             | 715      |
# |    iterations      | 242      |
# |    time_elapsed    | 2771     |
# |    total_timesteps | 1982464  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 908          |
# |    ep_rew_mean          | 306          |
# | time/                   |              |
# |    fps                  | 715          |
# |    iterations           | 243          |
# |    time_elapsed         | 2780         |
# |    total_timesteps      | 1990656      |
# | train/                  |              |
# |    approx_kl            | 0.0022999581 |
# |    clip_fraction        | 0.00327      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.69        |
# |    explained_variance   | 0.289        |
# |    learning_rate        | 2.63e-06     |
# |    loss                 | -0.000287    |
# |    n_updates            | 2420         |
# |    policy_gradient_loss | -0.00237     |
# |    std                  | 0.37         |
# |    value_loss           | 0.074        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 908           |
# |    ep_rew_mean          | 306           |
# | time/                   |               |
# |    fps                  | 716           |
# |    iterations           | 244           |
# |    time_elapsed         | 2790          |
# |    total_timesteps      | 1998848       |
# | train/                  |               |
# |    approx_kl            | 0.00053676835 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.69         |
# |    explained_variance   | 0.265         |
# |    learning_rate        | 1.4e-06       |
# |    loss                 | 0.0649        |
# |    n_updates            | 2430          |
# |    policy_gradient_loss | -0.00116      |
# |    std                  | 0.37          |
# |    value_loss           | 0.0738        |
# -------------------------------------------
# Eval num_timesteps=2000000, episode_reward=344.05 +/- 1.31
# Episode length: 849.80 +/- 8.03
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 850           |
# |    mean_reward          | 344           |
# | time/                   |               |
# |    total_timesteps      | 2000000       |
# | train/                  |               |
# |    approx_kl            | 1.4699781e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.69         |
# |    explained_variance   | 0.28          |
# |    learning_rate        | 1.73e-07      |
# |    loss                 | 0.0467        |
# |    n_updates            | 2440          |
# |    policy_gradient_loss | -0.000171     |
# |    std                  | 0.37          |
# |    value_loss           | 0.0797        |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 893      |
# |    ep_rew_mean     | 300      |
# | time/              |          |
# |    fps             | 716      |
# |    iterations      | 245      |
# |    time_elapsed    | 2803     |
# |    total_timesteps | 2007040  |
# ---------------------------------
# Training finished.
# --- Recording Video for improved_ppo_v2 ---
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2/improved_ppo_v2_agent-step-0-to-step-1600.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2/improved_ppo_v2_agent-step-0-to-step-1600.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2/improved_ppo_v2_agent-step-0-to-step-1600.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
import gymnasium as gym
import os
import numpy as np
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecMonitor, VecVideoRecorder, VecNormalize
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from typing import Callable
import base64
from IPython.display import HTML, display as ipy_display
from pyvirtualdisplay import Display

# --- COLAB SETUP ---
# 1. Mount Drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 2. Virtual Display (Prevent "Display not callable" error)
try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# Note: Distinct name to separate from Normal difficulty logs
EXPERIMENT_NAME = "improved_ppo_v2_hardcore"
ENV_ID = "BipedalWalkerHardcore-v3"  # <--- HARDCORE MODE
TOTAL_TIMESTEPS = 3_000_000          # 3M Budget (Fair limit for ablation)
NUM_CPU = 4
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- REWARD SHAPING ---
class EncouragingWalkerWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)

    def reward(self, reward):
        # Slightly increase reward to encourage trying new things despite failure
        return reward * 1.1

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env(rank, seed=0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = EncouragingWalkerWrapper(env)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (HARDCORE) ---")
    print(f"Saving to: {base_path}")

    env = SubprocVecEnv([make_env(i) for i in range(NUM_CPU)])
    env = VecMonitor(env, log_dir)

    # Normalization is CRITICAL for Hardcore (lidar values vary wildly)
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=max(20000 // NUM_CPU, 1),
        deterministic=True,
        render=False
    )

    # Using PPO V2 Config (Improved Baseline)
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=dict(
            net_arch=[64, 64],
            activation_fn=nn.Tanh
        ),
        learning_rate=linear_schedule(3e-4),
        n_steps=2048,
        batch_size=64,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.001,
        vf_coef=0.5,
        max_grad_norm=0.5,
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vecnormalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vecnormalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    env = gym.make(ENV_ID, render_mode="rgb_array")
    env = EncouragingWalkerWrapper(env)

    from stable_baselines3.common.vec_env import DummyVecEnv
    env = DummyVecEnv([lambda: env])

    # Load Stats
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = PPO.load(best_model_path)

    # Record longer for Hardcore (it takes time to cross pitfalls)
    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Streaming output truncated to the last 5000 lines.
# -----------------------------------------
# Eval num_timesteps=1420000, episode_reward=-26.79 +/- 58.70
# Episode length: 1437.00 +/- 726.85
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 1.44e+03  |
# |    mean_reward          | -26.8     |
# | time/                   |           |
# |    total_timesteps      | 1420000   |
# | train/                  |           |
# |    approx_kl            | 0.0251822 |
# |    clip_fraction        | 0.243     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -1.14     |
# |    explained_variance   | 0.908     |
# |    learning_rate        | 0.000158  |
# |    loss                 | 0.0312    |
# |    n_updates            | 1730      |
# |    policy_gradient_loss | -0.0278   |
# |    std                  | 0.322     |
# |    value_loss           | 0.181     |
# ---------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 781      |
# |    ep_rew_mean     | -77.4    |
# | time/              |          |
# |    fps             | 701      |
# |    iterations      | 174      |
# |    time_elapsed    | 2031     |
# |    total_timesteps | 1425408  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 801         |
# |    ep_rew_mean          | -78         |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 175         |
# |    time_elapsed         | 2040        |
# |    total_timesteps      | 1433600     |
# | train/                  |             |
# |    approx_kl            | 0.025057182 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.11       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.000157    |
# |    loss                 | 0.0272      |
# |    n_updates            | 1740        |
# |    policy_gradient_loss | -0.0268     |
# |    std                  | 0.319       |
# |    value_loss           | 0.181       |
# -----------------------------------------
# Eval num_timesteps=1440000, episode_reward=-60.27 +/- 48.23
# Episode length: 981.20 +/- 846.50
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 981         |
# |    mean_reward          | -60.3       |
# | time/                   |             |
# |    total_timesteps      | 1440000     |
# | train/                  |             |
# |    approx_kl            | 0.023407795 |
# |    clip_fraction        | 0.226       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.000157    |
# |    loss                 | 0.00134     |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | -0.0266     |
# |    std                  | 0.318       |
# |    value_loss           | 0.11        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 777      |
# |    ep_rew_mean     | -79.1    |
# | time/              |          |
# |    fps             | 701      |
# |    iterations      | 176      |
# |    time_elapsed    | 2054     |
# |    total_timesteps | 1441792  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 802         |
# |    ep_rew_mean          | -79.5       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 177         |
# |    time_elapsed         | 2064        |
# |    total_timesteps      | 1449984     |
# | train/                  |             |
# |    approx_kl            | 0.022412598 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.09       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.000156    |
# |    loss                 | -0.0245     |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.317       |
# |    value_loss           | 0.0924      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 811         |
# |    ep_rew_mean          | -78.3       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 178         |
# |    time_elapsed         | 2074        |
# |    total_timesteps      | 1458176     |
# | train/                  |             |
# |    approx_kl            | 0.022108627 |
# |    clip_fraction        | 0.214       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.04       |
# |    explained_variance   | 0.908       |
# |    learning_rate        | 0.000155    |
# |    loss                 | -0.000461   |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.313       |
# |    value_loss           | 0.0889      |
# -----------------------------------------
# Eval num_timesteps=1460000, episode_reward=-29.54 +/- 44.93
# Episode length: 1649.60 +/- 700.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.65e+03    |
# |    mean_reward          | -29.5       |
# | time/                   |             |
# |    total_timesteps      | 1460000     |
# | train/                  |             |
# |    approx_kl            | 0.023898143 |
# |    clip_fraction        | 0.231       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1          |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.000154    |
# |    loss                 | -0.0167     |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.0265     |
# |    std                  | 0.312       |
# |    value_loss           | 0.151       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 804      |
# |    ep_rew_mean     | -76.6    |
# | time/              |          |
# |    fps             | 702      |
# |    iterations      | 179      |
# |    time_elapsed    | 2087     |
# |    total_timesteps | 1466368  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 820         |
# |    ep_rew_mean          | -73.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 180         |
# |    time_elapsed         | 2097        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.025447272 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.985      |
# |    explained_variance   | 0.87        |
# |    learning_rate        | 0.000153    |
# |    loss                 | 0.036       |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0245     |
# |    std                  | 0.309       |
# |    value_loss           | 0.173       |
# -----------------------------------------
# Eval num_timesteps=1480000, episode_reward=-61.02 +/- 38.28
# Episode length: 871.00 +/- 670.89
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 871         |
# |    mean_reward          | -61         |
# | time/                   |             |
# |    total_timesteps      | 1480000     |
# | train/                  |             |
# |    approx_kl            | 0.023064319 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.939      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.000153    |
# |    loss                 | -0.00785    |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.0244     |
# |    std                  | 0.306       |
# |    value_loss           | 0.0742      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 898      |
# |    ep_rew_mean     | -72.6    |
# | time/              |          |
# |    fps             | 701      |
# |    iterations      | 181      |
# |    time_elapsed    | 2112     |
# |    total_timesteps | 1482752  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 914         |
# |    ep_rew_mean          | -70.7       |
# | time/                   |             |
# |    fps                  | 702         |
# |    iterations           | 182         |
# |    time_elapsed         | 2121        |
# |    total_timesteps      | 1490944     |
# | train/                  |             |
# |    approx_kl            | 0.021737274 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.926      |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.000152    |
# |    loss                 | -0.00222    |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.0222     |
# |    std                  | 0.306       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 925         |
# |    ep_rew_mean          | -70.9       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 183         |
# |    time_elapsed         | 2131        |
# |    total_timesteps      | 1499136     |
# | train/                  |             |
# |    approx_kl            | 0.021542277 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.9        |
# |    explained_variance   | 0.872       |
# |    learning_rate        | 0.000151    |
# |    loss                 | 0.00219     |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.302       |
# |    value_loss           | 0.056       |
# -----------------------------------------
# Eval num_timesteps=1500000, episode_reward=-96.45 +/- 22.21
# Episode length: 273.20 +/- 42.33
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 273         |
# |    mean_reward          | -96.4       |
# | time/                   |             |
# |    total_timesteps      | 1500000     |
# | train/                  |             |
# |    approx_kl            | 0.023227712 |
# |    clip_fraction        | 0.228       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.876      |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.00015     |
# |    loss                 | -0.0163     |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.302       |
# |    value_loss           | 0.0973      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 893      |
# |    ep_rew_mean     | -74.1    |
# | time/              |          |
# |    fps             | 703      |
# |    iterations      | 184      |
# |    time_elapsed    | 2142     |
# |    total_timesteps | 1507328  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 901         |
# |    ep_rew_mean          | -74.1       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 185         |
# |    time_elapsed         | 2152        |
# |    total_timesteps      | 1515520     |
# | train/                  |             |
# |    approx_kl            | 0.022860326 |
# |    clip_fraction        | 0.239       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.871      |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.000149    |
# |    loss                 | -0.0239     |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.0235     |
# |    std                  | 0.301       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# Eval num_timesteps=1520000, episode_reward=-66.41 +/- 29.05
# Episode length: 758.20 +/- 672.25
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 758         |
# |    mean_reward          | -66.4       |
# | time/                   |             |
# |    total_timesteps      | 1520000     |
# | train/                  |             |
# |    approx_kl            | 0.022421908 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.85       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.000148    |
# |    loss                 | 0.0109      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.299       |
# |    value_loss           | 0.147       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 913      |
# |    ep_rew_mean     | -75.5    |
# | time/              |          |
# |    fps             | 703      |
# |    iterations      | 186      |
# |    time_elapsed    | 2166     |
# |    total_timesteps | 1523712  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 937         |
# |    ep_rew_mean          | -73.8       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 187         |
# |    time_elapsed         | 2175        |
# |    total_timesteps      | 1531904     |
# | train/                  |             |
# |    approx_kl            | 0.023119804 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.816      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.000148    |
# |    loss                 | -0.045      |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.0261     |
# |    std                  | 0.297       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# Eval num_timesteps=1540000, episode_reward=1.31 +/- 105.98
# Episode length: 1169.80 +/- 717.88
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.17e+03    |
# |    mean_reward          | 1.31        |
# | time/                   |             |
# |    total_timesteps      | 1540000     |
# | train/                  |             |
# |    approx_kl            | 0.021627793 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.787      |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.000147    |
# |    loss                 | -0.00246    |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.024      |
# |    std                  | 0.294       |
# |    value_loss           | 0.0867      |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 965      |
# |    ep_rew_mean     | -75.2    |
# | time/              |          |
# |    fps             | 703      |
# |    iterations      | 188      |
# |    time_elapsed    | 2190     |
# |    total_timesteps | 1540096  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 988         |
# |    ep_rew_mean          | -74.6       |
# | time/                   |             |
# |    fps                  | 703         |
# |    iterations           | 189         |
# |    time_elapsed         | 2199        |
# |    total_timesteps      | 1548288     |
# | train/                  |             |
# |    approx_kl            | 0.024355726 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.735      |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.000146    |
# |    loss                 | -0.00265    |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.29        |
# |    value_loss           | 0.0517      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 979         |
# |    ep_rew_mean          | -76         |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 190         |
# |    time_elapsed         | 2209        |
# |    total_timesteps      | 1556480     |
# | train/                  |             |
# |    approx_kl            | 0.020086672 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.713      |
# |    explained_variance   | 0.89        |
# |    learning_rate        | 0.000145    |
# |    loss                 | 0.00096     |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.025      |
# |    std                  | 0.29        |
# |    value_loss           | 0.0841      |
# -----------------------------------------
# Eval num_timesteps=1560000, episode_reward=-25.60 +/- 96.97
# Episode length: 1032.60 +/- 794.52
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.03e+03    |
# |    mean_reward          | -25.6       |
# | time/                   |             |
# |    total_timesteps      | 1560000     |
# | train/                  |             |
# |    approx_kl            | 0.021540992 |
# |    clip_fraction        | 0.207       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.691      |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.000144    |
# |    loss                 | -0.0409     |
# |    n_updates            | 1900        |
# |    policy_gradient_loss | -0.0234     |
# |    std                  | 0.288       |
# |    value_loss           | 0.0783      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -74.9    |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 191      |
# |    time_elapsed    | 2222     |
# |    total_timesteps | 1564672  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -73.9       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 192         |
# |    time_elapsed         | 2231        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.023723377 |
# |    clip_fraction        | 0.244       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.668      |
# |    explained_variance   | 0.917       |
# |    learning_rate        | 0.000144    |
# |    loss                 | -0.00249    |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.0246     |
# |    std                  | 0.287       |
# |    value_loss           | 0.16        |
# -----------------------------------------
# Eval num_timesteps=1580000, episode_reward=-37.52 +/- 30.93
# Episode length: 1107.20 +/- 763.59
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.11e+03    |
# |    mean_reward          | -37.5       |
# | time/                   |             |
# |    total_timesteps      | 1580000     |
# | train/                  |             |
# |    approx_kl            | 0.022486668 |
# |    clip_fraction        | 0.215       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.655      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.000143    |
# |    loss                 | -0.0434     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.0252     |
# |    std                  | 0.286       |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -75.1    |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 193      |
# |    time_elapsed    | 2245     |
# |    total_timesteps | 1581056  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -74.3       |
# | time/                   |             |
# |    fps                  | 704         |
# |    iterations           | 194         |
# |    time_elapsed         | 2254        |
# |    total_timesteps      | 1589248     |
# | train/                  |             |
# |    approx_kl            | 0.021228544 |
# |    clip_fraction        | 0.211       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.633      |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.000142    |
# |    loss                 | -0.00506    |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.284       |
# |    value_loss           | 0.0739      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -73.6       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 195         |
# |    time_elapsed         | 2263        |
# |    total_timesteps      | 1597440     |
# | train/                  |             |
# |    approx_kl            | 0.021147454 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.606      |
# |    explained_variance   | 0.904       |
# |    learning_rate        | 0.000141    |
# |    loss                 | -0.0243     |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.0232     |
# |    std                  | 0.282       |
# |    value_loss           | 0.027       |
# -----------------------------------------
# Eval num_timesteps=1600000, episode_reward=-63.91 +/- 32.85
# Episode length: 970.20 +/- 842.71
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 970         |
# |    mean_reward          | -63.9       |
# | time/                   |             |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.026267778 |
# |    clip_fraction        | 0.252       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.572      |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.00014     |
# |    loss                 | 0.035       |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.0249     |
# |    std                  | 0.28        |
# |    value_loss           | 0.172       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -74.1    |
# | time/              |          |
# |    fps             | 705      |
# |    iterations      | 196      |
# |    time_elapsed    | 2277     |
# |    total_timesteps | 1605632  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -71.1       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 197         |
# |    time_elapsed         | 2287        |
# |    total_timesteps      | 1613824     |
# | train/                  |             |
# |    approx_kl            | 0.024339937 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.55       |
# |    explained_variance   | 0.873       |
# |    learning_rate        | 0.000139    |
# |    loss                 | -0.0116     |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | -0.0254     |
# |    std                  | 0.278       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# Eval num_timesteps=1620000, episode_reward=-40.72 +/- 35.30
# Episode length: 1220.60 +/- 725.85
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.22e+03    |
# |    mean_reward          | -40.7       |
# | time/                   |             |
# |    total_timesteps      | 1620000     |
# | train/                  |             |
# |    approx_kl            | 0.021247689 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.514      |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.000139    |
# |    loss                 | -0.0314     |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | -0.0236     |
# |    std                  | 0.275       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.08e+03 |
# |    ep_rew_mean     | -69.5    |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 198      |
# |    time_elapsed    | 2303     |
# |    total_timesteps | 1622016  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.1e+03    |
# |    ep_rew_mean          | -67.8      |
# | time/                   |            |
# |    fps                  | 704        |
# |    iterations           | 199        |
# |    time_elapsed         | 2313       |
# |    total_timesteps      | 1630208    |
# | train/                  |            |
# |    approx_kl            | 0.02551248 |
# |    clip_fraction        | 0.231      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.48      |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.000138   |
# |    loss                 | -0.0491    |
# |    n_updates            | 1980       |
# |    policy_gradient_loss | -0.0272    |
# |    std                  | 0.273      |
# |    value_loss           | 0.172      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.07e+03    |
# |    ep_rew_mean          | -66.1       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 200         |
# |    time_elapsed         | 2322        |
# |    total_timesteps      | 1638400     |
# | train/                  |             |
# |    approx_kl            | 0.024767114 |
# |    clip_fraction        | 0.246       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.454      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.000137    |
# |    loss                 | -0.00809    |
# |    n_updates            | 1990        |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.271       |
# |    value_loss           | 0.114       |
# -----------------------------------------
# Eval num_timesteps=1640000, episode_reward=-80.07 +/- 29.63
# Episode length: 730.40 +/- 640.02
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 730        |
# |    mean_reward          | -80.1      |
# | time/                   |            |
# |    total_timesteps      | 1640000    |
# | train/                  |            |
# |    approx_kl            | 0.02358614 |
# |    clip_fraction        | 0.226      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.453     |
# |    explained_variance   | 0.921      |
# |    learning_rate        | 0.000136   |
# |    loss                 | 0.035      |
# |    n_updates            | 2000       |
# |    policy_gradient_loss | -0.0269    |
# |    std                  | 0.272      |
# |    value_loss           | 0.175      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 975      |
# |    ep_rew_mean     | -70.6    |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 201      |
# |    time_elapsed    | 2336     |
# |    total_timesteps | 1646592  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 986         |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 202         |
# |    time_elapsed         | 2345        |
# |    total_timesteps      | 1654784     |
# | train/                  |             |
# |    approx_kl            | 0.025549255 |
# |    clip_fraction        | 0.242       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.443      |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.000135    |
# |    loss                 | -0.0246     |
# |    n_updates            | 2010        |
# |    policy_gradient_loss | -0.0264     |
# |    std                  | 0.271       |
# |    value_loss           | 0.26        |
# -----------------------------------------
# Eval num_timesteps=1660000, episode_reward=-55.72 +/- 30.27
# Episode length: 988.60 +/- 840.59
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 989        |
# |    mean_reward          | -55.7      |
# | time/                   |            |
# |    total_timesteps      | 1660000    |
# | train/                  |            |
# |    approx_kl            | 0.02377196 |
# |    clip_fraction        | 0.215      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.421     |
# |    explained_variance   | 0.914      |
# |    learning_rate        | 0.000135   |
# |    loss                 | 0.011      |
# |    n_updates            | 2020       |
# |    policy_gradient_loss | -0.0234    |
# |    std                  | 0.269      |
# |    value_loss           | 0.137      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 930      |
# |    ep_rew_mean     | -68      |
# | time/              |          |
# |    fps             | 704      |
# |    iterations      | 203      |
# |    time_elapsed    | 2359     |
# |    total_timesteps | 1662976  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 955         |
# |    ep_rew_mean          | -69.5       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 204         |
# |    time_elapsed         | 2369        |
# |    total_timesteps      | 1671168     |
# | train/                  |             |
# |    approx_kl            | 0.023547065 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.402      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.000134    |
# |    loss                 | 0.107       |
# |    n_updates            | 2030        |
# |    policy_gradient_loss | -0.0262     |
# |    std                  | 0.268       |
# |    value_loss           | 0.249       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 965         |
# |    ep_rew_mean          | -68.6       |
# | time/                   |             |
# |    fps                  | 705         |
# |    iterations           | 205         |
# |    time_elapsed         | 2378        |
# |    total_timesteps      | 1679360     |
# | train/                  |             |
# |    approx_kl            | 0.023563199 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.377      |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.000133    |
# |    loss                 | -0.0301     |
# |    n_updates            | 2040        |
# |    policy_gradient_loss | -0.026      |
# |    std                  | 0.266       |
# |    value_loss           | 0.0381      |
# -----------------------------------------
# Eval num_timesteps=1680000, episode_reward=-76.90 +/- 22.87
# Episode length: 1059.60 +/- 783.54
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.06e+03    |
# |    mean_reward          | -76.9       |
# | time/                   |             |
# |    total_timesteps      | 1680000     |
# | train/                  |             |
# |    approx_kl            | 0.021726433 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.355      |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.000132    |
# |    loss                 | 0.0427      |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | -0.0239     |
# |    std                  | 0.265       |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 938      |
# |    ep_rew_mean     | -68.5    |
# | time/              |          |
# |    fps             | 705      |
# |    iterations      | 206      |
# |    time_elapsed    | 2391     |
# |    total_timesteps | 1687552  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 944         |
# |    ep_rew_mean          | -69.5       |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 207         |
# |    time_elapsed         | 2401        |
# |    total_timesteps      | 1695744     |
# | train/                  |             |
# |    approx_kl            | 0.022461621 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.362      |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.000131    |
# |    loss                 | 0.0256      |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | -0.0216     |
# |    std                  | 0.267       |
# |    value_loss           | 0.127       |
# -----------------------------------------
# Eval num_timesteps=1700000, episode_reward=-45.16 +/- 68.29
# Episode length: 1051.40 +/- 784.60
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.05e+03    |
# |    mean_reward          | -45.2       |
# | time/                   |             |
# |    total_timesteps      | 1700000     |
# | train/                  |             |
# |    approx_kl            | 0.022513725 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.363      |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.00013     |
# |    loss                 | 0.00258     |
# |    n_updates            | 2070        |
# |    policy_gradient_loss | -0.0231     |
# |    std                  | 0.266       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | -69.1    |
# | time/              |          |
# |    fps             | 705      |
# |    iterations      | 208      |
# |    time_elapsed    | 2414     |
# |    total_timesteps | 1703936  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 963         |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 706         |
# |    iterations           | 209         |
# |    time_elapsed         | 2423        |
# |    total_timesteps      | 1712128     |
# | train/                  |             |
# |    approx_kl            | 0.023484783 |
# |    clip_fraction        | 0.241       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.335      |
# |    explained_variance   | 0.899       |
# |    learning_rate        | 0.00013     |
# |    loss                 | 0.0239      |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | -0.0247     |
# |    std                  | 0.264       |
# |    value_loss           | 0.165       |
# -----------------------------------------
# Eval num_timesteps=1720000, episode_reward=-96.21 +/- 13.82
# Episode length: 581.60 +/- 710.36
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 582        |
# |    mean_reward          | -96.2      |
# | time/                   |            |
# |    total_timesteps      | 1720000    |
# | train/                  |            |
# |    approx_kl            | 0.02396039 |
# |    clip_fraction        | 0.238      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.311     |
# |    explained_variance   | 0.933      |
# |    learning_rate        | 0.000129   |
# |    loss                 | 0.0285     |
# |    n_updates            | 2090       |
# |    policy_gradient_loss | -0.026     |
# |    std                  | 0.262      |
# |    value_loss           | 0.127      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 970      |
# |    ep_rew_mean     | -68.1    |
# | time/              |          |
# |    fps             | 706      |
# |    iterations      | 210      |
# |    time_elapsed    | 2436     |
# |    total_timesteps | 1720320  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 968        |
# |    ep_rew_mean          | -69.3      |
# | time/                   |            |
# |    fps                  | 706        |
# |    iterations           | 211        |
# |    time_elapsed         | 2445       |
# |    total_timesteps      | 1728512    |
# | train/                  |            |
# |    approx_kl            | 0.02535259 |
# |    clip_fraction        | 0.236      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.301     |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.000128   |
# |    loss                 | 0.0137     |
# |    n_updates            | 2100       |
# |    policy_gradient_loss | -0.0237    |
# |    std                  | 0.263      |
# |    value_loss           | 0.166      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -69.4       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 212         |
# |    time_elapsed         | 2455        |
# |    total_timesteps      | 1736704     |
# | train/                  |             |
# |    approx_kl            | 0.022041917 |
# |    clip_fraction        | 0.221       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.289      |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.000127    |
# |    loss                 | -0.0401     |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | -0.0253     |
# |    std                  | 0.261       |
# |    value_loss           | 0.0314      |
# -----------------------------------------
# Eval num_timesteps=1740000, episode_reward=-56.77 +/- 22.94
# Episode length: 1659.40 +/- 681.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.66e+03    |
# |    mean_reward          | -56.8       |
# | time/                   |             |
# |    total_timesteps      | 1740000     |
# | train/                  |             |
# |    approx_kl            | 0.022400081 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.277      |
# |    explained_variance   | 0.932       |
# |    learning_rate        | 0.000126    |
# |    loss                 | -0.016      |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | -0.0227     |
# |    std                  | 0.261       |
# |    value_loss           | 0.0598      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -71.2    |
# | time/              |          |
# |    fps             | 706      |
# |    iterations      | 213      |
# |    time_elapsed    | 2469     |
# |    total_timesteps | 1744896  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.06e+03    |
# |    ep_rew_mean          | -66.5       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 214         |
# |    time_elapsed         | 2478        |
# |    total_timesteps      | 1753088     |
# | train/                  |             |
# |    approx_kl            | 0.025507793 |
# |    clip_fraction        | 0.25        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.262      |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.000126    |
# |    loss                 | 0.0185      |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | -0.0275     |
# |    std                  | 0.26        |
# |    value_loss           | 0.119       |
# -----------------------------------------
# Eval num_timesteps=1760000, episode_reward=-26.72 +/- 39.05
# Episode length: 1298.80 +/- 858.81
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.3e+03     |
# |    mean_reward          | -26.7       |
# | time/                   |             |
# |    total_timesteps      | 1760000     |
# | train/                  |             |
# |    approx_kl            | 0.022041053 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.246      |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.000125    |
# |    loss                 | 0.0786      |
# |    n_updates            | 2140        |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.259       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -69.7    |
# | time/              |          |
# |    fps             | 706      |
# |    iterations      | 215      |
# |    time_elapsed    | 2491     |
# |    total_timesteps | 1761280  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -70.5       |
# | time/                   |             |
# |    fps                  | 707         |
# |    iterations           | 216         |
# |    time_elapsed         | 2500        |
# |    total_timesteps      | 1769472     |
# | train/                  |             |
# |    approx_kl            | 0.022927798 |
# |    clip_fraction        | 0.213       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.239      |
# |    explained_variance   | 0.858       |
# |    learning_rate        | 0.000124    |
# |    loss                 | 0.0187      |
# |    n_updates            | 2150        |
# |    policy_gradient_loss | -0.0237     |
# |    std                  | 0.258       |
# |    value_loss           | 0.145       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -68.8       |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 217         |
# |    time_elapsed         | 2510        |
# |    total_timesteps      | 1777664     |
# | train/                  |             |
# |    approx_kl            | 0.023358501 |
# |    clip_fraction        | 0.22        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.225      |
# |    explained_variance   | 0.926       |
# |    learning_rate        | 0.000123    |
# |    loss                 | 0.0253      |
# |    n_updates            | 2160        |
# |    policy_gradient_loss | -0.0257     |
# |    std                  | 0.257       |
# |    value_loss           | 0.182       |
# -----------------------------------------
# Eval num_timesteps=1780000, episode_reward=-61.92 +/- 39.01
# Episode length: 887.20 +/- 587.07
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 887         |
# |    mean_reward          | -61.9       |
# | time/                   |             |
# |    total_timesteps      | 1780000     |
# | train/                  |             |
# |    approx_kl            | 0.022837806 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.218      |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.000122    |
# |    loss                 | 0.0411      |
# |    n_updates            | 2170        |
# |    policy_gradient_loss | -0.0243     |
# |    std                  | 0.257       |
# |    value_loss           | 0.12        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -68.7    |
# | time/              |          |
# |    fps             | 707      |
# |    iterations      | 218      |
# |    time_elapsed    | 2523     |
# |    total_timesteps | 1785856  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 708         |
# |    iterations           | 219         |
# |    time_elapsed         | 2533        |
# |    total_timesteps      | 1794048     |
# | train/                  |             |
# |    approx_kl            | 0.024837047 |
# |    clip_fraction        | 0.236       |
# |    clip_range           | 0.2         |
# ...
# |    n_updates            | 3520         |
# |    policy_gradient_loss | -0.0142      |
# |    std                  | 0.193        |
# |    value_loss           | 0.285        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 870         |
# |    ep_rew_mean          | -60.3       |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 354         |
# |    time_elapsed         | 4062        |
# |    total_timesteps      | 2899968     |
# | train/                  |             |
# |    approx_kl            | 0.005920033 |
# |    clip_fraction        | 0.0447      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.947       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 1.08e-05    |
# |    loss                 | 0.0223      |
# |    n_updates            | 3530        |
# |    policy_gradient_loss | -0.0127     |
# |    std                  | 0.193       |
# |    value_loss           | 0.157       |
# -----------------------------------------
# Eval num_timesteps=2900000, episode_reward=-46.80 +/- 41.91
# Episode length: 1331.20 +/- 820.91
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.33e+03    |
# |    mean_reward          | -46.8       |
# | time/                   |             |
# |    total_timesteps      | 2900000     |
# | train/                  |             |
# |    approx_kl            | 0.005784002 |
# |    clip_fraction        | 0.0431      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.948       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 1e-05       |
# |    loss                 | -0.00205    |
# |    n_updates            | 3540        |
# |    policy_gradient_loss | -0.0139     |
# |    std                  | 0.193       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 805      |
# |    ep_rew_mean     | -63.1    |
# | time/              |          |
# |    fps             | 713      |
# |    iterations      | 355      |
# |    time_elapsed    | 4076     |
# |    total_timesteps | 2908160  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 875          |
# |    ep_rew_mean          | -59.8        |
# | time/                   |              |
# |    fps                  | 713          |
# |    iterations           | 356          |
# |    time_elapsed         | 4085         |
# |    total_timesteps      | 2916352      |
# | train/                  |              |
# |    approx_kl            | 0.0066033667 |
# |    clip_fraction        | 0.0558       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.948        |
# |    explained_variance   | 0.933        |
# |    learning_rate        | 9.18e-06     |
# |    loss                 | 0.16         |
# |    n_updates            | 3550         |
# |    policy_gradient_loss | -0.0137      |
# |    std                  | 0.193        |
# |    value_loss           | 0.391        |
# ------------------------------------------
# Eval num_timesteps=2920000, episode_reward=-43.20 +/- 56.75
# Episode length: 888.40 +/- 689.90
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 888          |
# |    mean_reward          | -43.2        |
# | time/                   |              |
# |    total_timesteps      | 2920000      |
# | train/                  |              |
# |    approx_kl            | 0.0057445355 |
# |    clip_fraction        | 0.0417       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.949        |
# |    explained_variance   | 0.913        |
# |    learning_rate        | 8.36e-06     |
# |    loss                 | 0.0667       |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -0.0121      |
# |    std                  | 0.193        |
# |    value_loss           | 0.0952       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 874      |
# |    ep_rew_mean     | -59.5    |
# | time/              |          |
# |    fps             | 713      |
# |    iterations      | 357      |
# |    time_elapsed    | 4099     |
# |    total_timesteps | 2924544  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 911         |
# |    ep_rew_mean          | -56.5       |
# | time/                   |             |
# |    fps                  | 713         |
# |    iterations           | 358         |
# |    time_elapsed         | 4108        |
# |    total_timesteps      | 2932736     |
# | train/                  |             |
# |    approx_kl            | 0.005305102 |
# |    clip_fraction        | 0.0335      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.951       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 7.55e-06    |
# |    loss                 | 0.141       |
# |    n_updates            | 3570        |
# |    policy_gradient_loss | -0.0109     |
# |    std                  | 0.193       |
# |    value_loss           | 0.176       |
# -----------------------------------------
# Eval num_timesteps=2940000, episode_reward=-55.31 +/- 57.16
# Episode length: 1022.00 +/- 821.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.02e+03    |
# |    mean_reward          | -55.3       |
# | time/                   |             |
# |    total_timesteps      | 2940000     |
# | train/                  |             |
# |    approx_kl            | 0.006168504 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.952       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 6.73e-06    |
# |    loss                 | 0.112       |
# |    n_updates            | 3580        |
# |    policy_gradient_loss | -0.0121     |
# |    std                  | 0.193       |
# |    value_loss           | 0.275       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 939      |
# |    ep_rew_mean     | -53.9    |
# | time/              |          |
# |    fps             | 713      |
# |    iterations      | 359      |
# |    time_elapsed    | 4122     |
# |    total_timesteps | 2940928  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 988          |
# |    ep_rew_mean          | -52.4        |
# | time/                   |              |
# |    fps                  | 713          |
# |    iterations           | 360          |
# |    time_elapsed         | 4131         |
# |    total_timesteps      | 2949120      |
# | train/                  |              |
# |    approx_kl            | 0.0048057055 |
# |    clip_fraction        | 0.0249       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.953        |
# |    explained_variance   | 0.807        |
# |    learning_rate        | 5.91e-06     |
# |    loss                 | 0.104        |
# |    n_updates            | 3590         |
# |    policy_gradient_loss | -0.008       |
# |    std                  | 0.193        |
# |    value_loss           | 0.209        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 899          |
# |    ep_rew_mean          | -55.4        |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 361          |
# |    time_elapsed         | 4140         |
# |    total_timesteps      | 2957312      |
# | train/                  |              |
# |    approx_kl            | 0.0049423673 |
# |    clip_fraction        | 0.0334       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.954        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 5.09e-06     |
# |    loss                 | 0.121        |
# |    n_updates            | 3600         |
# |    policy_gradient_loss | -0.00837     |
# |    std                  | 0.193        |
# |    value_loss           | 0.232        |
# ------------------------------------------
# Eval num_timesteps=2960000, episode_reward=-92.66 +/- 30.39
# Episode length: 915.40 +/- 885.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 915         |
# |    mean_reward          | -92.7       |
# | time/                   |             |
# |    total_timesteps      | 2960000     |
# | train/                  |             |
# |    approx_kl            | 0.003728859 |
# |    clip_fraction        | 0.0158      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.954       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 4.27e-06    |
# |    loss                 | 0.16        |
# |    n_updates            | 3610        |
# |    policy_gradient_loss | -0.00729    |
# |    std                  | 0.193       |
# |    value_loss           | 0.386       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 862      |
# |    ep_rew_mean     | -59.1    |
# | time/              |          |
# |    fps             | 713      |
# |    iterations      | 362      |
# |    time_elapsed    | 4153     |
# |    total_timesteps | 2965504  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 904         |
# |    ep_rew_mean          | -55.9       |
# | time/                   |             |
# |    fps                  | 714         |
# |    iterations           | 363         |
# |    time_elapsed         | 4162        |
# |    total_timesteps      | 2973696     |
# | train/                  |             |
# |    approx_kl            | 0.004878753 |
# |    clip_fraction        | 0.0223      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | 0.954       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 3.45e-06    |
# |    loss                 | 0.402       |
# |    n_updates            | 3620        |
# |    policy_gradient_loss | -0.00766    |
# |    std                  | 0.193       |
# |    value_loss           | 0.251       |
# -----------------------------------------
# Eval num_timesteps=2980000, episode_reward=-39.48 +/- 15.38
# Episode length: 795.40 +/- 622.97
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 795          |
# |    mean_reward          | -39.5        |
# | time/                   |              |
# |    total_timesteps      | 2980000      |
# | train/                  |              |
# |    approx_kl            | 0.0027353135 |
# |    clip_fraction        | 0.00497      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.954        |
# |    explained_variance   | 0.94         |
# |    learning_rate        | 2.63e-06     |
# |    loss                 | 0.0463       |
# |    n_updates            | 3630         |
# |    policy_gradient_loss | -0.00414     |
# |    std                  | 0.193        |
# |    value_loss           | 0.123        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 938      |
# |    ep_rew_mean     | -53.7    |
# | time/              |          |
# |    fps             | 714      |
# |    iterations      | 364      |
# |    time_elapsed    | 4176     |
# |    total_timesteps | 2981888  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 971          |
# |    ep_rew_mean          | -53.6        |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 365          |
# |    time_elapsed         | 4185         |
# |    total_timesteps      | 2990080      |
# | train/                  |              |
# |    approx_kl            | 0.0023464034 |
# |    clip_fraction        | 0.00276      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.955        |
# |    explained_variance   | 0.902        |
# |    learning_rate        | 1.81e-06     |
# |    loss                 | 0.018        |
# |    n_updates            | 3640         |
# |    policy_gradient_loss | -0.00365     |
# |    std                  | 0.193        |
# |    value_loss           | 0.156        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 939          |
# |    ep_rew_mean          | -58          |
# | time/                   |              |
# |    fps                  | 714          |
# |    iterations           | 366          |
# |    time_elapsed         | 4194         |
# |    total_timesteps      | 2998272      |
# | train/                  |              |
# |    approx_kl            | 0.0018774415 |
# |    clip_fraction        | 0.00143      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | 0.955        |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 9.92e-07     |
# |    loss                 | 0.072        |
# |    n_updates            | 3650         |
# |    policy_gradient_loss | -0.00246     |
# |    std                  | 0.193        |
# |    value_loss           | 0.176        |
# ------------------------------------------
# Eval num_timesteps=3000000, episode_reward=-22.09 +/- 15.23
# Episode length: 1827.20 +/- 345.60
# -------------------------------------------
# | eval/                   |               |
# |    mean_ep_length       | 1.83e+03      |
# |    mean_reward          | -22.1         |
# | time/                   |               |
# |    total_timesteps      | 3000000       |
# | train/                  |               |
# |    approx_kl            | 2.8298542e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | 0.955         |
# |    explained_variance   | 0.93          |
# |    learning_rate        | 1.73e-07      |
# |    loss                 | 0.437         |
# |    n_updates            | 3660          |
# |    policy_gradient_loss | -0.000436     |
# |    std                  | 0.193         |
# |    value_loss           | 0.422         |
# -------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 947      |
# |    ep_rew_mean     | -56.8    |
# | time/              |          |
# |    fps             | 713      |
# |    iterations      | 367      |
# |    time_elapsed    | 4211     |
# |    total_timesteps | 3006464  |
# ---------------------------------
# Training finished.
# --- Recording Video for improved_ppo_v2_hardcore ---
# Saving video to /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2_hardcore/improved_ppo_v2_hardcore_agent-step-0-to-step-2000.mp4
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2_hardcore/improved_ppo_v2_hardcore_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2_hardcore/improved_ppo_v2_hardcore_agent-step-0-to-step-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/improved_ppo_v2_hardcore/improved_ppo_v2_hardcore_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
import gymnasium as gym
import os
import base64
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecMonitor, VecVideoRecorder, VecNormalize
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
# 1. Mount Drive
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# 2. Virtual Display (Renamed to avoid conflict)
try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
EXPERIMENT_NAME = "sota_ppo_v3_hardcore"
ENV_ID = "BipedalWalkerHardcore-v3"  # <--- CRITICAL UPDATE FOR HARDCORE
TOTAL_TIMESTEPS = 3_000_000          # 3M Budget (Matches your V2 run)
NUM_CPU = 4
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- REWARD SHAPING ---
class EncouragingWalkerWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)
    def reward(self, reward):
        return reward * 1.1

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env(rank, seed=0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = EncouragingWalkerWrapper(env)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (SOTA HARDCORE) ---")
    print(f"Saving to: {base_path}")

    env = SubprocVecEnv([make_env(i) for i in range(NUM_CPU)])
    env = VecMonitor(env, log_dir)

    # Normalization (CRITICAL for Hardcore)
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=max(20000 // NUM_CPU, 1),
        deterministic=True,
        render=False
    )

    # 4. SOTA PPO Model
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,

        # --- SOTA IMPROVEMENTS ---
        use_sde=True,           # 1. gSDE Exploration (Key for Hardcore)
        policy_kwargs=dict(
            # 2. Separate Networks & Increased Size [256, 256]
            net_arch=dict(pi=[256, 256], vf=[256, 256]),
            activation_fn=nn.Tanh,
            # 3. Adam Optimizer Tweak
            optimizer_kwargs=dict(eps=1e-5)
        ),

        # Hyperparameters (Tuned for Power)
        learning_rate=linear_schedule(3e-4),
        n_steps=2048,
        batch_size=1024,        # 4. Larger Batch Size
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.001,
        vf_coef=0.5,
        max_grad_norm=0.5,
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vecnormalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vecnormalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    env = gym.make(ENV_ID, render_mode="rgb_array")
    env = EncouragingWalkerWrapper(env)

    from stable_baselines3.common.vec_env import DummyVecEnv
    env = DummyVecEnv([lambda: env])

    # Load Stats
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = PPO.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# --- Starting Training: sota_ppo_v3_hardcore (SOTA HARDCORE) ---
# Saving to: /content/drive/MyDrive/aisf_project
# Using cpu device
# Logging to /content/drive/MyDrive/aisf_project/logs/sota_ppo_v3_hardcore/PPO_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 67.5     |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    fps             | 1625     |
# |    iterations      | 1        |
# |    time_elapsed    | 5        |
# |    total_timesteps | 8192     |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 83.6       |
# |    ep_rew_mean          | -127       |
# | time/                   |            |
# |    fps                  | 1428       |
# |    iterations           | 2          |
# |    time_elapsed         | 11         |
# |    total_timesteps      | 16384      |
# | train/                  |            |
# |    approx_kl            | 0.06825566 |
# |    clip_fraction        | 0.282      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.4      |
# |    explained_variance   | -0.207     |
# |    learning_rate        | 0.000299   |
# |    loss                 | 0.506      |
# |    n_updates            | 10         |
# |    policy_gradient_loss | -0.0227    |
# |    std                  | 0.983      |
# |    value_loss           | 3.44       |
# ----------------------------------------
# Eval num_timesteps=20000, episode_reward=-194.00 +/- 65.63
# Episode length: 854.00 +/- 881.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 854         |
# |    mean_reward          | -194        |
# | time/                   |             |
# |    total_timesteps      | 20000       |
# | train/                  |             |
# |    approx_kl            | 0.069741994 |
# |    clip_fraction        | 0.427       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.6       |
# |    explained_variance   | 0.752       |
# |    learning_rate        | 0.000298    |
# |    loss                 | 0.278       |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0456     |
# |    std                  | 0.967       |
# |    value_loss           | 1.38        |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 103      |
# |    ep_rew_mean     | -130     |
# | time/              |          |
# |    fps             | 1134     |
# |    iterations      | 3        |
# |    time_elapsed    | 21       |
# |    total_timesteps | 24576    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 105        |
# |    ep_rew_mean          | -132       |
# | time/                   |            |
# |    fps                  | 1188       |
# |    iterations           | 4          |
# |    time_elapsed         | 27         |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.12411903 |
# |    clip_fraction        | 0.526      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.2      |
# |    explained_variance   | 0.689      |
# |    learning_rate        | 0.000298   |
# |    loss                 | 0.294      |
# |    n_updates            | 30         |
# |    policy_gradient_loss | 0.0135     |
# |    std                  | 0.949      |
# |    value_loss           | 0.909      |
# ----------------------------------------
# Eval num_timesteps=40000, episode_reward=-188.11 +/- 53.43
# Episode length: 942.80 +/- 864.97
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 943        |
# |    mean_reward          | -188       |
# | time/                   |            |
# |    total_timesteps      | 40000      |
# | train/                  |            |
# |    approx_kl            | 0.09805006 |
# |    clip_fraction        | 0.521      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.2      |
# |    explained_variance   | 0.698      |
# |    learning_rate        | 0.000297   |
# |    loss                 | 0.0834     |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0715    |
# |    std                  | 0.945      |
# |    value_loss           | 0.819      |
# ----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.6     |
# |    ep_rew_mean     | -128     |
# | time/              |          |
# |    fps             | 1075     |
# |    iterations      | 5        |
# |    time_elapsed    | 38       |
# |    total_timesteps | 40960    |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 120        |
# |    ep_rew_mean          | -131       |
# | time/                   |            |
# |    fps                  | 1126       |
# |    iterations           | 6          |
# |    time_elapsed         | 43         |
# |    total_timesteps      | 49152      |
# | train/                  |            |
# |    approx_kl            | 0.12495382 |
# |    clip_fraction        | 0.634      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.6      |
# |    explained_variance   | 0.786      |
# |    learning_rate        | 0.000296   |
# |    loss                 | 0.0677     |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.104     |
# |    std                  | 0.941      |
# |    value_loss           | 0.555      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 99         |
# |    ep_rew_mean          | -130       |
# | time/                   |            |
# |    fps                  | 1143       |
# |    iterations           | 7          |
# |    time_elapsed         | 50         |
# |    total_timesteps      | 57344      |
# | train/                  |            |
# |    approx_kl            | 0.09090274 |
# |    clip_fraction        | 0.535      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15.1      |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.000295   |
# |    loss                 | -0.0369    |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0742    |
# |    std                  | 0.916      |
# |    value_loss           | 0.274      |
# ----------------------------------------
# Eval num_timesteps=60000, episode_reward=-122.87 +/- 0.98
# Episode length: 48.00 +/- 17.18
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 48          |
# |    mean_reward          | -123        |
# | time/                   |             |
# |    total_timesteps      | 60000       |
# | train/                  |             |
# |    approx_kl            | 0.057559125 |
# |    clip_fraction        | 0.422       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.9       |
# |    explained_variance   | 0.717       |
# |    learning_rate        | 0.000294    |
# |    loss                 | 0.0236      |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0723     |
# |    std                  | 0.901       |
# |    value_loss           | 0.466       |
# -----------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 87.7     |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    fps             | 1167     |
# |    iterations      | 8        |
# |    time_elapsed    | 56       |
# |    total_timesteps | 65536    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 143         |
# |    ep_rew_mean          | -139        |
# | time/                   |             |
# |    fps                  | 1183        |
# |    iterations           | 9           |
# |    time_elapsed         | 62          |
# |    total_timesteps      | 73728       |
# | train/                  |             |
# |    approx_kl            | 0.036823694 |
# |    clip_fraction        | 0.473       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15         |
# |    explained_variance   | 0.79        |
# |    learning_rate        | 0.000293    |
# |    loss                 | 0.000934    |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0823     |
# |    std                  | 0.895       |
# |    value_loss           | 0.38        |
# -----------------------------------------
# Eval num_timesteps=80000, episode_reward=-172.41 +/- 54.21
# Episode length: 884.60 +/- 912.12
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 885        |
# |    mean_reward          | -172       |
# | time/                   |            |
# |    total_timesteps      | 80000      |
# | train/                  |            |
# |    approx_kl            | 0.06364535 |
# |    clip_fraction        | 0.507      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.648      |
# |    learning_rate        | 0.000293   |
# |    loss                 | 0.0555     |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0813    |
# |    std                  | 0.894      |
# |    value_loss           | 0.497      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 136      |
# |    ep_rew_mean     | -131     |
# | time/              |          |
# |    fps             | 1133     |
# |    iterations      | 10       |
# |    time_elapsed    | 72       |
# |    total_timesteps | 81920    |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 147         |
# |    ep_rew_mean          | -133        |
# | time/                   |             |
# |    fps                  | 1152        |
# |    iterations           | 11          |
# |    time_elapsed         | 78          |
# |    total_timesteps      | 90112       |
# | train/                  |             |
# |    approx_kl            | 0.033053465 |
# |    clip_fraction        | 0.359       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.1       |
# |    explained_variance   | 0.8         |
# |    learning_rate        | 0.000292    |
# |    loss                 | -0.00165    |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0694     |
# |    std                  | 0.873       |
# |    value_loss           | 0.348       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 145         |
# |    ep_rew_mean          | -135        |
# | time/                   |             |
# |    fps                  | 1171        |
# |    iterations           | 12          |
# |    time_elapsed         | 83          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.054194298 |
# |    clip_fraction        | 0.646       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.8       |
# |    explained_variance   | 0.748       |
# |    learning_rate        | 0.000291    |
# |    loss                 | -0.0457     |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0959     |
# |    std                  | 0.869       |
# |    value_loss           | 0.265       |
# -----------------------------------------
# Eval num_timesteps=100000, episode_reward=-230.86 +/- 44.59
# Episode length: 1625.40 +/- 749.20
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.63e+03    |
# |    mean_reward          | -231        |
# | time/                   |             |
# |    total_timesteps      | 100000      |
# | train/                  |             |
# |    approx_kl            | 0.083333984 |
# |    clip_fraction        | 0.548       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15         |
# |    explained_variance   | 0.834       |
# |    learning_rate        | 0.00029     |
# |    loss                 | -0.0577     |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.098      |
# |    std                  | 0.861       |
# |    value_loss           | 0.253       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 140      |
# |    ep_rew_mean     | -137     |
# | time/              |          |
# |    fps             | 1136     |
# |    iterations      | 13       |
# |    time_elapsed    | 93       |
# |    total_timesteps | 106496   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 190         |
# |    ep_rew_mean          | -141        |
# | time/                   |             |
# |    fps                  | 1153        |
# |    iterations           | 14          |
# |    time_elapsed         | 99          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.035205733 |
# |    clip_fraction        | 0.455       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.8       |
# |    explained_variance   | 0.662       |
# |    learning_rate        | 0.000289    |
# |    loss                 | -0.0108     |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0592     |
# |    std                  | 0.858       |
# |    value_loss           | 0.31        |
# -----------------------------------------
# Eval num_timesteps=120000, episode_reward=-179.50 +/- 58.19
# Episode length: 831.60 +/- 954.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 832        |
# |    mean_reward          | -179       |
# | time/                   |            |
# |    total_timesteps      | 120000     |
# | train/                  |            |
# |    approx_kl            | 0.23830429 |
# |    clip_fraction        | 0.628      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.8      |
# |    explained_variance   | 0.736      |
# |    learning_rate        | 0.000289   |
# |    loss                 | -0.0722    |
# |    n_updates            | 140        |
# |    policy_gradient_loss | -0.0835    |
# |    std                  | 0.853      |
# |    value_loss           | 0.148      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 259      |
# |    ep_rew_mean     | -146     |
# | time/              |          |
# |    fps             | 1129     |
# |    iterations      | 15       |
# |    time_elapsed    | 108      |
# |    total_timesteps | 122880   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 196         |
# |    ep_rew_mean          | -136        |
# | time/                   |             |
# |    fps                  | 1140        |
# |    iterations           | 16          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.046631224 |
# |    clip_fraction        | 0.51        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.6       |
# |    explained_variance   | 0.867       |
# |    learning_rate        | 0.000288    |
# |    loss                 | -0.0897     |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0922     |
# |    std                  | 0.834       |
# |    value_loss           | 0.125       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 144         |
# |    ep_rew_mean          | -132        |
# | time/                   |             |
# |    fps                  | 1157        |
# |    iterations           | 17          |
# |    time_elapsed         | 120         |
# |    total_timesteps      | 139264      |
# | train/                  |             |
# |    approx_kl            | 0.109124705 |
# |    clip_fraction        | 0.7         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.8       |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.000287    |
# |    loss                 | -0.0482     |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.106      |
# |    std                  | 0.836       |
# |    value_loss           | 0.236       |
# -----------------------------------------
# Eval num_timesteps=140000, episode_reward=-246.03 +/- 11.77
# Episode length: 2000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 2e+03      |
# |    mean_reward          | -246       |
# | time/                   |            |
# |    total_timesteps      | 140000     |
# | train/                  |            |
# |    approx_kl            | 0.05540795 |
# |    clip_fraction        | 0.561      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.91       |
# |    learning_rate        | 0.000286   |
# |    loss                 | -0.079     |
# |    n_updates            | 170        |
# |    policy_gradient_loss | -0.0939    |
# |    std                  | 0.838      |
# |    value_loss           | 0.176      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 155      |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    fps             | 1103     |
# |    iterations      | 18       |
# |    time_elapsed    | 133      |
# |    total_timesteps | 147456   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 236        |
# |    ep_rew_mean          | -141       |
# | time/                   |            |
# |    fps                  | 1114       |
# |    iterations           | 19         |
# |    time_elapsed         | 139        |
# |    total_timesteps      | 155648     |
# | train/                  |            |
# |    approx_kl            | 0.13605458 |
# |    clip_fraction        | 0.624      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.6      |
# |    explained_variance   | 0.902      |
# |    learning_rate        | 0.000285   |
# |    loss                 | -0.0827    |
# |    n_updates            | 180        |
# |    policy_gradient_loss | -0.0716    |
# |    std                  | 0.831      |
# |    value_loss           | 0.0544     |
# ----------------------------------------
# Eval num_timesteps=160000, episode_reward=-208.90 +/- 10.35
# Episode length: 2000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2e+03       |
# |    mean_reward          | -209        |
# | time/                   |             |
# |    total_timesteps      | 160000      |
# | train/                  |             |
# |    approx_kl            | 0.046436563 |
# |    clip_fraction        | 0.5         |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15         |
# |    explained_variance   | 0.857       |
# |    learning_rate        | 0.000284    |
# |    loss                 | -0.054      |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0896     |
# |    std                  | 0.825       |
# |    value_loss           | 0.272       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 224      |
# |    ep_rew_mean     | -138     |
# | time/              |          |
# |    fps             | 1072     |
# |    iterations      | 20       |
# |    time_elapsed    | 152      |
# |    total_timesteps | 163840   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 155        |
# |    ep_rew_mean          | -133       |
# | time/                   |            |
# |    fps                  | 1087       |
# |    iterations           | 21         |
# |    time_elapsed         | 158        |
# |    total_timesteps      | 172032     |
# | train/                  |            |
# |    approx_kl            | 0.04908246 |
# |    clip_fraction        | 0.625      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.882      |
# |    learning_rate        | 0.000284   |
# |    loss                 | -0.078     |
# |    n_updates            | 200        |
# |    policy_gradient_loss | -0.1       |
# |    std                  | 0.828      |
# |    value_loss           | 0.217      |
# ----------------------------------------
# Eval num_timesteps=180000, episode_reward=-182.18 +/- 33.55
# Episode length: 1624.60 +/- 750.80
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.62e+03   |
# |    mean_reward          | -182       |
# | time/                   |            |
# |    total_timesteps      | 180000     |
# | train/                  |            |
# |    approx_kl            | 0.13616842 |
# |    clip_fraction        | 0.745      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.000283   |
# |    loss                 | -0.085     |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.102     |
# |    std                  | 0.827      |
# |    value_loss           | 0.173      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 199      |
# |    ep_rew_mean     | -134     |
# | time/              |          |
# |    fps             | 1051     |
# |    iterations      | 22       |
# |    time_elapsed    | 171      |
# |    total_timesteps | 180224   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 238        |
# |    ep_rew_mean          | -137       |
# | time/                   |            |
# |    fps                  | 1065       |
# |    iterations           | 23         |
# |    time_elapsed         | 176        |
# |    total_timesteps      | 188416     |
# | train/                  |            |
# |    approx_kl            | 0.05462619 |
# |    clip_fraction        | 0.524      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.811      |
# |    learning_rate        | 0.000282   |
# |    loss                 | 0.0103     |
# |    n_updates            | 220        |
# |    policy_gradient_loss | -0.0507    |
# |    std                  | 0.824      |
# |    value_loss           | 0.221      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 211         |
# |    ep_rew_mean          | -140        |
# | time/                   |             |
# |    fps                  | 1074        |
# |    iterations           | 24          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 196608      |
# | train/                  |             |
# |    approx_kl            | 0.093720146 |
# |    clip_fraction        | 0.689       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.1       |
# |    explained_variance   | 0.869       |
# |    learning_rate        | 0.000281    |
# |    loss                 | -0.0466     |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0935     |
# |    std                  | 0.827       |
# |    value_loss           | 0.25        |
# -----------------------------------------
# Eval num_timesteps=200000, episode_reward=-207.38 +/- 60.57
# Episode length: 1240.40 +/- 930.33
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.24e+03   |
# |    mean_reward          | -207       |
# | time/                   |            |
# |    total_timesteps      | 200000     |
# | train/                  |            |
# |    approx_kl            | 0.12946849 |
# |    clip_fraction        | 0.559      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15.1      |
# |    explained_variance   | 0.872      |
# |    learning_rate        | 0.00028    |
# |    loss                 | -0.0234    |
# |    n_updates            | 240        |
# |    policy_gradient_loss | -0.0953    |
# |    std                  | 0.82       |
# |    value_loss           | 0.319      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 190      |
# |    ep_rew_mean     | -139     |
# | time/              |          |
# |    fps             | 1062     |
# |    iterations      | 25       |
# |    time_elapsed    | 192      |
# |    total_timesteps | 204800   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 264        |
# |    ep_rew_mean          | -143       |
# | time/                   |            |
# |    fps                  | 1075       |
# |    iterations           | 26         |
# |    time_elapsed         | 198        |
# |    total_timesteps      | 212992     |
# | train/                  |            |
# |    approx_kl            | 0.07237847 |
# |    clip_fraction        | 0.598      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.8      |
# |    explained_variance   | 0.823      |
# |    learning_rate        | 0.00028    |
# |    loss                 | -0.0681    |
# |    n_updates            | 250        |
# |    policy_gradient_loss | -0.081     |
# |    std                  | 0.816      |
# |    value_loss           | 0.149      |
# ----------------------------------------
# Eval num_timesteps=220000, episode_reward=-248.34 +/- 0.51
# Episode length: 2000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 2e+03      |
# |    mean_reward          | -248       |
# | time/                   |            |
# |    total_timesteps      | 220000     |
# | train/                  |            |
# |    approx_kl            | 0.07243614 |
# |    clip_fraction        | 0.74       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.7      |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.000279   |
# |    loss                 | -0.104     |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0919    |
# |    std                  | 0.813      |
# |    value_loss           | 0.0632     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 296      |
# |    ep_rew_mean     | -147     |
# | time/              |          |
# |    fps             | 1046     |
# |    iterations      | 27       |
# |    time_elapsed    | 211      |
# |    total_timesteps | 221184   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 356        |
# |    ep_rew_mean          | -150       |
# | time/                   |            |
# |    fps                  | 1057       |
# |    iterations           | 28         |
# |    time_elapsed         | 216        |
# |    total_timesteps      | 229376     |
# | train/                  |            |
# |    approx_kl            | 0.03758693 |
# |    clip_fraction        | 0.544      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.884      |
# |    learning_rate        | 0.000278   |
# |    loss                 | 0.00106    |
# |    n_updates            | 270        |
# |    policy_gradient_loss | -0.0734    |
# |    std                  | 0.807      |
# |    value_loss           | 0.283      |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 426        |
# |    ep_rew_mean          | -154       |
# | time/                   |            |
# |    fps                  | 1068       |
# |    iterations           | 29         |
# |    time_elapsed         | 222        |
# |    total_timesteps      | 237568     |
# | train/                  |            |
# |    approx_kl            | 0.21304753 |
# |    clip_fraction        | 0.751      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.898      |
# |    learning_rate        | 0.000277   |
# |    loss                 | -0.105     |
# |    n_updates            | 280        |
# |    policy_gradient_loss | -0.0773    |
# |    std                  | 0.805      |
# |    value_loss           | 0.0383     |
# ----------------------------------------
# Eval num_timesteps=240000, episode_reward=-214.80 +/- 48.04
# Episode length: 1615.20 +/- 769.60
# ---------------------------------------
# | eval/                   |           |
# |    mean_ep_length       | 1.62e+03  |
# |    mean_reward          | -215      |
# | time/                   |           |
# |    total_timesteps      | 240000    |
# | train/                  |           |
# |    approx_kl            | 0.0367372 |
# |    clip_fraction        | 0.654     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -14.9     |
# |    explained_variance   | 0.874     |
# |    learning_rate        | 0.000276  |
# |    loss                 | -0.0228   |
# |    n_updates            | 290       |
# |    policy_gradient_loss | -0.053    |
# |    std                  | 0.807     |
# |    value_loss           | 0.135     |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 299      |
# |    ep_rew_mean     | -141     |
# | time/              |          |
# |    fps             | 1058     |
# |    iterations      | 30       |
# |    time_elapsed    | 232      |
# |    total_timesteps | 245760   |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 132       |
# |    ep_rew_mean          | -129      |
# | time/                   |           |
# |    fps                  | 1068      |
# |    iterations           | 31        |
# |    time_elapsed         | 237       |
# |    total_timesteps      | 253952    |
# | train/                  |           |
# |    approx_kl            | 0.0787638 |
# |    clip_fraction        | 0.552     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -15       |
# |    explained_variance   | 0.917     |
# |    learning_rate        | 0.000275  |
# |    loss                 | -0.0785   |
# |    n_updates            | 300       |
# |    policy_gradient_loss | -0.1      |
# |    std                  | 0.792     |
# |    value_loss           | 0.156     |
# ---------------------------------------
# Eval num_timesteps=260000, episode_reward=-197.66 +/- 61.39
# Episode length: 1226.60 +/- 947.22
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.23e+03    |
# |    mean_reward          | -198        |
# | time/                   |             |
# |    total_timesteps      | 260000      |
# | train/                  |             |
# |    approx_kl            | 0.030093402 |
# |    clip_fraction        | 0.521       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15.1       |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.000275    |
# |    loss                 | -0.011      |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.0758     |
# |    std                  | 0.786       |
# |    value_loss           | 0.302       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 173      |
# |    ep_rew_mean     | -132     |
# | time/              |          |
# |    fps             | 1046     |
# |    iterations      | 32       |
# |    time_elapsed    | 250      |
# |    total_timesteps | 262144   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 217        |
# |    ep_rew_mean          | -139       |
# | time/                   |            |
# |    fps                  | 1054       |
# |    iterations           | 33         |
# |    time_elapsed         | 256        |
# |    total_timesteps      | 270336     |
# | train/                  |            |
# |    approx_kl            | 0.03188573 |
# |    clip_fraction        | 0.687      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.000274   |
# |    loss                 | -0.101     |
# |    n_updates            | 320        |
# |    policy_gradient_loss | -0.0823    |
# |    std                  | 0.782      |
# |    value_loss           | 0.0618     |
# ----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 212        |
# |    ep_rew_mean          | -140       |
# | time/                   |            |
# |    fps                  | 1063       |
# |    iterations           | 34         |
# |    time_elapsed         | 262        |
# |    total_timesteps      | 278528     |
# | train/                  |            |
# |    approx_kl            | 0.10438599 |
# |    clip_fraction        | 0.725      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -14.9      |
# |    explained_variance   | 0.934      |
# |    learning_rate        | 0.000273   |
# |    loss                 | -0.086     |
# |    n_updates            | 330        |
# |    policy_gradient_loss | -0.0922    |
# |    std                  | 0.78       |
# |    value_loss           | 0.133      |
# ----------------------------------------
# Eval num_timesteps=280000, episode_reward=-170.01 +/- 47.64
# Episode length: 843.80 +/- 944.05
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 844        |
# |    mean_reward          | -170       |
# | time/                   |            |
# |    total_timesteps      | 280000     |
# | train/                  |            |
# |    approx_kl            | 0.04425288 |
# |    clip_fraction        | 0.566      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.9        |
# |    learning_rate        | 0.000272   |
# |    loss                 | -0.0423    |
# |    n_updates            | 340        |
# |    policy_gradient_loss | -0.0828    |
# |    std                  | 0.785      |
# |    value_loss           | 0.275      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 279      |
# |    ep_rew_mean     | -144     |
# | time/              |          |
# |    fps             | 1056     |
# |    iterations      | 35       |
# |    time_elapsed    | 271      |
# |    total_timesteps | 286720   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 282         |
# |    ep_rew_mean          | -142        |
# | time/                   |             |
# |    fps                  | 1064        |
# |    iterations           | 36          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 294912      |
# | train/                  |             |
# |    approx_kl            | 0.045495443 |
# |    clip_fraction        | 0.551       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.9       |
# |    explained_variance   | 0.78        |
# |    learning_rate        | 0.000271    |
# |    loss                 | -0.101      |
# |    n_updates            | 350         |
# |    policy_gradient_loss | -0.0892     |
# |    std                  | 0.782       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# Eval num_timesteps=300000, episode_reward=-252.88 +/- 3.79
# Episode length: 2000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2e+03       |
# |    mean_reward          | -253        |
# | time/                   |             |
# |    total_timesteps      | 300000      |
# | train/                  |             |
# |    approx_kl            | 0.046161175 |
# |    clip_fraction        | 0.711       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.9       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.000271    |
# |    loss                 | -0.0863     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.0884     |
# |    std                  | 0.779       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 305      |
# |    ep_rew_mean     | -145     |
# | time/              |          |
# |    fps             | 1045     |
# |    iterations      | 37       |
# |    time_elapsed    | 289      |
# |    total_timesteps | 303104   |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 348         |
# |    ep_rew_mean          | -146        |
# | time/                   |             |
# |    fps                  | 1052        |
# |    iterations           | 38          |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 311296      |
# | train/                  |             |
# |    approx_kl            | 0.028747555 |
# |    clip_fraction        | 0.464       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15         |
# |    explained_variance   | 0.882       |
# |    learning_rate        | 0.00027     |
# |    loss                 | -0.0425     |
# |    n_updates            | 370         |
# |    policy_gradient_loss | -0.0465     |
# |    std                  | 0.771       |
# |    value_loss           | 0.0875      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 407        |
# |    ep_rew_mean          | -150       |
# | time/                   |            |
# |    fps                  | 1061       |
# |    iterations           | 39         |
# |    time_elapsed         | 301        |
# |    total_timesteps      | 319488     |
# | train/                  |            |
# |    approx_kl            | 0.10794535 |
# |    clip_fraction        | 0.757      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.937      |
# |    learning_rate        | 0.000269   |
# |    loss                 | -0.0899    |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.101     |
# |    std                  | 0.771      |
# |    value_loss           | 0.13       |
# ----------------------------------------
# Eval num_timesteps=320000, episode_reward=-252.67 +/- 1.45
# Episode length: 2000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 2e+03      |
# |    mean_reward          | -253       |
# | time/                   |            |
# |    total_timesteps      | 320000     |
# | train/                  |            |
# |    approx_kl            | 0.06586126 |
# |    clip_fraction        | 0.754      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.916      |
# |    learning_rate        | 0.000268   |
# |    loss                 | -0.0966    |
# |    n_updates            | 390        |
# |    policy_gradient_loss | -0.0805    |
# |    std                  | 0.773      |
# |    value_loss           | 0.0489     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 289      |
# |    ep_rew_mean     | -145     |
# | time/              |          |
# |    fps             | 1043     |
# |    iterations      | 40       |
# |    time_elapsed    | 314      |
# |    total_timesteps | 327680   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 366        |
# |    ep_rew_mean          | -152       |
# | time/                   |            |
# |    fps                  | 1051       |
# |    iterations           | 41         |
# |    time_elapsed         | 319        |
# |    total_timesteps      | 335872     |
# | train/                  |            |
# |    approx_kl            | 0.11062769 |
# |    clip_fraction        | 0.766      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15.1      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.000267   |
# |    loss                 | -0.015     |
# |    n_updates            | 400        |
# |    policy_gradient_loss | -0.0944    |
# |    std                  | 0.774      |
# |    value_loss           | 0.242      |
# ----------------------------------------
# Eval num_timesteps=340000, episode_reward=-249.98 +/- 2.11
# Episode length: 2000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 2e+03      |
# |    mean_reward          | -250       |
# | time/                   |            |
# |    total_timesteps      | 340000     |
# | train/                  |            |
# |    approx_kl            | 0.12600747 |
# |    clip_fraction        | 0.824      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 0.000266   |
# |    loss                 | -0.0777    |
# |    n_updates            | 410        |
# |    policy_gradient_loss | -0.088     |
# |    std                  | 0.771      |
# |    value_loss           | 0.0528     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 300      |
# |    ep_rew_mean     | -145     |
# | time/              |          |
# |    fps             | 1034     |
# |    iterations      | 42       |
# |    time_elapsed    | 332      |
# |    total_timesteps | 344064   |
# ---------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 375       |
# |    ep_rew_mean          | -149      |
# | time/                   |           |
# |    fps                  | 1041      |
# |    iterations           | 43        |
# |    time_elapsed         | 338       |
# |    total_timesteps      | 352256    |
# | train/                  |           |
# |    approx_kl            | 0.0714978 |
# |    clip_fraction        | 0.614     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -15.2     |
# |    explained_variance   | 0.926     |
# |    learning_rate        | 0.000266  |
# |    loss                 | -0.105    |
# |    n_updates            | 420       |
# |    policy_gradient_loss | -0.105    |
# |    std                  | 0.771     |
# |    value_loss           | 0.14      |
# ---------------------------------------
# Eval num_timesteps=360000, episode_reward=-204.65 +/- 55.59
# Episode length: 1276.20 +/- 887.35
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.28e+03   |
# |    mean_reward          | -205       |
# | time/                   |            |
# |    total_timesteps      | 360000     |
# | train/                  |            |
# |    approx_kl            | 0.08899802 |
# |    clip_fraction        | 0.675      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.533      |
# |    learning_rate        | 0.000265   |
# |    loss                 | -0.117     |
# |    n_updates            | 430        |
# |    policy_gradient_loss | -0.0921    |
# |    std                  | 0.765      |
# |    value_loss           | 0.0454     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 393      |
# |    ep_rew_mean     | -150     |
# | time/              |          |
# |    fps             | 1025     |
# |    iterations      | 44       |
# |    time_elapsed    | 351      |
# |    total_timesteps | 360448   |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 449        |
# |    ep_rew_mean          | -153       |
# | time/                   |            |
# |    fps                  | 1033       |
# |    iterations           | 45         |
# |    time_elapsed         | 356        |
# |    total_timesteps      | 368640     |
# | train/                  |            |
# |    approx_kl            | 0.08052124 |
# |    clip_fraction        | 0.604      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -15        |
# |    explained_variance   | 0.845      |
# |    learning_rate        | 0.000264   |
# |    loss                 | -0.0879    |
# |    n_updates            | 440        |
# |    policy_gradient_loss | -0.0641    |
# |    std                  | 0.75       |
# |    value_loss           | 0.0437     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 278         |
# |    ep_rew_mean          | -138        |
# | time/                   |             |
# |    fps                  | 1038        |
# |    iterations           | 46          |
# |    time_elapsed         | 362         |
# |    total_timesteps      | 376832      |
# | train/                  |             |
# |    approx_kl            | 0.027085047 |
# |    clip_fraction        | 0.337       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -14.9       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.000263    |
# |    loss                 | -0.0564     |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0374     |
# |    std                  | 0.746       |
# |    value_loss           | 0.018       |
# -----------------------------------------
# Eval num_timesteps=380000, episode_reward=-199.66 +/- 59.83
# Episode length: 1220.00 +/- 955.30
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.22e+03    |
# |    mean_reward          | -200        |
# | time/                   |             |
# |    total_timesteps      | 380000      |
# | train/                  |             |
# |    approx_kl            | 0.059299763 |
# |    clip_fraction        | 0.62        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -15         |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.000262    |
# |    loss                 | -0.115      |
# |    n_updates            | 460         |
# |    policy_gradient_loss | -0.119      |
# |    std                  | 0.746       |
# |    value_loss           | 0.18        |
# -----------------------------------------
# ---------------------------------
# ...
# |    entropy_loss         | -13.8     |
# |    explained_variance   | 0.805     |
# |    learning_rate        | 0.000189  |
# |    loss                 | -0.0709   |
# |    n_updates            | 1360      |
# |    policy_gradient_loss | -0.0661   |
# |    std                  | 0.538     |
# |    value_loss           | 0.00258   |
# ---------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | -204     |
# | time/              |          |
# |    fps             | 968      |
# |    iterations      | 137      |
# |    time_elapsed    | 1159     |
# |    total_timesteps | 1122304  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.36e+03   |
# |    ep_rew_mean          | -204       |
# | time/                   |            |
# |    fps                  | 970        |
# |    iterations           | 138        |
# |    time_elapsed         | 1164       |
# |    total_timesteps      | 1130496    |
# | train/                  |            |
# |    approx_kl            | 0.04262411 |
# |    clip_fraction        | 0.743      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.8      |
# |    explained_variance   | 0.493      |
# |    learning_rate        | 0.000188   |
# |    loss                 | -0.0425    |
# |    n_updates            | 1370       |
# |    policy_gradient_loss | -0.0322    |
# |    std                  | 0.537      |
# |    value_loss           | 0.0061     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.36e+03    |
# |    ep_rew_mean          | -204        |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 139         |
# |    time_elapsed         | 1170        |
# |    total_timesteps      | 1138688     |
# | train/                  |             |
# |    approx_kl            | 0.036431197 |
# |    clip_fraction        | 0.456       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.000187    |
# |    loss                 | -0.0395     |
# |    n_updates            | 1380        |
# |    policy_gradient_loss | -0.0274     |
# |    std                  | 0.534       |
# |    value_loss           | 0.0205      |
# -----------------------------------------
# Eval num_timesteps=1140000, episode_reward=-235.18 +/- 2.51
# Episode length: 2000.00 +/- 0.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 2e+03      |
# |    mean_reward          | -235       |
# | time/                   |            |
# |    total_timesteps      | 1140000    |
# | train/                  |            |
# |    approx_kl            | 0.18463829 |
# |    clip_fraction        | 0.817      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.7      |
# |    explained_variance   | 0.572      |
# |    learning_rate        | 0.000186   |
# |    loss                 | -0.0886    |
# |    n_updates            | 1390       |
# |    policy_gradient_loss | -0.0654    |
# |    std                  | 0.536      |
# |    value_loss           | 0.0011     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | -200     |
# | time/              |          |
# |    fps             | 969      |
# |    iterations      | 140      |
# |    time_elapsed    | 1183     |
# |    total_timesteps | 1146880  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.31e+03   |
# |    ep_rew_mean          | -202       |
# | time/                   |            |
# |    fps                  | 971        |
# |    iterations           | 141        |
# |    time_elapsed         | 1188       |
# |    total_timesteps      | 1155072    |
# | train/                  |            |
# |    approx_kl            | 0.08622033 |
# |    clip_fraction        | 0.739      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.8      |
# |    explained_variance   | 0.849      |
# |    learning_rate        | 0.000185   |
# |    loss                 | -0.069     |
# |    n_updates            | 1400       |
# |    policy_gradient_loss | -0.0544    |
# |    std                  | 0.534      |
# |    value_loss           | 0.0397     |
# ----------------------------------------
# Eval num_timesteps=1160000, episode_reward=-231.67 +/- 1.28
# Episode length: 2000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2e+03       |
# |    mean_reward          | -232        |
# | time/                   |             |
# |    total_timesteps      | 1160000     |
# | train/                  |             |
# |    approx_kl            | 0.082543224 |
# |    clip_fraction        | 0.623       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 0.771       |
# |    learning_rate        | 0.000184    |
# |    loss                 | -0.0801     |
# |    n_updates            | 1410        |
# |    policy_gradient_loss | -0.0635     |
# |    std                  | 0.531       |
# |    value_loss           | 0.031       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | -202     |
# | time/              |          |
# |    fps             | 967      |
# |    iterations      | 142      |
# |    time_elapsed    | 1201     |
# |    total_timesteps | 1163264  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.39e+03    |
# |    ep_rew_mean          | -207        |
# | time/                   |             |
# |    fps                  | 970         |
# |    iterations           | 143         |
# |    time_elapsed         | 1207        |
# |    total_timesteps      | 1171456     |
# | train/                  |             |
# |    approx_kl            | 0.040371794 |
# |    clip_fraction        | 0.504       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 0.772       |
# |    learning_rate        | 0.000184    |
# |    loss                 | -0.0529     |
# |    n_updates            | 1420        |
# |    policy_gradient_loss | -0.042      |
# |    std                  | 0.531       |
# |    value_loss           | 0.0441      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.39e+03    |
# |    ep_rew_mean          | -206        |
# | time/                   |             |
# |    fps                  | 972         |
# |    iterations           | 144         |
# |    time_elapsed         | 1213        |
# |    total_timesteps      | 1179648     |
# | train/                  |             |
# |    approx_kl            | 0.052717272 |
# |    clip_fraction        | 0.689       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.9       |
# |    explained_variance   | 0.725       |
# |    learning_rate        | 0.000183    |
# |    loss                 | -0.0816     |
# |    n_updates            | 1430        |
# |    policy_gradient_loss | -0.055      |
# |    std                  | 0.532       |
# |    value_loss           | 0.00461     |
# -----------------------------------------
# Eval num_timesteps=1180000, episode_reward=-229.74 +/- 6.91
# Episode length: 2000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2e+03       |
# |    mean_reward          | -230        |
# | time/                   |             |
# |    total_timesteps      | 1180000     |
# | train/                  |             |
# |    approx_kl            | 0.094056875 |
# |    clip_fraction        | 0.861       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 0.879       |
# |    learning_rate        | 0.000182    |
# |    loss                 | -0.119      |
# |    n_updates            | 1440        |
# |    policy_gradient_loss | -0.0854     |
# |    std                  | 0.53        |
# |    value_loss           | 0.000993    |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -206     |
# | time/              |          |
# |    fps             | 968      |
# |    iterations      | 145      |
# |    time_elapsed    | 1226     |
# |    total_timesteps | 1187840  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.38e+03   |
# |    ep_rew_mean          | -204       |
# | time/                   |            |
# |    fps                  | 971        |
# |    iterations           | 146        |
# |    time_elapsed         | 1231       |
# |    total_timesteps      | 1196032    |
# | train/                  |            |
# |    approx_kl            | 0.07970171 |
# |    clip_fraction        | 0.468      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -13.7      |
# |    explained_variance   | 0.913      |
# |    learning_rate        | 0.000181   |
# |    loss                 | -0.0554    |
# |    n_updates            | 1450       |
# |    policy_gradient_loss | -0.0393    |
# |    std                  | 0.527      |
# |    value_loss           | 0.017      |
# ----------------------------------------
# Eval num_timesteps=1200000, episode_reward=-224.44 +/- 2.66
# Episode length: 2000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2e+03       |
# |    mean_reward          | -224        |
# | time/                   |             |
# |    total_timesteps      | 1200000     |
# | train/                  |             |
# |    approx_kl            | 0.120705225 |
# |    clip_fraction        | 0.575       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 0.793       |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0775     |
# |    n_updates            | 1460        |
# |    policy_gradient_loss | -0.0604     |
# |    std                  | 0.522       |
# |    value_loss           | 0.045       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | -201     |
# | time/              |          |
# |    fps             | 967      |
# |    iterations      | 147      |
# |    time_elapsed    | 1244     |
# |    total_timesteps | 1204224  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.14e+03    |
# |    ep_rew_mean          | -190        |
# | time/                   |             |
# |    fps                  | 969         |
# |    iterations           | 148         |
# |    time_elapsed         | 1251        |
# |    total_timesteps      | 1212416     |
# | train/                  |             |
# |    approx_kl            | 0.048229057 |
# |    clip_fraction        | 0.543       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -13.8       |
# |    explained_variance   | 0.82        |
# |    learning_rate        | 0.00018     |
# |    loss                 | -0.0251     |
# |    n_updates            | 1470        |
# |    policy_gradient_loss | -0.0425     |
# |    std                  | 0.522       |
# |    value_loss           | 0.0947      |
# -----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1148877003.py in <cell line: 0>()
#     174
#     175 if __name__ == "__main__":
# --> 176     train()
#     177     record_and_show_video()
#
# /tmp/ipython-input-1148877003.py in train()
#     112     )
#     113
# --> 114     model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback)
#     115
#     116     model.save(f"{model_dir}/final_model")
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/ppo/ppo.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     309         progress_bar: bool = False,
#     310     ) -> SelfPPO:
# --> 311         return super().learn(
#     312             total_timesteps=total_timesteps,
#     313             callback=callback,
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     322
#     323         while self.num_timesteps < total_timesteps:
# --> 324             continue_training = self.collect_rollouts(self.env, callback, self.rollout_buffer, n_rollout_steps=self.n_steps)
#     325
#     326             if not continue_training:
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py in collect_rollouts(self, env, callback, rollout_buffer, n_rollout_steps)
#     216                     clipped_actions = np.clip(actions, self.action_space.low, self.action_space.high)
#     217
# --> 218             new_obs, rewards, dones, infos = env.step(clipped_actions)
#     219
#     220             self.num_timesteps += env.num_envs
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/base_vec_env.py in step(self, actions)
#     220         """
#     221         self.step_async(actions)
# --> 222         return self.step_wait()
#     223
#     224     def get_images(self) -> Sequence[Optional[np.ndarray]]:
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/vec_normalize.py in step_wait(self)
#     179         where ``dones`` is a boolean vector indicating whether each element is new.
#     180         """
# --> 181         obs, rewards, dones, infos = self.venv.step_wait()
#     182         assert isinstance(obs, (np.ndarray, dict))  # for mypy
#     183         self.old_obs = obs
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/vec_monitor.py in step_wait(self)
#      74
#      75     def step_wait(self) -> VecEnvStepReturn:
# ---> 76         obs, rewards, dones, infos = self.venv.step_wait()
#      77         self.episode_returns += rewards
#      78         self.episode_lengths += 1
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/vec_env/subproc_vec_env.py in step_wait(self)
#     135
#     136     def step_wait(self) -> VecEnvStepReturn:
# --> 137         results = [remote.recv() for remote in self.remotes]
#     138         self.waiting = False
#     139         obs, rews, dones, infos, self.reset_infos = zip(*results)  # type: ignore[assignment]
#
# /usr/lib/python3.12/multiprocessing/connection.py in recv(self)
#     248         self._check_closed()
#     249         self._check_readable()
# --> 250         buf = self._recv_bytes()
#     251         return _ForkingPickler.loads(buf.getbuffer())
#     252
#
# /usr/lib/python3.12/multiprocessing/connection.py in _recv_bytes(self, maxsize)
#     428
#     429     def _recv_bytes(self, maxsize=None):
# --> 430         buf = self._recv(4)
#     431         size, = struct.unpack("!i", buf.getvalue())
#     432         if size == -1:
#
# /usr/lib/python3.12/multiprocessing/connection.py in _recv(self, size, read)
#     393         remaining = size
#     394         while remaining > 0:
# --> 395             chunk = read(handle, remaining)
#     396             n = len(chunk)
#     397             if n == 0:
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
import os
import base64
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecMonitor, VecVideoRecorder, VecNormalize
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION: V3.1 (SOTA Config BUT Standard Noise) ---
EXPERIMENT_NAME = "sota_ppo_v3_1_hardcore"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
NUM_CPU = 4
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- REWARD SHAPING ---
class EncouragingWalkerWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)
    def reward(self, reward):
        return reward * 1.1

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env(rank, seed=0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = EncouragingWalkerWrapper(env)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (Big Net, No gSDE) ---")
    print(f"Saving to: {base_path}")

    env = SubprocVecEnv([make_env(i) for i in range(NUM_CPU)])
    env = VecMonitor(env, log_dir)

    # Normalization (Mandatory for Hardcore)
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=max(20000 // NUM_CPU, 1),
        deterministic=True,
        render=False
    )

    # 4. SOTA PPO Model (Modified V3.1)
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,

        # --- KEY CHANGE: DISABLE gSDE ---
        use_sde=False,          # <--- V3.1 Change: Standard Noise for "Twitch" reactivity

        policy_kwargs=dict(
            # Keep the SOTA Architecture [256, 256] Separate
            net_arch=dict(pi=[256, 256], vf=[256, 256]),
            activation_fn=nn.Tanh,
            optimizer_kwargs=dict(eps=1e-5)
        ),

        # Keep SOTA Hyperparameters
        learning_rate=linear_schedule(3e-4),
        n_steps=2048,
        batch_size=1024,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.001,
        vf_coef=0.5,
        max_grad_norm=0.5,
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vecnormalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vecnormalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    env = gym.make(ENV_ID, render_mode="rgb_array")
    env = EncouragingWalkerWrapper(env)

    from stable_baselines3.common.vec_env import DummyVecEnv
    env = DummyVecEnv([lambda: env])

    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = PPO.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Streaming output truncated to the last 5000 lines.
# |    value_loss           | 0.204        |
# ------------------------------------------
# Eval num_timesteps=1420000, episode_reward=-56.01 +/- 51.00
# Episode length: 591.20 +/- 714.43
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 591         |
# |    mean_reward          | -56         |
# | time/                   |             |
# |    total_timesteps      | 1420000     |
# | train/                  |             |
# |    approx_kl            | 0.008916704 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.85       |
# |    explained_variance   | 0.928       |
# |    learning_rate        | 0.000158    |
# |    loss                 | -0.0211     |
# |    n_updates            | 1730        |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.635       |
# |    value_loss           | 0.0468      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -70.5    |
# | time/              |          |
# |    fps             | 1078     |
# |    iterations      | 174      |
# |    time_elapsed    | 1321     |
# |    total_timesteps | 1425408  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.04e+03     |
# |    ep_rew_mean          | -71.5        |
# | time/                   |              |
# |    fps                  | 1080         |
# |    iterations           | 175          |
# |    time_elapsed         | 1326         |
# |    total_timesteps      | 1433600      |
# | train/                  |              |
# |    approx_kl            | 0.0091361925 |
# |    clip_fraction        | 0.102        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.85        |
# |    explained_variance   | 0.911        |
# |    learning_rate        | 0.000157     |
# |    loss                 | 0.0297       |
# |    n_updates            | 1740         |
# |    policy_gradient_loss | -0.0164      |
# |    std                  | 0.635        |
# |    value_loss           | 0.167        |
# ------------------------------------------
# Eval num_timesteps=1440000, episode_reward=-31.86 +/- 42.58
# Episode length: 1367.20 +/- 776.51
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.37e+03    |
# |    mean_reward          | -31.9       |
# | time/                   |             |
# |    total_timesteps      | 1440000     |
# | train/                  |             |
# |    approx_kl            | 0.008230602 |
# |    clip_fraction        | 0.0946      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.84       |
# |    explained_variance   | 0.942       |
# |    learning_rate        | 0.000157    |
# |    loss                 | 0.0154      |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | -0.0169     |
# |    std                  | 0.633       |
# |    value_loss           | 0.123       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 999      |
# |    ep_rew_mean     | -76.1    |
# | time/              |          |
# |    fps             | 1078     |
# |    iterations      | 176      |
# |    time_elapsed    | 1336     |
# |    total_timesteps | 1441792  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 999        |
# |    ep_rew_mean          | -75        |
# | time/                   |            |
# |    fps                  | 1080       |
# |    iterations           | 177        |
# |    time_elapsed         | 1342       |
# |    total_timesteps      | 1449984    |
# | train/                  |            |
# |    approx_kl            | 0.00828689 |
# |    clip_fraction        | 0.0883     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.84      |
# |    explained_variance   | 0.918      |
# |    learning_rate        | 0.000156   |
# |    loss                 | 0.0408     |
# |    n_updates            | 1760       |
# |    policy_gradient_loss | -0.0182    |
# |    std                  | 0.633      |
# |    value_loss           | 0.24       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 970         |
# |    ep_rew_mean          | -73.6       |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 178         |
# |    time_elapsed         | 1347        |
# |    total_timesteps      | 1458176     |
# | train/                  |             |
# |    approx_kl            | 0.008686891 |
# |    clip_fraction        | 0.0864      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.000155    |
# |    loss                 | -0.000102   |
# |    n_updates            | 1770        |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.632       |
# |    value_loss           | 0.0854      |
# -----------------------------------------
# Eval num_timesteps=1460000, episode_reward=-57.84 +/- 34.43
# Episode length: 811.40 +/- 675.79
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 811         |
# |    mean_reward          | -57.8       |
# | time/                   |             |
# |    total_timesteps      | 1460000     |
# | train/                  |             |
# |    approx_kl            | 0.008239465 |
# |    clip_fraction        | 0.0937      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.000154    |
# |    loss                 | 0.0605      |
# |    n_updates            | 1780        |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.633       |
# |    value_loss           | 0.243       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 995      |
# |    ep_rew_mean     | -71.1    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 179      |
# |    time_elapsed    | 1356     |
# |    total_timesteps | 1466368  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1e+03       |
# |    ep_rew_mean          | -66.9       |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 180         |
# |    time_elapsed         | 1362        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.008963252 |
# |    clip_fraction        | 0.0959      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.000153    |
# |    loss                 | 0.0164      |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.631       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# Eval num_timesteps=1480000, episode_reward=-74.99 +/- 10.61
# Episode length: 941.60 +/- 865.38
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 942        |
# |    mean_reward          | -75        |
# | time/                   |            |
# |    total_timesteps      | 1480000    |
# | train/                  |            |
# |    approx_kl            | 0.00823178 |
# |    clip_fraction        | 0.0864     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.82      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.000153   |
# |    loss                 | 0.00993    |
# |    n_updates            | 1800       |
# |    policy_gradient_loss | -0.0165    |
# |    std                  | 0.629      |
# |    value_loss           | 0.0922     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -66.6    |
# | time/              |          |
# |    fps             | 1078     |
# |    iterations      | 181      |
# |    time_elapsed    | 1374     |
# |    total_timesteps | 1482752  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -68.9       |
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 182         |
# |    time_elapsed         | 1379        |
# |    total_timesteps      | 1490944     |
# | train/                  |             |
# |    approx_kl            | 0.009167368 |
# |    clip_fraction        | 0.0985      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.000152    |
# |    loss                 | 0.0245      |
# |    n_updates            | 1810        |
# |    policy_gradient_loss | -0.0117     |
# |    std                  | 0.628       |
# |    value_loss           | 0.129       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -72.1       |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 183         |
# |    time_elapsed         | 1385        |
# |    total_timesteps      | 1499136     |
# | train/                  |             |
# |    approx_kl            | 0.009530375 |
# |    clip_fraction        | 0.092       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.929       |
# |    learning_rate        | 0.000151    |
# |    loss                 | 0.0435      |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.017      |
# |    std                  | 0.628       |
# |    value_loss           | 0.192       |
# -----------------------------------------
# Eval num_timesteps=1500000, episode_reward=-61.72 +/- 24.24
# Episode length: 1348.60 +/- 800.18
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.35e+03    |
# |    mean_reward          | -61.7       |
# | time/                   |             |
# |    total_timesteps      | 1500000     |
# | train/                  |             |
# |    approx_kl            | 0.008384092 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.935       |
# |    learning_rate        | 0.00015     |
# |    loss                 | 0.0022      |
# |    n_updates            | 1830        |
# |    policy_gradient_loss | -0.0149     |
# |    std                  | 0.626       |
# |    value_loss           | 0.108       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -72.4    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 184      |
# |    time_elapsed    | 1395     |
# |    total_timesteps | 1507328  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -71         |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 185         |
# |    time_elapsed         | 1400        |
# |    total_timesteps      | 1515520     |
# | train/                  |             |
# |    approx_kl            | 0.007193115 |
# |    clip_fraction        | 0.0862      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.79       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.000149    |
# |    loss                 | 0.000407    |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.625       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# Eval num_timesteps=1520000, episode_reward=-40.53 +/- 32.26
# Episode length: 1175.80 +/- 702.64
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.18e+03    |
# |    mean_reward          | -40.5       |
# | time/                   |             |
# |    total_timesteps      | 1520000     |
# | train/                  |             |
# |    approx_kl            | 0.008357863 |
# |    clip_fraction        | 0.0878      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.000148    |
# |    loss                 | 0.00208     |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.624       |
# |    value_loss           | 0.09        |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -71.6    |
# | time/              |          |
# |    fps             | 1079     |
# |    iterations      | 186      |
# |    time_elapsed    | 1411     |
# |    total_timesteps | 1523712  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.03e+03    |
# |    ep_rew_mean          | -73.9       |
# | time/                   |             |
# |    fps                  | 1081        |
# |    iterations           | 187         |
# |    time_elapsed         | 1416        |
# |    total_timesteps      | 1531904     |
# | train/                  |             |
# |    approx_kl            | 0.008345693 |
# |    clip_fraction        | 0.0901      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.000148    |
# |    loss                 | 0.0574      |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.0181     |
# |    std                  | 0.623       |
# |    value_loss           | 0.172       |
# -----------------------------------------
# Eval num_timesteps=1540000, episode_reward=-53.98 +/- 36.91
# Episode length: 1483.60 +/- 673.49
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.48e+03    |
# |    mean_reward          | -54         |
# | time/                   |             |
# |    total_timesteps      | 1540000     |
# | train/                  |             |
# |    approx_kl            | 0.008443927 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.77       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.000147    |
# |    loss                 | 0.00707     |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.0186     |
# |    std                  | 0.622       |
# |    value_loss           | 0.117       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -70.5    |
# | time/              |          |
# |    fps             | 1078     |
# |    iterations      | 188      |
# |    time_elapsed    | 1427     |
# |    total_timesteps | 1540096  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.05e+03    |
# |    ep_rew_mean          | -70.7       |
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 189         |
# |    time_elapsed         | 1432        |
# |    total_timesteps      | 1548288     |
# | train/                  |             |
# |    approx_kl            | 0.008383526 |
# |    clip_fraction        | 0.0857      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.919       |
# |    learning_rate        | 0.000146    |
# |    loss                 | 0.0513      |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.622       |
# |    value_loss           | 0.235       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.04e+03    |
# |    ep_rew_mean          | -68.9       |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 190         |
# |    time_elapsed         | 1438        |
# |    total_timesteps      | 1556480     |
# | train/                  |             |
# |    approx_kl            | 0.008517834 |
# |    clip_fraction        | 0.0921      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.76       |
# |    explained_variance   | 0.948       |
# |    learning_rate        | 0.000145    |
# |    loss                 | 0.0153      |
# |    n_updates            | 1890        |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.621       |
# |    value_loss           | 0.151       |
# -----------------------------------------
# Eval num_timesteps=1560000, episode_reward=-37.91 +/- 53.78
# Episode length: 998.80 +/- 643.94
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 999          |
# |    mean_reward          | -37.9        |
# | time/                   |              |
# |    total_timesteps      | 1560000      |
# | train/                  |              |
# |    approx_kl            | 0.0081036445 |
# |    clip_fraction        | 0.0973       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.75        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.000144     |
# |    loss                 | 0.01         |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.0183      |
# |    std                  | 0.62         |
# |    value_loss           | 0.137        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | -67.7    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 191      |
# |    time_elapsed    | 1447     |
# |    total_timesteps | 1564672  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -65.4       |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 192         |
# |    time_elapsed         | 1453        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.008797353 |
# |    clip_fraction        | 0.0875      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.75       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 0.000144    |
# |    loss                 | 0.0512      |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.619       |
# |    value_loss           | 0.213       |
# -----------------------------------------
# Eval num_timesteps=1580000, episode_reward=-19.27 +/- 52.92
# Episode length: 1200.00 +/- 695.29
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.2e+03     |
# |    mean_reward          | -19.3       |
# | time/                   |             |
# |    total_timesteps      | 1580000     |
# | train/                  |             |
# |    approx_kl            | 0.009119991 |
# |    clip_fraction        | 0.0937      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.74       |
# |    explained_variance   | 0.925       |
# |    learning_rate        | 0.000143    |
# |    loss                 | 0.00548     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.618       |
# |    value_loss           | 0.0979      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.05e+03 |
# |    ep_rew_mean     | -71.3    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 193      |
# |    time_elapsed    | 1462     |
# |    total_timesteps | 1581056  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 977         |
# |    ep_rew_mean          | -70         |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 194         |
# |    time_elapsed         | 1467        |
# |    total_timesteps      | 1589248     |
# | train/                  |             |
# |    approx_kl            | 0.009345504 |
# |    clip_fraction        | 0.11        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.000142    |
# |    loss                 | 0.0342      |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.617       |
# |    value_loss           | 0.177       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 990         |
# |    ep_rew_mean          | -70.2       |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 195         |
# |    time_elapsed         | 1472        |
# |    total_timesteps      | 1597440     |
# | train/                  |             |
# |    approx_kl            | 0.009405718 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.000141    |
# |    loss                 | 0.0361      |
# |    n_updates            | 1940        |
# |    policy_gradient_loss | -0.0192     |
# |    std                  | 0.616       |
# |    value_loss           | 0.215       |
# -----------------------------------------
# Eval num_timesteps=1600000, episode_reward=-46.46 +/- 22.37
# Episode length: 1553.00 +/- 688.63
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.55e+03    |
# |    mean_reward          | -46.5       |
# | time/                   |             |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.009085901 |
# |    clip_fraction        | 0.094       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.72       |
# |    explained_variance   | 0.931       |
# |    learning_rate        | 0.00014     |
# |    loss                 | 0.0404      |
# |    n_updates            | 1950        |
# |    policy_gradient_loss | -0.0167     |
# |    std                  | 0.615       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 960      |
# |    ep_rew_mean     | -69.7    |
# | time/              |          |
# |    fps             | 1081     |
# |    iterations      | 196      |
# |    time_elapsed    | 1485     |
# |    total_timesteps | 1605632  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 962         |
# |    ep_rew_mean          | -69.8       |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 197         |
# |    time_elapsed         | 1491        |
# |    total_timesteps      | 1613824     |
# | train/                  |             |
# |    approx_kl            | 0.009784196 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.897       |
# |    learning_rate        | 0.000139    |
# |    loss                 | 0.0573      |
# |    n_updates            | 1960        |
# |    policy_gradient_loss | -0.0159     |
# |    std                  | 0.613       |
# |    value_loss           | 0.254       |
# -----------------------------------------
# Eval num_timesteps=1620000, episode_reward=-64.94 +/- 23.06
# Episode length: 1632.60 +/- 734.80
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.63e+03    |
# |    mean_reward          | -64.9       |
# | time/                   |             |
# |    total_timesteps      | 1620000     |
# | train/                  |             |
# |    approx_kl            | 0.008723572 |
# |    clip_fraction        | 0.0867      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.000139    |
# |    loss                 | 0.014       |
# |    n_updates            | 1970        |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.612       |
# |    value_loss           | 0.139       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 954      |
# |    ep_rew_mean     | -69.9    |
# | time/              |          |
# |    fps             | 1078     |
# |    iterations      | 198      |
# |    time_elapsed    | 1503     |
# |    total_timesteps | 1622016  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 932         |
# |    ep_rew_mean          | -72.6       |
# | time/                   |             |
# |    fps                  | 1080        |
# |    iterations           | 199         |
# |    time_elapsed         | 1508        |
# |    total_timesteps      | 1630208     |
# | train/                  |             |
# |    approx_kl            | 0.009223549 |
# |    clip_fraction        | 0.0825      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.69       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.000138    |
# |    loss                 | 0.00951     |
# |    n_updates            | 1980        |
# |    policy_gradient_loss | -0.0191     |
# |    std                  | 0.611       |
# |    value_loss           | 0.125       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 915          |
# |    ep_rew_mean          | -73.6        |
# | time/                   |              |
# |    fps                  | 1081         |
# |    iterations           | 200          |
# |    time_elapsed         | 1514         |
# |    total_timesteps      | 1638400      |
# | train/                  |              |
# |    approx_kl            | 0.0069044516 |
# |    clip_fraction        | 0.0724       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.68        |
# |    explained_variance   | 0.935        |
# |    learning_rate        | 0.000137     |
# |    loss                 | 0.0129       |
# |    n_updates            | 1990         |
# |    policy_gradient_loss | -0.0173      |
# |    std                  | 0.609        |
# |    value_loss           | 0.117        |
# ------------------------------------------
# Eval num_timesteps=1640000, episode_reward=-37.16 +/- 47.39
# Episode length: 1143.20 +/- 593.02
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.14e+03    |
# |    mean_reward          | -37.2       |
# | time/                   |             |
# |    total_timesteps      | 1640000     |
# | train/                  |             |
# |    approx_kl            | 0.009149478 |
# |    clip_fraction        | 0.0886      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.92        |
# |    learning_rate        | 0.000136    |
# |    loss                 | 0.0365      |
# |    n_updates            | 2000        |
# |    policy_gradient_loss | -0.0189     |
# |    std                  | 0.607       |
# |    value_loss           | 0.174       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 912      |
# |    ep_rew_mean     | -74.3    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 201      |
# |    time_elapsed    | 1523     |
# |    total_timesteps | 1646592  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 884        |
# |    ep_rew_mean          | -74.6      |
# | time/                   |            |
# |    fps                  | 1081       |
# |    iterations           | 202        |
# |    time_elapsed         | 1529       |
# |    total_timesteps      | 1654784    |
# | train/                  |            |
# |    approx_kl            | 0.00908601 |
# |    clip_fraction        | 0.096      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.67      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.000135   |
# |    loss                 | 0.0229     |
# |    n_updates            | 2010       |
# |    policy_gradient_loss | -0.0176    |
# |    std                  | 0.607      |
# |    value_loss           | 0.17       |
# ----------------------------------------
# Eval num_timesteps=1660000, episode_reward=-74.12 +/- 25.89
# Episode length: 748.20 +/- 674.51
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 748         |
# |    mean_reward          | -74.1       |
# | time/                   |             |
# |    total_timesteps      | 1660000     |
# | train/                  |             |
# |    approx_kl            | 0.008509619 |
# |    clip_fraction        | 0.0827      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.66       |
# |    explained_variance   | 0.916       |
# |    learning_rate        | 0.000135    |
# |    loss                 | 0.0546      |
# |    n_updates            | 2020        |
# |    policy_gradient_loss | -0.0158     |
# |    std                  | 0.605       |
# |    value_loss           | 0.189       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 933      |
# |    ep_rew_mean     | -75.2    |
# | time/              |          |
# |    fps             | 1080     |
# |    iterations      | 203      |
# |    time_elapsed    | 1538     |
# |    total_timesteps | 1662976  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 935         |
# |    ep_rew_mean          | -75.7       |
# | time/                   |             |
# |    fps                  | 1082        |
# |    iterations           | 204         |
# |    time_elapsed         | 1544        |
# |    total_timesteps      | 1671168     |
# | train/                  |             |
# |    approx_kl            | 0.008711239 |
# |    clip_fraction        | 0.0947      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.65       |
# |    explained_variance   | 0.936       |
# |    learning_rate        | 0.000134    |
# |    loss                 | 0.0251      |
# |    n_updates            | 2030        |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.605       |
# |    value_loss           | 0.148       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 929          |
# |    ep_rew_mean          | -72          |
# | time/                   |              |
# |    fps                  | 1083         |
# |    iterations           | 205          |
# |    time_elapsed         | 1549         |
# |    total_timesteps      | 1679360      |
# | train/                  |              |
# |    approx_kl            | 0.0080922935 |
# |    clip_fraction        | 0.096        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.65        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.000133     |
# |    loss                 | -0.0114      |
# |    n_updates            | 2040         |
# |    policy_gradient_loss | -0.0179      |
# |    std                  | 0.604        |
# |    value_loss           | 0.0636       |
# ------------------------------------------
# Eval num_timesteps=1680000, episode_reward=-41.74 +/- 71.93
# Episode length: 594.40 +/- 708.43
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 594         |
# |    mean_reward          | -41.7       |
# | time/                   |             |
# |    total_timesteps      | 1680000     |
# | train/                  |             |
# |    approx_kl            | 0.008394119 |
# |    clip_fraction        | 0.0832      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.938       |
# |    learning_rate        | 0.000132    |
# |    loss                 | 0.072       |
# |    n_updates            | 2050        |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.603       |
# |    value_loss           | 0.235       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 915      |
# |    ep_rew_mean     | -73      |
# | time/              |          |
# |    fps             | 1082     |
# |    iterations      | 206      |
# |    time_elapsed    | 1559     |
# |    total_timesteps | 1687552  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 954         |
# |    ep_rew_mean          | -71.8       |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 207         |
# |    time_elapsed         | 1564        |
# |    total_timesteps      | 1695744     |
# | train/                  |             |
# |    approx_kl            | 0.008871979 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.000131    |
# |    loss                 | 0.0483      |
# |    n_updates            | 2060        |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.603       |
# |    value_loss           | 0.21        |
# -----------------------------------------
# Eval num_timesteps=1700000, episode_reward=-32.87 +/- 13.16
# Episode length: 895.40 +/- 563.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 895          |
# |    mean_reward          | -32.9        |
# | time/                   |              |
# |    total_timesteps      | 1700000      |
# | train/                  |              |
# |    approx_kl            | 0.0078022964 |
# |    clip_fraction        | 0.0777       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.64        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.00013      |
# |    loss                 | 0.00765      |
# |    n_updates            | 2070         |
# |    policy_gradient_loss | -0.0176      |
# |    std                  | 0.602        |
# |    value_loss           | 0.102        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 957      |
# |    ep_rew_mean     | -72.5    |
# | time/              |          |
# |    fps             | 1082     |
# |    iterations      | 208      |
# |    time_elapsed    | 1573     |
# |    total_timesteps | 1703936  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 956         |
# |    ep_rew_mean          | -74.5       |
# | time/                   |             |
# |    fps                  | 1084        |
# |    iterations           | 209         |
# |    time_elapsed         | 1578        |
# |    total_timesteps      | 1712128     |
# | train/                  |             |
# |    approx_kl            | 0.008655734 |
# |    clip_fraction        | 0.0951      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.937       |
# |    learning_rate        | 0.00013     |
# |    loss                 | -0.00624    |
# |    n_updates            | 2080        |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.6         |
# |    value_loss           | 0.103       |
# -----------------------------------------
# Eval num_timesteps=1720000, episode_reward=-30.50 +/- 53.71
# Episode length: 1292.40 +/- 868.33
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.29e+03    |
# |    mean_reward          | -30.5       |
# | time/                   |             |
# |    total_timesteps      | 1720000     |
# | train/                  |             |
# |    approx_kl            | 0.008923751 |
# |    clip_fraction        | 0.0876      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.000129    |
# |    loss                 | -0.0035     |
# |    n_updates            | 2090        |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.598       |
# |    value_loss           | 0.0882      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 987      |
# |    ep_rew_mean     | -72.7    |
# | time/              |          |
# |    fps             | 1082     |
# |    iterations      | 210      |
# |    time_elapsed    | 1589     |
# |    total_timesteps | 1720320  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 994         |
# |    ep_rew_mean          | -71         |
# | time/                   |             |
# |    fps                  | 1083        |
# |    iterations           | 211         |
# |    time_elapsed         | 1594        |
# |    total_timesteps      | 1728512     |
# | train/                  |             |
# |    approx_kl            | 0.008458985 |
# |    clip_fraction        | 0.089       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.000128    |
# |    loss                 | 0.0361      |
# |    n_updates            | 2100        |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.597       |
# |    value_loss           | 0.179       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.02e+03    |
# |    ep_rew_mean          | -68.3       |
# | time/                   |             |
# |    fps                  | 1085        |
# |    iterations           | 212         |
# |    time_elapsed         | 1599        |
# |    total_timesteps      | 1736704     |
# | train/                  |             |
# |    approx_kl            | 0.009018811 |
# |    clip_fraction        | 0.0912      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.000127    |
# |    loss                 | 0.00964     |
# |    n_updates            | 2110        |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.596       |
# |    value_loss           | 0.143       |
# -----------------------------------------
# Eval num_timesteps=1740000, episode_reward=-33.32 +/- 26.45
# Episode length: 936.80 +/- 593.19
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 937         |
# |    mean_reward          | -33.3       |
# | time/                   |             |
# |    total_timesteps      | 1740000     |
# | train/                  |             |
# |    approx_kl            | 0.008719138 |
# |    clip_fraction        | 0.0907      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.000126    |
# |    loss                 | -0.00208    |
# |    n_updates            | 2120        |
# |    policy_gradient_loss | -0.0157     |
# |    std                  | 0.594       |
# |    value_loss           | 0.0802      |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | -67.5    |
# | time/              |          |
# |    fps             | 1084     |
# |    iterations      | 213      |
# |    time_elapsed    | 1609     |
# |    total_timesteps | 1744896  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.08e+03    |
# |    ep_rew_mean          | -67.5       |
# | time/                   |             |
# |    fps                  | 1085        |
# |    iterations           | 214         |
# |    time_elapsed         | 1614        |
# |    total_timesteps      | 1753088     |
# | train/                  |             |
# |    approx_kl            | 0.009340287 |
# |    clip_fraction        | 0.0936      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 0.000126    |
# |    loss                 | 0.0177      |
# |    n_updates            | 2130        |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.593       |
# |    value_loss           | 0.135       |
# -----------------------------------------
# Eval num_timesteps=1760000, episode_reward=-40.96 +/- 40.68
# Episode length: 1137.20 +/- 798.72
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.14e+03    |
# |    mean_reward          | -41         |
# | time/                   |             |
# |    total_timesteps      | 1760000     |
# | train/                  |             |
# |    approx_kl            | 0.009197208 |
# |    clip_fraction        | 0.0931      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.57       |
# |    explained_variance   | 0.957       |
# |    learning_rate        | 0.000125    |
# |    loss                 | 0.0116      |
# |    n_updates            | 2140        |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.593       |
# |    value_loss           | 0.112       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | -70      |
# | time/              |          |
# |    fps             | 1084     |
# |    iterations      | 215      |
# |    time_elapsed    | 1624     |
# |    total_timesteps | 1761280  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.1e+03    |
# |    ep_rew_mean          | -71.3      |
# | time/                   |            |
# |    fps                  | 1085       |
# |    iterations           | 216        |
# |    time_elapsed         | 1629       |
# |    total_timesteps      | 1769472    |
# | train/                  |            |
# |    approx_kl            | 0.00890715 |
# |    clip_fraction        | 0.0986     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.57      |
# |    explained_variance   | 0.905      |
# |    learning_rate        | 0.000124   |
# |    loss                 | 0.0911     |
# |    n_updates            | 2150       |
# |    policy_gradient_loss | -0.017     |
# |    std                  | 0.591      |
# |    value_loss           | 0.251      |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.11e+03     |
# |    ep_rew_mean          | -73.2        |
# | time/                   |              |
# |    fps                  | 1087         |
# |    iterations           | 217          |
# |    time_elapsed         | 1635         |
# |    total_timesteps      | 1777664      |
# | train/                  |              |
# |    approx_kl            | 0.0074577434 |
# |    clip_fraction        | 0.0854       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.56        |
# |    explained_variance   | 0.914        |
# |    learning_rate        | 0.000123     |
# |    loss                 | -0.0126      |
# |    n_updates            | 2160         |
# |    policy_gradient_loss | -0.0178      |
# |    std                  | 0.591        |
# |    value_loss           | 0.0619       |
# ------------------------------------------
# Eval num_timesteps=1780000, episode_reward=-49.60 +/- 29.24
# Episode length: 1324.80 +/- 829.31
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.32e+03    |
# |    mean_reward          | -49.6       |
# | time/                   |             |
# |    total_timesteps      | 1780000     |
# | train/                  |             |
# |    approx_kl            | 0.009251025 |
# |    clip_fraction        | 0.104       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.93        |
# |    learning_rate        | 0.000122    |
# |    loss                 | 0.000207    |
# |    n_updates            | 2170        |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.59        |
# |    value_loss           | 0.104       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | -73.6    |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 218      |
# |    time_elapsed    | 1644     |
# |    total_timesteps | 1785856  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.09e+03    |
# |    ep_rew_mean          | -71.7       |
# | time/                   |             |
# |    fps                  | 1086        |
# |    iterations           | 219         |
# |    time_elapsed         | 1650        |
# |    total_timesteps      | 1794048     |
# ...
# |    loss                 | 0.0853       |
# |    n_updates            | 3520         |
# |    policy_gradient_loss | -0.00575     |
# |    std                  | 0.536        |
# |    value_loss           | 0.284        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.16e+03     |
# |    ep_rew_mean          | -37.1        |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 354          |
# |    time_elapsed         | 2668         |
# |    total_timesteps      | 2899968      |
# | train/                  |              |
# |    approx_kl            | 0.0036904407 |
# |    clip_fraction        | 0.0138       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.919        |
# |    learning_rate        | 1.08e-05     |
# |    loss                 | 0.0941       |
# |    n_updates            | 3530         |
# |    policy_gradient_loss | -0.00519     |
# |    std                  | 0.536        |
# |    value_loss           | 0.205        |
# ------------------------------------------
# Eval num_timesteps=2900000, episode_reward=-9.82 +/- 45.12
# Episode length: 1197.00 +/- 742.73
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.2e+03     |
# |    mean_reward          | -9.82       |
# | time/                   |             |
# |    total_timesteps      | 2900000     |
# | train/                  |             |
# |    approx_kl            | 0.004885017 |
# |    clip_fraction        | 0.0198      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.933       |
# |    learning_rate        | 1e-05       |
# |    loss                 | 0.0327      |
# |    n_updates            | 3540        |
# |    policy_gradient_loss | -0.00489    |
# |    std                  | 0.536       |
# |    value_loss           | 0.142       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -37      |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 355      |
# |    time_elapsed    | 2679     |
# |    total_timesteps | 2908160  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.21e+03     |
# |    ep_rew_mean          | -36.5        |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 356          |
# |    time_elapsed         | 2684         |
# |    total_timesteps      | 2916352      |
# | train/                  |              |
# |    approx_kl            | 0.0034419545 |
# |    clip_fraction        | 0.0126       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.944        |
# |    learning_rate        | 9.18e-06     |
# |    loss                 | 0.0179       |
# |    n_updates            | 3550         |
# |    policy_gradient_loss | -0.00454     |
# |    std                  | 0.536        |
# |    value_loss           | 0.0831       |
# ------------------------------------------
# Eval num_timesteps=2920000, episode_reward=112.92 +/- 109.40
# Episode length: 1477.80 +/- 664.05
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.48e+03     |
# |    mean_reward          | 113          |
# | time/                   |              |
# |    total_timesteps      | 2920000      |
# | train/                  |              |
# |    approx_kl            | 0.0041348087 |
# |    clip_fraction        | 0.00975      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.921        |
# |    learning_rate        | 8.36e-06     |
# |    loss                 | 0.046        |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -0.00459     |
# |    std                  | 0.536        |
# |    value_loss           | 0.124        |
# ------------------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | -37.5    |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 357      |
# |    time_elapsed    | 2695     |
# |    total_timesteps | 2924544  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.23e+03     |
# |    ep_rew_mean          | -37.5        |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 358          |
# |    time_elapsed         | 2700         |
# |    total_timesteps      | 2932736      |
# | train/                  |              |
# |    approx_kl            | 0.0041139247 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 7.55e-06     |
# |    loss                 | 0.0609       |
# |    n_updates            | 3570         |
# |    policy_gradient_loss | -0.00482     |
# |    std                  | 0.536        |
# |    value_loss           | 0.17         |
# ------------------------------------------
# Eval num_timesteps=2940000, episode_reward=-49.72 +/- 50.95
# Episode length: 802.60 +/- 819.58
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 803          |
# |    mean_reward          | -49.7        |
# | time/                   |              |
# |    total_timesteps      | 2940000      |
# | train/                  |              |
# |    approx_kl            | 0.0025265054 |
# |    clip_fraction        | 0.00308      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.926        |
# |    learning_rate        | 6.73e-06     |
# |    loss                 | 0.0699       |
# |    n_updates            | 3580         |
# |    policy_gradient_loss | -0.00358     |
# |    std                  | 0.536        |
# |    value_loss           | 0.144        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.25e+03 |
# |    ep_rew_mean     | -31.6    |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 359      |
# |    time_elapsed    | 2709     |
# |    total_timesteps | 2940928  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.22e+03     |
# |    ep_rew_mean          | -29          |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 360          |
# |    time_elapsed         | 2714         |
# |    total_timesteps      | 2949120      |
# | train/                  |              |
# |    approx_kl            | 0.0036934186 |
# |    clip_fraction        | 0.00819      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 5.91e-06     |
# |    loss                 | 0.05         |
# |    n_updates            | 3590         |
# |    policy_gradient_loss | -0.0043      |
# |    std                  | 0.536        |
# |    value_loss           | 0.0902       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | -30         |
# | time/                   |             |
# |    fps                  | 1087        |
# |    iterations           | 361         |
# |    time_elapsed         | 2720        |
# |    total_timesteps      | 2957312     |
# | train/                  |             |
# |    approx_kl            | 0.002331928 |
# |    clip_fraction        | 0.00302     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 5.09e-06    |
# |    loss                 | 0.0632      |
# |    n_updates            | 3600        |
# |    policy_gradient_loss | -0.00325    |
# |    std                  | 0.536       |
# |    value_loss           | 0.152       |
# -----------------------------------------
# Eval num_timesteps=2960000, episode_reward=42.63 +/- 108.57
# Episode length: 1351.60 +/- 629.51
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.35e+03     |
# |    mean_reward          | 42.6         |
# | time/                   |              |
# |    total_timesteps      | 2960000      |
# | train/                  |              |
# |    approx_kl            | 0.0016871102 |
# |    clip_fraction        | 0.00145      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.92         |
# |    learning_rate        | 4.27e-06     |
# |    loss                 | 0.0801       |
# |    n_updates            | 3610         |
# |    policy_gradient_loss | -0.00278     |
# |    std                  | 0.536        |
# |    value_loss           | 0.19         |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | -33.8    |
# | time/              |          |
# |    fps             | 1086     |
# |    iterations      | 362      |
# |    time_elapsed    | 2729     |
# |    total_timesteps | 2965504  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.21e+03     |
# |    ep_rew_mean          | -34          |
# | time/                   |              |
# |    fps                  | 1087         |
# |    iterations           | 363          |
# |    time_elapsed         | 2735         |
# |    total_timesteps      | 2973696      |
# | train/                  |              |
# |    approx_kl            | 0.0012059667 |
# |    clip_fraction        | 0.000366     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 3.45e-06     |
# |    loss                 | 0.108        |
# |    n_updates            | 3620         |
# |    policy_gradient_loss | -0.00196     |
# |    std                  | 0.536        |
# |    value_loss           | 0.196        |
# ------------------------------------------
# Eval num_timesteps=2980000, episode_reward=24.07 +/- 54.86
# Episode length: 1372.00 +/- 673.04
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.37e+03    |
# |    mean_reward          | 24.1        |
# | time/                   |             |
# |    total_timesteps      | 2980000     |
# | train/                  |             |
# |    approx_kl            | 0.001168643 |
# |    clip_fraction        | 0.000415    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.17       |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 2.63e-06    |
# |    loss                 | 0.0643      |
# |    n_updates            | 3630        |
# |    policy_gradient_loss | -0.00217    |
# |    std                  | 0.536       |
# |    value_loss           | 0.137       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -34.6    |
# | time/              |          |
# |    fps             | 1085     |
# |    iterations      | 364      |
# |    time_elapsed    | 2746     |
# |    total_timesteps | 2981888  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.19e+03     |
# |    ep_rew_mean          | -32.2        |
# | time/                   |              |
# |    fps                  | 1086         |
# |    iterations           | 365          |
# |    time_elapsed         | 2752         |
# |    total_timesteps      | 2990080      |
# | train/                  |              |
# |    approx_kl            | 0.0006888318 |
# |    clip_fraction        | 0.00011      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 1.81e-06     |
# |    loss                 | 0.0688       |
# |    n_updates            | 3640         |
# |    policy_gradient_loss | -0.00101     |
# |    std                  | 0.536        |
# |    value_loss           | 0.219        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 1.18e+03      |
# |    ep_rew_mean          | -33.4         |
# | time/                   |               |
# |    fps                  | 1087          |
# |    iterations           | 366           |
# |    time_elapsed         | 2758          |
# |    total_timesteps      | 2998272       |
# | train/                  |               |
# |    approx_kl            | 0.00014314748 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -3.17         |
# |    explained_variance   | 0.959         |
# |    learning_rate        | 9.92e-07      |
# |    loss                 | 0.0545        |
# |    n_updates            | 3650          |
# |    policy_gradient_loss | -0.000804     |
# |    std                  | 0.536         |
# |    value_loss           | 0.13          |
# -------------------------------------------
# Eval num_timesteps=3000000, episode_reward=35.97 +/- 127.99
# Episode length: 809.00 +/- 611.24
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 809          |
# |    mean_reward          | 36           |
# | time/                   |              |
# |    total_timesteps      | 3000000      |
# | train/                  |              |
# |    approx_kl            | 3.683046e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.17        |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 1.73e-07     |
# |    loss                 | 0.0767       |
# |    n_updates            | 3660         |
# |    policy_gradient_loss | -0.000167    |
# |    std                  | 0.536        |
# |    value_loss           | 0.135        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -30.4    |
# | time/              |          |
# |    fps             | 1086     |
# |    iterations      | 367      |
# |    time_elapsed    | 2766     |
# |    total_timesteps | 3006464  |
# ---------------------------------
# Training finished.
# --- Recording Video for sota_ppo_v3_1_hardcore ---
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/sota_ppo_v3_1_hardcore/sota_ppo_v3_1_hardcore_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/sota_ppo_v3_1_hardcore/sota_ppo_v3_1_hardcore_agent-step-0-to-step-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/sota_ppo_v3_1_hardcore/sota_ppo_v3_1_hardcore_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
# !pip install sb3-contrib
import gymnasium as gym
import os
import torch.nn as nn
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION (Zoo Tuned) ---
EXPERIMENT_NAME = "tqc_hardcore_zoo_tuned"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- LINEAR SCHEDULE (Matches Zoo 'lin_7.3e-4') ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env():
    env = gym.make(ENV_ID, render_mode="rgb_array")
    env = Monitor(env, log_dir)
    return env

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (Zoo Config) ---")

    env = DummyVecEnv([make_env])

    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=25_000, # TQC is slower per step, check less often
        deterministic=True,
        render=False
    )

    # --- TQC HYPERPARAMETERS (From RL Zoo) ---
    policy_kwargs = dict(
        n_critics=2,
        n_quantiles=25,
        net_arch=[400, 300], # Zoo Architecture
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,

        # Zoo Tuning:
        learning_rate=linear_schedule(7.3e-4), # Matches 'lin_7.3e-4'
        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,              # Faster updates than standard
        train_freq=1,
        gradient_steps=1,
        learning_starts=10_000,
        use_sde=False          # Zoo default is usually False for Hardcore
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=1000)

    model.save(f"{model_dir}/final_model")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    model = TQC.load(best_model_path)

    env = gym.make(ENV_ID, render_mode="rgb_array")
    from stable_baselines3.common.vec_env import DummyVecEnv
    env = DummyVecEnv([lambda: env])

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: stable_baselines3<3.0,>=2.7.0 in /usr/local/lib/python3.12/dist-packages (from sb3-contrib) (2.7.1)
# Requirement already satisfied: gymnasium<1.3.0,>=0.29.1 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3-contrib) (1.2.2)
# Requirement already satisfied: numpy<3.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2.0.2)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2.9.0+cpu)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.1.2)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.10.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium<1.3.0,>=0.29.1->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (0.0.4)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2025.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.7.0->sb3-contrib) (3.0.3)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 5.9 MB/s eta 0:00:00
# Installing collected packages: sb3-contrib
# Successfully installed sb3-contrib-2.7.1
# --- Starting Training: tqc_hardcore_zoo_tuned (Zoo Config) ---
# Using cpu device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_hardcore_zoo_tuned/TQC_1
# Eval num_timesteps=25000, episode_reward=-110.23 +/- 0.23
# Episode length: 48.60 +/- 1.74
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 48.6     |
# |    mean_reward     | -110     |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -7.31    |
# |    critic_loss     | 0.19     |
# |    ent_coef        | 0.00543  |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.000724 |
# |    n_updates       | 14999    |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=50000, episode_reward=-91.57 +/- 15.09
# Episode length: 505.40 +/- 747.62
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 505      |
# |    mean_reward     | -91.6    |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -0.34    |
# |    critic_loss     | 0.0758   |
# |    ent_coef        | 0.00352  |
# |    ent_coef_loss   | -0.215   |
# |    learning_rate   | 0.000718 |
# |    n_updates       | 39999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-1580945835.py in <cell line: 0>()
#     140
#     141 if __name__ == "__main__":
# --> 142     train()
#     143     record_and_show_video()
#
# /tmp/ipython-input-1580945835.py in train()
#      91     )
#      92
# ---> 93     model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=1000)
#      94
#      95     model.save(f"{model_dir}/final_model")
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/tqc.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305         progress_bar: bool = False,
#     306     ) -> SelfTQC:
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     352                 # Special case when the user passes `gradient_steps=0`
#     353                 if gradient_steps > 0:
# --> 354                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     355
#     356         callback.on_training_end()
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/tqc.py in train(self, gradient_steps, batch_size)
#     247                 # Compute and cut quantiles at the next state
#     248                 # batch x nets x quantiles
# --> 249                 next_quantiles = self.critic_target(replay_data.next_observations, next_actions)
#     250
#     251                 # Sort and drop top k quantiles to control overestimation.
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/policies.py in forward(self, obs, action)
#     238             features = self.extract_features(obs, self.features_extractor)
#     239         qvalue_input = th.cat([features, action], dim=1)
# --> 240         quantiles = th.stack(tuple(qf(qvalue_input) for qf in self.q_networks), dim=1)
#     241         return quantiles
#     242
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/policies.py in <genexpr>(.0)
#     238             features = self.extract_features(obs, self.features_extractor)
#     239         qvalue_input = th.cat([features, action], dim=1)
# --> 240         quantiles = th.stack(tuple(qf(qvalue_input) for qf in self.q_networks), dim=1)
#     241         return quantiles
#     242
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/container.py in forward(self, input)
#     248         """
#     249         for module in self:
# --> 250             input = module(input)
#     251         return input
#     252
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1773             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774         else:
# -> 1775             return self._call_impl(*args, **kwargs)
#    1776
#    1777     # torchrec tests the code consistency with the following code
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1784                 or _global_backward_pre_hooks or _global_backward_hooks
#    1785                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786             return forward_call(*args, **kwargs)
#    1787
#    1788         result = None
#
# /usr/local/lib/python3.12/dist-packages/torch/nn/modules/linear.py in forward(self, input)
#     132         Runs the forward pass.
#     133         """
# --> 134         return F.linear(input, self.weight, self.bias)
#     135
#     136     def extra_repr(self) -> str:
#
# KeyboardInterrupt:

# %%
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib
import gymnasium as gym
import os
import torch.nn as nn
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import DummyVecEnv, VecVideoRecorder
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION (Zoo Tuned + GPU) ---
EXPERIMENT_NAME = "tqc_hardcore_zoo_tuned_gpu" # <--- New name to avoid conflicts
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env():
    env = gym.make(ENV_ID, render_mode="rgb_array")
    env = Monitor(env, log_dir)
    return env

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (GPU Powered) ---")
    print(f"Logs will be saved to: {log_dir}")

    # Check if GPU is available
    import torch
    if torch.cuda.is_available():
        print(f"SUCCESS: Training on {torch.cuda.get_device_name(0)}")
    else:
        print("WARNING: GPU not detected. Go to Runtime > Change runtime type > T4 GPU")

    env = DummyVecEnv([make_env])

    eval_callback = EvalCallback(
        env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=25_000,
        deterministic=True,
        render=False
    )

    # --- TQC HYPERPARAMETERS (Zoo) ---
    policy_kwargs = dict(
        n_critics=2,
        n_quantiles=25,
        net_arch=[400, 300],
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,

        # Zoo Tuning:
        learning_rate=linear_schedule(7.3e-4),
        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,
        train_freq=1,
        gradient_steps=1,
        learning_starts=10_000,
        use_sde=False
    )

    # Lowered log_interval to 100 so you see updates faster
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    model = TQC.load(best_model_path)

    env = gym.make(ENV_ID, render_mode="rgb_array")
    from stable_baselines3.common.vec_env import DummyVecEnv
    env = DummyVecEnv([lambda: env])

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 1s (900 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 43.7 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 16.7 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 8.2 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381960 sha256=6eb0842bba21b6d88df179e0bdb7af0d7806dfdace6931b595578b4f8b0f9a8a
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3, sb3-contrib
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 sb3-contrib-2.7.1 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Starting Training: tqc_hardcore_zoo_tuned_gpu (GPU Powered) ---
# Logs will be saved to: /content/drive/MyDrive/aisf_project/logs/tqc_hardcore_zoo_tuned_gpu
# SUCCESS: Training on Tesla T4
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# Using cuda device
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_hardcore_zoo_tuned_gpu/TQC_1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Eval num_timesteps=25000, episode_reward=-89.88 +/- 31.15
# Episode length: 1703.60 +/- 592.80
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.7e+03  |
# |    mean_reward     | -89.9    |
# | time/              |          |
# |    total_timesteps | 25000    |
# | train/             |          |
# |    actor_loss      | -6.2     |
# |    critic_loss     | 0.237    |
# |    ent_coef        | 0.00544  |
# |    ent_coef_loss   | -1.98    |
# |    learning_rate   | 0.000724 |
# |    n_updates       | 14999    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 461      |
# |    ep_rew_mean     | -110     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 99       |
# |    time_elapsed    | 483      |
# |    total_timesteps | 47892    |
# | train/             |          |
# |    actor_loss      | -3.37    |
# |    critic_loss     | 0.218    |
# |    ent_coef        | 0.00783  |
# |    ent_coef_loss   | 0.126    |
# |    learning_rate   | 0.000718 |
# |    n_updates       | 37891    |
# ---------------------------------
# Eval num_timesteps=50000, episode_reward=-114.64 +/- 1.11
# Episode length: 70.80 +/- 8.45
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 70.8     |
# |    mean_reward     | -115     |
# | time/              |          |
# |    total_timesteps | 50000    |
# | train/             |          |
# |    actor_loss      | -4.33    |
# |    critic_loss     | 0.217    |
# |    ent_coef        | 0.0059   |
# |    ent_coef_loss   | 2.23     |
# |    learning_rate   | 0.000718 |
# |    n_updates       | 39999    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3958550267.py in <cell line: 0>()
#     150
#     151 if __name__ == "__main__":
# --> 152     train()
#     153     record_and_show_video()
#
# /tmp/ipython-input-3958550267.py in train()
#     101
#     102     # Lowered log_interval to 100 so you see updates faster
# --> 103     model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)
#     104
#     105     model.save(f"{model_dir}/final_model")
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/tqc.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305         progress_bar: bool = False,
#     306     ) -> SelfTQC:
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     352                 # Special case when the user passes `gradient_steps=0`
#     353                 if gradient_steps > 0:
# --> 354                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     355
#     356         callback.on_training_end()
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/tqc.py in train(self, gradient_steps, batch_size)
#     278             # Optimize the actor
#     279             self.actor.optimizer.zero_grad()
# --> 280             actor_loss.backward()
#     281             self.actor.optimizer.step()
#     282
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     623                 inputs=inputs,
#     624             )
# --> 625         torch.autograd.backward(
#     626             self, gradient, retain_graph, create_graph, inputs=inputs
#     627         )
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     352     # some Python versions print out the first line of a multi-line function
#     353     # calls in the traceback and some print out the last line
# --> 354     _engine_run_backward(
#     355         tensors,
#     356         grad_tensors_,
#
# /usr/local/lib/python3.12/dist-packages/torch/autograd/graph.py in _engine_run_backward(t_outputs, *args, **kwargs)
#     839         unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     840     try:
# --> 841         return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     842             t_outputs, *args, **kwargs
#     843         )  # Calls into the C++ engine to run the backward pass
#
# KeyboardInterrupt:

# %%
# Install dependencies
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import torch
import numpy as np
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION (The "Ultimate" Hybrid) ---
EXPERIMENT_NAME = "tqc_hardcore_ultimate"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
NUM_CPU = 4  # Matches your fast code
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- LINEAR SCHEDULE (Zoo Trick) ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = Monitor(env, log_dir)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} ---")
    print(f"Hardware: {'GPU' if torch.cuda.is_available() else 'CPU'}")

    # 1. PARALLELISM (Speed)
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # 2. SEPARATE EVAL ENV (Accuracy)
    eval_env = SubprocVecEnv([make_env(999, SEED)])
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # 3. ZOO HYPERPARAMETERS (Intelligence)
    # These specific numbers are from the RL Zoo benchmark for Hardcore
    policy_kwargs = dict(
        n_critics=2,
        n_quantiles=25,
        net_arch=[400, 300], # Bigger network than your previous run
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,

        # --- The Hybrid Optimization ---
        # 1. High LR (from Zoo)
        learning_rate=linear_schedule(7.3e-4),

        # 2. Batched Updates (from your Fast Code)
        # This is CRITICAL for speed. Do not change this to 1.
        train_freq=64,
        gradient_steps=64,

        # 3. Forced Entropy (Inspired by your code)
        # "auto_0.05" is technically "auto" with init value 0.05.
        # Standard "auto" is safer for TQC, but we rely on the high LR here.
        ent_coef="auto",

        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01, # Faster target updates (Zoo style)
        use_sde=False
    )

    # 4. TRAIN (With frequent logs)
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=50)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    # Fallback to final model if best not saved yet
    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    # Recreate Eval Environment
    # We use DummyVecEnv for video recording compatibility
    env = SubprocVecEnv([make_env(0, SEED)])
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("WARNING: Normalization stats not found. Video agent will likely fail.")

    model = TQC.load(best_model_path)

    # Use VecVideoRecorder
    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    # Depending on SB3 version, VecEnv reset returns only obs
    # but Gymnasium returns (obs, info). SB3 wrappers usually handle this.
    # If using VecEnv, done is a boolean array.

    # Run simulation
    step_count = 0
    while step_count < 2000:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, dones, _ = video_env.step(action)
        step_count += 1
        if any(dones):
             break

    video_env.close()

    # Display
    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (481 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 31.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 97.4 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 17.4 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 10.2 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381958 sha256=93e59ad679f52ed9bfa7dbfc9fc5f09bd586dff5cdc30cbf0c956cb8c85df53b
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3, sb3-contrib
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 sb3-contrib-2.7.1 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Starting Training: tqc_hardcore_ultimate ---
# Hardware: GPU
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_hardcore_ultimate/TQC_1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 444      |
# |    ep_rew_mean     | -121     |
# | time/              |          |
# |    episodes        | 50       |
# |    fps             | 302      |
# |    time_elapsed    | 87       |
# |    total_timesteps | 26400    |
# | train/             |          |
# |    actor_loss      | -18.1    |
# |    critic_loss     | 0.0332   |
# |    ent_coef        | 0.0111   |
# |    ent_coef_loss   | -16.6    |
# |    learning_rate   | 0.000724 |
# |    n_updates       | 6592     |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 409      |
# |    ep_rew_mean     | -123     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 304      |
# |    time_elapsed    | 135      |
# |    total_timesteps | 41348    |
# | train/             |          |
# |    actor_loss      | -12.1    |
# |    critic_loss     | 0.0321   |
# |    ent_coef        | 0.00329  |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.00072  |
# |    n_updates       | 10304    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 534      |
# |    ep_rew_mean     | -127     |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 304      |
# |    time_elapsed    | 255      |
# |    total_timesteps | 77748    |
# | train/             |          |
# |    actor_loss      | -4.55    |
# |    critic_loss     | 0.0104   |
# |    ent_coef        | 0.00112  |
# |    ent_coef_loss   | -0.229   |
# |    learning_rate   | 0.000711 |
# |    n_updates       | 19392    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 839      |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 304      |
# |    time_elapsed    | 416      |
# |    total_timesteps | 126992   |
# | train/             |          |
# |    actor_loss      | -0.756   |
# |    critic_loss     | 0.00426  |
# |    ent_coef        | 0.000532 |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.000699 |
# |    n_updates       | 31744    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 912      |
# |    ep_rew_mean     | -102     |
# | time/              |          |
# |    episodes        | 250      |
# |    fps             | 305      |
# |    time_elapsed    | 549      |
# |    total_timesteps | 167828   |
# | train/             |          |
# |    actor_loss      | 0.0598   |
# |    critic_loss     | 0.0042   |
# |    ent_coef        | 0.000482 |
# |    ent_coef_loss   | -0.92    |
# |    learning_rate   | 0.000689 |
# |    n_updates       | 41920    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 697      |
# |    ep_rew_mean     | -96.9    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 305      |
# |    time_elapsed    | 643      |
# |    total_timesteps | 196756   |
# | train/             |          |
# |    actor_loss      | 0.214    |
# |    critic_loss     | 0.0048   |
# |    ent_coef        | 0.000605 |
# |    ent_coef_loss   | -0.802   |
# |    learning_rate   | 0.000682 |
# |    n_updates       | 49152    |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=-96.45 +/- 25.83
# Episode length: 2000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2e+03    |
# |    mean_reward     | -96.5    |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 0.227    |
# |    critic_loss     | 0.004    |
# |    ent_coef        | 0.000572 |
# |    ent_coef_loss   | -0.342   |
# |    learning_rate   | 0.000681 |
# |    n_updates       | 49984    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 698      |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    episodes        | 350      |
# |    fps             | 300      |
# |    time_elapsed    | 795      |
# |    total_timesteps | 238748   |
# | train/             |          |
# |    actor_loss      | 0.337    |
# |    critic_loss     | 0.00432  |
# |    ent_coef        | 0.000559 |
# |    ent_coef_loss   | -0.206   |
# |    learning_rate   | 0.000672 |
# |    n_updates       | 59648    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 806      |
# |    ep_rew_mean     | -84.4    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 301      |
# |    time_elapsed    | 915      |
# |    total_timesteps | 275736   |
# | train/             |          |
# |    actor_loss      | 0.385    |
# |    critic_loss     | 0.00436  |
# |    ent_coef        | 0.000576 |
# |    ent_coef_loss   | 0.042    |
# |    learning_rate   | 0.000663 |
# |    n_updates       | 68928    |
# ---------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-2858220971.py in <cell line: 0>()
#     189
#     190 if __name__ == "__main__":
# --> 191     train()
#     192     record_and_show_video()
#
# /tmp/ipython-input-2858220971.py in train()
#     119
#     120     # 4. TRAIN (With frequent logs)
# --> 121     model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=50)
#     122
#     123     model.save(f"{model_dir}/final_model")
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/tqc.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     305         progress_bar: bool = False,
#     306     ) -> SelfTQC:
# --> 307         return super().learn(
#     308             total_timesteps=total_timesteps,
#     309             callback=callback,
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/off_policy_algorithm.py in learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     352                 # Special case when the user passes `gradient_steps=0`
#     353                 if gradient_steps > 0:
# --> 354                     self.train(batch_size=self.batch_size, gradient_steps=gradient_steps)
#     355
#     356         callback.on_training_end()
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/tqc.py in train(self, gradient_steps, batch_size)
#     219
#     220             # Action by the current actor for the sampled state
# --> 221             actions_pi, log_prob = self.actor.action_log_prob(replay_data.observations)
#     222             log_prob = log_prob.reshape(-1, 1)
#     223
#
# /usr/local/lib/python3.12/dist-packages/sb3_contrib/tqc/policies.py in action_log_prob(self, obs)
#     172         mean_actions, log_std, kwargs = self.get_action_dist_params(obs)
#     173         # return action and associated log prob
# --> 174         return self.action_dist.log_prob_from_params(mean_actions, log_std, **kwargs)
#     175
#     176     def _predict(self, observation: PyTorchObs, deterministic: bool = False) -> th.Tensor:
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/distributions.py in log_prob_from_params(self, mean_actions, log_std)
#     257     def log_prob_from_params(self, mean_actions: th.Tensor, log_std: th.Tensor) -> tuple[th.Tensor, th.Tensor]:
#     258         action = self.actions_from_params(mean_actions, log_std)
# --> 259         log_prob = self.log_prob(action, self.gaussian_actions)
#     260         return action, log_prob
#     261
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/distributions.py in log_prob(self, actions, gaussian_actions)
#     234
#     235         # Log likelihood for a Gaussian distribution
# --> 236         log_prob = super().log_prob(gaussian_actions)
#     237         # Squash correction (from original SAC implementation)
#     238         # this comes from the fact that tanh is bijective and differentiable
#
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/distributions.py in log_prob(self, actions)
#     173         :return:
#     174         """
# --> 175         log_prob = self.distribution.log_prob(actions)
#     176         return sum_independent_dims(log_prob)
#     177
#
# /usr/local/lib/python3.12/dist-packages/torch/distributions/normal.py in log_prob(self, value)
#      89             self._validate_sample(value)
#      90         # compute the variance
# ---> 91         var = self.scale**2
#      92         log_scale = (
#      93             math.log(self.scale)
#
# /usr/local/lib/python3.12/dist-packages/torch/_tensor.py in wrapped(self, *args, **kwargs)
#      36     f: Callable[Concatenate[_TensorLike, _P], "Tensor"],
#      37 ) -> Callable[Concatenate[_TensorLike, _P], "Tensor"]:
# ---> 38     @functools.wraps(f)
#      39     def wrapped(self: _TensorLike, *args: _P.args, **kwargs: _P.kwargs) -> "Tensor":
#      40         try:
#
# KeyboardInterrupt:

# %%
import warnings
# Ignore all DeprecationWarnings so the logs are clean
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
# Install dependencies if you restarted the runtime
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import torch
import numpy as np
import base64
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# CHANGED: Updated version number to v3 to prevent conflict
EXPERIMENT_NAME = "tqc_v3_hardcore"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
SEED = 42
NUM_CPU = 4  # Keep 4 CPUs for data collection speed

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

# --- ENVIRONMENT MAKER ---
def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = Monitor(env, log_dir)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (Balanced Mode) ---")

    # 1. PARALLEL ENVIRONMENTS (Speed)
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])

    # 2. NORMALIZATION (Stability for Hardcore)
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # Eval Env
    eval_env = SubprocVecEnv([make_env(999, SEED)])
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # --- TQC v2 CONFIGURATION ---
    policy_kwargs = dict(
        n_critics=2,            # Kept at 2 for SPEED
        n_quantiles=25,         # 25 Atoms
        net_arch=[400, 300],    # Zoo Architecture (Stronger than 256, faster than 512)
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2, # Drop top 2 atoms per critic (Safety)
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,

        # --- TUNING ---
        learning_rate=linear_schedule(7.3e-4), # Fast Zoo Learning Rate
        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,

        # --- SPEED & SAFETY ---
        train_freq=64,         # Batched Collection (Fast CPU)
        gradient_steps=64,     # Batched Updates (Fast GPU)
        learning_starts=10_000,
        use_sde=False          # Standard noise for reactivity
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    # Use DummyVecEnv for recording (Compatibility)
    env = DummyVecEnv([make_env(0, SEED)])

    # Load Stats
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = TQC.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)
        # Fix for vector environment returning array of dones
        if isinstance(done, (list, np.ndarray)):
             done = done[0]

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# --- Starting Training: tqc_v3_hardcore (Balanced Mode) ---
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore/TQC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 334      |
# |    time_elapsed    | 312      |
# |    total_timesteps | 104392   |
# | train/             |          |
# |    actor_loss      | -2.97    |
# |    critic_loss     | 0.00307  |
# |    ent_coef        | 0.000429 |
# |    ent_coef_loss   | 0.214    |
# |    learning_rate   | 0.000705 |
# |    n_updates       | 23552    |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=-54.71 +/- 25.32
# Episode length: 1638.20 +/- 723.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.64e+03 |
# |    mean_reward     | -54.7    |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 0.355    |
# |    critic_loss     | 0.00193  |
# |    ent_coef        | 0.000427 |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.000681 |
# |    n_updates       | 47488    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -92.3    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 310      |
# |    time_elapsed    | 721      |
# |    total_timesteps | 224020   |
# | train/             |          |
# |    actor_loss      | 0.441    |
# |    critic_loss     | 0.00229  |
# |    ent_coef        | 0.00036  |
# |    ent_coef_loss   | 0.451    |
# |    learning_rate   | 0.000675 |
# |    n_updates       | 53504    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 893      |
# |    ep_rew_mean     | -89.4    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 308      |
# |    time_elapsed    | 1011     |
# |    total_timesteps | 311508   |
# | train/             |          |
# |    actor_loss      | 0.44     |
# |    critic_loss     | 0.00247  |
# |    ent_coef        | 0.000479 |
# |    ent_coef_loss   | 0.541    |
# |    learning_rate   | 0.000654 |
# |    n_updates       | 75328    |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=-83.07 +/- 34.88
# Episode length: 1637.00 +/- 726.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.64e+03 |
# |    mean_reward     | -83.1    |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 0.457    |
# |    critic_loss     | 0.00313  |
# |    ent_coef        | 0.000529 |
# |    ent_coef_loss   | 0.111    |
# |    learning_rate   | 0.000633 |
# |    n_updates       | 97472    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 304      |
# |    time_elapsed    | 1340     |
# |    total_timesteps | 407536   |
# | train/             |          |
# |    actor_loss      | 0.449    |
# |    critic_loss     | 0.00348  |
# |    ent_coef        | 0.000553 |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.000631 |
# |    n_updates       | 99328    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -72.8    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 303      |
# |    time_elapsed    | 1687     |
# |    total_timesteps | 512356   |
# | train/             |          |
# |    actor_loss      | 0.362    |
# |    critic_loss     | 0.0032   |
# |    ent_coef        | 0.000537 |
# |    ent_coef_loss   | -0.388   |
# |    learning_rate   | 0.000605 |
# |    n_updates       | 125568   |
# ---------------------------------
# Eval num_timesteps=600000, episode_reward=-29.18 +/- 93.74
# Episode length: 1694.40 +/- 611.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.69e+03 |
# |    mean_reward     | -29.2    |
# | time/              |          |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | 0.328    |
# |    critic_loss     | 0.00321  |
# |    ent_coef        | 0.000528 |
# |    ent_coef_loss   | 0.717    |
# |    learning_rate   | 0.000584 |
# |    n_updates       | 147456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -63.7    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 301      |
# |    time_elapsed    | 2036     |
# |    total_timesteps | 614196   |
# | train/             |          |
# |    actor_loss      | 0.328    |
# |    critic_loss     | 0.00305  |
# |    ent_coef        | 0.000577 |
# |    ent_coef_loss   | 0.584    |
# |    learning_rate   | 0.000581 |
# |    n_updates       | 151040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | -34.5    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 301      |
# |    time_elapsed    | 2471     |
# |    total_timesteps | 745500   |
# | train/             |          |
# |    actor_loss      | 0.163    |
# |    critic_loss     | 0.00312  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | -0.591   |
# |    learning_rate   | 0.000549 |
# |    n_updates       | 183872   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=-12.70 +/- 71.57
# Episode length: 1263.80 +/- 546.88
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.26e+03 |
# |    mean_reward     | -12.7    |
# | time/              |          |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | 0.191    |
# |    critic_loss     | 0.00315  |
# |    ent_coef        | 0.000596 |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.000535 |
# |    n_updates       | 197440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | -14.8    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 300      |
# |    time_elapsed    | 2946     |
# |    total_timesteps | 886188   |
# | train/             |          |
# |    actor_loss      | 0.102    |
# |    critic_loss     | 0.00328  |
# |    ent_coef        | 0.000639 |
# |    ent_coef_loss   | -0.0696  |
# |    learning_rate   | 0.000514 |
# |    n_updates       | 219008   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=3.87 +/- 53.28
# Episode length: 1423.80 +/- 730.19
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.42e+03 |
# |    mean_reward     | 3.87     |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 0.145    |
# |    critic_loss     | 0.0036   |
# |    ent_coef        | 0.000591 |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.000487 |
# |    n_updates       | 247488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 300      |
# |    time_elapsed    | 3387     |
# |    total_timesteps | 1016336  |
# | train/             |          |
# |    actor_loss      | 0.136    |
# |    critic_loss     | 0.00357  |
# |    ent_coef        | 0.00063  |
# |    ent_coef_loss   | 0.395    |
# |    learning_rate   | 0.000483 |
# |    n_updates       | 251584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 300      |
# |    time_elapsed    | 3849     |
# |    total_timesteps | 1155560  |
# | train/             |          |
# |    actor_loss      | 0.00398  |
# |    critic_loss     | 0.00358  |
# |    ent_coef        | 0.000679 |
# |    ent_coef_loss   | 0.672    |
# |    learning_rate   | 0.000449 |
# |    n_updates       | 286336   |
# ---------------------------------
# Eval num_timesteps=1200000, episode_reward=-60.24 +/- 100.28
# Episode length: 2000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2e+03    |
# |    mean_reward     | -60.2    |
# | time/              |          |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -0.0412  |
# |    critic_loss     | 0.00392  |
# |    ent_coef        | 0.000761 |
# |    ent_coef_loss   | 0.452    |
# |    learning_rate   | 0.000438 |
# |    n_updates       | 297472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | 53       |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 299      |
# |    time_elapsed    | 4359     |
# |    total_timesteps | 1304712  |
# | train/             |          |
# |    actor_loss      | -0.158   |
# |    critic_loss     | 0.0029   |
# |    ent_coef        | 0.000722 |
# |    ent_coef_loss   | -0.563   |
# |    learning_rate   | 0.000413 |
# |    n_updates       | 323648   |
# ---------------------------------
# Eval num_timesteps=1400000, episode_reward=53.22 +/- 149.74
# Episode length: 1523.20 +/- 685.94
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.52e+03 |
# |    mean_reward     | 53.2     |
# | time/              |          |
# |    total_timesteps | 1400000  |
# | train/             |          |
# |    actor_loss      | -0.203   |
# |    critic_loss     | 0.00269  |
# |    ent_coef        | 0.000698 |
# |    ent_coef_loss   | -0.0448  |
# |    learning_rate   | 0.000389 |
# |    n_updates       | 347456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.57e+03 |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 298      |
# |    time_elapsed    | 4886     |
# |    total_timesteps | 1460708  |
# | train/             |          |
# |    actor_loss      | -0.218   |
# |    critic_loss     | 0.00255  |
# |    ent_coef        | 0.000668 |
# |    ent_coef_loss   | 0.0742   |
# |    learning_rate   | 0.000375 |
# |    n_updates       | 362624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | 94.5     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 299      |
# |    time_elapsed    | 5338     |
# |    total_timesteps | 1597472  |
# | train/             |          |
# |    actor_loss      | -0.318   |
# |    critic_loss     | 0.00251  |
# |    ent_coef        | 0.000611 |
# |    ent_coef_loss   | 0.196    |
# |    learning_rate   | 0.000341 |
# |    n_updates       | 396864   |
# ---------------------------------
# Eval num_timesteps=1600000, episode_reward=85.80 +/- 62.95
# Episode length: 1750.80 +/- 498.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.75e+03 |
# |    mean_reward     | 85.8     |
# | time/              |          |
# |    total_timesteps | 1600000  |
# | train/             |          |
# |    actor_loss      | -0.328   |
# |    critic_loss     | 0.00218  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | -0.0693  |
# |    learning_rate   | 0.000341 |
# |    n_updates       | 397440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 68.9     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 298      |
# |    time_elapsed    | 5795     |
# |    total_timesteps | 1732208  |
# | train/             |          |
# |    actor_loss      | -0.345   |
# |    critic_loss     | 0.00207  |
# |    ent_coef        | 0.000579 |
# |    ent_coef_loss   | 0.289    |
# |    learning_rate   | 0.000309 |
# |    n_updates       | 430528   |
# ---------------------------------
# Eval num_timesteps=1800000, episode_reward=79.96 +/- 153.97
# Episode length: 1080.60 +/- 659.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.08e+03 |
# |    mean_reward     | 80       |
# | time/              |          |
# |    total_timesteps | 1800000  |
# | train/             |          |
# |    actor_loss      | -0.379   |
# |    critic_loss     | 0.00218  |
# |    ent_coef        | 0.000545 |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.000292 |
# |    n_updates       | 447488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 298      |
# |    time_elapsed    | 6260     |
# |    total_timesteps | 1870456  |
# | train/             |          |
# |    actor_loss      | -0.439   |
# |    critic_loss     | 0.00195  |
# |    ent_coef        | 0.000555 |
# |    ent_coef_loss   | -0.277   |
# |    learning_rate   | 0.000275 |
# |    n_updates       | 465088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 299      |
# |    time_elapsed    | 6662     |
# |    total_timesteps | 1992176  |
# | train/             |          |
# |    actor_loss      | -0.5     |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000579 |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.000245 |
# |    n_updates       | 495488   |
# ---------------------------------
# Eval num_timesteps=2000000, episode_reward=106.80 +/- 134.72
# Episode length: 1481.80 +/- 425.18
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.48e+03 |
# |    mean_reward     | 107      |
# | time/              |          |
# |    total_timesteps | 2000000  |
# | train/             |          |
# |    actor_loss      | -0.472   |
# |    critic_loss     | 0.00196  |
# |    ent_coef        | 0.00059  |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.000243 |
# |    n_updates       | 497472   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 298      |
# |    time_elapsed    | 7107     |
# |    total_timesteps | 2123804  |
# | train/             |          |
# |    actor_loss      | -0.523   |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000581 |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.000213 |
# |    n_updates       | 528448   |
# ---------------------------------
# Eval num_timesteps=2200000, episode_reward=147.82 +/- 116.46
# Episode length: 1439.40 +/- 534.55
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.44e+03 |
# |    mean_reward     | 148      |
# | time/              |          |
# |    total_timesteps | 2200000  |
# | train/             |          |
# |    actor_loss      | -0.522   |
# |    critic_loss     | 0.00162  |
# |    ent_coef        | 0.000569 |
# |    ent_coef_loss   | -0.677   |
# |    learning_rate   | 0.000195 |
# |    n_updates       | 547456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 298      |
# |    time_elapsed    | 7594     |
# |    total_timesteps | 2268268  |
# | train/             |          |
# |    actor_loss      | -0.535   |
# |    critic_loss     | 0.00164  |
# |    ent_coef        | 0.00056  |
# |    ent_coef_loss   | 0.33     |
# |    learning_rate   | 0.000178 |
# |    n_updates       | 564544   |
# ---------------------------------
# Eval num_timesteps=2400000, episode_reward=137.00 +/- 158.27
# Episode length: 968.40 +/- 494.07
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 968      |
# |    mean_reward     | 137      |
# | time/              |          |
# |    total_timesteps | 2400000  |
# | train/             |          |
# |    actor_loss      | -0.593   |
# |    critic_loss     | 0.00156  |
# |    ent_coef        | 0.000596 |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.000146 |
# |    n_updates       | 597440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 298      |
# |    time_elapsed    | 8069     |
# |    total_timesteps | 2409904  |
# | train/             |          |
# |    actor_loss      | -0.61    |
# |    critic_loss     | 0.00145  |
# |    ent_coef        | 0.000586 |
# |    ent_coef_loss   | -0.491   |
# |    learning_rate   | 0.000144 |
# |    n_updates       | 599936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 298      |
# |    time_elapsed    | 8484     |
# |    total_timesteps | 2535380  |
# | train/             |          |
# |    actor_loss      | -0.595   |
# |    critic_loss     | 0.00178  |
# |    ent_coef        | 0.000591 |
# |    ent_coef_loss   | 0.429    |
# |    learning_rate   | 0.000113 |
# |    n_updates       | 631296   |
# ---------------------------------
# Eval num_timesteps=2600000, episode_reward=260.89 +/- 20.78
# Episode length: 1406.80 +/- 297.13
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.41e+03 |
# |    mean_reward     | 261      |
# | time/              |          |
# |    total_timesteps | 2600000  |
# | train/             |          |
# |    actor_loss      | -0.61    |
# |    critic_loss     | 0.00146  |
# |    ent_coef        | 0.000585 |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 9.73e-05 |
# |    n_updates       | 647488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 298      |
# |    time_elapsed    | 8929     |
# |    total_timesteps | 2667264  |
# | train/             |          |
# |    actor_loss      | -0.615   |
# |    critic_loss     | 0.00135  |
# |    ent_coef        | 0.000567 |
# |    ent_coef_loss   | -0.337   |
# |    learning_rate   | 8.1e-05  |
# |    n_updates       | 664256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 298      |
# |    time_elapsed    | 9367     |
# |    total_timesteps | 2799820  |
# | train/             |          |
# |    actor_loss      | -0.666   |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.000608 |
# |    ent_coef_loss   | -0.485   |
# |    learning_rate   | 4.88e-05 |
# |    n_updates       | 697408   |
# ---------------------------------
# Eval num_timesteps=2800000, episode_reward=274.19 +/- 5.11
# Episode length: 1223.60 +/- 66.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.22e+03 |
# |    mean_reward     | 274      |
# | time/              |          |
# |    total_timesteps | 2800000  |
# | train/             |          |
# |    actor_loss      | -0.654   |
# |    critic_loss     | 0.00132  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 4.87e-05 |
# |    n_updates       | 697472   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 298      |
# |    time_elapsed    | 9770     |
# |    total_timesteps | 2920612  |
# | train/             |          |
# |    actor_loss      | -0.613   |
# |    critic_loss     | 0.00163  |
# |    ent_coef        | 0.000591 |
# |    ent_coef_loss   | -0.267   |
# |    learning_rate   | 1.94e-05 |
# |    n_updates       | 727616   |
# ---------------------------------
# Eval num_timesteps=3000000, episode_reward=226.37 +/- 70.59
# Episode length: 1363.20 +/- 328.58
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.36e+03 |
# |    mean_reward     | 226      |
# | time/              |          |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -0.559   |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 0.000593 |
# |    ent_coef_loss   | -0.0149  |
# |    learning_rate   | 4.67e-08 |
# |    n_updates       | 747456   |
# ---------------------------------
# Training finished.
# --- Recording Video for tqc_v3_hardcore ---
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore/tqc_v3_hardcore_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore/tqc_v3_hardcore_agent-step-0-to-step-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore/tqc_v3_hardcore_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib
import gymnasium as gym
import os
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# We use a new name to keep the logs separate, but we LOAD the old model
LOAD_FROM_EXPERIMENT = "tqc_v3_hardcore"
EXPERIMENT_NAME = "tqc_v3_hardcore_finetune"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 2_000_000  # 2M extra steps to polish the score
NUM_CPU = 4

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"
load_model_path = f"{base_path}/models/{LOAD_FROM_EXPERIMENT}/best_model.zip"
load_stats_path = f"{base_path}/models/{LOAD_FROM_EXPERIMENT}/vec_normalize.pkl"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = Monitor(env, log_dir)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Resuming Training: {EXPERIMENT_NAME} ---")

    # 1. Setup Environment
    env = SubprocVecEnv([make_env(i, 42) for i in range(NUM_CPU)])

    # 2. Load Normalization Stats (CRITICAL)
    # We must start with the stats (mean/std) the agent learned previously
    print(f"Loading normalization stats from: {load_stats_path}")
    env = VecNormalize.load(load_stats_path, env)
    env.training = True # Keep updating stats
    env.norm_reward = True

    # 3. Setup Eval
    eval_env = SubprocVecEnv([make_env(999, 42)])
    eval_env = VecNormalize.load(load_stats_path, eval_env)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=25_000,
        deterministic=True,
        render=False
    )

    # 4. Load the Pre-Trained Model
    print(f"Loading model from: {load_model_path}")
    # custom_objects argument lets us overwrite the learning rate!
    # We set it to a constant low value (5e-5) to fine-tune.
    model = TQC.load(
        load_model_path,
        env=env,
        custom_objects={"learning_rate": 5e-5, "learning_starts": 0},
        print_system_info=True
    )

    # 5. Train
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Fine-tuning finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Final Video ---")

    # Load Best Model from the NEW finetune folder
    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    model = TQC.load(best_model_path)

    # Video Env
    env = DummyVecEnv([make_env(0, 42)])
    env = VecNormalize.load(stats_path, env)
    env.training = False
    env.norm_reward = False

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2500, # Longer video to catch the win
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (538 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 27.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 97.4 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 20.8 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 11.7 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381958 sha256=588b51460f6e349f4cfd45741b2a39f8130e52bab0f468eb4c555ab7747cd30a
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3, sb3-contrib
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 sb3-contrib-2.7.1 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Mounted at /content/drive
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Resuming Training: tqc_v3_hardcore_finetune ---
# Loading normalization stats from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore/vec_normalize.pkl
# Loading model from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore/best_model.zip
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.6.105+-x86_64-with-glibc2.35 # 1 SMP Thu Oct  2 10:42:05 UTC 2025
# - Python: 3.12.12
# - Stable-Baselines3: 2.7.1
# - PyTorch: 2.9.0+cu126
# - GPU Enabled: True
# - Numpy: 2.0.2
# - Cloudpickle: 3.1.2
# - Gymnasium: 1.2.2
# - OpenAI Gym: 0.25.2
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.6.105+-x86_64-with-glibc2.35 # 1 SMP Thu Oct  2 10:42:05 UTC 2025
# - Python: 3.12.12
# - Stable-Baselines3: 2.7.1
# - PyTorch: 2.9.0+cu126
# - GPU Enabled: True
# - Numpy: 2.0.2
# - Cloudpickle: 3.1.2
# - Gymnasium: 1.2.2
# - OpenAI Gym: 0.25.2
#
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore/TQC_2
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Eval num_timesteps=100000, episode_reward=111.91 +/- 160.77
# Episode length: 1020.20 +/- 662.51
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.02e+03 |
# |    mean_reward     | 112      |
# | time/              |          |
# |    total_timesteps | 100000   |
# | train/             |          |
# |    actor_loss      | -0.587   |
# |    critic_loss     | 0.00157  |
# |    ent_coef        | 0.000904 |
# |    ent_coef_loss   | 0.136    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 722432   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 288      |
# |    time_elapsed    | 408      |
# |    total_timesteps | 117692   |
# | train/             |          |
# |    actor_loss      | -0.565   |
# |    critic_loss     | 0.00185  |
# |    ent_coef        | 0.000934 |
# |    ent_coef_loss   | 0.0304   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 726848   |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=151.51 +/- 108.15
# Episode length: 1289.20 +/- 447.41
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.29e+03 |
# |    mean_reward     | 152      |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | -0.444   |
# |    critic_loss     | 0.00208  |
# |    ent_coef        | 0.000827 |
# |    ent_coef_loss   | -0.405   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 747456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 287      |
# |    time_elapsed    | 818      |
# |    total_timesteps | 235236   |
# | train/             |          |
# |    actor_loss      | -0.439   |
# |    critic_loss     | 0.00201  |
# |    ent_coef        | 0.000786 |
# |    ent_coef_loss   | -0.27    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 756224   |
# ---------------------------------
# Eval num_timesteps=300000, episode_reward=187.34 +/- 113.17
# Episode length: 1034.80 +/- 298.33
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.03e+03 |
# |    mean_reward     | 187      |
# | time/              |          |
# |    total_timesteps | 300000   |
# | train/             |          |
# |    actor_loss      | -0.452   |
# |    critic_loss     | 0.00267  |
# |    ent_coef        | 0.000877 |
# |    ent_coef_loss   | -0.444   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 772416   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 95.8     |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 287      |
# |    time_elapsed    | 1220     |
# |    total_timesteps | 350336   |
# | train/             |          |
# |    actor_loss      | -0.417   |
# |    critic_loss     | 0.00257  |
# |    ent_coef        | 0.000823 |
# |    ent_coef_loss   | -0.703   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 785024   |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=197.89 +/- 91.25
# Episode length: 1208.00 +/- 138.83
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.21e+03 |
# |    mean_reward     | 198      |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | -0.356   |
# |    critic_loss     | 0.00236  |
# |    ent_coef        | 0.000779 |
# |    ent_coef_loss   | 0.333    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 797440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 287      |
# |    time_elapsed    | 1676     |
# |    total_timesteps | 481516   |
# | train/             |          |
# |    actor_loss      | -0.356   |
# |    critic_loss     | 0.00207  |
# |    ent_coef        | 0.000815 |
# |    ent_coef_loss   | -0.701   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 817792   |
# ---------------------------------
# Eval num_timesteps=500000, episode_reward=200.91 +/- 91.43
# Episode length: 1451.40 +/- 288.21
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.45e+03 |
# |    mean_reward     | 201      |
# | time/              |          |
# |    total_timesteps | 500000   |
# | train/             |          |
# |    actor_loss      | -0.355   |
# |    critic_loss     | 0.00217  |
# |    ent_coef        | 0.000779 |
# |    ent_coef_loss   | -0.354   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 822464   |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=600000, episode_reward=217.86 +/- 117.28
# Episode length: 1365.80 +/- 317.96
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.37e+03 |
# |    mean_reward     | 218      |
# | time/              |          |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | -0.414   |
# |    critic_loss     | 0.00177  |
# |    ent_coef        | 0.000759 |
# |    ent_coef_loss   | -0.289   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 847424   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 285      |
# |    time_elapsed    | 2160     |
# |    total_timesteps | 616788   |
# | train/             |          |
# |    actor_loss      | -0.424   |
# |    critic_loss     | 0.00196  |
# |    ent_coef        | 0.000729 |
# |    ent_coef_loss   | -0.51    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 851648   |
# ---------------------------------
# Eval num_timesteps=700000, episode_reward=175.90 +/- 141.58
# Episode length: 1489.20 +/- 419.58
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.49e+03 |
# |    mean_reward     | 176      |
# | time/              |          |
# |    total_timesteps | 700000   |
# | train/             |          |
# |    actor_loss      | -0.461   |
# |    critic_loss     | 0.00179  |
# |    ent_coef        | 0.000698 |
# |    ent_coef_loss   | 0.345    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 872448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 285      |
# |    time_elapsed    | 2648     |
# |    total_timesteps | 756440   |
# | train/             |          |
# |    actor_loss      | -0.502   |
# |    critic_loss     | 0.00165  |
# |    ent_coef        | 0.000682 |
# |    ent_coef_loss   | -0.349   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 886528   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=239.34 +/- 71.39
# Episode length: 1352.40 +/- 325.38
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.35e+03 |
# |    mean_reward     | 239      |
# | time/              |          |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | -0.515   |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000687 |
# |    ent_coef_loss   | 0.63     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 897408   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 285      |
# |    time_elapsed    | 3126     |
# |    total_timesteps | 892800   |
# | train/             |          |
# |    actor_loss      | -0.515   |
# |    critic_loss     | 0.00149  |
# |    ent_coef        | 0.000671 |
# |    ent_coef_loss   | -0.229   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 920640   |
# ---------------------------------
# Eval num_timesteps=900000, episode_reward=198.02 +/- 117.92
# Episode length: 1333.60 +/- 336.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.33e+03 |
# |    mean_reward     | 198      |
# | time/              |          |
# |    total_timesteps | 900000   |
# | train/             |          |
# |    actor_loss      | -0.518   |
# |    critic_loss     | 0.00154  |
# |    ent_coef        | 0.000661 |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 922432   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=91.29 +/- 151.83
# Episode length: 1128.00 +/- 560.08
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.13e+03 |
# |    mean_reward     | 91.3     |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | -0.523   |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.000674 |
# |    ent_coef_loss   | 0.0611   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 947456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 180      |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 284      |
# |    time_elapsed    | 3593     |
# |    total_timesteps | 1023732  |
# | train/             |          |
# |    actor_loss      | -0.514   |
# |    critic_loss     | 0.00148  |
# |    ent_coef        | 0.000668 |
# |    ent_coef_loss   | -0.971   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 953344   |
# ---------------------------------
# Eval num_timesteps=1100000, episode_reward=170.07 +/- 85.77
# Episode length: 1110.00 +/- 171.85
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.11e+03 |
# |    mean_reward     | 170      |
# | time/              |          |
# |    total_timesteps | 1100000  |
# | train/             |          |
# |    actor_loss      | -0.518   |
# |    critic_loss     | 0.00153  |
# |    ent_coef        | 0.000638 |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 972416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 167      |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 285      |
# |    time_elapsed    | 4052     |
# |    total_timesteps | 1155932  |
# | train/             |          |
# |    actor_loss      | -0.496   |
# |    critic_loss     | 0.00134  |
# |    ent_coef        | 0.000639 |
# |    ent_coef_loss   | -0.68    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 986432   |
# ---------------------------------
# Eval num_timesteps=1200000, episode_reward=220.87 +/- 116.88
# Episode length: 1332.20 +/- 336.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.33e+03 |
# |    mean_reward     | 221      |
# | time/              |          |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -0.496   |
# |    critic_loss     | 0.00142  |
# |    ent_coef        | 0.000618 |
# |    ent_coef_loss   | -0.0307  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 997440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 285      |
# |    time_elapsed    | 4500     |
# |    total_timesteps | 1282912  |
# | train/             |          |
# |    actor_loss      | -0.527   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | -0.538   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1018176  |
# ---------------------------------
# Eval num_timesteps=1300000, episode_reward=259.16 +/- 39.99
# Episode length: 1392.40 +/- 309.70
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.39e+03 |
# |    mean_reward     | 259      |
# | time/              |          |
# |    total_timesteps | 1300000  |
# | train/             |          |
# |    actor_loss      | -0.525   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000605 |
# |    ent_coef_loss   | 0.456    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1022464  |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=1400000, episode_reward=207.60 +/- 94.25
# Episode length: 1522.20 +/- 393.10
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.52e+03 |
# |    mean_reward     | 208      |
# | time/              |          |
# |    total_timesteps | 1400000  |
# | train/             |          |
# |    actor_loss      | -0.586   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | 0.236    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1047424  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 284      |
# |    time_elapsed    | 4942     |
# |    total_timesteps | 1404864  |
# | train/             |          |
# |    actor_loss      | -0.58    |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.000623 |
# |    ent_coef_loss   | 0.639    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1048640  |
# ---------------------------------
# Eval num_timesteps=1500000, episode_reward=258.46 +/- 51.68
# Episode length: 1245.60 +/- 53.90
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.25e+03 |
# |    mean_reward     | 258      |
# | time/              |          |
# |    total_timesteps | 1500000  |
# | train/             |          |
# |    actor_loss      | -0.591   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | 0.357    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1072448  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 284      |
# |    time_elapsed    | 5375     |
# |    total_timesteps | 1528244  |
# | train/             |          |
# |    actor_loss      | -0.611   |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | 0.316    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1079488  |
# ---------------------------------
# Eval num_timesteps=1600000, episode_reward=281.78 +/- 3.90
# Episode length: 1169.00 +/- 53.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.17e+03 |
# |    mean_reward     | 282      |
# | time/              |          |
# |    total_timesteps | 1600000  |
# | train/             |          |
# |    actor_loss      | -0.603   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000599 |
# |    ent_coef_loss   | 0.439    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1097408  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 284      |
# |    time_elapsed    | 5847     |
# |    total_timesteps | 1663392  |
# | train/             |          |
# |    actor_loss      | -0.605   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | 0.387    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1113280  |
# ---------------------------------
# Eval num_timesteps=1700000, episode_reward=259.18 +/- 40.94
# Episode length: 1347.60 +/- 334.02
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.35e+03 |
# |    mean_reward     | 259      |
# | time/              |          |
# |    total_timesteps | 1700000  |
# | train/             |          |
# |    actor_loss      | -0.639   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000648 |
# |    ent_coef_loss   | 0.0542   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1122432  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 284      |
# |    time_elapsed    | 6312     |
# |    total_timesteps | 1796216  |
# | train/             |          |
# |    actor_loss      | -0.63    |
# |    critic_loss     | 0.00106  |
# |    ent_coef        | 0.000619 |
# |    ent_coef_loss   | -0.414   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1146496  |
# ---------------------------------
# Eval num_timesteps=1800000, episode_reward=216.19 +/- 89.11
# Episode length: 1302.80 +/- 352.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.3e+03  |
# |    mean_reward     | 216      |
# | time/              |          |
# |    total_timesteps | 1800000  |
# | train/             |          |
# |    actor_loss      | -0.643   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000613 |
# |    ent_coef_loss   | -0.557   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1147456  |
# ---------------------------------
# Eval num_timesteps=1900000, episode_reward=277.24 +/- 5.02
# Episode length: 1215.60 +/- 39.47
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.22e+03 |
# |    mean_reward     | 277      |
# | time/              |          |
# |    total_timesteps | 1900000  |
# | train/             |          |
# |    actor_loss      | -0.618   |
# |    critic_loss     | 0.00105  |
# |    ent_coef        | 0.000629 |
# |    ent_coef_loss   | 0.195    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1172416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 284      |
# |    time_elapsed    | 6782     |
# |    total_timesteps | 1927300  |
# | train/             |          |
# |    actor_loss      | -0.643   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000611 |
# |    ent_coef_loss   | -0.0771  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1179264  |
# ---------------------------------
# Eval num_timesteps=2000000, episode_reward=276.79 +/- 17.85
# Episode length: 1302.20 +/- 350.25
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.3e+03  |
# |    mean_reward     | 277      |
# | time/              |          |
# |    total_timesteps | 2000000  |
# | train/             |          |
# |    actor_loss      | -0.648   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000584 |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1197440  |
# ---------------------------------
# Fine-tuning finished.
# --- Recording Final Video ---
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_finetune/tqc_v3_hardcore_finetune_agent-step-0-to-step-2500.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_finetune/tqc_v3_hardcore_finetune_agent-step-0-to-step-2500.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_finetune/tqc_v3_hardcore_finetune_agent-step-0-to-step-2500.mp4
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1872403840.py in <cell line: 0>()
#     142 if __name__ == "__main__":
#     143     train()
# --> 144     record_and_show_video()
#
# /tmp/ipython-input-1872403840.py in record_and_show_video()
#     133         mp4 = os.path.join(video_dir, mp4_list[0])
#     134         video_data = open(mp4, "rb").read()
# --> 135         b64 = base64.b64encode(video_data)
#     136         ipy_display(HTML(f'''
#     137         <video width="600" controls autoplay loop>
#
# NameError: name 'base64' is not defined

# %%
# Install dependencies if you restarted the runtime
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import torch
import numpy as np
import base64
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# CHANGED: Updated version number to v3 to prevent conflict
EXPERIMENT_NAME = "tqc_v3_hardcore_5M"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 5_000_000
SEED = 42
NUM_CPU = 4  # Keep 4 CPUs for data collection speed

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

# --- ENVIRONMENT MAKER ---
def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = Monitor(env, log_dir)
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} (Balanced Mode) ---")

    # 1. PARALLEL ENVIRONMENTS (Speed)
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])

    # 2. NORMALIZATION (Stability for Hardcore)
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # Eval Env
    eval_env = SubprocVecEnv([make_env(999, SEED)])
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # --- TQC v2 CONFIGURATION ---
    policy_kwargs = dict(
        n_critics=2,            # Kept at 2 for SPEED
        n_quantiles=25,         # 25 Atoms
        net_arch=[400, 300],    # Zoo Architecture (Stronger than 256, faster than 512)
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2, # Drop top 2 atoms per critic (Safety)
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,

        # --- TUNING ---
        learning_rate=linear_schedule(7.3e-4), # Fast Zoo Learning Rate
        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,

        # --- SPEED & SAFETY ---
        train_freq=64,         # Batched Collection (Fast CPU)
        gradient_steps=64,     # Batched Updates (Fast GPU)
        learning_starts=10_000,
        use_sde=False          # Standard noise for reactivity
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    # Use DummyVecEnv for recording (Compatibility)
    env = DummyVecEnv([make_env(0, SEED)])

    # Load Stats
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = TQC.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)
        # Fix for vector environment returning array of dones
        if isinstance(done, (list, np.ndarray)):
             done = done[0]

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.0)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# --- Starting Training: tqc_v3_hardcore_5M (Balanced Mode) ---
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_5M/TQC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 669      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 332      |
# |    time_elapsed    | 210      |
# |    total_timesteps | 70084    |
# | train/             |          |
# |    actor_loss      | -7.79    |
# |    critic_loss     | 0.0114   |
# |    ent_coef        | 0.0013   |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.00072  |
# |    n_updates       | 14976    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 970      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 305      |
# |    time_elapsed    | 545      |
# |    total_timesteps | 166680   |
# | train/             |          |
# |    actor_loss      | -0.199   |
# |    critic_loss     | 0.00386  |
# |    ent_coef        | 0.000515 |
# |    ent_coef_loss   | -0.795   |
# |    learning_rate   | 0.000706 |
# |    n_updates       | 39168    |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=-82.99 +/- 28.80
# Episode length: 1443.20 +/- 692.44
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.44e+03 |
# |    mean_reward     | -83      |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 0.0459   |
# |    critic_loss     | 0.00303  |
# |    ent_coef        | 0.000598 |
# |    ent_coef_loss   | 0.959    |
# |    learning_rate   | 0.000701 |
# |    n_updates       | 47488    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.06e+03 |
# |    ep_rew_mean     | -90.4    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 295      |
# |    time_elapsed    | 921      |
# |    total_timesteps | 272248   |
# | train/             |          |
# |    actor_loss      | 0.13     |
# |    critic_loss     | 0.00396  |
# |    ent_coef        | 0.000685 |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 0.00069  |
# |    n_updates       | 65536    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 932      |
# |    ep_rew_mean     | -66.5    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 293      |
# |    time_elapsed    | 1254     |
# |    total_timesteps | 367624   |
# | train/             |          |
# |    actor_loss      | 0.162    |
# |    critic_loss     | 0.0042   |
# |    ent_coef        | 0.00069  |
# |    ent_coef_loss   | 0.74     |
# |    learning_rate   | 0.000676 |
# |    n_updates       | 89408    |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=30.95 +/- 147.41
# Episode length: 1367.20 +/- 784.54
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.37e+03 |
# |    mean_reward     | 30.9     |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 0.104    |
# |    critic_loss     | 0.00391  |
# |    ent_coef        | 0.000712 |
# |    ent_coef_loss   | 1.38     |
# |    learning_rate   | 0.000672 |
# |    n_updates       | 97472    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -34      |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 290      |
# |    time_elapsed    | 1616     |
# |    total_timesteps | 469156   |
# | train/             |          |
# |    actor_loss      | 0.0391   |
# |    critic_loss     | 0.00379  |
# |    ent_coef        | 0.000723 |
# |    ent_coef_loss   | -0.922   |
# |    learning_rate   | 0.000662 |
# |    n_updates       | 114752   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | -38.1    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 289      |
# |    time_elapsed    | 2037     |
# |    total_timesteps | 590684   |
# | train/             |          |
# |    actor_loss      | -0.0212  |
# |    critic_loss     | 0.00432  |
# |    ent_coef        | 0.000662 |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.000644 |
# |    n_updates       | 145152   |
# ---------------------------------
# Eval num_timesteps=600000, episode_reward=-53.71 +/- 20.54
# Episode length: 1075.20 +/- 759.99
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.08e+03 |
# |    mean_reward     | -53.7    |
# | time/              |          |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | -0.0544  |
# |    critic_loss     | 0.0045   |
# |    ent_coef        | 0.00073  |
# |    ent_coef_loss   | -1.65    |
# |    learning_rate   | 0.000642 |
# |    n_updates       | 147456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | -31.3    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 288      |
# |    time_elapsed    | 2500     |
# |    total_timesteps | 721128   |
# | train/             |          |
# |    actor_loss      | -0.0973  |
# |    critic_loss     | 0.00423  |
# |    ent_coef        | 0.000689 |
# |    ent_coef_loss   | 0.0987   |
# |    learning_rate   | 0.000625 |
# |    n_updates       | 177728   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=-31.92 +/- 45.56
# Episode length: 893.60 +/- 682.04
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 894      |
# |    mean_reward     | -31.9    |
# | time/              |          |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | -0.0993  |
# |    critic_loss     | 0.0043   |
# |    ent_coef        | 0.000686 |
# |    ent_coef_loss   | 0.23     |
# |    learning_rate   | 0.000613 |
# |    n_updates       | 197440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | -22.4    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 287      |
# |    time_elapsed    | 2977     |
# |    total_timesteps | 855604   |
# | train/             |          |
# |    actor_loss      | -0.443   |
# |    critic_loss     | 0.00507  |
# |    ent_coef        | 0.000833 |
# |    ent_coef_loss   | -0.227   |
# |    learning_rate   | 0.000605 |
# |    n_updates       | 211392   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=41.58 +/- 115.91
# Episode length: 1669.80 +/- 453.51
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.67e+03 |
# |    mean_reward     | 41.6     |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | -0.0831  |
# |    critic_loss     | 0.00364  |
# |    ent_coef        | 0.000545 |
# |    ent_coef_loss   | 1.65     |
# |    learning_rate   | 0.000584 |
# |    n_updates       | 247488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 9.58     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 286      |
# |    time_elapsed    | 3520     |
# |    total_timesteps | 1007968  |
# | train/             |          |
# |    actor_loss      | -0.0969  |
# |    critic_loss     | 0.00356  |
# |    ent_coef        | 0.000536 |
# |    ent_coef_loss   | -1.17    |
# |    learning_rate   | 0.000583 |
# |    n_updates       | 249472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 49.4     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 286      |
# |    time_elapsed    | 4059     |
# |    total_timesteps | 1163212  |
# | train/             |          |
# |    actor_loss      | -0.124   |
# |    critic_loss     | 0.00303  |
# |    ent_coef        | 0.000554 |
# |    ent_coef_loss   | -0.29    |
# |    learning_rate   | 0.00056  |
# |    n_updates       | 288256   |
# ---------------------------------
# Eval num_timesteps=1200000, episode_reward=34.36 +/- 150.59
# Episode length: 1939.80 +/- 120.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.94e+03 |
# |    mean_reward     | 34.4     |
# | time/              |          |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -0.158   |
# |    critic_loss     | 0.00292  |
# |    ent_coef        | 0.000514 |
# |    ent_coef_loss   | 0.305    |
# |    learning_rate   | 0.000555 |
# |    n_updates       | 297472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.58e+03 |
# |    ep_rew_mean     | 58.8     |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 285      |
# |    time_elapsed    | 4615     |
# |    total_timesteps | 1319580  |
# | train/             |          |
# |    actor_loss      | -0.205   |
# |    critic_loss     | 0.00244  |
# |    ent_coef        | 0.00046  |
# |    ent_coef_loss   | 2.31     |
# |    learning_rate   | 0.000537 |
# |    n_updates       | 327360   |
# ---------------------------------
# Eval num_timesteps=1400000, episode_reward=55.41 +/- 153.76
# Episode length: 1851.60 +/- 296.80
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.85e+03 |
# |    mean_reward     | 55.4     |
# | time/              |          |
# |    total_timesteps | 1400000  |
# | train/             |          |
# |    actor_loss      | -0.185   |
# |    critic_loss     | 0.00227  |
# |    ent_coef        | 0.000431 |
# |    ent_coef_loss   | 1.14     |
# |    learning_rate   | 0.000526 |
# |    n_updates       | 347456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | 40.1     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 285      |
# |    time_elapsed    | 5138     |
# |    total_timesteps | 1468780  |
# | train/             |          |
# |    actor_loss      | -0.185   |
# |    critic_loss     | 0.00229  |
# |    ent_coef        | 0.000373 |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.000516 |
# |    n_updates       | 364672   |
# ---------------------------------
# Eval num_timesteps=1600000, episode_reward=196.15 +/- 72.80
# Episode length: 1719.60 +/- 344.30
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.72e+03 |
# |    mean_reward     | 196      |
# | time/              |          |
# |    total_timesteps | 1600000  |
# | train/             |          |
# |    actor_loss      | -0.286   |
# |    critic_loss     | 0.00157  |
# |    ent_coef        | 0.000378 |
# |    ent_coef_loss   | 0.893    |
# |    learning_rate   | 0.000496 |
# |    n_updates       | 397440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 285      |
# |    time_elapsed    | 5611     |
# |    total_timesteps | 1603720  |
# | train/             |          |
# |    actor_loss      | -0.26    |
# |    critic_loss     | 0.00171  |
# |    ent_coef        | 0.000394 |
# |    ent_coef_loss   | 0.13     |
# |    learning_rate   | 0.000496 |
# |    n_updates       | 398400   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 91.3     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 286      |
# |    time_elapsed    | 6083     |
# |    total_timesteps | 1742580  |
# | train/             |          |
# |    actor_loss      | -0.36    |
# |    critic_loss     | 0.00154  |
# |    ent_coef        | 0.000372 |
# |    ent_coef_loss   | -0.946   |
# |    learning_rate   | 0.000476 |
# |    n_updates       | 433088   |
# ---------------------------------
# Eval num_timesteps=1800000, episode_reward=230.28 +/- 51.95
# Episode length: 1443.80 +/- 340.21
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.44e+03 |
# |    mean_reward     | 230      |
# | time/              |          |
# |    total_timesteps | 1800000  |
# | train/             |          |
# |    actor_loss      | -0.387   |
# |    critic_loss     | 0.00158  |
# |    ent_coef        | 0.000376 |
# |    ent_coef_loss   | 0.155    |
# |    learning_rate   | 0.000467 |
# |    n_updates       | 447488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | 128      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 286      |
# |    time_elapsed    | 6512     |
# |    total_timesteps | 1865248  |
# | train/             |          |
# |    actor_loss      | -0.41    |
# |    critic_loss     | 0.00142  |
# |    ent_coef        | 0.000373 |
# |    ent_coef_loss   | -0.147   |
# |    learning_rate   | 0.000458 |
# |    n_updates       | 463808   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 286      |
# |    time_elapsed    | 6969     |
# |    total_timesteps | 1999704  |
# | train/             |          |
# |    actor_loss      | -0.513   |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.000382 |
# |    ent_coef_loss   | -0.776   |
# |    learning_rate   | 0.000438 |
# |    n_updates       | 497408   |
# ---------------------------------
# Eval num_timesteps=2000000, episode_reward=71.39 +/- 122.76
# Episode length: 979.20 +/- 590.98
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 979      |
# |    mean_reward     | 71.4     |
# | time/              |          |
# |    total_timesteps | 2000000  |
# | train/             |          |
# |    actor_loss      | -0.492   |
# |    critic_loss     | 0.00145  |
# |    ent_coef        | 0.000379 |
# |    ent_coef_loss   | -0.447   |
# |    learning_rate   | 0.000438 |
# |    n_updates       | 497472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 114      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 287      |
# |    time_elapsed    | 7389     |
# |    total_timesteps | 2120856  |
# | train/             |          |
# |    actor_loss      | -0.503   |
# |    critic_loss     | 0.00132  |
# |    ent_coef        | 0.000401 |
# |    ent_coef_loss   | 0.467    |
# |    learning_rate   | 0.00042  |
# |    n_updates       | 527680   |
# ---------------------------------
# Eval num_timesteps=2200000, episode_reward=108.53 +/- 108.20
# Episode length: 1850.00 +/- 300.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.85e+03 |
# |    mean_reward     | 109      |
# | time/              |          |
# |    total_timesteps | 2200000  |
# | train/             |          |
# |    actor_loss      | -0.526   |
# |    critic_loss     | 0.00162  |
# |    ent_coef        | 0.000386 |
# |    ent_coef_loss   | -0.578   |
# |    learning_rate   | 0.000409 |
# |    n_updates       | 547456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 151      |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 286      |
# |    time_elapsed    | 7870     |
# |    total_timesteps | 2257820  |
# | train/             |          |
# |    actor_loss      | -0.547   |
# |    critic_loss     | 0.00136  |
# |    ent_coef        | 0.000382 |
# |    ent_coef_loss   | -0.306   |
# |    learning_rate   | 0.0004   |
# |    n_updates       | 561920   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 138      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 287      |
# |    time_elapsed    | 8322     |
# |    total_timesteps | 2390420  |
# | train/             |          |
# |    actor_loss      | -0.548   |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 0.000444 |
# |    ent_coef_loss   | 0.328    |
# |    learning_rate   | 0.000381 |
# |    n_updates       | 595072   |
# ---------------------------------
# Eval num_timesteps=2400000, episode_reward=107.96 +/- 153.11
# Episode length: 1095.20 +/- 557.05
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.1e+03  |
# |    mean_reward     | 108      |
# | time/              |          |
# |    total_timesteps | 2400000  |
# | train/             |          |
# |    actor_loss      | -0.554   |
# |    critic_loss     | 0.00138  |
# |    ent_coef        | 0.000393 |
# |    ent_coef_loss   | 0.489    |
# |    learning_rate   | 0.00038  |
# |    n_updates       | 597440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 115      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 287      |
# |    time_elapsed    | 8727     |
# |    total_timesteps | 2506952  |
# | train/             |          |
# |    actor_loss      | -0.541   |
# |    critic_loss     | 0.00156  |
# |    ent_coef        | 0.000446 |
# |    ent_coef_loss   | -0.719   |
# |    learning_rate   | 0.000364 |
# |    n_updates       | 624192   |
# ---------------------------------
# Eval num_timesteps=2600000, episode_reward=119.10 +/- 140.44
# Episode length: 1070.80 +/- 510.14
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.07e+03 |
# |    mean_reward     | 119      |
# | time/              |          |
# |    total_timesteps | 2600000  |
# | train/             |          |
# |    actor_loss      | -0.553   |
# |    critic_loss     | 0.00183  |
# |    ent_coef        | 0.000434 |
# |    ent_coef_loss   | -0.0101  |
# |    learning_rate   | 0.00035  |
# |    n_updates       | 647488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 148      |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 287      |
# |    time_elapsed    | 9141     |
# |    total_timesteps | 2626284  |
# | train/             |          |
# |    actor_loss      | -0.565   |
# |    critic_loss     | 0.00149  |
# |    ent_coef        | 0.000483 |
# |    ent_coef_loss   | -0.984   |
# |    learning_rate   | 0.000347 |
# |    n_updates       | 654016   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 287      |
# |    time_elapsed    | 9566     |
# |    total_timesteps | 2750888  |
# | train/             |          |
# |    actor_loss      | -0.656   |
# |    critic_loss     | 0.00154  |
# |    ent_coef        | 0.000473 |
# |    ent_coef_loss   | -1.27    |
# |    learning_rate   | 0.000328 |
# |    n_updates       | 685184   |
# ---------------------------------
# Eval num_timesteps=2800000, episode_reward=140.32 +/- 121.93
# Episode length: 1055.40 +/- 551.17
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.06e+03 |
# |    mean_reward     | 140      |
# | time/              |          |
# |    total_timesteps | 2800000  |
# | train/             |          |
# |    actor_loss      | -0.675   |
# |    critic_loss     | 0.00166  |
# |    ent_coef        | 0.000467 |
# |    ent_coef_loss   | -0.717   |
# |    learning_rate   | 0.000321 |
# |    n_updates       | 697472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | 117      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 287      |
# |    time_elapsed    | 9931     |
# |    total_timesteps | 2855700  |
# | train/             |          |
# |    actor_loss      | -0.746   |
# |    critic_loss     | 0.00188  |
# |    ent_coef        | 0.000537 |
# |    ent_coef_loss   | 1.49     |
# |    learning_rate   | 0.000313 |
# |    n_updates       | 711424   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 287      |
# |    time_elapsed    | 10357    |
# |    total_timesteps | 2981096  |
# | train/             |          |
# |    actor_loss      | -0.698   |
# |    critic_loss     | 0.00164  |
# |    ent_coef        | 0.000496 |
# |    ent_coef_loss   | -0.326   |
# |    learning_rate   | 0.000295 |
# |    n_updates       | 742720   |
# ---------------------------------
# Eval num_timesteps=3000000, episode_reward=242.98 +/- 67.00
# Episode length: 1270.40 +/- 187.17
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.27e+03 |
# |    mean_reward     | 243      |
# | time/              |          |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -0.75    |
# |    critic_loss     | 0.00175  |
# |    ent_coef        | 0.000699 |
# |    ent_coef_loss   | -0.251   |
# |    learning_rate   | 0.000292 |
# |    n_updates       | 747456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | 139      |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 287      |
# |    time_elapsed    | 10783    |
# |    total_timesteps | 3103488  |
# | train/             |          |
# |    actor_loss      | -0.717   |
# |    critic_loss     | 0.00156  |
# |    ent_coef        | 0.000481 |
# |    ent_coef_loss   | -0.687   |
# |    learning_rate   | 0.000277 |
# |    n_updates       | 773312   |
# ---------------------------------
# Eval num_timesteps=3200000, episode_reward=215.68 +/- 135.96
# Episode length: 905.00 +/- 349.79
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 905      |
# |    mean_reward     | 216      |
# | time/              |          |
# |    total_timesteps | 3200000  |
# | train/             |          |
# |    actor_loss      | -0.677   |
# |    critic_loss     | 0.0015   |
# |    ent_coef        | 0.000539 |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.000263 |
# |    n_updates       | 797440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 287      |
# |    time_elapsed    | 11184    |
# |    total_timesteps | 3219216  |
# | train/             |          |
# |    actor_loss      | -0.665   |
# |    critic_loss     | 0.00154  |
# |    ent_coef        | 0.000504 |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.00026  |
# |    n_updates       | 802304   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 288      |
# |    time_elapsed    | 11614    |
# |    total_timesteps | 3345476  |
# | train/             |          |
# |    actor_loss      | -0.662   |
# |    critic_loss     | 0.00136  |
# |    ent_coef        | 0.000449 |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.000242 |
# |    n_updates       | 833856   |
# ---------------------------------
# Eval num_timesteps=3400000, episode_reward=81.28 +/- 150.60
# Episode length: 1414.60 +/- 484.52
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.41e+03 |
# |    mean_reward     | 81.3     |
# | time/              |          |
# |    total_timesteps | 3400000  |
# | train/             |          |
# |    actor_loss      | -0.645   |
# |    critic_loss     | 0.00148  |
# |    ent_coef        | 0.00045  |
# |    ent_coef_loss   | 1.42     |
# |    learning_rate   | 0.000234 |
# |    n_updates       | 847488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 287      |
# |    time_elapsed    | 12043    |
# |    total_timesteps | 3467480  |
# | train/             |          |
# |    actor_loss      | -0.637   |
# |    critic_loss     | 0.00183  |
# |    ent_coef        | 0.000446 |
# |    ent_coef_loss   | -0.0439  |
# |    learning_rate   | 0.000224 |
# |    n_updates       | 864320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 287      |
# |    time_elapsed    | 12422    |
# |    total_timesteps | 3576688  |
# | train/             |          |
# |    actor_loss      | -0.654   |
# |    critic_loss     | 0.00137  |
# |    ent_coef        | 0.000469 |
# |    ent_coef_loss   | 0.686    |
# |    learning_rate   | 0.000208 |
# |    n_updates       | 891648   |
# ---------------------------------
# Eval num_timesteps=3600000, episode_reward=158.39 +/- 140.46
# Episode length: 1370.80 +/- 521.58
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.37e+03 |
# |    mean_reward     | 158      |
# | time/              |          |
# |    total_timesteps | 3600000  |
# | train/             |          |
# |    actor_loss      | -0.662   |
# |    critic_loss     | 0.00134  |
# |    ent_coef        | 0.000481 |
# |    ent_coef_loss   | -0.742   |
# |    learning_rate   | 0.000204 |
# |    n_updates       | 897472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 162      |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 287      |
# |    time_elapsed    | 12860    |
# |    total_timesteps | 3699924  |
# | train/             |          |
# |    actor_loss      | -0.641   |
# |    critic_loss     | 0.0012   |
# |    ent_coef        | 0.0005   |
# |    ent_coef_loss   | -0.564   |
# |    learning_rate   | 0.00019  |
# |    n_updates       | 922432   |
# ---------------------------------
# Eval num_timesteps=3800000, episode_reward=239.32 +/- 78.13
# Episode length: 1188.40 +/- 35.75
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.19e+03 |
# |    mean_reward     | 239      |
# | time/              |          |
# |    total_timesteps | 3800000  |
# | train/             |          |
# |    actor_loss      | -0.64    |
# |    critic_loss     | 0.00129  |
# |    ent_coef        | 0.000458 |
# |    ent_coef_loss   | 0.158    |
# |    learning_rate   | 0.000175 |
# |    n_updates       | 947456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.17e+03 |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 287      |
# |    time_elapsed    | 13268    |
# |    total_timesteps | 3817040  |
# | train/             |          |
# |    actor_loss      | -0.641   |
# |    critic_loss     | 0.00148  |
# |    ent_coef        | 0.000459 |
# |    ent_coef_loss   | -0.0789  |
# |    learning_rate   | 0.000173 |
# |    n_updates       | 951744   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 157      |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 287      |
# |    time_elapsed    | 13660    |
# |    total_timesteps | 3932092  |
# | train/             |          |
# |    actor_loss      | -0.628   |
# |    critic_loss     | 0.00109  |
# |    ent_coef        | 0.000457 |
# |    ent_coef_loss   | -0.307   |
# |    learning_rate   | 0.000156 |
# |    n_updates       | 980480   |
# ---------------------------------
# Eval num_timesteps=4000000, episode_reward=158.05 +/- 163.61
# Episode length: 1418.00 +/- 478.01
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.42e+03 |
# |    mean_reward     | 158      |
# | time/              |          |
# |    total_timesteps | 4000000  |
# | train/             |          |
# |    actor_loss      | -0.632   |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.000443 |
# |    ent_coef_loss   | -1.05    |
# |    learning_rate   | 0.000146 |
# |    n_updates       | 997440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 287      |
# |    time_elapsed    | 14080    |
# |    total_timesteps | 4052192  |
# | train/             |          |
# |    actor_loss      | -0.642   |
# |    critic_loss     | 0.00121  |
# |    ent_coef        | 0.000472 |
# |    ent_coef_loss   | 0.848    |
# |    learning_rate   | 0.000138 |
# |    n_updates       | 1010496  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 287      |
# |    time_elapsed    | 14499    |
# |    total_timesteps | 4174616  |
# | train/             |          |
# |    actor_loss      | -0.7     |
# |    critic_loss     | 0.00106  |
# |    ent_coef        | 0.000471 |
# |    ent_coef_loss   | -0.446   |
# |    learning_rate   | 0.000121 |
# |    n_updates       | 1041152  |
# ---------------------------------
# Eval num_timesteps=4200000, episode_reward=230.70 +/- 103.85
# Episode length: 1318.60 +/- 344.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.32e+03 |
# |    mean_reward     | 231      |
# | time/              |          |
# |    total_timesteps | 4200000  |
# | train/             |          |
# |    actor_loss      | -0.713   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000459 |
# |    ent_coef_loss   | 1.15     |
# |    learning_rate   | 0.000117 |
# |    n_updates       | 1047488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.09e+03 |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 287      |
# |    time_elapsed    | 14878    |
# |    total_timesteps | 4282944  |
# | train/             |          |
# |    actor_loss      | -0.696   |
# |    critic_loss     | 0.00136  |
# |    ent_coef        | 0.000488 |
# |    ent_coef_loss   | 0.149    |
# |    learning_rate   | 0.000105 |
# |    n_updates       | 1068224  |
# ---------------------------------
# Eval num_timesteps=4400000, episode_reward=226.42 +/- 97.61
# Episode length: 1378.40 +/- 320.87
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.38e+03 |
# |    mean_reward     | 226      |
# | time/              |          |
# |    total_timesteps | 4400000  |
# | train/             |          |
# |    actor_loss      | -0.681   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000489 |
# |    ent_coef_loss   | 0.0299   |
# |    learning_rate   | 8.76e-05 |
# |    n_updates       | 1097472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 180      |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 287      |
# |    time_elapsed    | 15329    |
# |    total_timesteps | 4411572  |
# | train/             |          |
# |    actor_loss      | -0.685   |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.000491 |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 8.59e-05 |
# |    n_updates       | 1100352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 287      |
# |    time_elapsed    | 15769    |
# |    total_timesteps | 4539528  |
# | train/             |          |
# |    actor_loss      | -0.65    |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.000445 |
# |    ent_coef_loss   | -0.793   |
# |    learning_rate   | 6.72e-05 |
# |    n_updates       | 1132352  |
# ---------------------------------
# Eval num_timesteps=4600000, episode_reward=224.36 +/- 121.20
# Episode length: 1291.80 +/- 359.23
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.29e+03 |
# |    mean_reward     | 224      |
# | time/              |          |
# |    total_timesteps | 4600000  |
# | train/             |          |
# |    actor_loss      | -0.63    |
# |    critic_loss     | 0.00105  |
# |    ent_coef        | 0.000447 |
# |    ent_coef_loss   | 0.621    |
# |    learning_rate   | 5.84e-05 |
# |    n_updates       | 1147456  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 3800     |
# |    fps             | 287      |
# |    time_elapsed    | 16197    |
# |    total_timesteps | 4662060  |
# | train/             |          |
# |    actor_loss      | -0.602   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.00047  |
# |    ent_coef_loss   | -0.138   |
# |    learning_rate   | 4.93e-05 |
# |    n_updates       | 1163008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    episodes        | 3900     |
# |    fps             | 287      |
# |    time_elapsed    | 16647    |
# |    total_timesteps | 4793380  |
# | train/             |          |
# |    actor_loss      | -0.571   |
# |    critic_loss     | 0.00125  |
# |    ent_coef        | 0.000465 |
# |    ent_coef_loss   | -0.739   |
# |    learning_rate   | 3.02e-05 |
# |    n_updates       | 1195840  |
# ---------------------------------
# Eval num_timesteps=4800000, episode_reward=249.17 +/- 74.14
# Episode length: 1261.00 +/- 375.04
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.26e+03 |
# |    mean_reward     | 249      |
# | time/              |          |
# |    total_timesteps | 4800000  |
# | train/             |          |
# |    actor_loss      | -0.562   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000459 |
# |    ent_coef_loss   | -0.75    |
# |    learning_rate   | 2.92e-05 |
# |    n_updates       | 1197440  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 4000     |
# |    fps             | 287      |
# |    time_elapsed    | 17102    |
# |    total_timesteps | 4923868  |
# | train/             |          |
# |    actor_loss      | -0.531   |
# |    critic_loss     | 0.00115  |
# |    ent_coef        | 0.000453 |
# |    ent_coef_loss   | -0.157   |
# |    learning_rate   | 1.11e-05 |
# |    n_updates       | 1228416  |
# ---------------------------------
# Eval num_timesteps=5000000, episode_reward=242.72 +/- 84.83
# Episode length: 1030.80 +/- 156.82
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.03e+03 |
# |    mean_reward     | 243      |
# | time/              |          |
# |    total_timesteps | 5000000  |
# | train/             |          |
# |    actor_loss      | -0.51    |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.000445 |
# |    ent_coef_loss   | -0.52    |
# |    learning_rate   | 9.34e-09 |
# |    n_updates       | 1247488  |
# ---------------------------------
# Training finished.
# --- Recording Video for tqc_v3_hardcore_5M ---
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_5M/tqc_v3_hardcore_5M_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_5M/tqc_v3_hardcore_5M_agent-step-0-to-step-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_5M/tqc_v3_hardcore_5M_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- CONFIGURATION ---
BASE_PATH = "/content/drive/MyDrive/aisf_project/logs"
SMOOTHING_WINDOW = 50000  # Smooths the jagged lines (Rolling average over 50k steps)

# Define your experiments groups
# Format: "Label for Legend": "Folder Name in Drive"
normal_experiments = {
    "PPO Baseline (Untuned)": "basic_ppo_final",
    "PPO V2 (Tuned)": "improved_ppo_v2"
}

hardcore_experiments = {
    "PPO V2 (Standard)": "improved_ppo_v2_hardcore",
    "PPO V3 (gSDE)": "sota_ppo_v3_hardcore",
    "PPO V3.1 (No gSDE)": "sota_ppo_v3_1_hardcore",
    "TQC (Basic)": "tqc_v3_hardcore",
    "TQC (Resume Training)": "tqc_v3_hardcore_finetune",
    "TQC (5M)": "tqc_v3_hardcore_5M" # Or whatever you named your final run
}

def load_data(experiment_name):
    """Loads monitor.csv and calculates cumulative steps."""
    log_path = os.path.join(BASE_PATH, experiment_name)

    # Find the monitor file (sometimes it's in a subfolder like 'PPO_1')
    monitor_file = None
    for root, dirs, files in os.walk(log_path):
        for file in files:
            if file.endswith("monitor.csv"):
                monitor_file = os.path.join(root, file)
                break
        if monitor_file: break

    if not monitor_file:
        print(f"Warning: No monitor.csv found for {experiment_name}")
        return None

    # Load CSV, skipping the first 2 metadata lines
    df = pd.read_csv(monitor_file, skiprows=1)

    # 'l' is episode length, 'r' is reward, 't' is wall time
    # We construct 'Total Timesteps' by cumsumming episode lengths
    if 'l' in df:
        df['timesteps'] = df['l'].cumsum()
        return df
    return None

def plot_experiments(experiment_dict, title, filename):
    plt.figure(figsize=(10, 6))

    for label, folder_name in experiment_dict.items():
        df = load_data(folder_name)
        if df is not None:
            # Smoothing
            # We use a rolling window to make the trend visible amidst the noise
            rolling_mean = df['r'].rolling(window=50, min_periods=1).mean()

            # Plot
            plt.plot(df['timesteps'], rolling_mean, label=label, linewidth=2)

            # Optional: Add shadow for variance (if you had multiple seeds, you'd calculate std here)
            # For single runs, we just plot the line.

    plt.axhline(y=300, color='r', linestyle='--', label='Solved (300)')
    plt.axhline(y=0, color='k', linestyle='-', alpha=0.3)

    plt.title(f"Ablation Study: {title}", fontsize=14)
    plt.xlabel("Total Timesteps", fontsize=12)
    plt.ylabel("Average Reward", fontsize=12)
    plt.legend(loc='lower right')
    plt.grid(True, alpha=0.3)
    plt.tight_layout()
    plt.savefig(f"{filename}.png") # Saves to Colab so you can download
    plt.show()

# --- GENERATE PLOTS ---
print("Generating Normal Difficulty Graph...")
plot_experiments(normal_experiments, "Impact of Tuning on PPO (Normal)", "ablation_normal")

print("\nGenerating Hardcore Difficulty Graph...")
plot_experiments(hardcore_experiments, "PPO vs TQC on Hardcore Mode", "ablation_hardcore")
# Out:
# Generating Normal Difficulty Graph...
# Generating Hardcore Difficulty Graph...

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# --- CONFIGURATION ---
BASE_PATH = "/content/drive/MyDrive/aisf_project/logs"
SMOOTHING_WINDOW = 50  # Rolling average over 50 data points

# Define your experiments groups
# Format: "Label for Legend": "Folder Name in Drive"
normal_experiments = {
    "PPO Baseline (Untuned)": "basic_ppo_final",
    "PPO V2 (Tuned)": "improved_ppo_v2"
}

# UPDATED dictionary with correct folder names from your logs
hardcore_experiments = {
    "PPO V2 (Standard)": "improved_ppo_v2_hardcore",
    "PPO V3 (gSDE)": "sota_ppo_v3_hardcore",
    "PPO V3.1 (No gSDE)": "sota_ppo_v3_1_hardcore",
    "TQC (Basic 3M)": "tqc_v3_hardcore",        # Matches your first TQC run
    "TQC (Finetuned +2M)": "tqc_v3_hardcore_finetune", # Matches your resume run
    "TQC (5M SOTA)": "tqc_v3_hardcore_5M"           # Matches your final 5M run
}

def load_data(experiment_name):
    """Loads monitor.csv and calculates cumulative steps."""
    log_path = os.path.join(BASE_PATH, experiment_name)

    # Search for monitor.csv in subfolders (e.g., TQC_1)
    monitor_file = None
    if os.path.exists(log_path):
        for root, dirs, files in os.walk(log_path):
            for file in files:
                if file.endswith("monitor.csv"):
                    monitor_file = os.path.join(root, file)
                    break
            if monitor_file: break

    if not monitor_file:
        print(f"⚠️ Warning: Could not find data for '{experiment_name}'")
        return None

    try:
        # Load CSV, skipping the first 2 metadata lines
        df = pd.read_csv(monitor_file, skiprows=1)

        # 'l' is episode length, 'r' is reward
        # We construct 'Total Timesteps' by cumsumming episode lengths
        if 'l' in df and 'r' in df:
            df['timesteps'] = df['l'].cumsum()
            return df
    except Exception as e:
        print(f"Error reading {experiment_name}: {e}")

    return None

def plot_experiments(experiment_dict, title, filename):
    plt.figure(figsize=(12, 7))

    found_data = False
    for label, folder_name in experiment_dict.items():
        df = load_data(folder_name)
        if df is not None:
            found_data = True
            # Smoothing
            rolling_mean = df['r'].rolling(window=SMOOTHING_WINDOW, min_periods=1).mean()

            # Plot
            plt.plot(df['timesteps'], rolling_mean, label=label, linewidth=2)
            print(f"✅ Plotted: {label}")
        else:
            print(f"❌ Skipped: {label}")

    if found_data:
        plt.axhline(y=300, color='r', linestyle='--', label='Solved (300)')
        plt.axhline(y=0, color='k', linestyle='-', alpha=0.3)

        plt.title(f"Ablation Study: {title}", fontsize=14)
        plt.xlabel("Total Timesteps", fontsize=12)
        plt.ylabel("Average Reward (Smoothed)", fontsize=12)
        plt.legend(loc='lower right')
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.savefig(f"{filename}.png")
        plt.show()
    else:
        print(f"No data found for {title}. Check folder names in Drive.")

# --- GENERATE PLOTS ---
print("--- Generating Normal Difficulty Graph ---")
plot_experiments(normal_experiments, "Impact of Tuning on PPO (Normal)", "ablation_normal")

print("\n--- Generating Hardcore Difficulty Graph ---")
plot_experiments(hardcore_experiments, "PPO vs TQC on Hardcore Mode", "ablation_hardcore")
# Out:
# --- Generating Normal Difficulty Graph ---
# ✅ Plotted: PPO Baseline (Untuned)
# ✅ Plotted: PPO V2 (Tuned)
# --- Generating Hardcore Difficulty Graph ---
# ✅ Plotted: PPO V2 (Standard)
# ✅ Plotted: PPO V3 (gSDE)
# ✅ Plotted: PPO V3.1 (No gSDE)
# ✅ Plotted: TQC (Basic 3M)
# ✅ Plotted: TQC (Finetuned +2M)
# ✅ Plotted: TQC (5M SOTA)

# %%
import os
LOG_DIR = "/content/drive/MyDrive/aisf_project/logs"

print("--- Available Log Folders ---")
if os.path.exists(LOG_DIR):
    for folder in os.listdir(LOG_DIR):
        print(f"'{folder}'")
else:
    print(f"Error: Directory {LOG_DIR} not found!")
# Out:
# --- Available Log Folders ---
# 'basic_ppo_final'
# 'improved_ppo_v2'
# 'improved_ppo_v2_hardcore'
# 'sota_ppo_v3_hardcore'
# 'sota_ppo_v3_1_hardcore'
# 'tqc_hardcore_zoo_tuned'
# '.ipynb_checkpoints'
# 'tqc_hardcore_zoo_tuned_gpu'
# 'tqc_hardcore_ultimate'
# 'tqc_v2_hardcore'
# 'tqc_v3_hardcore'
# 'tqc_v3_hardcore_finetune'
# 'tqc_v3_hardcore_5M'

# %%
# Install necessary library for reading TensorBoard files
# !pip install pandas matplotlib tensorflow

import os
import glob
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.core.util import event_pb2

# --- CONFIGURATION ---
BASE_PATH = "/content/drive/MyDrive/aisf_project/logs"
SMOOTHING_WINDOW = 15  # Smooths the line to make it readable

# Dictionary of your experiments
# keys = Legend Label, values = Folder Name in Drive
experiments = {
    "PPO V2 (Tuned)": "improved_ppo_v2_hardcore",
    "PPO V3 (SOTA gSDE)": "sota_ppo_v3_hardcore",
    "PPO V3.1 (SOTA No-gSDE)": "sota_ppo_v3_1_hardcore",
    "TQC (Initial)": "tqc_v3_hardcore",
    "TQC (5M Winner)": "tqc_v3_hardcore_5M",
    "TQC (Fine-Tuning)": "tqc_v3_hardcore_finetune"
}

def extract_tensorboard_data(log_dir):
    """
    Recursively finds all event files in a directory and extracts reward data.
    Returns a DataFrame with 'step' and 'reward'.
    """
    data = []

    # Find all event files recursively (e.g., inside TQC_1, PPO_1 subfolders)
    # This captures the data hidden inside the numbered subfolders
    event_files = glob.glob(f"{log_dir}/**/events.out.tfevents.*", recursive=True)

    if not event_files:
        print(f"  [Skipping] No TensorBoard files found in {log_dir}")
        return None

    print(f"  [Reading] Found {len(event_files)} log file(s) in {log_dir}...")

    for file_path in event_files:
        try:
            # Create an iterator to read the binary event file
            iterator = tf.data.TFRecordDataset(file_path)

            for record in iterator:
                event = event_pb2.Event.FromString(record.numpy())
                for value in event.summary.value:
                    # 'rollout/ep_rew_mean' is the standard tag for mean reward
                    if value.tag == "rollout/ep_rew_mean":
                        data.append({
                            "step": event.step,
                            "reward": value.simple_value
                        })
        except Exception as e:
            print(f"  ! Error reading file {os.path.basename(file_path)}")

    if not data:
        return None

    # Create DataFrame and sort by step so the line draws correctly
    df = pd.DataFrame(data).sort_values("step")
    return df

# --- PLOTTING ---
plt.figure(figsize=(14, 8))

for label, folder_name in experiments.items():
    full_path = os.path.join(BASE_PATH, folder_name)

    df = extract_tensorboard_data(full_path)

    if df is not None and not df.empty:
        # Smoothing
        df["smoothed_reward"] = df["reward"].rolling(window=SMOOTHING_WINDOW, min_periods=1).mean()

        # Plot
        plt.plot(df["step"], df["smoothed_reward"], label=label, linewidth=2)
        print(f"  -> Plotted {len(df)} points for {label}")

# --- FORMATTING ---
plt.axhline(y=300, color='r', linestyle='--', linewidth=2, label='Solved (300)')
plt.axhline(y=0, color='k', linestyle='-', alpha=0.3)

plt.title("Ablation Study: Hardcore Difficulty Learning Curves", fontsize=16)
plt.xlabel("Total Timesteps", fontsize=14)
plt.ylabel("Average Reward (Smoothed)", fontsize=14)
plt.legend(loc='lower right', fontsize=12)
plt.grid(True, alpha=0.3)
plt.tight_layout()

# Save and Show
save_path = "hardcore_ablation_plot.png"
plt.savefig(save_path, dpi=300)
print(f"\nGraph saved to {save_path}")
plt.show()
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.19.0)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.9.23)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.2.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.15.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.1)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.76.0)
# Requirement already satisfied: tensorboard~=2.19.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.10.0)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.15.1)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.5.0->tensorflow) (0.18.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.11.12)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.19.0->tensorflow) (3.1.4)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#   [Reading] Found 1 log file(s) in /content/drive/MyDrive/aisf_project/logs/improved_ppo_v2_hardcore...
#   -> Plotted 367 points for PPO V2 (Tuned)
#   [Reading] Found 1 log file(s) in /content/drive/MyDrive/aisf_project/logs/sota_ppo_v3_hardcore...
#   -> Plotted 148 points for PPO V3 (SOTA gSDE)
#   [Reading] Found 1 log file(s) in /content/drive/MyDrive/aisf_project/logs/sota_ppo_v3_1_hardcore...
#   -> Plotted 367 points for PPO V3.1 (SOTA No-gSDE)
#   [Reading] Found 2 log file(s) in /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore...
#   -> Plotted 38 points for TQC (Initial)
#   [Reading] Found 1 log file(s) in /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_5M...
#   -> Plotted 40 points for TQC (5M Winner)
#   [Skipping] No TensorBoard files found in /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_finetune
#
# Graph saved to hardcore_ablation_plot.png

# %%
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib
import gymnasium as gym
import pandas as pd
import os
import numpy as np
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines3.common.evaluation import evaluate_policy

# --- CONFIGURATION ---
base_path = "/content/drive/MyDrive/aisf_project"
models_dir = f"{base_path}/models"
logs_dir = f"{base_path}/logs"

# 1. PPO Experiments (Read from Logs if available, as they are likely unchanged)
ppo_experiments = {
    "basic_ppo_final": "PPO Baseline (Normal)",
    "improved_ppo_v2": "PPO Tuned (Normal)",
    "sota_ppo_v3_hardcore": "PPO SOTA (Hardcore)",
    "sota_ppo_v3_1_hardcore": "PPO Hybrid (Hardcore)"
}

# 2. TQC Experiments (Will be RETESTED Live)
tqc_experiments = [
    "tqc_v3_hardcore",
    "tqc_v3_hardcore_5M",
    "tqc_v3_hardcore_finetune"
]

# --- HELPER: GET STATS FROM OLD LOGS (PPO) ---
def get_log_stats(exp_name, label):
    path = os.path.join(logs_dir, exp_name, "monitor.csv")
    if not os.path.exists(path):
        return {"Experiment": label, "Final Score": "N/A (Log Missing)", "Result": "Unknown"}

    try:
        df = pd.read_csv(path, skiprows=1)
        final_mean = df['r'].iloc[-100:].mean()
        # Infer Result
        if final_mean > 290: result = "Solved"
        elif final_mean < 100: result = "Failed"
        else: result = "Converged/Stuck"

        return {
            "Experiment": label,
            "Final Score": round(final_mean, 2),
            "Result": result
        }
    except:
        return {"Experiment": label, "Final Score": "Error", "Result": "Error"}

# --- HELPER: LIVE RETEST (TQC) ---
def retest_tqc(exp_name):
    print(f"--- Retesting {exp_name} (Live Evaluation)...")

    model_path = os.path.join(models_dir, exp_name, "final_model.zip")
    stats_path = os.path.join(models_dir, exp_name, "vec_normalize.pkl") # Standard name

    # Fallback for stats naming if 'vec_normalize.pkl' doesn't exist
    if not os.path.exists(stats_path):
        stats_path = os.path.join(models_dir, exp_name, "vecnormalize.pkl")

    if not os.path.exists(model_path):
        return {"Experiment": exp_name, "Final Score": "Model Not Found", "Result": "N/A"}

    # 1. Create Env
    env = gym.make("BipedalWalkerHardcore-v3")
    env = DummyVecEnv([lambda: env])

    # 2. Load Stats (Crucial)
    if os.path.exists(stats_path):
        print(f"   Loaded normalization stats from {os.path.basename(stats_path)}")
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("   WARNING: No normalization stats found! Score may be incorrect.")

    # 3. Load Model
    try:
        model = TQC.load(model_path)
    except:
        return {"Experiment": exp_name, "Final Score": "Load Error", "Result": "Error"}

    # 4. Run Evaluation (100 Episodes)
    # This gives the most scientifically accurate "Current Performance"
    mean_reward, std_reward = evaluate_policy(model, env, n_eval_episodes=100)

    env.close()

    # Logic for "Result" column
    if mean_reward > 295: result = "Solved (Perfect)"
    elif mean_reward > 250: result = "Solved (Robust)"
    elif mean_reward > 200: result = "Converging"
    else: result = "Failed"

    return {
        "Experiment": exp_name,
        "Final Score": f"{mean_reward:.2f} +/- {std_reward:.2f}",
        "Result": result
    }

# --- MAIN EXECUTION ---
all_stats = []

# 1. Process PPO (Fast, from logs)
for exp, label in ppo_experiments.items():
    all_stats.append(get_log_stats(exp, label))

# 2. Process TQC (Slow, accurate retest)
for exp in tqc_experiments:
    all_stats.append(retest_tqc(exp))

# 3. Generate Table
df = pd.DataFrame(all_stats)
print("\n" + "="*60)
print("FINAL ABLATION RESULTS (Paste into Writeup)")
print("="*60)
print(df.to_markdown(index=False))
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Collecting stable-baselines3
#   Using cached stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Using cached Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Using cached PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cpu)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.0-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 38.9 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 11.9 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 5.4 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381959 sha256=59ae3a0cbb8754343a0be22dd6512a3a06035ab75f49fc053734b292c3978d54
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3, sb3-contrib
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 sb3-contrib-2.7.1 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.0
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Retesting tqc_v3_hardcore (Live Evaluation)...
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
#    Loaded normalization stats from vec_normalize.pkl
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/evaluation.py:70: UserWarning: Evaluation environment is not wrapped with a ``Monitor`` wrapper. This may result in reporting modified episode lengths and rewards, if other wrappers happen to modify these. Consider wrapping environment first with ``Monitor`` wrapper.
#   warnings.warn(
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Retesting tqc_v3_hardcore_5M (Live Evaluation)...
#    Loaded normalization stats from vec_normalize.pkl
# --- Retesting tqc_v3_hardcore_finetune (Live Evaluation)...
#    Loaded normalization stats from vec_normalize.pkl
#
# ============================================================
# FINAL ABLATION RESULTS (Paste into Writeup)
# ============================================================
# | Experiment               | Final Score       | Result          |
# |:-------------------------|:------------------|:----------------|
# | PPO Baseline (Normal)    | 271.98            | Converged/Stuck |
# | PPO Tuned (Normal)       | 319.27            | Solved          |
# | PPO SOTA (Hardcore)      | -195.16           | Failed          |
# | PPO Hybrid (Hardcore)    | -18.43            | Failed          |
# | tqc_v3_hardcore          | 175.62 +/- 130.53 | Failed          |
# | tqc_v3_hardcore_5M       | 178.28 +/- 141.84 | Failed          |
# | tqc_v3_hardcore_finetune | 208.97 +/- 116.59 | Converging      |

# %%
# Create a clean requirements file
content = """gymnasium[box2d]
stable-baselines3[extra]
shimmy>=0.2.1
box2d-py==2.3.8
numpy
pandas
matplotlib
seaborn
"""
with open("requirements.txt", "w") as f:
    f.write(content)
print("requirements.txt created!")
# Out:
# requirements.txt created!

# %%
# Install dependencies if you restarted the runtime
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import torch
import numpy as np
import base64
from datetime import datetime
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# TIMESTAMP: Ensures unique folder for every run
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
EXPERIMENT_NAME = f"tqc_v3_hardcore_rerun_{timestamp}"

ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
SEED = 42
NUM_CPU = 4

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

print(f"Logging to: {log_dir}")

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

# --- ENVIRONMENT MAKER ---
def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        # UNIQUE MONITOR: Prevents parallel crash & overwriting
        env = Monitor(env, os.path.join(log_dir, str(rank)))
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} ---")

    # 1. PARALLEL ENVIRONMENTS
    # Ranks 0, 1, 2, 3 created here.
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])

    # 2. NORMALIZATION
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # Eval Env (Rank 999 to be safe)
    eval_env = SubprocVecEnv([make_env(999, SEED)])
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # --- TQC CONFIGURATION ---
    policy_kwargs = dict(
        n_critics=2,
        n_quantiles=25,
        net_arch=[400, 300],
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,
        learning_rate=linear_schedule(7.3e-4),
        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,
        train_freq=64,
        gradient_steps=64,
        learning_starts=10_000,
        use_sde=False
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    # --- CRITICAL FIX ---
    # We use rank 1000 here.
    # If we used rank 0, 'Monitor' would overwrite '0.monitor.csv'
    # and destroy 25% of the training data.
    env = DummyVecEnv([make_env(1000, SEED)])

    # Load Stats
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = TQC.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)
        if isinstance(done, (list, np.ndarray)):
             done = done[0]

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (589 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 2.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 6.4 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 8.0 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.6 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381959 sha256=eea316490a1908ea509f190ee68ac1ec4e0950fa5db9bc0fff4292258ea2dc35
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3, sb3-contrib
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 sb3-contrib-2.7.1 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.1
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Logging to: /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_rerun_20251227_1644
# --- Starting Training: tqc_v3_hardcore_rerun_20251227_1644 ---
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_rerun_20251227_1644/TQC_1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 853      |
# |    ep_rew_mean     | -117     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 354      |
# |    time_elapsed    | 248      |
# |    total_timesteps | 88072    |
# | train/             |          |
# |    actor_loss      | -5.04    |
# |    critic_loss     | 0.00572  |
# |    ent_coef        | 0.000557 |
# |    ent_coef_loss   | 1.59     |
# |    learning_rate   | 0.000709 |
# |    n_updates       | 19520    |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=-85.17 +/- 7.73
# Episode length: 939.80 +/- 866.17
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 940      |
# |    mean_reward     | -85.2    |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 0.198    |
# |    critic_loss     | 0.00206  |
# |    ent_coef        | 0.000479 |
# |    ent_coef_loss   | 0.211    |
# |    learning_rate   | 0.000681 |
# |    n_updates       | 47488    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | -94.5    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 330      |
# |    time_elapsed    | 623      |
# |    total_timesteps | 205780   |
# | train/             |          |
# |    actor_loss      | 0.2      |
# |    critic_loss     | 0.00204  |
# |    ent_coef        | 0.00044  |
# |    ent_coef_loss   | -0.523   |
# |    learning_rate   | 0.00068  |
# |    n_updates       | 48896    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 819      |
# |    ep_rew_mean     | -89.7    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 326      |
# |    time_elapsed    | 889      |
# |    total_timesteps | 290604   |
# | train/             |          |
# |    actor_loss      | 0.3      |
# |    critic_loss     | 0.00308  |
# |    ent_coef        | 0.000633 |
# |    ent_coef_loss   | 0.887    |
# |    learning_rate   | 0.000659 |
# |    n_updates       | 70144    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 928      |
# |    ep_rew_mean     | -89.5    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 325      |
# |    time_elapsed    | 1169     |
# |    total_timesteps | 380384   |
# | train/             |          |
# |    actor_loss      | 0.28     |
# |    critic_loss     | 0.00335  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | 0.816    |
# |    learning_rate   | 0.000637 |
# |    n_updates       | 92544    |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=-71.84 +/- 20.25
# Episode length: 1043.20 +/- 809.85
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.04e+03 |
# |    mean_reward     | -71.8    |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 0.253    |
# |    critic_loss     | 0.00317  |
# |    ent_coef        | 0.00057  |
# |    ent_coef_loss   | -0.0436  |
# |    learning_rate   | 0.000633 |
# |    n_updates       | 97472    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 995      |
# |    ep_rew_mean     | -73.9    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 322      |
# |    time_elapsed    | 1490     |
# |    total_timesteps | 480292   |
# | train/             |          |
# |    actor_loss      | 0.293    |
# |    critic_loss     | 0.0037   |
# |    ent_coef        | 0.000617 |
# |    ent_coef_loss   | 1.9      |
# |    learning_rate   | 0.000613 |
# |    n_updates       | 117568   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | -55.3    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 321      |
# |    time_elapsed    | 1853     |
# |    total_timesteps | 596120   |
# | train/             |          |
# |    actor_loss      | 0.267    |
# |    critic_loss     | 0.00363  |
# |    ent_coef        | 0.00058  |
# |    ent_coef_loss   | -0.556   |
# |    learning_rate   | 0.000585 |
# |    n_updates       | 146496   |
# ---------------------------------
# Eval num_timesteps=600000, episode_reward=-14.41 +/- 38.85
# Episode length: 1445.40 +/- 679.68
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.45e+03 |
# |    mean_reward     | -14.4    |
# | time/              |          |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | 0.28     |
# |    critic_loss     | 0.00364  |
# |    ent_coef        | 0.000619 |
# |    ent_coef_loss   | -0.279   |
# |    learning_rate   | 0.000584 |
# |    n_updates       | 147456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | -24      |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 319      |
# |    time_elapsed    | 2305     |
# |    total_timesteps | 737444   |
# | train/             |          |
# |    actor_loss      | 0.193    |
# |    critic_loss     | 0.00341  |
# |    ent_coef        | 0.000643 |
# |    ent_coef_loss   | -0.4     |
# |    learning_rate   | 0.000551 |
# |    n_updates       | 181824   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=36.58 +/- 64.05
# Episode length: 2000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2e+03    |
# |    mean_reward     | 36.6     |
# | time/              |          |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | 0.122    |
# |    critic_loss     | 0.00359  |
# |    ent_coef        | 0.000632 |
# |    ent_coef_loss   | -0.428   |
# |    learning_rate   | 0.000535 |
# |    n_updates       | 197440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | -10.8    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 318      |
# |    time_elapsed    | 2750     |
# |    total_timesteps | 875620   |
# | train/             |          |
# |    actor_loss      | 0.139    |
# |    critic_loss     | 0.0035   |
# |    ent_coef        | 0.000661 |
# |    ent_coef_loss   | -0.0174  |
# |    learning_rate   | 0.000517 |
# |    n_updates       | 216384   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=18.37 +/- 71.59
# Episode length: 1625.00 +/- 499.25
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.62e+03 |
# |    mean_reward     | 18.4     |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 0.126    |
# |    critic_loss     | 0.00352  |
# |    ent_coef        | 0.000636 |
# |    ent_coef_loss   | 2.07     |
# |    learning_rate   | 0.000487 |
# |    n_updates       | 247488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.47e+03 |
# |    ep_rew_mean     | -1.28    |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 317      |
# |    time_elapsed    | 3222     |
# |    total_timesteps | 1023712  |
# | train/             |          |
# |    actor_loss      | 0.121    |
# |    critic_loss     | 0.00337  |
# |    ent_coef        | 0.000596 |
# |    ent_coef_loss   | 0.281    |
# |    learning_rate   | 0.000481 |
# |    n_updates       | 253376   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.63e+03 |
# |    ep_rew_mean     | 27.7     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 318      |
# |    time_elapsed    | 3723     |
# |    total_timesteps | 1184648  |
# | train/             |          |
# |    actor_loss      | -0.00637 |
# |    critic_loss     | 0.00296  |
# |    ent_coef        | 0.000664 |
# |    ent_coef_loss   | 0.0352   |
# |    learning_rate   | 0.000442 |
# |    n_updates       | 293632   |
# ---------------------------------
# Eval num_timesteps=1200000, episode_reward=79.73 +/- 106.92
# Episode length: 1928.00 +/- 144.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.93e+03 |
# |    mean_reward     | 79.7     |
# | time/              |          |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -0.0126  |
# |    critic_loss     | 0.00261  |
# |    ent_coef        | 0.000648 |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.000438 |
# |    n_updates       | 297472   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.54e+03 |
# |    ep_rew_mean     | 46.5     |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 317      |
# |    time_elapsed    | 4220     |
# |    total_timesteps | 1340360  |
# | train/             |          |
# |    actor_loss      | -0.054   |
# |    critic_loss     | 0.0025   |
# |    ent_coef        | 0.000665 |
# |    ent_coef_loss   | 0.194    |
# |    learning_rate   | 0.000404 |
# |    n_updates       | 332544   |
# ---------------------------------
# Eval num_timesteps=1400000, episode_reward=72.78 +/- 108.11
# Episode length: 1622.40 +/- 566.02
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.62e+03 |
# |    mean_reward     | 72.8     |
# | time/              |          |
# |    total_timesteps | 1400000  |
# | train/             |          |
# |    actor_loss      | -0.0593  |
# |    critic_loss     | 0.00262  |
# |    ent_coef        | 0.00063  |
# |    ent_coef_loss   | 0.137    |
# |    learning_rate   | 0.000389 |
# |    n_updates       | 347456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.46e+03 |
# |    ep_rew_mean     | 47       |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 317      |
# |    time_elapsed    | 4682     |
# |    total_timesteps | 1485304  |
# | train/             |          |
# |    actor_loss      | -0.129   |
# |    critic_loss     | 0.00216  |
# |    ent_coef        | 0.000597 |
# |    ent_coef_loss   | -0.522   |
# |    learning_rate   | 0.000369 |
# |    n_updates       | 368768   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 722      |
# |    ep_rew_mean     | -36.2    |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 317      |
# |    time_elapsed    | 4908     |
# |    total_timesteps | 1557280  |
# | train/             |          |
# |    actor_loss      | -0.132   |
# |    critic_loss     | 0.00261  |
# |    ent_coef        | 0.000622 |
# |    ent_coef_loss   | -0.234   |
# |    learning_rate   | 0.000351 |
# |    n_updates       | 386816   |
# ---------------------------------
# Eval num_timesteps=1600000, episode_reward=30.51 +/- 132.63
# Episode length: 1670.40 +/- 555.34
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.67e+03 |
# |    mean_reward     | 30.5     |
# | time/              |          |
# |    total_timesteps | 1600000  |
# | train/             |          |
# |    actor_loss      | -0.137   |
# |    critic_loss     | 0.00232  |
# |    ent_coef        | 0.00063  |
# |    ent_coef_loss   | -0.535   |
# |    learning_rate   | 0.000341 |
# |    n_updates       | 397440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 924      |
# |    ep_rew_mean     | 6.39     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 316      |
# |    time_elapsed    | 5210     |
# |    total_timesteps | 1650900  |
# | train/             |          |
# |    actor_loss      | -0.155   |
# |    critic_loss     | 0.0024   |
# |    ent_coef        | 0.000657 |
# |    ent_coef_loss   | -0.446   |
# |    learning_rate   | 0.000328 |
# |    n_updates       | 410176   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | 108      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 317      |
# |    time_elapsed    | 5672     |
# |    total_timesteps | 1799560  |
# | train/             |          |
# |    actor_loss      | -0.234   |
# |    critic_loss     | 0.00206  |
# |    ent_coef        | 0.000592 |
# |    ent_coef_loss   | -0.912   |
# |    learning_rate   | 0.000292 |
# |    n_updates       | 447360   |
# ---------------------------------
# Eval num_timesteps=1800000, episode_reward=37.48 +/- 129.08
# Episode length: 1388.40 +/- 536.06
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.39e+03 |
# |    mean_reward     | 37.5     |
# | time/              |          |
# |    total_timesteps | 1800000  |
# | train/             |          |
# |    actor_loss      | -0.235   |
# |    critic_loss     | 0.0021   |
# |    ent_coef        | 0.00058  |
# |    ent_coef_loss   | -0.342   |
# |    learning_rate   | 0.000292 |
# |    n_updates       | 447488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 86.2     |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 317      |
# |    time_elapsed    | 6107     |
# |    total_timesteps | 1936800  |
# | train/             |          |
# |    actor_loss      | -0.294   |
# |    critic_loss     | 0.00208  |
# |    ent_coef        | 0.000577 |
# |    ent_coef_loss   | 0.0153   |
# |    learning_rate   | 0.000259 |
# |    n_updates       | 481664   |
# ---------------------------------
# Eval num_timesteps=2000000, episode_reward=-19.93 +/- 97.69
# Episode length: 580.00 +/- 712.67
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 580      |
# |    mean_reward     | -19.9    |
# | time/              |          |
# |    total_timesteps | 2000000  |
# | train/             |          |
# |    actor_loss      | -0.312   |
# |    critic_loss     | 0.00198  |
# |    ent_coef        | 0.000576 |
# |    ent_coef_loss   | 0.0989   |
# |    learning_rate   | 0.000243 |
# |    n_updates       | 497472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 112      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 317      |
# |    time_elapsed    | 6527     |
# |    total_timesteps | 2070892  |
# | train/             |          |
# |    actor_loss      | -0.352   |
# |    critic_loss     | 0.00182  |
# |    ent_coef        | 0.000599 |
# |    ent_coef_loss   | 0.614    |
# |    learning_rate   | 0.000226 |
# |    n_updates       | 515200   |
# ---------------------------------
# Eval num_timesteps=2200000, episode_reward=241.46 +/- 51.75
# Episode length: 1475.20 +/- 268.87
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.48e+03 |
# |    mean_reward     | 241      |
# | time/              |          |
# |    total_timesteps | 2200000  |
# | train/             |          |
# |    actor_loss      | -0.346   |
# |    critic_loss     | 0.00202  |
# |    ent_coef        | 0.000605 |
# |    ent_coef_loss   | -0.748   |
# |    learning_rate   | 0.000195 |
# |    n_updates       | 547456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 82.2     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 317      |
# |    time_elapsed    | 6942     |
# |    total_timesteps | 2201192  |
# | train/             |          |
# |    actor_loss      | -0.365   |
# |    critic_loss     | 0.00185  |
# |    ent_coef        | 0.000597 |
# |    ent_coef_loss   | -0.965   |
# |    learning_rate   | 0.000194 |
# |    n_updates       | 547776   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.47e+03 |
# |    ep_rew_mean     | 92.1     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 317      |
# |    time_elapsed    | 7394     |
# |    total_timesteps | 2347092  |
# | train/             |          |
# |    actor_loss      | -0.368   |
# |    critic_loss     | 0.00178  |
# |    ent_coef        | 0.000576 |
# |    ent_coef_loss   | -0.0725  |
# |    learning_rate   | 0.000159 |
# |    n_updates       | 584256   |
# ---------------------------------
# Eval num_timesteps=2400000, episode_reward=59.76 +/- 170.56
# Episode length: 1105.20 +/- 654.77
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.11e+03 |
# |    mean_reward     | 59.8     |
# | time/              |          |
# |    total_timesteps | 2400000  |
# | train/             |          |
# |    actor_loss      | -0.388   |
# |    critic_loss     | 0.00172  |
# |    ent_coef        | 0.000595 |
# |    ent_coef_loss   | -0.432   |
# |    learning_rate   | 0.000146 |
# |    n_updates       | 597440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | 132      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 317      |
# |    time_elapsed    | 7840     |
# |    total_timesteps | 2488440  |
# | train/             |          |
# |    actor_loss      | -0.376   |
# |    critic_loss     | 0.00172  |
# |    ent_coef        | 0.000594 |
# |    ent_coef_loss   | -0.0195  |
# |    learning_rate   | 0.000125 |
# |    n_updates       | 619584   |
# ---------------------------------
# Eval num_timesteps=2600000, episode_reward=256.10 +/- 20.44
# Episode length: 1445.80 +/- 281.83
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.45e+03 |
# |    mean_reward     | 256      |
# | time/              |          |
# |    total_timesteps | 2600000  |
# | train/             |          |
# |    actor_loss      | -0.444   |
# |    critic_loss     | 0.0017   |
# |    ent_coef        | 0.000557 |
# |    ent_coef_loss   | -0.338   |
# |    learning_rate   | 9.73e-05 |
# |    n_updates       | 647488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | 126      |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 317      |
# |    time_elapsed    | 8289     |
# |    total_timesteps | 2630304  |
# | train/             |          |
# |    actor_loss      | -0.444   |
# |    critic_loss     | 0.00157  |
# |    ent_coef        | 0.000576 |
# |    ent_coef_loss   | -0.594   |
# |    learning_rate   | 9e-05    |
# |    n_updates       | 655040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | 162      |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 317      |
# |    time_elapsed    | 8717     |
# |    total_timesteps | 2767796  |
# | train/             |          |
# |    actor_loss      | -0.428   |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000584 |
# |    ent_coef_loss   | 0.613    |
# |    learning_rate   | 5.65e-05 |
# |    n_updates       | 689408   |
# ---------------------------------
# Eval num_timesteps=2800000, episode_reward=109.36 +/- 143.12
# Episode length: 1030.80 +/- 599.64
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.03e+03 |
# |    mean_reward     | 109      |
# | time/              |          |
# |    total_timesteps | 2800000  |
# | train/             |          |
# |    actor_loss      | -0.419   |
# |    critic_loss     | 0.00167  |
# |    ent_coef        | 0.000594 |
# |    ent_coef_loss   | 0.31     |
# |    learning_rate   | 4.87e-05 |
# |    n_updates       | 697472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | 150      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 317      |
# |    time_elapsed    | 9153     |
# |    total_timesteps | 2906016  |
# | train/             |          |
# |    actor_loss      | -0.387   |
# |    critic_loss     | 0.00128  |
# |    ent_coef        | 0.000575 |
# |    ent_coef_loss   | -0.349   |
# |    learning_rate   | 2.29e-05 |
# |    n_updates       | 723968   |
# ---------------------------------
# Eval num_timesteps=3000000, episode_reward=186.70 +/- 109.38
# Episode length: 1278.40 +/- 423.61
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.28e+03 |
# |    mean_reward     | 187      |
# | time/              |          |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -0.352   |
# |    critic_loss     | 0.00162  |
# |    ent_coef        | 0.0006   |
# |    ent_coef_loss   | -0.508   |
# |    learning_rate   | 4.67e-08 |
# |    n_updates       | 747456   |
# ---------------------------------
# Training finished.
# --- Recording Video for tqc_v3_hardcore_rerun_20251227_1644 ---
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_rerun_20251227_1644/tqc_v3_hardcore_rerun_20251227_1644_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_rerun_20251227_1644/tqc_v3_hardcore_rerun_20251227_1644_agent-step-0-to-step-2000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_rerun_20251227_1644/tqc_v3_hardcore_rerun_20251227_1644_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from google.colab import drive

# 1. SETUP
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# --- USER INPUT ---
EXPERIMENT_NAME = "tqc_v3_hardcore_rerun_20251227_1644"
BASE_PATH = "/content/drive/MyDrive/aisf_project"
# ------------------

LOG_DIR = f"{BASE_PATH}/logs/{EXPERIMENT_NAME}"
EVAL_FILE = f"{LOG_DIR}/evaluations.npz"

plt.figure(figsize=(12, 6))

# --- PART A: FIND BEST MEAN REWARD (From Evaluations) ---
if os.path.exists(EVAL_FILE):
    data = np.load(EVAL_FILE)
    timesteps = data['timesteps']
    results = data['results'] # Shape: (n_evaluations, n_eval_episodes)

    # Calculate mean and std for each evaluation step
    means = np.mean(results, axis=1)
    stds = np.std(results, axis=1)

    # Find the best record
    best_idx = np.argmax(means)
    best_reward = means[best_idx]
    best_step = timesteps[best_idx]

    print(f"🏆 BEST MEAN REWARD: {best_reward:.2f} (at timestep {best_step})")

    # Plot Evaluation Curve
    plt.plot(timesteps, means, label='Evaluation Mean Reward', color='blue', linewidth=2)
    plt.fill_between(timesteps, means - stds, means + stds, color='blue', alpha=0.2, label='Std Dev')

    # Mark the best point
    plt.scatter([best_step], [best_reward], color='red', zorder=5)
    plt.text(best_step, best_reward + 5, f"Best: {best_reward:.1f}", color='red', fontweight='bold')

else:
    print("⚠️ No evaluations.npz found. Did EvalCallback run yet?")

# --- PART B: DRAW TRAINING CURVE (From Monitor CSVs) ---
def load_monitor_logs(log_dir):
    all_dfs = []
    # Find all 0.monitor.csv, 1.monitor.csv, etc.
    for file in os.listdir(log_dir):
        if file.endswith("monitor.csv"):
            try:
                # Skip first 2 lines (header info)
                df = pd.read_csv(os.path.join(log_dir, file), skiprows=1)
                all_dfs.append(df)
            except Exception as e:
                print(f"Skipping {file}: {e}")

    if not all_dfs:
        return None

    # Combine all CPU logs
    combined_df = pd.concat(all_dfs)
    # Sort by total time or walltime to approximate order
    combined_df = combined_df.sort_values(by='t')

    # Create cumulative timesteps
    # Note: 'l' is episode length. We estimate total steps by cumulative sum of lengths.
    combined_df['cumulative_steps'] = combined_df['l'].cumsum()

    return combined_df

train_df = load_monitor_logs(LOG_DIR)

if train_df is not None:
    # Calculate Rolling Average (Window of 100 episodes)
    window = 100
    train_df['rolling_reward'] = train_df['r'].rolling(window=window).mean()

    plt.plot(train_df['cumulative_steps'], train_df['rolling_reward'],
             color='orange', alpha=0.6, label=f'Training Reward ({window}-ep avg)')
else:
    print("⚠️ No monitor.csv files found. Check your log directory.")

# --- FINAL PLOT CONFIG ---
plt.title(f"Learning Curve: {EXPERIMENT_NAME}")
plt.xlabel("Timesteps")
plt.ylabel("Reward")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=300, color='green', linestyle='--', label='Hardcore Solved (300)')
plt.show()
# Out:
# 🏆 BEST MEAN REWARD: 256.10 (at timestep 2600000)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# Install dependencies if you restarted the runtime
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import torch
import numpy as np
import base64
from datetime import datetime
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# TIMESTAMP: Ensures unique folder for every run
timestamp = datetime.now().strftime("%Y%m%d_%H%M")
EXPERIMENT_NAME = f"tqc_v3_hardcore_rerun_{timestamp}"

ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
SEED = 42
NUM_CPU = 4

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

print(f"Logging to: {log_dir}")

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

# --- ENVIRONMENT MAKER ---
def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        # UNIQUE MONITOR: Prevents parallel crash & overwriting
        env = Monitor(env, os.path.join(log_dir, str(rank)))
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} ---")

    # 1. PARALLEL ENVIRONMENTS
    # Ranks 0, 1, 2, 3 created here.
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])

    # 2. NORMALIZATION
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # Eval Env (Rank 999 to be safe)
    eval_env = SubprocVecEnv([make_env(999, SEED)])
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # --- TQC CONFIGURATION ---
    policy_kwargs = dict(
        n_critics=2,
        n_quantiles=25,
        net_arch=[400, 300],
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,
        learning_rate=linear_schedule(7.3e-4),
        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,
        train_freq=64,
        gradient_steps=64,
        learning_starts=10_000,
        use_sde=False
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    # --- CRITICAL FIX ---
    # We use rank 1000 here.
    # If we used rank 0, 'Monitor' would overwrite '0.monitor.csv'
    # and destroy 25% of the training data.
    env = DummyVecEnv([make_env(1000, SEED)])

    # Load Stats
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = TQC.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)
        if isinstance(done, (list, np.ndarray)):
             done = done[0]

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Logging to: /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_rerun_20251227_1928
# --- Starting Training: tqc_v3_hardcore_rerun_20251227_1928 ---
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_rerun_20251227_1928/TQC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.03e+03 |
# |    ep_rew_mean     | -118     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 342      |
# |    time_elapsed    | 304      |
# |    total_timesteps | 104392   |
# | train/             |          |
# |    actor_loss      | -2.97    |
# |    critic_loss     | 0.00307  |
# |    ent_coef        | 0.000429 |
# |    ent_coef_loss   | 0.214    |
# |    learning_rate   | 0.000705 |
# |    n_updates       | 23552    |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=-54.71 +/- 25.32
# Episode length: 1638.20 +/- 723.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.64e+03 |
# |    mean_reward     | -54.7    |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 0.355    |
# |    critic_loss     | 0.00193  |
# |    ent_coef        | 0.000427 |
# |    ent_coef_loss   | -0.257   |
# |    learning_rate   | 0.000681 |
# |    n_updates       | 47488    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | -92.3    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 321      |
# |    time_elapsed    | 697      |
# |    total_timesteps | 224020   |
# | train/             |          |
# |    actor_loss      | 0.441    |
# |    critic_loss     | 0.00229  |
# |    ent_coef        | 0.00036  |
# |    ent_coef_loss   | 0.451    |
# |    learning_rate   | 0.000675 |
# |    n_updates       | 53504    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 893      |
# |    ep_rew_mean     | -89.4    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 319      |
# |    time_elapsed    | 976      |
# |    total_timesteps | 311508   |
# | train/             |          |
# |    actor_loss      | 0.44     |
# |    critic_loss     | 0.00247  |
# |    ent_coef        | 0.000479 |
# |    ent_coef_loss   | 0.541    |
# |    learning_rate   | 0.000654 |
# |    n_updates       | 75328    |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=-83.07 +/- 34.88
# Episode length: 1637.00 +/- 726.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.64e+03 |
# |    mean_reward     | -83.1    |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 0.457    |
# |    critic_loss     | 0.00313  |
# |    ent_coef        | 0.000529 |
# |    ent_coef_loss   | 0.111    |
# |    learning_rate   | 0.000633 |
# |    n_updates       | 97472    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 961      |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 315      |
# |    time_elapsed    | 1292     |
# |    total_timesteps | 407536   |
# | train/             |          |
# |    actor_loss      | 0.449    |
# |    critic_loss     | 0.00348  |
# |    ent_coef        | 0.000553 |
# |    ent_coef_loss   | 1.1      |
# |    learning_rate   | 0.000631 |
# |    n_updates       | 99328    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.04e+03 |
# |    ep_rew_mean     | -72.8    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 314      |
# |    time_elapsed    | 1627     |
# |    total_timesteps | 512356   |
# | train/             |          |
# |    actor_loss      | 0.362    |
# |    critic_loss     | 0.0032   |
# |    ent_coef        | 0.000537 |
# |    ent_coef_loss   | -0.388   |
# |    learning_rate   | 0.000605 |
# |    n_updates       | 125568   |
# ---------------------------------
# Eval num_timesteps=600000, episode_reward=-29.18 +/- 93.74
# Episode length: 1694.40 +/- 611.20
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.69e+03 |
# |    mean_reward     | -29.2    |
# | time/              |          |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | 0.328    |
# |    critic_loss     | 0.00321  |
# |    ent_coef        | 0.000528 |
# |    ent_coef_loss   | 0.717    |
# |    learning_rate   | 0.000584 |
# |    n_updates       | 147456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.02e+03 |
# |    ep_rew_mean     | -63.7    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 313      |
# |    time_elapsed    | 1962     |
# |    total_timesteps | 614196   |
# | train/             |          |
# |    actor_loss      | 0.328    |
# |    critic_loss     | 0.00305  |
# |    ent_coef        | 0.000577 |
# |    ent_coef_loss   | 0.584    |
# |    learning_rate   | 0.000581 |
# |    n_updates       | 151040   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | -34.5    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 312      |
# |    time_elapsed    | 2383     |
# |    total_timesteps | 745500   |
# | train/             |          |
# |    actor_loss      | 0.163    |
# |    critic_loss     | 0.00312  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | -0.591   |
# |    learning_rate   | 0.000549 |
# |    n_updates       | 183872   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=-12.70 +/- 71.57
# Episode length: 1263.80 +/- 546.88
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.26e+03 |
# |    mean_reward     | -12.7    |
# | time/              |          |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | 0.191    |
# |    critic_loss     | 0.00315  |
# |    ent_coef        | 0.000596 |
# |    ent_coef_loss   | -1.61    |
# |    learning_rate   | 0.000535 |
# |    n_updates       | 197440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.42e+03 |
# |    ep_rew_mean     | -14.8    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 311      |
# |    time_elapsed    | 2840     |
# |    total_timesteps | 886188   |
# | train/             |          |
# |    actor_loss      | 0.102    |
# |    critic_loss     | 0.00328  |
# |    ent_coef        | 0.000639 |
# |    ent_coef_loss   | -0.0696  |
# |    learning_rate   | 0.000514 |
# |    n_updates       | 219008   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=3.87 +/- 53.28
# Episode length: 1423.80 +/- 730.19
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.42e+03 |
# |    mean_reward     | 3.87     |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 0.145    |
# |    critic_loss     | 0.0036   |
# |    ent_coef        | 0.000591 |
# |    ent_coef_loss   | 0.436    |
# |    learning_rate   | 0.000487 |
# |    n_updates       | 247488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 11.9     |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 311      |
# |    time_elapsed    | 3264     |
# |    total_timesteps | 1016336  |
# | train/             |          |
# |    actor_loss      | 0.136    |
# |    critic_loss     | 0.00357  |
# |    ent_coef        | 0.00063  |
# |    ent_coef_loss   | 0.395    |
# |    learning_rate   | 0.000483 |
# |    n_updates       | 251584   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 48.1     |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 311      |
# |    time_elapsed    | 3708     |
# |    total_timesteps | 1155560  |
# | train/             |          |
# |    actor_loss      | 0.00398  |
# |    critic_loss     | 0.00358  |
# |    ent_coef        | 0.000679 |
# |    ent_coef_loss   | 0.672    |
# |    learning_rate   | 0.000449 |
# |    n_updates       | 286336   |
# ---------------------------------
# Eval num_timesteps=1200000, episode_reward=-60.24 +/- 100.28
# Episode length: 2000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2e+03    |
# |    mean_reward     | -60.2    |
# | time/              |          |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -0.0412  |
# |    critic_loss     | 0.00392  |
# |    ent_coef        | 0.000761 |
# |    ent_coef_loss   | 0.452    |
# |    learning_rate   | 0.000438 |
# |    n_updates       | 297472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | 53       |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 310      |
# |    time_elapsed    | 4199     |
# |    total_timesteps | 1304712  |
# | train/             |          |
# |    actor_loss      | -0.158   |
# |    critic_loss     | 0.0029   |
# |    ent_coef        | 0.000722 |
# |    ent_coef_loss   | -0.563   |
# |    learning_rate   | 0.000413 |
# |    n_updates       | 323648   |
# ---------------------------------
# Eval num_timesteps=1400000, episode_reward=53.22 +/- 149.74
# Episode length: 1523.20 +/- 685.94
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.52e+03 |
# |    mean_reward     | 53.2     |
# | time/              |          |
# |    total_timesteps | 1400000  |
# | train/             |          |
# |    actor_loss      | -0.203   |
# |    critic_loss     | 0.00269  |
# |    ent_coef        | 0.000698 |
# |    ent_coef_loss   | -0.0448  |
# |    learning_rate   | 0.000389 |
# |    n_updates       | 347456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.57e+03 |
# |    ep_rew_mean     | 97.3     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 310      |
# |    time_elapsed    | 4707     |
# |    total_timesteps | 1460708  |
# | train/             |          |
# |    actor_loss      | -0.218   |
# |    critic_loss     | 0.00255  |
# |    ent_coef        | 0.000668 |
# |    ent_coef_loss   | 0.0742   |
# |    learning_rate   | 0.000375 |
# |    n_updates       | 362624   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | 94.5     |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 310      |
# |    time_elapsed    | 5143     |
# |    total_timesteps | 1597472  |
# | train/             |          |
# |    actor_loss      | -0.318   |
# |    critic_loss     | 0.00251  |
# |    ent_coef        | 0.000611 |
# |    ent_coef_loss   | 0.196    |
# |    learning_rate   | 0.000341 |
# |    n_updates       | 396864   |
# ---------------------------------
# Eval num_timesteps=1600000, episode_reward=85.80 +/- 62.95
# Episode length: 1750.80 +/- 498.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.75e+03 |
# |    mean_reward     | 85.8     |
# | time/              |          |
# |    total_timesteps | 1600000  |
# | train/             |          |
# |    actor_loss      | -0.328   |
# |    critic_loss     | 0.00218  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | -0.0693  |
# |    learning_rate   | 0.000341 |
# |    n_updates       | 397440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 68.9     |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 310      |
# |    time_elapsed    | 5585     |
# |    total_timesteps | 1732208  |
# | train/             |          |
# |    actor_loss      | -0.345   |
# |    critic_loss     | 0.00207  |
# |    ent_coef        | 0.000579 |
# |    ent_coef_loss   | 0.289    |
# |    learning_rate   | 0.000309 |
# |    n_updates       | 430528   |
# ---------------------------------
# Eval num_timesteps=1800000, episode_reward=79.96 +/- 153.97
# Episode length: 1080.60 +/- 659.89
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.08e+03 |
# |    mean_reward     | 80       |
# | time/              |          |
# |    total_timesteps | 1800000  |
# | train/             |          |
# |    actor_loss      | -0.379   |
# |    critic_loss     | 0.00218  |
# |    ent_coef        | 0.000545 |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.000292 |
# |    n_updates       | 447488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 158      |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 310      |
# |    time_elapsed    | 6032     |
# |    total_timesteps | 1870456  |
# | train/             |          |
# |    actor_loss      | -0.439   |
# |    critic_loss     | 0.00195  |
# |    ent_coef        | 0.000555 |
# |    ent_coef_loss   | -0.277   |
# |    learning_rate   | 0.000275 |
# |    n_updates       | 465088   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 130      |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 310      |
# |    time_elapsed    | 6419     |
# |    total_timesteps | 1992176  |
# | train/             |          |
# |    actor_loss      | -0.5     |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000579 |
# |    ent_coef_loss   | -0.365   |
# |    learning_rate   | 0.000245 |
# |    n_updates       | 495488   |
# ---------------------------------
# Eval num_timesteps=2000000, episode_reward=106.80 +/- 134.72
# Episode length: 1481.80 +/- 425.18
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.48e+03 |
# |    mean_reward     | 107      |
# | time/              |          |
# |    total_timesteps | 2000000  |
# | train/             |          |
# |    actor_loss      | -0.472   |
# |    critic_loss     | 0.00196  |
# |    ent_coef        | 0.00059  |
# |    ent_coef_loss   | 0.348    |
# |    learning_rate   | 0.000243 |
# |    n_updates       | 497472   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 309      |
# |    time_elapsed    | 6851     |
# |    total_timesteps | 2123804  |
# | train/             |          |
# |    actor_loss      | -0.523   |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000581 |
# |    ent_coef_loss   | 1.39     |
# |    learning_rate   | 0.000213 |
# |    n_updates       | 528448   |
# ---------------------------------
# Eval num_timesteps=2200000, episode_reward=147.82 +/- 116.46
# Episode length: 1439.40 +/- 534.55
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.44e+03 |
# |    mean_reward     | 148      |
# | time/              |          |
# |    total_timesteps | 2200000  |
# | train/             |          |
# |    actor_loss      | -0.522   |
# |    critic_loss     | 0.00162  |
# |    ent_coef        | 0.000569 |
# |    ent_coef_loss   | -0.677   |
# |    learning_rate   | 0.000195 |
# |    n_updates       | 547456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 107      |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 309      |
# |    time_elapsed    | 7321     |
# |    total_timesteps | 2268268  |
# | train/             |          |
# |    actor_loss      | -0.535   |
# |    critic_loss     | 0.00164  |
# |    ent_coef        | 0.00056  |
# |    ent_coef_loss   | 0.33     |
# |    learning_rate   | 0.000178 |
# |    n_updates       | 564544   |
# ---------------------------------
# Eval num_timesteps=2400000, episode_reward=137.00 +/- 158.27
# Episode length: 968.40 +/- 494.07
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 968      |
# |    mean_reward     | 137      |
# | time/              |          |
# |    total_timesteps | 2400000  |
# | train/             |          |
# |    actor_loss      | -0.593   |
# |    critic_loss     | 0.00156  |
# |    ent_coef        | 0.000596 |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.000146 |
# |    n_updates       | 597440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 309      |
# |    time_elapsed    | 7779     |
# |    total_timesteps | 2409904  |
# | train/             |          |
# |    actor_loss      | -0.61    |
# |    critic_loss     | 0.00145  |
# |    ent_coef        | 0.000586 |
# |    ent_coef_loss   | -0.491   |
# |    learning_rate   | 0.000144 |
# |    n_updates       | 599936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 147      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 309      |
# |    time_elapsed    | 8179     |
# |    total_timesteps | 2535380  |
# | train/             |          |
# |    actor_loss      | -0.595   |
# |    critic_loss     | 0.00178  |
# |    ent_coef        | 0.000591 |
# |    ent_coef_loss   | 0.429    |
# |    learning_rate   | 0.000113 |
# |    n_updates       | 631296   |
# ---------------------------------
# Eval num_timesteps=2600000, episode_reward=260.89 +/- 20.78
# Episode length: 1406.80 +/- 297.13
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.41e+03 |
# |    mean_reward     | 261      |
# | time/              |          |
# |    total_timesteps | 2600000  |
# | train/             |          |
# |    actor_loss      | -0.61    |
# |    critic_loss     | 0.00146  |
# |    ent_coef        | 0.000585 |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 9.73e-05 |
# |    n_updates       | 647488   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 309      |
# |    time_elapsed    | 8608     |
# |    total_timesteps | 2667264  |
# | train/             |          |
# |    actor_loss      | -0.615   |
# |    critic_loss     | 0.00135  |
# |    ent_coef        | 0.000567 |
# |    ent_coef_loss   | -0.337   |
# |    learning_rate   | 8.1e-05  |
# |    n_updates       | 664256   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 310      |
# |    time_elapsed    | 9030     |
# |    total_timesteps | 2799820  |
# | train/             |          |
# |    actor_loss      | -0.666   |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.000608 |
# |    ent_coef_loss   | -0.485   |
# |    learning_rate   | 4.88e-05 |
# |    n_updates       | 697408   |
# ---------------------------------
# Eval num_timesteps=2800000, episode_reward=274.19 +/- 5.11
# Episode length: 1223.60 +/- 66.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.22e+03 |
# |    mean_reward     | 274      |
# | time/              |          |
# |    total_timesteps | 2800000  |
# | train/             |          |
# |    actor_loss      | -0.654   |
# |    critic_loss     | 0.00132  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | -0.121   |
# |    learning_rate   | 4.87e-05 |
# |    n_updates       | 697472   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 160      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 309      |
# |    time_elapsed    | 9423     |
# |    total_timesteps | 2920612  |
# | train/             |          |
# |    actor_loss      | -0.613   |
# |    critic_loss     | 0.00163  |
# |    ent_coef        | 0.000591 |
# |    ent_coef_loss   | -0.267   |
# |    learning_rate   | 1.94e-05 |
# |    n_updates       | 727616   |
# ---------------------------------
# Eval num_timesteps=3000000, episode_reward=226.37 +/- 70.59
# Episode length: 1363.20 +/- 328.58
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.36e+03 |
# |    mean_reward     | 226      |
# | time/              |          |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -0.559   |
# |    critic_loss     | 0.00151  |
# |    ent_coef        | 0.000593 |
# |    ent_coef_loss   | -0.0149  |
# |    learning_rate   | 4.67e-08 |
# |    n_updates       | 747456   |
# ---------------------------------
# Training finished.
# --- Recording Video for tqc_v3_hardcore_rerun_20251227_1928 ---
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_rerun_20251227_1928/tqc_v3_hardcore_rerun_20251227_1928_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_rerun_20251227_1928/tqc_v3_hardcore_rerun_20251227_1928_agent-step-0-to-step-2000.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_rerun_20251227_1928/tqc_v3_hardcore_rerun_20251227_1928_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from google.colab import drive

# 1. SETUP
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# --- USER INPUT ---
EXPERIMENT_NAME = "tqc_v3_hardcore_rerun_20251227_1928"
BASE_PATH = "/content/drive/MyDrive/aisf_project"
# ------------------

LOG_DIR = f"{BASE_PATH}/logs/{EXPERIMENT_NAME}"
EVAL_FILE = f"{LOG_DIR}/evaluations.npz"

plt.figure(figsize=(12, 6))

# --- PART A: FIND BEST MEAN REWARD (From Evaluations) ---
if os.path.exists(EVAL_FILE):
    data = np.load(EVAL_FILE)
    timesteps = data['timesteps']
    results = data['results'] # Shape: (n_evaluations, n_eval_episodes)

    # Calculate mean and std for each evaluation step
    means = np.mean(results, axis=1)
    stds = np.std(results, axis=1)

    # Find the best record
    best_idx = np.argmax(means)
    best_reward = means[best_idx]
    best_step = timesteps[best_idx]

    print(f"🏆 BEST MEAN REWARD: {best_reward:.2f} (at timestep {best_step})")

    # Plot Evaluation Curve
    plt.plot(timesteps, means, label='Evaluation Mean Reward', color='blue', linewidth=2)
    plt.fill_between(timesteps, means - stds, means + stds, color='blue', alpha=0.2, label='Std Dev')

    # Mark the best point
    plt.scatter([best_step], [best_reward], color='red', zorder=5)
    plt.text(best_step, best_reward + 5, f"Best: {best_reward:.1f}", color='red', fontweight='bold')

else:
    print("⚠️ No evaluations.npz found. Did EvalCallback run yet?")

# --- PART B: DRAW TRAINING CURVE (From Monitor CSVs) ---
def load_monitor_logs(log_dir):
    all_dfs = []
    # Find all 0.monitor.csv, 1.monitor.csv, etc.
    for file in os.listdir(log_dir):
        if file.endswith("monitor.csv"):
            try:
                # Skip first 2 lines (header info)
                df = pd.read_csv(os.path.join(log_dir, file), skiprows=1)
                all_dfs.append(df)
            except Exception as e:
                print(f"Skipping {file}: {e}")

    if not all_dfs:
        return None

    # Combine all CPU logs
    combined_df = pd.concat(all_dfs)
    # Sort by total time or walltime to approximate order
    combined_df = combined_df.sort_values(by='t')

    # Create cumulative timesteps
    # Note: 'l' is episode length. We estimate total steps by cumulative sum of lengths.
    combined_df['cumulative_steps'] = combined_df['l'].cumsum()

    return combined_df

train_df = load_monitor_logs(LOG_DIR)

if train_df is not None:
    # Calculate Rolling Average (Window of 100 episodes)
    window = 100
    train_df['rolling_reward'] = train_df['r'].rolling(window=window).mean()

    plt.plot(train_df['cumulative_steps'], train_df['rolling_reward'],
             color='orange', alpha=0.6, label=f'Training Reward ({window}-ep avg)')
else:
    print("⚠️ No monitor.csv files found. Check your log directory.")

# --- FINAL PLOT CONFIG ---
plt.title(f"Learning Curve: {EXPERIMENT_NAME}")
plt.xlabel("Timesteps")
plt.ylabel("Reward")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=300, color='green', linestyle='--', label='Hardcore Solved (300)')
plt.show()
# Out:
# 🏆 BEST MEAN REWARD: 274.19 (at timestep 2800000)

# %%
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib
import gymnasium as gym
import os
import numpy as np
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# --- CONFIGURATION ---
OLD_EXP_NAME = "tqc_v3_hardcore_rerun_20251227_1928"
base_path = "/content/drive/MyDrive/aisf_project"

# Paths
old_model_path = f"{base_path}/models/{OLD_EXP_NAME}/best_model.zip"
old_stats_path = f"{base_path}/models/{OLD_EXP_NAME}/vec_normalize.pkl"

NEW_EXP_NAME = f"{OLD_EXP_NAME}_resume_3M"
log_dir = f"{base_path}/logs/{NEW_EXP_NAME}"
model_dir = f"{base_path}/models/{NEW_EXP_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)

ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
NUM_CPU = 4
SEED = 42

# --- ENVIRONMENT SETUP ---
def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        # Unique log file for each CPU
        log_file = os.path.join(log_dir, str(rank))
        env = Monitor(env, log_file)
        env.reset(seed=seed + rank)
        return env
    return _init

def resume_training():
    print(f"--- Resuming Training from: {OLD_EXP_NAME} ---")

    # 1. Setup Parallel Environment
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])

    # 2. Load Training Normalization Stats
    if os.path.exists(old_stats_path):
        print(f"Loaded VecNormalize stats from: {old_stats_path}")
        env = VecNormalize.load(old_stats_path, env)
        env.training = True
        env.norm_reward = True
    else:
        raise FileNotFoundError(f"Stats not found at {old_stats_path}")

    # 3. Load the Model with Custom Objects (Safe LR override)
    print(f"Loading TQC model from: {old_model_path}")

    # FIX 1: Override Learning Rate cleanly during load
    # We pass 'learning_rate' as a constant function (lambda) to avoid "float is not callable" error
    custom_objects = {
        "learning_rate": lambda _: 5e-5,
        "lr_schedule": lambda _: 5e-5,
        "clip_range": lambda _: 0.2 # Just in case
    }

    model = TQC.load(old_model_path, env=env, custom_objects=custom_objects)

    # 4. Setup Evaluation Environment
    eval_env = SubprocVecEnv([make_env(999, SEED)])

    # FIX 2: Load Stats into Eval Env
    # The evaluator must see the world exactly like the agent does!
    eval_env = VecNormalize.load(old_stats_path, eval_env)
    eval_env.training = False     # Do not update stats during eval
    eval_env.norm_reward = False  # Do not normalize reward (we want real score)

    # 5. Callbacks
    checkpoint_callback = CheckpointCallback(
        save_freq=100_000 // NUM_CPU,
        save_path=model_dir,
        name_prefix="tqc_resume"
    )

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # 6. Resume Learning
    print("Starting 3M step fine-tuning loop...")
    model.learn(
        total_timesteps=TOTAL_TIMESTEPS,
        callback=[eval_callback, checkpoint_callback],
        reset_num_timesteps=False
    )

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Resume Training Finished.")
    env.close()

if __name__ == "__main__":
    resume_training()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# The following additional packages will be installed:
#   swig4.0
# Suggested packages:
#   swig-doc swig-examples swig4.0-examples swig4.0-doc
# The following NEW packages will be installed:
#   swig swig4.0
# 0 upgraded, 2 newly installed, 0 to remove and 41 not upgraded.
# Need to get 1,116 kB of archives.
# After this operation, 5,542 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig4.0 amd64 4.0.2-1ubuntu1 [1,110 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 swig all 4.0.2-1ubuntu1 [5,632 B]
# Fetched 1,116 kB in 2s (537 kB/s)
# Selecting previously unselected package swig4.0.
# (Reading database ... 121689 files and directories currently installed.)
# Preparing to unpack .../swig4.0_4.0.2-1ubuntu1_amd64.deb ...
# Unpacking swig4.0 (4.0.2-1ubuntu1) ...
# Selecting previously unselected package swig.
# Preparing to unpack .../swig_4.0.2-1ubuntu1_all.deb ...
# Unpacking swig (4.0.2-1ubuntu1) ...
# Setting up swig4.0 (4.0.2-1ubuntu1) ...
# Setting up swig (4.0.2-1ubuntu1) ...
# Processing triggers for man-db (2.10.2-1) ...
# Collecting stable-baselines3
#   Downloading stable_baselines3-2.7.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting shimmy
#   Downloading Shimmy-2.0.0-py3-none-any.whl.metadata (3.5 kB)
# Collecting pyvirtualdisplay
#   Downloading PyVirtualDisplay-3.0-py3-none-any.whl.metadata (943 bytes)
# Collecting sb3-contrib
#   Downloading sb3_contrib-2.7.1-py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d])
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 30.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Collecting swig==4.* (from gymnasium[box2d])
#   Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Downloading swig-4.4.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 102.0 MB/s eta 0:00:00
# Downloading stable_baselines3-2.7.1-py3-none-any.whl (188 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.0/188.0 kB 21.4 MB/s eta 0:00:00
# Downloading Shimmy-2.0.0-py3-none-any.whl (30 kB)
# Downloading PyVirtualDisplay-3.0-py3-none-any.whl (15 kB)
# Downloading sb3_contrib-2.7.1-py3-none-any.whl (93 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 11.0 MB/s eta 0:00:00
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp312-cp312-linux_x86_64.whl size=2381957 sha256=1588989279f15c3306352ef4f264388dbb18440014705f4c90c086df5f334005
#   Stored in directory: /root/.cache/pip/wheels/2a/e9/60/774da0bcd07f7dc7761a8590fa2d065e4069568e78dcdc3318
# Successfully built box2d-py
# Installing collected packages: swig, pyvirtualdisplay, box2d-py, shimmy, stable-baselines3, sb3-contrib
# Successfully installed box2d-py-2.3.5 pyvirtualdisplay-3.0 sb3-contrib-2.7.1 shimmy-2.0.0 stable-baselines3-2.7.1 swig-4.4.1
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# --- Resuming Training from: tqc_v3_hardcore_rerun_20251227_1928 ---
# Loaded VecNormalize stats from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore_rerun_20251227_1928/vec_normalize.pkl
# Loading TQC model from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore_rerun_20251227_1928/best_model.zip
# Starting 3M step fine-tuning loop...
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore_rerun_20251227_1928/TQC_1
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Streaming output truncated to the last 5000 lines.
# |    ep_len_mean     | 1.24e+03 |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 3444     |
# |    fps             | 299      |
# |    time_elapsed    | 5289     |
# |    total_timesteps | 4384300  |
# | train/             |          |
# |    actor_loss      | -0.599   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.0006   |
# |    ent_coef_loss   | 0.0106   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1093504  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 187      |
# | time/              |          |
# |    episodes        | 3448     |
# |    fps             | 299      |
# |    time_elapsed    | 5306     |
# |    total_timesteps | 4389692  |
# | train/             |          |
# |    actor_loss      | -0.601   |
# |    critic_loss     | 0.00126  |
# |    ent_coef        | 0.0006   |
# |    ent_coef_loss   | -0.158   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1094848  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 3452     |
# |    fps             | 299      |
# |    time_elapsed    | 5322     |
# |    total_timesteps | 4394480  |
# | train/             |          |
# |    actor_loss      | -0.604   |
# |    critic_loss     | 0.00103  |
# |    ent_coef        | 0.000596 |
# |    ent_coef_loss   | 0.489    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1096064  |
# ---------------------------------
# Eval num_timesteps=4400000, episode_reward=208.15 +/- 89.05
# Episode length: 1269.40 +/- 376.66
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.27e+03 |
# |    mean_reward     | 208      |
# | time/              |          |
# |    total_timesteps | 4400000  |
# | train/             |          |
# |    actor_loss      | -0.603   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000599 |
# |    ent_coef_loss   | 0.439    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1097408  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 3456     |
# |    fps             | 299      |
# |    time_elapsed    | 5353     |
# |    total_timesteps | 4401428  |
# | train/             |          |
# |    actor_loss      | -0.609   |
# |    critic_loss     | 0.0012   |
# |    ent_coef        | 0.000602 |
# |    ent_coef_loss   | 0.3      |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1097792  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 3460     |
# |    fps             | 299      |
# |    time_elapsed    | 5371     |
# |    total_timesteps | 4406812  |
# | train/             |          |
# |    actor_loss      | -0.595   |
# |    critic_loss     | 0.0012   |
# |    ent_coef        | 0.000606 |
# |    ent_coef_loss   | 0.673    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1099136  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 3464     |
# |    fps             | 299      |
# |    time_elapsed    | 5396     |
# |    total_timesteps | 4414360  |
# | train/             |          |
# |    actor_loss      | -0.6     |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.000611 |
# |    ent_coef_loss   | 0.246    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1101056  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 3468     |
# |    fps             | 299      |
# |    time_elapsed    | 5411     |
# |    total_timesteps | 4419068  |
# | train/             |          |
# |    actor_loss      | -0.602   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | -0.391   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1102208  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 3472     |
# |    fps             | 299      |
# |    time_elapsed    | 5437     |
# |    total_timesteps | 4427068  |
# | train/             |          |
# |    actor_loss      | -0.6     |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.000615 |
# |    ent_coef_loss   | 0.0476   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1104192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 3476     |
# |    fps             | 299      |
# |    time_elapsed    | 5451     |
# |    total_timesteps | 4431016  |
# | train/             |          |
# |    actor_loss      | -0.611   |
# |    critic_loss     | 0.00115  |
# |    ent_coef        | 0.000614 |
# |    ent_coef_loss   | 0.62     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1105216  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 3480     |
# |    fps             | 299      |
# |    time_elapsed    | 5465     |
# |    total_timesteps | 4435556  |
# | train/             |          |
# |    actor_loss      | -0.597   |
# |    critic_loss     | 0.00108  |
# |    ent_coef        | 0.000613 |
# |    ent_coef_loss   | -0.207   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1106304  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 192      |
# | time/              |          |
# |    episodes        | 3484     |
# |    fps             | 299      |
# |    time_elapsed    | 5480     |
# |    total_timesteps | 4439912  |
# | train/             |          |
# |    actor_loss      | -0.606   |
# |    critic_loss     | 0.00113  |
# |    ent_coef        | 0.000613 |
# |    ent_coef_loss   | 0.77     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1107392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 188      |
# | time/              |          |
# |    episodes        | 3488     |
# |    fps             | 299      |
# |    time_elapsed    | 5500     |
# |    total_timesteps | 4445980  |
# | train/             |          |
# |    actor_loss      | -0.601   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | -0.0895  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1108928  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 184      |
# | time/              |          |
# |    episodes        | 3492     |
# |    fps             | 299      |
# |    time_elapsed    | 5522     |
# |    total_timesteps | 4452716  |
# | train/             |          |
# |    actor_loss      | -0.615   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000617 |
# |    ent_coef_loss   | 0.129    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1110592  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 3496     |
# |    fps             | 299      |
# |    time_elapsed    | 5543     |
# |    total_timesteps | 4458900  |
# | train/             |          |
# |    actor_loss      | -0.609   |
# |    critic_loss     | 0.00109  |
# |    ent_coef        | 0.00062  |
# |    ent_coef_loss   | -0.211   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1112192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 299      |
# |    time_elapsed    | 5557     |
# |    total_timesteps | 4463392  |
# | train/             |          |
# |    actor_loss      | -0.605   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | 0.387    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1113280  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 182      |
# | time/              |          |
# |    episodes        | 3504     |
# |    fps             | 299      |
# |    time_elapsed    | 5575     |
# |    total_timesteps | 4468856  |
# | train/             |          |
# |    actor_loss      | -0.618   |
# |    critic_loss     | 0.00115  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | 0.12     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1114624  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 186      |
# | time/              |          |
# |    episodes        | 3508     |
# |    fps             | 299      |
# |    time_elapsed    | 5590     |
# |    total_timesteps | 4473436  |
# | train/             |          |
# |    actor_loss      | -0.629   |
# |    critic_loss     | 0.0012   |
# |    ent_coef        | 0.00062  |
# |    ent_coef_loss   | -0.0916  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1115776  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 3512     |
# |    fps             | 299      |
# |    time_elapsed    | 5617     |
# |    total_timesteps | 4481436  |
# | train/             |          |
# |    actor_loss      | -0.63    |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000637 |
# |    ent_coef_loss   | 0.295    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1117824  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 176      |
# | time/              |          |
# |    episodes        | 3516     |
# |    fps             | 299      |
# |    time_elapsed    | 5637     |
# |    total_timesteps | 4487796  |
# | train/             |          |
# |    actor_loss      | -0.647   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000645 |
# |    ent_coef_loss   | 0.582    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1119360  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 3520     |
# |    fps             | 299      |
# |    time_elapsed    | 5658     |
# |    total_timesteps | 4494012  |
# | train/             |          |
# |    actor_loss      | -0.64    |
# |    critic_loss     | 0.00125  |
# |    ent_coef        | 0.000651 |
# |    ent_coef_loss   | 0.549    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1120960  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 172      |
# | time/              |          |
# |    episodes        | 3524     |
# |    fps             | 299      |
# |    time_elapsed    | 5678     |
# |    total_timesteps | 4500248  |
# | train/             |          |
# |    actor_loss      | -0.642   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000648 |
# |    ent_coef_loss   | -0.189   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1122496  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 172      |
# | time/              |          |
# |    episodes        | 3528     |
# |    fps             | 299      |
# |    time_elapsed    | 5686     |
# |    total_timesteps | 4502628  |
# | train/             |          |
# |    actor_loss      | -0.632   |
# |    critic_loss     | 0.00124  |
# |    ent_coef        | 0.000648 |
# |    ent_coef_loss   | 0.774    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1123072  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 3532     |
# |    fps             | 299      |
# |    time_elapsed    | 5706     |
# |    total_timesteps | 4508740  |
# | train/             |          |
# |    actor_loss      | -0.636   |
# |    critic_loss     | 0.00127  |
# |    ent_coef        | 0.000653 |
# |    ent_coef_loss   | -0.49    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1124608  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.36e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3536     |
# |    fps             | 299      |
# |    time_elapsed    | 5724     |
# |    total_timesteps | 4513980  |
# | train/             |          |
# |    actor_loss      | -0.634   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000643 |
# |    ent_coef_loss   | 0.41     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1125952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3540     |
# |    fps             | 299      |
# |    time_elapsed    | 5744     |
# |    total_timesteps | 4520084  |
# | train/             |          |
# |    actor_loss      | -0.628   |
# |    critic_loss     | 0.00131  |
# |    ent_coef        | 0.000652 |
# |    ent_coef_loss   | 0.535    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1127488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | 172      |
# | time/              |          |
# |    episodes        | 3544     |
# |    fps             | 299      |
# |    time_elapsed    | 5760     |
# |    total_timesteps | 4525008  |
# | train/             |          |
# |    actor_loss      | -0.635   |
# |    critic_loss     | 0.00109  |
# |    ent_coef        | 0.000655 |
# |    ent_coef_loss   | 0.112    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1128704  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.4e+03  |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 3548     |
# |    fps             | 299      |
# |    time_elapsed    | 5778     |
# |    total_timesteps | 4530540  |
# | train/             |          |
# |    actor_loss      | -0.637   |
# |    critic_loss     | 0.000987 |
# |    ent_coef        | 0.000655 |
# |    ent_coef_loss   | -0.68    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1130048  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 3552     |
# |    fps             | 299      |
# |    time_elapsed    | 5793     |
# |    total_timesteps | 4534992  |
# | train/             |          |
# |    actor_loss      | -0.652   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000642 |
# |    ent_coef_loss   | -0.885   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1131200  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 3556     |
# |    fps             | 299      |
# |    time_elapsed    | 5812     |
# |    total_timesteps | 4540844  |
# | train/             |          |
# |    actor_loss      | -0.652   |
# |    critic_loss     | 0.00105  |
# |    ent_coef        | 0.000629 |
# |    ent_coef_loss   | -0.72    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1132672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 3560     |
# |    fps             | 299      |
# |    time_elapsed    | 5833     |
# |    total_timesteps | 4547148  |
# | train/             |          |
# |    actor_loss      | -0.647   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000625 |
# |    ent_coef_loss   | 0.356    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1134208  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 3564     |
# |    fps             | 299      |
# |    time_elapsed    | 5850     |
# |    total_timesteps | 4552092  |
# | train/             |          |
# |    actor_loss      | -0.636   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000622 |
# |    ent_coef_loss   | -0.02    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1135488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.37e+03 |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 3568     |
# |    fps             | 299      |
# |    time_elapsed    | 5865     |
# |    total_timesteps | 4556984  |
# | train/             |          |
# |    actor_loss      | -0.645   |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | -0.569   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1136704  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3572     |
# |    fps             | 299      |
# |    time_elapsed    | 5876     |
# |    total_timesteps | 4560332  |
# | train/             |          |
# |    actor_loss      | -0.614   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000617 |
# |    ent_coef_loss   | -0.181   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1137536  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 176      |
# | time/              |          |
# |    episodes        | 3576     |
# |    fps             | 299      |
# |    time_elapsed    | 5893     |
# |    total_timesteps | 4565348  |
# | train/             |          |
# |    actor_loss      | -0.633   |
# |    critic_loss     | 0.00109  |
# |    ent_coef        | 0.000626 |
# |    ent_coef_loss   | 1.22     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1138752  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 3580     |
# |    fps             | 299      |
# |    time_elapsed    | 5908     |
# |    total_timesteps | 4569988  |
# | train/             |          |
# |    actor_loss      | -0.638   |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.000632 |
# |    ent_coef_loss   | 0.332    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1139968  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3584     |
# |    fps             | 299      |
# |    time_elapsed    | 5929     |
# |    total_timesteps | 4576288  |
# | train/             |          |
# |    actor_loss      | -0.634   |
# |    critic_loss     | 0.00101  |
# |    ent_coef        | 0.00063  |
# |    ent_coef_loss   | -0.648   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1141504  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 3588     |
# |    fps             | 299      |
# |    time_elapsed    | 5937     |
# |    total_timesteps | 4578892  |
# | train/             |          |
# |    actor_loss      | -0.638   |
# |    critic_loss     | 0.0011   |
# |    ent_coef        | 0.000627 |
# |    ent_coef_loss   | -0.00694 |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1142144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 171      |
# | time/              |          |
# |    episodes        | 3592     |
# |    fps             | 299      |
# |    time_elapsed    | 5961     |
# |    total_timesteps | 4586160  |
# | train/             |          |
# |    actor_loss      | -0.645   |
# |    critic_loss     | 0.00133  |
# |    ent_coef        | 0.000624 |
# |    ent_coef_loss   | 0.152    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1144000  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 3596     |
# |    fps             | 299      |
# |    time_elapsed    | 5977     |
# |    total_timesteps | 4591060  |
# | train/             |          |
# |    actor_loss      | -0.642   |
# |    critic_loss     | 0.00106  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | -0.65    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1145216  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 299      |
# |    time_elapsed    | 5994     |
# |    total_timesteps | 4596216  |
# | train/             |          |
# |    actor_loss      | -0.63    |
# |    critic_loss     | 0.00106  |
# |    ent_coef        | 0.000619 |
# |    ent_coef_loss   | -0.414   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1146496  |
# ---------------------------------
# Eval num_timesteps=4600000, episode_reward=160.37 +/- 156.47
# Episode length: 1282.00 +/- 399.36
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.28e+03 |
# |    mean_reward     | 160      |
# | time/              |          |
# |    total_timesteps | 4600000  |
# | train/             |          |
# |    actor_loss      | -0.643   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000613 |
# |    ent_coef_loss   | -0.557   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1147456  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 3604     |
# |    fps             | 299      |
# |    time_elapsed    | 6019     |
# |    total_timesteps | 4601152  |
# | train/             |          |
# |    actor_loss      | -0.644   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000611 |
# |    ent_coef_loss   | -0.259   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1147712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 169      |
# | time/              |          |
# |    episodes        | 3608     |
# |    fps             | 299      |
# |    time_elapsed    | 6037     |
# |    total_timesteps | 4606588  |
# | train/             |          |
# |    actor_loss      | -0.647   |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.000609 |
# |    ent_coef_loss   | -0.143   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1149056  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 3612     |
# |    fps             | 299      |
# |    time_elapsed    | 6052     |
# |    total_timesteps | 4611356  |
# | train/             |          |
# |    actor_loss      | -0.637   |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | 0.0684   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1150272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 174      |
# | time/              |          |
# |    episodes        | 3616     |
# |    fps             | 299      |
# |    time_elapsed    | 6069     |
# |    total_timesteps | 4616340  |
# | train/             |          |
# |    actor_loss      | -0.655   |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | 0.392    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1151552  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 3620     |
# |    fps             | 299      |
# |    time_elapsed    | 6089     |
# |    total_timesteps | 4622588  |
# | train/             |          |
# |    actor_loss      | -0.646   |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.000623 |
# |    ent_coef_loss   | 0.333    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1153088  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 176      |
# | time/              |          |
# |    episodes        | 3624     |
# |    fps             | 299      |
# |    time_elapsed    | 6103     |
# |    total_timesteps | 4626728  |
# | train/             |          |
# |    actor_loss      | -0.648   |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.000631 |
# |    ent_coef_loss   | -0.0519  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1154112  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 178      |
# | time/              |          |
# |    episodes        | 3628     |
# |    fps             | 299      |
# |    time_elapsed    | 6125     |
# |    total_timesteps | 4633692  |
# | train/             |          |
# |    actor_loss      | -0.645   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000615 |
# |    ent_coef_loss   | -0.511   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1155840  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 3632     |
# |    fps             | 299      |
# |    time_elapsed    | 6149     |
# |    total_timesteps | 4640760  |
# | train/             |          |
# |    actor_loss      | -0.644   |
# |    critic_loss     | 0.000961 |
# |    ent_coef        | 0.000604 |
# |    ent_coef_loss   | 0.0417   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1157632  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 3636     |
# |    fps             | 299      |
# |    time_elapsed    | 6156     |
# |    total_timesteps | 4642900  |
# | train/             |          |
# |    actor_loss      | -0.636   |
# |    critic_loss     | 0.00108  |
# |    ent_coef        | 0.000605 |
# |    ent_coef_loss   | 0.594    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1158144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 175      |
# | time/              |          |
# |    episodes        | 3640     |
# |    fps             | 299      |
# |    time_elapsed    | 6183     |
# |    total_timesteps | 4650900  |
# | train/             |          |
# |    actor_loss      | -0.634   |
# |    critic_loss     | 0.00108  |
# |    ent_coef        | 0.000603 |
# |    ent_coef_loss   | 0.276    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1160192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 3644     |
# |    fps             | 299      |
# |    time_elapsed    | 6197     |
# |    total_timesteps | 4655328  |
# | train/             |          |
# |    actor_loss      | -0.651   |
# |    critic_loss     | 0.00104  |
# |    ent_coef        | 0.000602 |
# |    ent_coef_loss   | 0.0993   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1161280  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3648     |
# |    fps             | 299      |
# |    time_elapsed    | 6206     |
# |    total_timesteps | 4658276  |
# | train/             |          |
# |    actor_loss      | -0.635   |
# |    critic_loss     | 0.000983 |
# |    ent_coef        | 0.000604 |
# |    ent_coef_loss   | 0.317    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1161984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3652     |
# |    fps             | 299      |
# |    time_elapsed    | 6226     |
# |    total_timesteps | 4664044  |
# | train/             |          |
# |    actor_loss      | -0.639   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | 0.136    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1163456  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | 164      |
# | time/              |          |
# |    episodes        | 3656     |
# |    fps             | 299      |
# |    time_elapsed    | 6235     |
# |    total_timesteps | 4666940  |
# | train/             |          |
# |    actor_loss      | -0.632   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000608 |
# |    ent_coef_loss   | 0.149    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1164160  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 3660     |
# |    fps             | 299      |
# |    time_elapsed    | 6252     |
# |    total_timesteps | 4672044  |
# | train/             |          |
# |    actor_loss      | -0.638   |
# |    critic_loss     | 0.0011   |
# |    ent_coef        | 0.000618 |
# |    ent_coef_loss   | 0.229    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1165440  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 167      |
# | time/              |          |
# |    episodes        | 3664     |
# |    fps             | 299      |
# |    time_elapsed    | 6269     |
# |    total_timesteps | 4677192  |
# | train/             |          |
# |    actor_loss      | -0.629   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000618 |
# |    ent_coef_loss   | 0.584    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1166720  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 3668     |
# |    fps             | 299      |
# |    time_elapsed    | 6293     |
# |    total_timesteps | 4684652  |
# | train/             |          |
# |    actor_loss      | -0.633   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000617 |
# |    ent_coef_loss   | 0.269    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1168576  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 3672     |
# |    fps             | 299      |
# |    time_elapsed    | 6309     |
# |    total_timesteps | 4689412  |
# | train/             |          |
# |    actor_loss      | -0.626   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000623 |
# |    ent_coef_loss   | 0.691    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1169792  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 3676     |
# |    fps             | 299      |
# |    time_elapsed    | 6327     |
# |    total_timesteps | 4694708  |
# | train/             |          |
# |    actor_loss      | -0.629   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000628 |
# |    ent_coef_loss   | 0.0376   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1171136  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 168      |
# | time/              |          |
# |    episodes        | 3680     |
# |    fps             | 299      |
# |    time_elapsed    | 6349     |
# |    total_timesteps | 4701324  |
# | train/             |          |
# |    actor_loss      | -0.616   |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.000629 |
# |    ent_coef_loss   | 0.256    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1172800  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 172      |
# | time/              |          |
# |    episodes        | 3684     |
# |    fps             | 299      |
# |    time_elapsed    | 6366     |
# |    total_timesteps | 4706880  |
# | train/             |          |
# |    actor_loss      | -0.625   |
# |    critic_loss     | 0.000926 |
# |    ent_coef        | 0.000625 |
# |    ent_coef_loss   | -0.423   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1174144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 173      |
# | time/              |          |
# |    episodes        | 3688     |
# |    fps             | 299      |
# |    time_elapsed    | 6382     |
# |    total_timesteps | 4711668  |
# | train/             |          |
# |    actor_loss      | -0.626   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000614 |
# |    ent_coef_loss   | -0.129   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1175360  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | 178      |
# ...
# |    fps             | 299      |
# |    time_elapsed    | 9595     |
# |    total_timesteps | 5673308  |
# | train/             |          |
# |    actor_loss      | -0.707   |
# |    critic_loss     | 0.0013   |
# |    ent_coef        | 0.000618 |
# |    ent_coef_loss   | 0.0786   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1415744  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.21e+03 |
# |    ep_rew_mean     | 216      |
# | time/              |          |
# |    episodes        | 4488     |
# |    fps             | 299      |
# |    time_elapsed    | 9610     |
# |    total_timesteps | 5677844  |
# | train/             |          |
# |    actor_loss      | -0.701   |
# |    critic_loss     | 0.00128  |
# |    ent_coef        | 0.000622 |
# |    ent_coef_loss   | 0.413    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1416896  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 222      |
# | time/              |          |
# |    episodes        | 4492     |
# |    fps             | 299      |
# |    time_elapsed    | 9625     |
# |    total_timesteps | 5682216  |
# | train/             |          |
# |    actor_loss      | -0.723   |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.000633 |
# |    ent_coef_loss   | 0.402    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1417984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 219      |
# | time/              |          |
# |    episodes        | 4496     |
# |    fps             | 299      |
# |    time_elapsed    | 9642     |
# |    total_timesteps | 5687568  |
# | train/             |          |
# |    actor_loss      | -0.711   |
# |    critic_loss     | 0.00134  |
# |    ent_coef        | 0.000643 |
# |    ent_coef_loss   | 0.43     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1419328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.2e+03  |
# |    ep_rew_mean     | 215      |
# | time/              |          |
# |    episodes        | 4500     |
# |    fps             | 299      |
# |    time_elapsed    | 9656     |
# |    total_timesteps | 5691808  |
# | train/             |          |
# |    actor_loss      | -0.712   |
# |    critic_loss     | 0.00131  |
# |    ent_coef        | 0.000645 |
# |    ent_coef_loss   | -0.113   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1420416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 213      |
# | time/              |          |
# |    episodes        | 4504     |
# |    fps             | 299      |
# |    time_elapsed    | 9672     |
# |    total_timesteps | 5696876  |
# | train/             |          |
# |    actor_loss      | -0.71    |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.00064  |
# |    ent_coef_loss   | -0.517   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1421632  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 4508     |
# |    fps             | 299      |
# |    time_elapsed    | 9682     |
# |    total_timesteps | 5699880  |
# | train/             |          |
# |    actor_loss      | -0.704   |
# |    critic_loss     | 0.0012   |
# |    ent_coef        | 0.000636 |
# |    ent_coef_loss   | -0.1     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1422400  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 4512     |
# |    fps             | 299      |
# |    time_elapsed    | 9696     |
# |    total_timesteps | 5704204  |
# | train/             |          |
# |    actor_loss      | -0.723   |
# |    critic_loss     | 0.0011   |
# |    ent_coef        | 0.000637 |
# |    ent_coef_loss   | 0.054    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1423488  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 207      |
# | time/              |          |
# |    episodes        | 4516     |
# |    fps             | 299      |
# |    time_elapsed    | 9709     |
# |    total_timesteps | 5708132  |
# | train/             |          |
# |    actor_loss      | -0.713   |
# |    critic_loss     | 0.00129  |
# |    ent_coef        | 0.000642 |
# |    ent_coef_loss   | 0.415    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1424448  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 210      |
# | time/              |          |
# |    episodes        | 4520     |
# |    fps             | 299      |
# |    time_elapsed    | 9727     |
# |    total_timesteps | 5713372  |
# | train/             |          |
# |    actor_loss      | -0.726   |
# |    critic_loss     | 0.00123  |
# |    ent_coef        | 0.000647 |
# |    ent_coef_loss   | 0.737    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1425792  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 4524     |
# |    fps             | 299      |
# |    time_elapsed    | 9743     |
# |    total_timesteps | 5718200  |
# | train/             |          |
# |    actor_loss      | -0.724   |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.000653 |
# |    ent_coef_loss   | -0.307   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1427008  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 4528     |
# |    fps             | 299      |
# |    time_elapsed    | 9755     |
# |    total_timesteps | 5722024  |
# | train/             |          |
# |    actor_loss      | -0.714   |
# |    critic_loss     | 0.00125  |
# |    ent_coef        | 0.000653 |
# |    ent_coef_loss   | 0.0325   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1427968  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 204      |
# | time/              |          |
# |    episodes        | 4532     |
# |    fps             | 299      |
# |    time_elapsed    | 9769     |
# |    total_timesteps | 5726376  |
# | train/             |          |
# |    actor_loss      | -0.731   |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.000653 |
# |    ent_coef_loss   | 0.141    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1429056  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 4536     |
# |    fps             | 299      |
# |    time_elapsed    | 9784     |
# |    total_timesteps | 5730732  |
# | train/             |          |
# |    actor_loss      | -0.721   |
# |    critic_loss     | 0.00111  |
# |    ent_coef        | 0.00065  |
# |    ent_coef_loss   | 0.156    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1430144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 4540     |
# |    fps             | 299      |
# |    time_elapsed    | 9798     |
# |    total_timesteps | 5735200  |
# | train/             |          |
# |    actor_loss      | -0.729   |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.000653 |
# |    ent_coef_loss   | 0.501    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1431232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 202      |
# | time/              |          |
# |    episodes        | 4544     |
# |    fps             | 299      |
# |    time_elapsed    | 9812     |
# |    total_timesteps | 5739604  |
# | train/             |          |
# |    actor_loss      | -0.729   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.00066  |
# |    ent_coef_loss   | -0.0908  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1432320  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 203      |
# | time/              |          |
# |    episodes        | 4548     |
# |    fps             | 299      |
# |    time_elapsed    | 9827     |
# |    total_timesteps | 5744072  |
# | train/             |          |
# |    actor_loss      | -0.729   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000657 |
# |    ent_coef_loss   | -0.0724  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1433472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.14e+03 |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 4552     |
# |    fps             | 299      |
# |    time_elapsed    | 9844     |
# |    total_timesteps | 5749160  |
# | train/             |          |
# |    actor_loss      | -0.725   |
# |    critic_loss     | 0.0015   |
# |    ent_coef        | 0.000646 |
# |    ent_coef_loss   | -0.0797  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1434752  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 200      |
# | time/              |          |
# |    episodes        | 4556     |
# |    fps             | 299      |
# |    time_elapsed    | 9852     |
# |    total_timesteps | 5751676  |
# | train/             |          |
# |    actor_loss      | -0.729   |
# |    critic_loss     | 0.0011   |
# |    ent_coef        | 0.000647 |
# |    ent_coef_loss   | -0.41    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1435328  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 198      |
# | time/              |          |
# |    episodes        | 4560     |
# |    fps             | 299      |
# |    time_elapsed    | 9873     |
# |    total_timesteps | 5757952  |
# | train/             |          |
# |    actor_loss      | -0.729   |
# |    critic_loss     | 0.00142  |
# |    ent_coef        | 0.000658 |
# |    ent_coef_loss   | 0.209    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1436928  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.12e+03 |
# |    ep_rew_mean     | 190      |
# | time/              |          |
# |    episodes        | 4564     |
# |    fps             | 299      |
# |    time_elapsed    | 9887     |
# |    total_timesteps | 5762304  |
# | train/             |          |
# |    actor_loss      | -0.731   |
# |    critic_loss     | 0.00126  |
# |    ent_coef        | 0.000653 |
# |    ent_coef_loss   | 0.023    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1438016  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 189      |
# | time/              |          |
# |    episodes        | 4568     |
# |    fps             | 299      |
# |    time_elapsed    | 9905     |
# |    total_timesteps | 5767584  |
# | train/             |          |
# |    actor_loss      | -0.72    |
# |    critic_loss     | 0.00161  |
# |    ent_coef        | 0.000643 |
# |    ent_coef_loss   | -0.752   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1439360  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.1e+03  |
# |    ep_rew_mean     | 191      |
# | time/              |          |
# |    episodes        | 4572     |
# |    fps             | 299      |
# |    time_elapsed    | 9924     |
# |    total_timesteps | 5773260  |
# | train/             |          |
# |    actor_loss      | -0.718   |
# |    critic_loss     | 0.0013   |
# |    ent_coef        | 0.000645 |
# |    ent_coef_loss   | 0.542    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1440768  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | 183      |
# | time/              |          |
# |    episodes        | 4576     |
# |    fps             | 299      |
# |    time_elapsed    | 9938     |
# |    total_timesteps | 5777692  |
# | train/             |          |
# |    actor_loss      | -0.712   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000649 |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1441856  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 4580     |
# |    fps             | 299      |
# |    time_elapsed    | 9958     |
# |    total_timesteps | 5783720  |
# | train/             |          |
# |    actor_loss      | -0.7     |
# |    critic_loss     | 0.00136  |
# |    ent_coef        | 0.000642 |
# |    ent_coef_loss   | 0.146    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1443392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 181      |
# | time/              |          |
# |    episodes        | 4584     |
# |    fps             | 299      |
# |    time_elapsed    | 9974     |
# |    total_timesteps | 5788680  |
# | train/             |          |
# |    actor_loss      | -0.702   |
# |    critic_loss     | 0.00124  |
# |    ent_coef        | 0.000634 |
# |    ent_coef_loss   | -0.476   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1444608  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.19e+03 |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 4588     |
# |    fps             | 299      |
# |    time_elapsed    | 9998     |
# |    total_timesteps | 5795780  |
# | train/             |          |
# |    actor_loss      | -0.707   |
# |    critic_loss     | 0.00128  |
# |    ent_coef        | 0.000632 |
# |    ent_coef_loss   | -0.271   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1446400  |
# ---------------------------------
# Eval num_timesteps=5800000, episode_reward=277.14 +/- 22.95
# Episode length: 1236.40 +/- 384.22
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.24e+03 |
# |    mean_reward     | 277      |
# | time/              |          |
# |    total_timesteps | 5800000  |
# | train/             |          |
# |    actor_loss      | -0.705   |
# |    critic_loss     | 0.00117  |
# |    ent_coef        | 0.000632 |
# |    ent_coef_loss   | -0.0963  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1447424  |
# ---------------------------------
# Resume Training Finished.

# %%
import gymnasium as gym
import numpy as np
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize
import os

# --- PATHS ---
# Make sure this matches the folder where your RESUME run saved its files
EXP_NAME = "tqc_v3_hardcore_rerun_20251227_1928_resume_3M"
base_path = "/content/drive/MyDrive/aisf_project"
model_path = f"{base_path}/models/{EXP_NAME}/best_model.zip"
stats_path = f"{base_path}/models/{EXP_NAME}/vec_normalize.pkl"

# --- SETUP ---
ENV_ID = "BipedalWalkerHardcore-v3"
print(f"--- Loading Model for Verification: {model_path} ---")

# 1. Create Env
env = DummyVecEnv([lambda: gym.make(ENV_ID, render_mode="rgb_array")])

# 2. Load Stats (CRITICAL)
# We must use the stats from the RESUME run
env = VecNormalize.load(stats_path, env)
env.training = False      # Do not update stats
env.norm_reward = False   # We want to see the REAL score (0 to 300), not normalized

# 3. Load Agent
model = TQC.load(model_path)

# --- RUN 100 EPISODES ---
n_episodes = 100
scores = []
successes = 0

print(f"Starting {n_episodes} Episode Test...")

for episode in range(1, n_episodes + 1):
    obs = env.reset()
    done = False
    episode_score = 0

    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, reward, done, info = env.step(action)
        episode_score += reward[0]

    scores.append(episode_score)

    # In Hardcore, finishing the level usually gives > 250 points
    if episode_score > 250:
        successes += 1

    print(f"Episode {episode}: {episode_score:.2f}")

# --- FINAL REPORT ---
mean_score = np.mean(scores)
std_score = np.std(scores)
min_score = np.min(scores)
max_score = np.max(scores)

print("\n" + "="*30)
print("FINAL RESULTS")
print("="*30)
print(f"Average Score: {mean_score:.2f} +/- {std_score:.2f}")
print(f"Max Score:     {max_score:.2f}")
print(f"Min Score:     {min_score:.2f}")
print(f"Success Rate:  {successes}/{n_episodes} ({successes}%)")
print("="*30)

if mean_score > 300:
    print("🏆 CONGRATULATIONS! YOU OFFICIALLY BEAT HARDCORE MODE! 🏆")
elif mean_score > 270:
    print("🥈 Incredible Performance. You have a stable, solving agent.")
else:
    print("Needs more work.")
# Out:
# --- Loading Model for Verification: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore_rerun_20251227_1928_resume_3M/best_model.zip ---
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Starting 100 Episode Test...
# Episode 1: 277.44
# Episode 2: 283.77
# Episode 3: -65.26
# Episode 4: 137.68
# Episode 5: 288.21
# Episode 6: 287.40
# Episode 7: 279.64
# Episode 8: 287.15
# Episode 9: 48.38
# Episode 10: 282.94
# Episode 11: -69.03
# Episode 12: 295.32
# Episode 13: 147.16
# Episode 14: -12.64
# Episode 15: 291.27
# Episode 16: 220.99
# Episode 17: 286.62
# Episode 18: 294.62
# Episode 19: 281.39
# Episode 20: 293.10
# Episode 21: 291.38
# Episode 22: 176.15
# Episode 23: 170.32
# Episode 24: 58.77
# Episode 25: 133.49
# Episode 26: 287.11
# Episode 27: 278.93
# Episode 28: 291.08
# Episode 29: 292.77
# Episode 30: 116.46
# Episode 31: -116.83
# Episode 32: 283.08
# Episode 33: 291.70
# Episode 34: 142.90
# Episode 35: 289.25
# Episode 36: 281.92
# Episode 37: 64.10
# Episode 38: -53.09
# Episode 39: 39.26
# Episode 40: 281.09
# Episode 41: 29.26
# Episode 42: 290.50
# Episode 43: 288.36
# Episode 44: -29.63
# Episode 45: -15.77
# Episode 46: 291.62
# Episode 47: 288.97
# Episode 48: 287.58
# Episode 49: 290.85
# Episode 50: 132.34
# Episode 51: 290.60
# Episode 52: 294.33
# Episode 53: 289.48
# Episode 54: 281.19
# Episode 55: 174.88
# Episode 56: 55.19
# Episode 57: 289.97
# Episode 58: 286.65
# Episode 59: 283.71
# Episode 60: 122.28
# Episode 61: 290.04
# Episode 62: 283.08
# Episode 63: 290.68
# Episode 64: 289.20
# Episode 65: 285.63
# Episode 66: 286.71
# Episode 67: 282.86
# Episode 68: 122.98
# Episode 69: 283.03
# Episode 70: 286.08
# Episode 71: 288.34
# Episode 72: 279.08
# Episode 73: 288.23
# Episode 74: 290.51
# Episode 75: 286.15
# Episode 76: -56.86
# Episode 77: 293.44
# Episode 78: 291.97
# Episode 79: 273.61
# Episode 80: 162.85
# Episode 81: 286.22
# Episode 82: 275.60
# Episode 83: 295.10
# Episode 84: 293.05
# Episode 85: 286.85
# Episode 86: 278.21
# Episode 87: 292.82
# Episode 88: 88.72
# Episode 89: -46.89
# Episode 90: 288.42
# Episode 91: 284.76
# Episode 92: 284.91
# Episode 93: 292.16
# Episode 94: 287.36
# Episode 95: 286.13
# Episode 96: 274.84
# Episode 97: 289.49
# Episode 98: 267.55
# Episode 99: 101.56
# Episode 100: -16.35
#
# ==============================
# FINAL RESULTS
# ==============================
# Average Score: 217.46 +/- 114.76
# Max Score:     295.32
# Min Score:     -116.83
# Success Rate:  69/100 (69%)
# ==============================
# Needs more work.

# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import pandas as pd
from google.colab import drive

# 1. SETUP
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

# --- USER INPUT ---
EXPERIMENT_NAME = "tqc_v3_hardcore_rerun_20251227_1928_resume_3M"
BASE_PATH = "/content/drive/MyDrive/aisf_project"
# ------------------

LOG_DIR = f"{BASE_PATH}/logs/{EXPERIMENT_NAME}"
EVAL_FILE = f"{LOG_DIR}/evaluations.npz"

plt.figure(figsize=(12, 6))

# --- PART A: FIND BEST MEAN REWARD (From Evaluations) ---
if os.path.exists(EVAL_FILE):
    data = np.load(EVAL_FILE)
    timesteps = data['timesteps']
    results = data['results'] # Shape: (n_evaluations, n_eval_episodes)

    # Calculate mean and std for each evaluation step
    means = np.mean(results, axis=1)
    stds = np.std(results, axis=1)

    # Find the best record
    best_idx = np.argmax(means)
    best_reward = means[best_idx]
    best_step = timesteps[best_idx]

    print(f"🏆 BEST MEAN REWARD: {best_reward:.2f} (at timestep {best_step})")

    # Plot Evaluation Curve
    plt.plot(timesteps, means, label='Evaluation Mean Reward', color='blue', linewidth=2)
    plt.fill_between(timesteps, means - stds, means + stds, color='blue', alpha=0.2, label='Std Dev')

    # Mark the best point
    plt.scatter([best_step], [best_reward], color='red', zorder=5)
    plt.text(best_step, best_reward + 5, f"Best: {best_reward:.1f}", color='red', fontweight='bold')

else:
    print("⚠️ No evaluations.npz found. Did EvalCallback run yet?")

# --- PART B: DRAW TRAINING CURVE (From Monitor CSVs) ---
def load_monitor_logs(log_dir):
    all_dfs = []
    # Find all 0.monitor.csv, 1.monitor.csv, etc.
    for file in os.listdir(log_dir):
        if file.endswith("monitor.csv"):
            try:
                # Skip first 2 lines (header info)
                df = pd.read_csv(os.path.join(log_dir, file), skiprows=1)
                all_dfs.append(df)
            except Exception as e:
                print(f"Skipping {file}: {e}")

    if not all_dfs:
        return None

    # Combine all CPU logs
    combined_df = pd.concat(all_dfs)
    # Sort by total time or walltime to approximate order
    combined_df = combined_df.sort_values(by='t')

    # Create cumulative timesteps
    # Note: 'l' is episode length. We estimate total steps by cumulative sum of lengths.
    combined_df['cumulative_steps'] = combined_df['l'].cumsum()

    return combined_df

train_df = load_monitor_logs(LOG_DIR)

if train_df is not None:
    # Calculate Rolling Average (Window of 100 episodes)
    window = 100
    train_df['rolling_reward'] = train_df['r'].rolling(window=window).mean()

    plt.plot(train_df['cumulative_steps'], train_df['rolling_reward'],
             color='orange', alpha=0.6, label=f'Training Reward ({window}-ep avg)')
else:
    print("⚠️ No monitor.csv files found. Check your log directory.")

# --- FINAL PLOT CONFIG ---
plt.title(f"Learning Curve: {EXPERIMENT_NAME}")
plt.xlabel("Timesteps")
plt.ylabel("Reward")
plt.legend()
plt.grid(True, alpha=0.3)
plt.axhline(y=300, color='green', linestyle='--', label='Hardcore Solved (300)')
plt.show()
# Out:
# 🏆 BEST MEAN REWARD: 281.34 (at timestep 5600000)
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)

# %%
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import base64
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
# IMPORTANT: Check your Drive to ensure this folder name matches exactly where your old model is!
LOAD_FROM_EXPERIMENT = "tqc_v3_hardcore"
EXPERIMENT_NAME = "tqc_v3_hardcore_finetune_rerun"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 2_000_000
NUM_CPU = 4

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

# Define paths to the OLD model we want to finetune
load_model_path = f"{base_path}/models/{LOAD_FROM_EXPERIMENT}/best_model.zip"
load_stats_path = f"{base_path}/models/{LOAD_FROM_EXPERIMENT}/vec_normalize.pkl"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        # 1. FIX: Unique filename per CPU to prevent overwriting
        env = Monitor(env, os.path.join(log_dir, str(rank)))
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Resuming Training: {EXPERIMENT_NAME} ---")

    # 1. Setup Environment
    env = SubprocVecEnv([make_env(i, 42) for i in range(NUM_CPU)])

    # 2. Load Normalization Stats
    print(f"Loading normalization stats from: {load_stats_path}")
    if os.path.exists(load_stats_path):
        env = VecNormalize.load(load_stats_path, env)
        env.training = True
        env.norm_reward = True
    else:
        print("WARNING: Stats file not found! Training might fail.")

    # 3. Setup Eval
    eval_env = SubprocVecEnv([make_env(999, 42)])
    if os.path.exists(load_stats_path):
        eval_env = VecNormalize.load(load_stats_path, eval_env)
        eval_env.training = False
        eval_env.norm_reward = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=25_000,
        deterministic=True,
        render=False
    )

    # 4. Load the Pre-Trained Model
    print(f"Loading model from: {load_model_path}")
    # We use a constant low learning rate to polish the weights
    custom_objects = {
        "learning_rate": 5e-5,
        "learning_starts": 0,
        "lr_schedule": lambda _: 5e-5 # Fix for schedule objects
    }

    model = TQC.load(
        load_model_path,
        env=env,
        custom_objects=custom_objects,
        print_system_info=True
    )

    # 5. Train
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100, reset_num_timesteps=False)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Fine-tuning finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Final Video ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    model = TQC.load(best_model_path)

    # 2. FIX: Use Rank 100 to avoid overwriting '0.monitor.csv'
    env = DummyVecEnv([make_env(100, 42)])

    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2500,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)
        if isinstance(done, list) or isinstance(done, np.ndarray):
            done = done[0]

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Video not found.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# --- Resuming Training: tqc_v3_hardcore_finetune_rerun ---
# Loading normalization stats from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore/vec_normalize.pkl
# Loading model from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore/best_model.zip
# == CURRENT SYSTEM INFO ==
# - OS: Linux-6.6.105+-x86_64-with-glibc2.35 # 1 SMP Thu Oct  2 10:42:05 UTC 2025
# - Python: 3.12.12
# - Stable-Baselines3: 2.7.1
# - PyTorch: 2.9.0+cu126
# - GPU Enabled: True
# - Numpy: 2.0.2
# - Cloudpickle: 3.1.2
# - Gymnasium: 1.2.2
# - OpenAI Gym: 0.25.2
#
# == SAVED MODEL SYSTEM INFO ==
# - OS: Linux-6.6.105+-x86_64-with-glibc2.35 # 1 SMP Thu Oct  2 10:42:05 UTC 2025
# - Python: 3.12.12
# - Stable-Baselines3: 2.7.1
# - PyTorch: 2.9.0+cu126
# - GPU Enabled: True
# - Numpy: 2.0.2
# - Cloudpickle: 3.1.2
# - Gymnasium: 1.2.2
# - OpenAI Gym: 0.25.2
#
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_hardcore/TQC_3
# Eval num_timesteps=2900000, episode_reward=111.91 +/- 160.77
# Episode length: 1020.20 +/- 662.51
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.02e+03 |
# |    mean_reward     | 112      |
# | time/              |          |
# |    total_timesteps | 2900000  |
# | train/             |          |
# |    actor_loss      | -0.587   |
# |    critic_loss     | 0.00157  |
# |    ent_coef        | 0.000904 |
# |    ent_coef_loss   | 0.136    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 722432   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.16e+03 |
# |    ep_rew_mean     | 106      |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 279      |
# |    time_elapsed    | 420      |
# |    total_timesteps | 2917692  |
# | train/             |          |
# |    actor_loss      | -0.565   |
# |    critic_loss     | 0.00185  |
# |    ent_coef        | 0.000934 |
# |    ent_coef_loss   | 0.0304   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 726848   |
# ---------------------------------
# Eval num_timesteps=3000000, episode_reward=151.51 +/- 108.15
# Episode length: 1289.20 +/- 447.41
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.29e+03 |
# |    mean_reward     | 152      |
# | time/              |          |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -0.444   |
# |    critic_loss     | 0.00208  |
# |    ent_coef        | 0.000827 |
# |    ent_coef_loss   | -0.405   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 747456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.18e+03 |
# |    ep_rew_mean     | 103      |
# | time/              |          |
# |    episodes        | 2400     |
# |    fps             | 281      |
# |    time_elapsed    | 834      |
# |    total_timesteps | 3035236  |
# | train/             |          |
# |    actor_loss      | -0.439   |
# |    critic_loss     | 0.00201  |
# |    ent_coef        | 0.000786 |
# |    ent_coef_loss   | -0.27    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 756224   |
# ---------------------------------
# Eval num_timesteps=3100000, episode_reward=187.34 +/- 113.17
# Episode length: 1034.80 +/- 298.33
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.03e+03 |
# |    mean_reward     | 187      |
# | time/              |          |
# |    total_timesteps | 3100000  |
# | train/             |          |
# |    actor_loss      | -0.452   |
# |    critic_loss     | 0.00267  |
# |    ent_coef        | 0.000877 |
# |    ent_coef_loss   | -0.444   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 772416   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.15e+03 |
# |    ep_rew_mean     | 95.8     |
# | time/              |          |
# |    episodes        | 2500     |
# |    fps             | 282      |
# |    time_elapsed    | 1238     |
# |    total_timesteps | 3150336  |
# | train/             |          |
# |    actor_loss      | -0.417   |
# |    critic_loss     | 0.00257  |
# |    ent_coef        | 0.000823 |
# |    ent_coef_loss   | -0.703   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 785024   |
# ---------------------------------
# Eval num_timesteps=3200000, episode_reward=197.89 +/- 91.25
# Episode length: 1208.00 +/- 138.83
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.21e+03 |
# |    mean_reward     | 198      |
# | time/              |          |
# |    total_timesteps | 3200000  |
# | train/             |          |
# |    actor_loss      | -0.356   |
# |    critic_loss     | 0.00236  |
# |    ent_coef        | 0.000779 |
# |    ent_coef_loss   | 0.333    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 797440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 109      |
# | time/              |          |
# |    episodes        | 2600     |
# |    fps             | 281      |
# |    time_elapsed    | 1708     |
# |    total_timesteps | 3281516  |
# | train/             |          |
# |    actor_loss      | -0.356   |
# |    critic_loss     | 0.00207  |
# |    ent_coef        | 0.000815 |
# |    ent_coef_loss   | -0.701   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 817792   |
# ---------------------------------
# Eval num_timesteps=3300000, episode_reward=200.91 +/- 91.43
# Episode length: 1451.40 +/- 288.21
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.45e+03 |
# |    mean_reward     | 201      |
# | time/              |          |
# |    total_timesteps | 3300000  |
# | train/             |          |
# |    actor_loss      | -0.355   |
# |    critic_loss     | 0.00217  |
# |    ent_coef        | 0.000779 |
# |    ent_coef_loss   | -0.354   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 822464   |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=3400000, episode_reward=217.86 +/- 117.28
# Episode length: 1365.80 +/- 317.96
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.37e+03 |
# |    mean_reward     | 218      |
# | time/              |          |
# |    total_timesteps | 3400000  |
# | train/             |          |
# |    actor_loss      | -0.414   |
# |    critic_loss     | 0.00177  |
# |    ent_coef        | 0.000759 |
# |    ent_coef_loss   | -0.289   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 847424   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 2700     |
# |    fps             | 281      |
# |    time_elapsed    | 2191     |
# |    total_timesteps | 3416788  |
# | train/             |          |
# |    actor_loss      | -0.424   |
# |    critic_loss     | 0.00196  |
# |    ent_coef        | 0.000729 |
# |    ent_coef_loss   | -0.51    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 851648   |
# ---------------------------------
# Eval num_timesteps=3500000, episode_reward=175.90 +/- 141.58
# Episode length: 1489.20 +/- 419.58
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.49e+03 |
# |    mean_reward     | 176      |
# | time/              |          |
# |    total_timesteps | 3500000  |
# | train/             |          |
# |    actor_loss      | -0.461   |
# |    critic_loss     | 0.00179  |
# |    ent_coef        | 0.000698 |
# |    ent_coef_loss   | 0.345    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 872448   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | 142      |
# | time/              |          |
# |    episodes        | 2800     |
# |    fps             | 281      |
# |    time_elapsed    | 2689     |
# |    total_timesteps | 3556440  |
# | train/             |          |
# |    actor_loss      | -0.502   |
# |    critic_loss     | 0.00165  |
# |    ent_coef        | 0.000682 |
# |    ent_coef_loss   | -0.349   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 886528   |
# ---------------------------------
# Eval num_timesteps=3600000, episode_reward=239.34 +/- 71.39
# Episode length: 1352.40 +/- 325.38
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.35e+03 |
# |    mean_reward     | 239      |
# | time/              |          |
# |    total_timesteps | 3600000  |
# | train/             |          |
# |    actor_loss      | -0.515   |
# |    critic_loss     | 0.0016   |
# |    ent_coef        | 0.000687 |
# |    ent_coef_loss   | 0.63     |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 897408   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 163      |
# | time/              |          |
# |    episodes        | 2900     |
# |    fps             | 281      |
# |    time_elapsed    | 3167     |
# |    total_timesteps | 3692800  |
# | train/             |          |
# |    actor_loss      | -0.515   |
# |    critic_loss     | 0.00149  |
# |    ent_coef        | 0.000671 |
# |    ent_coef_loss   | -0.229   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 920640   |
# ---------------------------------
# Eval num_timesteps=3700000, episode_reward=198.02 +/- 117.92
# Episode length: 1333.60 +/- 336.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.33e+03 |
# |    mean_reward     | 198      |
# | time/              |          |
# |    total_timesteps | 3700000  |
# | train/             |          |
# |    actor_loss      | -0.518   |
# |    critic_loss     | 0.00154  |
# |    ent_coef        | 0.000661 |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 922432   |
# ---------------------------------
# Eval num_timesteps=3800000, episode_reward=91.29 +/- 151.83
# Episode length: 1128.00 +/- 560.08
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.13e+03 |
# |    mean_reward     | 91.3     |
# | time/              |          |
# |    total_timesteps | 3800000  |
# | train/             |          |
# |    actor_loss      | -0.523   |
# |    critic_loss     | 0.00147  |
# |    ent_coef        | 0.000674 |
# |    ent_coef_loss   | 0.0611   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 947456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.29e+03 |
# |    ep_rew_mean     | 180      |
# | time/              |          |
# |    episodes        | 3000     |
# |    fps             | 281      |
# |    time_elapsed    | 3639     |
# |    total_timesteps | 3823732  |
# | train/             |          |
# |    actor_loss      | -0.514   |
# |    critic_loss     | 0.00148  |
# |    ent_coef        | 0.000668 |
# |    ent_coef_loss   | -0.971   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 953344   |
# ---------------------------------
# Eval num_timesteps=3900000, episode_reward=170.07 +/- 85.77
# Episode length: 1110.00 +/- 171.85
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.11e+03 |
# |    mean_reward     | 170      |
# | time/              |          |
# |    total_timesteps | 3900000  |
# | train/             |          |
# |    actor_loss      | -0.518   |
# |    critic_loss     | 0.00153  |
# |    ent_coef        | 0.000638 |
# |    ent_coef_loss   | 0.425    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 972416   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | 167      |
# | time/              |          |
# |    episodes        | 3100     |
# |    fps             | 281      |
# |    time_elapsed    | 4102     |
# |    total_timesteps | 3955932  |
# | train/             |          |
# |    actor_loss      | -0.496   |
# |    critic_loss     | 0.00134  |
# |    ent_coef        | 0.000639 |
# |    ent_coef_loss   | -0.68    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 986432   |
# ---------------------------------
# Eval num_timesteps=4000000, episode_reward=220.87 +/- 116.88
# Episode length: 1332.20 +/- 336.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.33e+03 |
# |    mean_reward     | 221      |
# | time/              |          |
# |    total_timesteps | 4000000  |
# | train/             |          |
# |    actor_loss      | -0.496   |
# |    critic_loss     | 0.00142  |
# |    ent_coef        | 0.000618 |
# |    ent_coef_loss   | -0.0307  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 997440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.27e+03 |
# |    ep_rew_mean     | 206      |
# | time/              |          |
# |    episodes        | 3200     |
# |    fps             | 281      |
# |    time_elapsed    | 4554     |
# |    total_timesteps | 4082912  |
# | train/             |          |
# |    actor_loss      | -0.527   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | -0.538   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1018176  |
# ---------------------------------
# Eval num_timesteps=4100000, episode_reward=259.16 +/- 39.99
# Episode length: 1392.40 +/- 309.70
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.39e+03 |
# |    mean_reward     | 259      |
# | time/              |          |
# |    total_timesteps | 4100000  |
# | train/             |          |
# |    actor_loss      | -0.525   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000605 |
# |    ent_coef_loss   | 0.456    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1022464  |
# ---------------------------------
# New best mean reward!
# Eval num_timesteps=4200000, episode_reward=207.60 +/- 94.25
# Episode length: 1522.20 +/- 393.10
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.52e+03 |
# |    mean_reward     | 208      |
# | time/              |          |
# |    total_timesteps | 4200000  |
# | train/             |          |
# |    actor_loss      | -0.586   |
# |    critic_loss     | 0.00118  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | 0.236    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1047424  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | 195      |
# | time/              |          |
# |    episodes        | 3300     |
# |    fps             | 280      |
# |    time_elapsed    | 5004     |
# |    total_timesteps | 4204864  |
# | train/             |          |
# |    actor_loss      | -0.58    |
# |    critic_loss     | 0.00116  |
# |    ent_coef        | 0.000623 |
# |    ent_coef_loss   | 0.639    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1048640  |
# ---------------------------------
# Eval num_timesteps=4300000, episode_reward=258.46 +/- 51.68
# Episode length: 1245.60 +/- 53.90
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.25e+03 |
# |    mean_reward     | 258      |
# | time/              |          |
# |    total_timesteps | 4300000  |
# | train/             |          |
# |    actor_loss      | -0.591   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000607 |
# |    ent_coef_loss   | 0.357    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1072448  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.22e+03 |
# |    ep_rew_mean     | 161      |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 281      |
# |    time_elapsed    | 5436     |
# |    total_timesteps | 4328244  |
# | train/             |          |
# |    actor_loss      | -0.611   |
# |    critic_loss     | 0.00122  |
# |    ent_coef        | 0.000616 |
# |    ent_coef_loss   | 0.316    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1079488  |
# ---------------------------------
# Eval num_timesteps=4400000, episode_reward=281.78 +/- 3.90
# Episode length: 1169.00 +/- 53.46
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.17e+03 |
# |    mean_reward     | 282      |
# | time/              |          |
# |    total_timesteps | 4400000  |
# | train/             |          |
# |    actor_loss      | -0.603   |
# |    critic_loss     | 0.00119  |
# |    ent_coef        | 0.000599 |
# |    ent_coef_loss   | 0.439    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1097408  |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.35e+03 |
# |    ep_rew_mean     | 179      |
# | time/              |          |
# |    episodes        | 3500     |
# |    fps             | 281      |
# |    time_elapsed    | 5914     |
# |    total_timesteps | 4463392  |
# | train/             |          |
# |    actor_loss      | -0.605   |
# |    critic_loss     | 0.00114  |
# |    ent_coef        | 0.000621 |
# |    ent_coef_loss   | 0.387    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1113280  |
# ---------------------------------
# Eval num_timesteps=4500000, episode_reward=259.18 +/- 40.94
# Episode length: 1347.60 +/- 334.02
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.35e+03 |
# |    mean_reward     | 259      |
# | time/              |          |
# |    total_timesteps | 4500000  |
# | train/             |          |
# |    actor_loss      | -0.639   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000648 |
# |    ent_coef_loss   | 0.0542   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1122432  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.32e+03 |
# |    ep_rew_mean     | 170      |
# | time/              |          |
# |    episodes        | 3600     |
# |    fps             | 281      |
# |    time_elapsed    | 6384     |
# |    total_timesteps | 4596216  |
# | train/             |          |
# |    actor_loss      | -0.63    |
# |    critic_loss     | 0.00106  |
# |    ent_coef        | 0.000619 |
# |    ent_coef_loss   | -0.414   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1146496  |
# ---------------------------------
# Eval num_timesteps=4600000, episode_reward=216.19 +/- 89.11
# Episode length: 1302.80 +/- 352.49
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.3e+03  |
# |    mean_reward     | 216      |
# | time/              |          |
# |    total_timesteps | 4600000  |
# | train/             |          |
# |    actor_loss      | -0.643   |
# |    critic_loss     | 0.00102  |
# |    ent_coef        | 0.000613 |
# |    ent_coef_loss   | -0.557   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1147456  |
# ---------------------------------
# Eval num_timesteps=4700000, episode_reward=277.24 +/- 5.02
# Episode length: 1215.60 +/- 39.47
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.22e+03 |
# |    mean_reward     | 277      |
# | time/              |          |
# |    total_timesteps | 4700000  |
# | train/             |          |
# |    actor_loss      | -0.618   |
# |    critic_loss     | 0.00105  |
# |    ent_coef        | 0.000629 |
# |    ent_coef_loss   | 0.195    |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1172416  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | 185      |
# | time/              |          |
# |    episodes        | 3700     |
# |    fps             | 281      |
# |    time_elapsed    | 6853     |
# |    total_timesteps | 4727300  |
# | train/             |          |
# |    actor_loss      | -0.643   |
# |    critic_loss     | 0.00107  |
# |    ent_coef        | 0.000611 |
# |    ent_coef_loss   | -0.0771  |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1179264  |
# ---------------------------------
# Eval num_timesteps=4800000, episode_reward=276.79 +/- 17.85
# Episode length: 1302.20 +/- 350.25
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.3e+03  |
# |    mean_reward     | 277      |
# | time/              |          |
# |    total_timesteps | 4800000  |
# | train/             |          |
# |    actor_loss      | -0.648   |
# |    critic_loss     | 0.00112  |
# |    ent_coef        | 0.000584 |
# |    ent_coef_loss   | -0.163   |
# |    learning_rate   | 5e-05    |
# |    n_updates       | 1197440  |
# ---------------------------------
# Fine-tuning finished.
# --- Recording Final Video ---
# /usr/local/lib/python3.12/dist-packages/pygame/pkgdata.py:25: DeprecationWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html
#   from pkg_resources import resource_stream, resource_exists
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('google.cloud')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# /usr/local/lib/python3.12/dist-packages/pkg_resources/__init__.py:3154: DeprecationWarning: Deprecated call to `pkg_resources.declare_namespace('sphinxcontrib')`.
# Implementing implicit namespace packages (as specified in PEP 420) is preferred to `pkg_resources.declare_namespace`. See https://setuptools.pypa.io/en/latest/references/keywords.html#keyword-namespace-packages
#   declare_namespace(pkg)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2926603189.py in <cell line: 0>()
#     161 if __name__ == "__main__":
#     162     train()
# --> 163     record_and_show_video()
#
# /tmp/ipython-input-2926603189.py in record_and_show_video()
#     141         action, _ = model.predict(obs, deterministic=True)
#     142         obs, _, done, _ = video_env.step(action)
# --> 143         if isinstance(done, list) or isinstance(done, np.ndarray):
#     144             done = done[0]
#     145
#
# NameError: name 'np' is not defined

# %%
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import base64
import numpy as np  # <--- FIXED: Added the missing import
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import DummyVecEnv, VecNormalize, VecVideoRecorder
from stable_baselines3.common.monitor import Monitor
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display

# --- 1. SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- 2. CONFIGURATION ---
# Target the experiment you just finished
EXPERIMENT_NAME = "tqc_v3_hardcore_finetune_rerun"
ENV_ID = "BipedalWalkerHardcore-v3"

base_path = "/content/drive/MyDrive/aisf_project"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"

# Define files to load
model_path = f"{model_dir}/best_model.zip"
stats_path = f"{model_dir}/vec_normalize.pkl"

# Fallback if best_model doesn't exist
if not os.path.exists(model_path):
    print("Best model not found, looking for final model...")
    model_path = f"{model_dir}/final_model.zip"

os.makedirs(video_dir, exist_ok=True)

# --- 3. VIDEO RECORDING FUNCTION ---
def record_video():
    print(f"--- Loading Model from: {model_path} ---")

    # 1. Load the Agent
    model = TQC.load(model_path)

    # 2. Create a Dummy Environment
    # CRITICAL FIX: We use rank 5555 to ensure this env creates '5555.monitor.csv'
    # instead of overwriting your training data at '0.monitor.csv'
    def make_video_env():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        # Log to the same folder but with a safe, high ID
        env = Monitor(env, os.path.join(log_dir, "5555"))
        return env

    env = DummyVecEnv([make_video_env])

    # 3. Load Normalization Stats
    # The agent is blind without these stats!
    print(f"Loading stats from: {stats_path}")
    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False     # Do not update stats during recording
        env.norm_reward = False  # Do not normalize rewards (we want to see the real score)
    else:
        print("WARNING: Stats file not found. The agent might perform poorly.")

    # 4. Setup Video Recorder
    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0, # Record immediately
        video_length=2500,                     # Long enough to finish the level
        name_prefix=f"{EXPERIMENT_NAME}_final_proof"
    )

    # 5. Run the Episode
    print("Recording...")
    obs = video_env.reset()
    done = False

    while not done:
        # deterministic=True is better for showing off the "best" behavior
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)

        # Handle the vectorized environment returning a list/array for 'done'
        if isinstance(done, (list, np.ndarray)):
            done = done[0]

    video_env.close()
    print("Recording finished.")

    # 6. Display the Video
    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        # Get the most recent video file
        latest_mp4 = max([os.path.join(video_dir, f) for f in mp4_list], key=os.path.getctime)
        video_data = open(latest_mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <h3>{EXPERIMENT_NAME}</h3>
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("No video file found.")

if __name__ == "__main__":
    record_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# --- Loading Model from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore_finetune_rerun/best_model.zip ---
# Loading stats from: /content/drive/MyDrive/aisf_project/models/tqc_v3_hardcore_finetune_rerun/vec_normalize.pkl
# Recording...
# /usr/local/lib/python3.12/dist-packages/moviepy/config_defaults.py:47: SyntaxWarning: invalid escape sequence '\P'
#   IMAGEMAGICK_BINARY = r"C:\Program Files\ImageMagick-6.8.8-Q16\magick.exe"
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_finetune_rerun/tqc_v3_hardcore_finetune_rerun_final_proof-step-0-to-step-2500.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_finetune_rerun/tqc_v3_hardcore_finetune_rerun_final_proof-step-0-to-step-2500.mp4
# /usr/local/lib/python3.12/dist-packages/jupyter_client/session.py:203: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   return datetime.utcnow().replace(tzinfo=utc)
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_hardcore_finetune_rerun/tqc_v3_hardcore_finetune_rerun_final_proof-step-0-to-step-2500.mp4
# Recording finished.
#         <h3>tqc_v3_hardcore_finetune_rerun</h3>
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
# Install dependencies if you restarted the runtime
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay sb3-contrib

import gymnasium as gym
import os
import torch
import numpy as np
import base64
from datetime import datetime
from sb3_contrib import TQC
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize, VecVideoRecorder, DummyVecEnv
from stable_baselines3.common.callbacks import EvalCallback
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.utils import set_random_seed
from google.colab import drive
from pyvirtualdisplay import Display
from IPython.display import HTML, display as ipy_display
from typing import Callable

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
timestamp = datetime.now().strftime("%Y%m%d_%H%M")

# --- EXPERIMENT NAME ---
# Labeled clearly for "Constant LR"
EXPERIMENT_NAME = f"tqc_v3_ablation_constant_lr_3M_{timestamp}"

ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
SEED = 42
NUM_CPU = 4

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

print(f"Logging to: {log_dir}")
print(f"Running Ablation: CONSTANT LEARNING RATE (7.3e-4)")

# --- LINEAR SCHEDULE REMOVED ---
# (Function def removed to prevent confusion)

# --- ENVIRONMENT MAKER ---
def make_env(rank: int, seed: int = 0):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = Monitor(env, os.path.join(log_dir, str(rank)))
        env.reset(seed=seed + rank)
        return env
    return _init

def train():
    print(f"--- Starting Training: {EXPERIMENT_NAME} ---")

    # 1. PARALLEL ENVIRONMENTS
    env = SubprocVecEnv([make_env(i, SEED) for i in range(NUM_CPU)])

    # 2. NORMALIZATION (Active)
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # Eval Env
    eval_env = SubprocVecEnv([make_env(999, SEED)])
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10.)
    eval_env.training = False

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=log_dir,
        eval_freq=50_000,
        deterministic=True,
        render=False
    )

    # --- TQC CONFIGURATION ---
    policy_kwargs = dict(
        n_critics=2,
        n_quantiles=25,
        net_arch=[400, 300],
    )

    model = TQC(
        "MlpPolicy",
        env,
        top_quantiles_to_drop_per_net=2,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        policy_kwargs=policy_kwargs,

        # --- CHANGE 1: CONSTANT LEARNING RATE ---
        # Replaced 'linear_schedule(7.3e-4)' with fixed float
        learning_rate=7.3e-4,

        buffer_size=1_000_000,
        batch_size=256,
        gamma=0.99,
        tau=0.01,
        train_freq=64,
        gradient_steps=64,
        learning_starts=10_000,
        use_sde=False
    )

    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=eval_callback, log_interval=100)

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vec_normalize.pkl")
    print("Training finished.")
    env.close()

def record_and_show_video():
    print(f"--- Recording Video for {EXPERIMENT_NAME} ---")

    best_model_path = os.path.join(model_dir, "best_model.zip")
    stats_path = os.path.join(model_dir, "vec_normalize.pkl")

    if not os.path.exists(best_model_path):
        best_model_path = os.path.join(model_dir, "final_model.zip")

    env = DummyVecEnv([make_env(1000, SEED)])

    if os.path.exists(stats_path):
        env = VecNormalize.load(stats_path, env)
        env.training = False
        env.norm_reward = False
    else:
        print("Warning: Normalization stats not found!")

    model = TQC.load(best_model_path)

    video_env = VecVideoRecorder(
        env,
        video_dir,
        record_video_trigger=lambda x: x == 0,
        video_length=2000,
        name_prefix=f"{EXPERIMENT_NAME}_agent"
    )

    obs = video_env.reset()
    done = False
    while not done:
        action, _ = model.predict(obs, deterministic=True)
        obs, _, done, _ = video_env.step(action)
        if isinstance(done, (list, np.ndarray)):
             done = done[0]

    video_env.close()

    mp4_list = [f for f in os.listdir(video_dir) if f.endswith('.mp4')]
    if mp4_list:
        mp4 = os.path.join(video_dir, mp4_list[0])
        video_data = open(mp4, "rb").read()
        b64 = base64.b64encode(video_data)
        ipy_display(HTML(f'''
        <video width="600" controls autoplay loop>
            <source src="data:video/mp4;base64,{b64.decode()}" type="video/mp4">
        </video>
        '''))
    else:
        print("Could not find video file.")

if __name__ == "__main__":
    train()
    record_and_show_video()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# Logging to: /content/drive/MyDrive/aisf_project/logs/tqc_v3_ablation_constant_lr_3M_20251228_1522
# Running Ablation: CONSTANT LEARNING RATE (7.3e-4)
# --- Starting Training: tqc_v3_ablation_constant_lr_3M_20251228_1522 ---
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/tqc_v3_ablation_constant_lr_3M_20251228_1522/TQC_1
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 963      |
# |    ep_rew_mean     | -116     |
# | time/              |          |
# |    episodes        | 100      |
# |    fps             | 317      |
# |    time_elapsed    | 315      |
# |    total_timesteps | 100124   |
# | train/             |          |
# |    actor_loss      | -3.66    |
# |    critic_loss     | 0.00569  |
# |    ent_coef        | 0.000604 |
# |    ent_coef_loss   | 0.27     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 22528    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 888      |
# |    ep_rew_mean     | -99.6    |
# | time/              |          |
# |    episodes        | 200      |
# |    fps             | 301      |
# |    time_elapsed    | 620      |
# |    total_timesteps | 187328   |
# | train/             |          |
# |    actor_loss      | 0.0473   |
# |    critic_loss     | 0.00328  |
# |    ent_coef        | 0.000549 |
# |    ent_coef_loss   | -0.22    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 44288    |
# ---------------------------------
# Eval num_timesteps=200000, episode_reward=-85.74 +/- 6.77
# Episode length: 770.00 +/- 644.91
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 770      |
# |    mean_reward     | -85.7    |
# | time/              |          |
# |    total_timesteps | 200000   |
# | train/             |          |
# |    actor_loss      | 0.0776   |
# |    critic_loss     | 0.0031   |
# |    ent_coef        | 0.000622 |
# |    ent_coef_loss   | 0.177    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 47488    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 883      |
# |    ep_rew_mean     | -86.4    |
# | time/              |          |
# |    episodes        | 300      |
# |    fps             | 294      |
# |    time_elapsed    | 943      |
# |    total_timesteps | 277860   |
# | train/             |          |
# |    actor_loss      | 0.113    |
# |    critic_loss     | 0.00374  |
# |    ent_coef        | 0.000628 |
# |    ent_coef_loss   | 0.409    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 66944    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 955      |
# |    ep_rew_mean     | -66.7    |
# | time/              |          |
# |    episodes        | 400      |
# |    fps             | 292      |
# |    time_elapsed    | 1273     |
# |    total_timesteps | 372456   |
# | train/             |          |
# |    actor_loss      | 0.0243   |
# |    critic_loss     | 0.00359  |
# |    ent_coef        | 0.000692 |
# |    ent_coef_loss   | -0.875   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 90560    |
# ---------------------------------
# Eval num_timesteps=400000, episode_reward=-45.77 +/- 40.83
# Episode length: 1489.40 +/- 625.36
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.49e+03 |
# |    mean_reward     | -45.8    |
# | time/              |          |
# |    total_timesteps | 400000   |
# | train/             |          |
# |    actor_loss      | 0.0507   |
# |    critic_loss     | 0.00436  |
# |    ent_coef        | 0.00065  |
# |    ent_coef_loss   | -0.199   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 97472    |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 976      |
# |    ep_rew_mean     | -66.1    |
# | time/              |          |
# |    episodes        | 500      |
# |    fps             | 290      |
# |    time_elapsed    | 1612     |
# |    total_timesteps | 468364   |
# | train/             |          |
# |    actor_loss      | 0.0196   |
# |    critic_loss     | 0.00466  |
# |    ent_coef        | 0.000667 |
# |    ent_coef_loss   | -0.515   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 114560   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -44.4    |
# | time/              |          |
# |    episodes        | 600      |
# |    fps             | 289      |
# |    time_elapsed    | 2007     |
# |    total_timesteps | 581004   |
# | train/             |          |
# |    actor_loss      | 0.0596   |
# |    critic_loss     | 0.0051   |
# |    ent_coef        | 0.000598 |
# |    ent_coef_loss   | -0.738   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 142720   |
# ---------------------------------
# Eval num_timesteps=600000, episode_reward=8.24 +/- 84.84
# Episode length: 1715.20 +/- 569.60
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.72e+03 |
# |    mean_reward     | 8.24     |
# | time/              |          |
# |    total_timesteps | 600000   |
# | train/             |          |
# |    actor_loss      | 0.0292   |
# |    critic_loss     | 0.00557  |
# |    ent_coef        | 0.000594 |
# |    ent_coef_loss   | 0.23     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 147456   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.13e+03 |
# |    ep_rew_mean     | -60.2    |
# | time/              |          |
# |    episodes        | 700      |
# |    fps             | 287      |
# |    time_elapsed    | 2419     |
# |    total_timesteps | 695212   |
# | train/             |          |
# |    actor_loss      | -0.611   |
# |    critic_loss     | 0.00675  |
# |    ent_coef        | 0.00101  |
# |    ent_coef_loss   | -0.0368  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 171264   |
# ---------------------------------
# Eval num_timesteps=800000, episode_reward=-13.85 +/- 41.54
# Episode length: 1634.80 +/- 730.40
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.63e+03 |
# |    mean_reward     | -13.9    |
# | time/              |          |
# |    total_timesteps | 800000   |
# | train/             |          |
# |    actor_loss      | -0.122   |
# |    critic_loss     | 0.00475  |
# |    ent_coef        | 0.000727 |
# |    ent_coef_loss   | 0.424    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 197440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | -35.2    |
# | time/              |          |
# |    episodes        | 800      |
# |    fps             | 286      |
# |    time_elapsed    | 2915     |
# |    total_timesteps | 836244   |
# | train/             |          |
# |    actor_loss      | -0.0998  |
# |    critic_loss     | 0.00408  |
# |    ent_coef        | 0.000638 |
# |    ent_coef_loss   | -0.619   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 206528   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.3e+03  |
# |    ep_rew_mean     | -37.5    |
# | time/              |          |
# |    episodes        | 900      |
# |    fps             | 286      |
# |    time_elapsed    | 3378     |
# |    total_timesteps | 968636   |
# | train/             |          |
# |    actor_loss      | -0.0149  |
# |    critic_loss     | 0.00422  |
# |    ent_coef        | 0.000588 |
# |    ent_coef_loss   | -0.683   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 239616   |
# ---------------------------------
# Eval num_timesteps=1000000, episode_reward=-20.83 +/- 77.15
# Episode length: 2000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2e+03    |
# |    mean_reward     | -20.8    |
# | time/              |          |
# |    total_timesteps | 1000000  |
# | train/             |          |
# |    actor_loss      | 0.0055   |
# |    critic_loss     | 0.00466  |
# |    ent_coef        | 0.000657 |
# |    ent_coef_loss   | 0.0815   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 247488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | -10      |
# | time/              |          |
# |    episodes        | 1000     |
# |    fps             | 285      |
# |    time_elapsed    | 3920     |
# |    total_timesteps | 1120736  |
# | train/             |          |
# |    actor_loss      | -0.035   |
# |    critic_loss     | 0.00431  |
# |    ent_coef        | 0.000642 |
# |    ent_coef_loss   | 1.21     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 277632   |
# ---------------------------------
# Eval num_timesteps=1200000, episode_reward=11.89 +/- 135.50
# Episode length: 1910.00 +/- 180.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.91e+03 |
# |    mean_reward     | 11.9     |
# | time/              |          |
# |    total_timesteps | 1200000  |
# | train/             |          |
# |    actor_loss      | -0.0896  |
# |    critic_loss     | 0.00337  |
# |    ent_coef        | 0.000548 |
# |    ent_coef_loss   | -1.77    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 297472   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | -1.56    |
# | time/              |          |
# |    episodes        | 1100     |
# |    fps             | 285      |
# |    time_elapsed    | 4461     |
# |    total_timesteps | 1273292  |
# | train/             |          |
# |    actor_loss      | -0.0895  |
# |    critic_loss     | 0.00319  |
# |    ent_coef        | 0.00052  |
# |    ent_coef_loss   | 0.838    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 315776   |
# ---------------------------------
# Eval num_timesteps=1400000, episode_reward=-8.21 +/- 68.30
# Episode length: 1456.60 +/- 723.95
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.46e+03 |
# |    mean_reward     | -8.21    |
# | time/              |          |
# |    total_timesteps | 1400000  |
# | train/             |          |
# |    actor_loss      | -0.109   |
# |    critic_loss     | 0.00286  |
# |    ent_coef        | 0.000544 |
# |    ent_coef_loss   | 0.645    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 347456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.52e+03 |
# |    ep_rew_mean     | 4.34     |
# | time/              |          |
# |    episodes        | 1200     |
# |    fps             | 284      |
# |    time_elapsed    | 5000     |
# |    total_timesteps | 1424900  |
# | train/             |          |
# |    actor_loss      | -0.128   |
# |    critic_loss     | 0.0032   |
# |    ent_coef        | 0.0005   |
# |    ent_coef_loss   | 2.11     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 353728   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.47e+03 |
# |    ep_rew_mean     | -15.2    |
# | time/              |          |
# |    episodes        | 1300     |
# |    fps             | 285      |
# |    time_elapsed    | 5506     |
# |    total_timesteps | 1571904  |
# | train/             |          |
# |    actor_loss      | -0.273   |
# |    critic_loss     | 0.00297  |
# |    ent_coef        | 0.000502 |
# |    ent_coef_loss   | 1.26     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 390464   |
# ---------------------------------
# Eval num_timesteps=1600000, episode_reward=-54.28 +/- 44.97
# Episode length: 1322.20 +/- 831.10
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.32e+03 |
# |    mean_reward     | -54.3    |
# | time/              |          |
# |    total_timesteps | 1600000  |
# | train/             |          |
# |    actor_loss      | -0.239   |
# |    critic_loss     | 0.003    |
# |    ent_coef        | 0.000532 |
# |    ent_coef_loss   | -0.65    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 397440   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.53e+03 |
# |    ep_rew_mean     | -12.7    |
# | time/              |          |
# |    episodes        | 1400     |
# |    fps             | 285      |
# |    time_elapsed    | 6049     |
# |    total_timesteps | 1725184  |
# | train/             |          |
# |    actor_loss      | -0.153   |
# |    critic_loss     | 0.0029   |
# |    ent_coef        | 0.000425 |
# |    ent_coef_loss   | 0.969    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 428736   |
# ---------------------------------
# Eval num_timesteps=1800000, episode_reward=-36.83 +/- 36.90
# Episode length: 2000.00 +/- 0.00
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 2e+03    |
# |    mean_reward     | -36.8    |
# | time/              |          |
# |    total_timesteps | 1800000  |
# | train/             |          |
# |    actor_loss      | -0.127   |
# |    critic_loss     | 0.00246  |
# |    ent_coef        | 0.000423 |
# |    ent_coef_loss   | 0.797    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 447488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.39e+03 |
# |    ep_rew_mean     | 21       |
# | time/              |          |
# |    episodes        | 1500     |
# |    fps             | 284      |
# |    time_elapsed    | 6541     |
# |    total_timesteps | 1864080  |
# | train/             |          |
# |    actor_loss      | -0.144   |
# |    critic_loss     | 0.00231  |
# |    ent_coef        | 0.000419 |
# |    ent_coef_loss   | 0.787    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 463488   |
# ---------------------------------
# Eval num_timesteps=2000000, episode_reward=-22.97 +/- 52.00
# Episode length: 1371.80 +/- 780.39
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.37e+03 |
# |    mean_reward     | -23      |
# | time/              |          |
# |    total_timesteps | 2000000  |
# | train/             |          |
# |    actor_loss      | -0.1     |
# |    critic_loss     | 0.0023   |
# |    ent_coef        | 0.000364 |
# |    ent_coef_loss   | 0.951    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 497472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | 26.7     |
# | time/              |          |
# |    episodes        | 1600     |
# |    fps             | 284      |
# |    time_elapsed    | 7071     |
# |    total_timesteps | 2014292  |
# | train/             |          |
# |    actor_loss      | -0.126   |
# |    critic_loss     | 0.00224  |
# |    ent_coef        | 0.000426 |
# |    ent_coef_loss   | -0.0991  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 501056   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | 23.1     |
# | time/              |          |
# |    episodes        | 1700     |
# |    fps             | 285      |
# |    time_elapsed    | 7550     |
# |    total_timesteps | 2153176  |
# | train/             |          |
# |    actor_loss      | -0.221   |
# |    critic_loss     | 0.00287  |
# |    ent_coef        | 0.000419 |
# |    ent_coef_loss   | -0.0704  |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 535744   |
# ---------------------------------
# Eval num_timesteps=2200000, episode_reward=2.40 +/- 88.98
# Episode length: 1459.40 +/- 662.31
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.46e+03 |
# |    mean_reward     | 2.4      |
# | time/              |          |
# |    total_timesteps | 2200000  |
# | train/             |          |
# |    actor_loss      | -0.209   |
# |    critic_loss     | 0.00212  |
# |    ent_coef        | 0.000396 |
# |    ent_coef_loss   | -0.536   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 547456   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.38e+03 |
# |    ep_rew_mean     | 30.9     |
# | time/              |          |
# |    episodes        | 1800     |
# |    fps             | 284      |
# |    time_elapsed    | 8049     |
# |    total_timesteps | 2292376  |
# | train/             |          |
# |    actor_loss      | -0.22    |
# |    critic_loss     | 0.00238  |
# |    ent_coef        | 0.000398 |
# |    ent_coef_loss   | -0.73    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 570560   |
# ---------------------------------
# Eval num_timesteps=2400000, episode_reward=188.55 +/- 82.20
# Episode length: 1453.40 +/- 453.92
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.45e+03 |
# |    mean_reward     | 189      |
# | time/              |          |
# |    total_timesteps | 2400000  |
# | train/             |          |
# |    actor_loss      | -0.176   |
# |    critic_loss     | 0.00252  |
# |    ent_coef        | 0.000451 |
# |    ent_coef_loss   | 0.857    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 597440   |
# ---------------------------------
# New best mean reward!
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.34e+03 |
# |    ep_rew_mean     | 49.5     |
# | time/              |          |
# |    episodes        | 1900     |
# |    fps             | 284      |
# |    time_elapsed    | 8525     |
# |    total_timesteps | 2427040  |
# | train/             |          |
# |    actor_loss      | -0.217   |
# |    critic_loss     | 0.00263  |
# |    ent_coef        | 0.000479 |
# |    ent_coef_loss   | -1.29    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 604224   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.45e+03 |
# |    ep_rew_mean     | 67.2     |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 284      |
# |    time_elapsed    | 9023     |
# |    total_timesteps | 2571060  |
# | train/             |          |
# |    actor_loss      | -0.186   |
# |    critic_loss     | 0.00245  |
# |    ent_coef        | 0.000388 |
# |    ent_coef_loss   | 0.166    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 640256   |
# ---------------------------------
# Eval num_timesteps=2600000, episode_reward=16.70 +/- 74.50
# Episode length: 1264.00 +/- 672.12
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.26e+03 |
# |    mean_reward     | 16.7     |
# | time/              |          |
# |    total_timesteps | 2600000  |
# | train/             |          |
# |    actor_loss      | -0.206   |
# |    critic_loss     | 0.00249  |
# |    ent_coef        | 0.000417 |
# |    ent_coef_loss   | -0.234   |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 647488   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 72.7     |
# | time/              |          |
# |    episodes        | 2100     |
# |    fps             | 284      |
# |    time_elapsed    | 9473     |
# |    total_timesteps | 2699884  |
# | train/             |          |
# |    actor_loss      | -0.229   |
# |    critic_loss     | 0.00247  |
# |    ent_coef        | 0.000431 |
# |    ent_coef_loss   | 0.327    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 672448   |
# ---------------------------------
# Eval num_timesteps=2800000, episode_reward=67.87 +/- 170.30
# Episode length: 1752.20 +/- 303.80
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.75e+03 |
# |    mean_reward     | 67.9     |
# | time/              |          |
# |    total_timesteps | 2800000  |
# | train/             |          |
# |    actor_loss      | -0.234   |
# |    critic_loss     | 0.00244  |
# |    ent_coef        | 0.000472 |
# |    ent_coef_loss   | 0.76     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 697472   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | 78.5     |
# | time/              |          |
# |    episodes        | 2200     |
# |    fps             | 284      |
# |    time_elapsed    | 9923     |
# |    total_timesteps | 2827396  |
# | train/             |          |
# |    actor_loss      | -0.276   |
# |    critic_loss     | 0.00247  |
# |    ent_coef        | 0.000435 |
# |    ent_coef_loss   | 1.31     |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 704320   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.11e+03 |
# |    ep_rew_mean     | 46.8     |
# | time/              |          |
# |    episodes        | 2300     |
# |    fps             | 284      |
# |    time_elapsed    | 10316    |
# |    total_timesteps | 2939468  |
# | train/             |          |
# |    actor_loss      | -0.226   |
# |    critic_loss     | 0.00261  |
# |    ent_coef        | 0.000483 |
# |    ent_coef_loss   | 0.523    |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 732352   |
# ---------------------------------
# Eval num_timesteps=3000000, episode_reward=63.38 +/- 108.99
# Episode length: 1617.20 +/- 538.23
# ---------------------------------
# | eval/              |          |
# |    mean_ep_length  | 1.62e+03 |
# |    mean_reward     | 63.4     |
# | time/              |          |
# |    total_timesteps | 3000000  |
# | train/             |          |
# |    actor_loss      | -0.248   |
# |    critic_loss     | 0.00258  |
# |    ent_coef        | 0.000432 |
# |    ent_coef_loss   | 1.3      |
# |    learning_rate   | 0.00073  |
# |    n_updates       | 747456   |
# ---------------------------------
# Training finished.
# --- Recording Video for tqc_v3_ablation_constant_lr_3M_20251228_1522 ---
# Saving video to /content/drive/MyDrive/aisf_project/videos/tqc_v3_ablation_constant_lr_3M_20251228_1522/tqc_v3_ablation_constant_lr_3M_20251228_1522_agent-step-0-to-step-2000.mp4
# Moviepy - Building video /content/drive/MyDrive/aisf_project/videos/tqc_v3_ablation_constant_lr_3M_20251228_1522/tqc_v3_ablation_constant_lr_3M_20251228_1522_agent-step-0-to-step-2000.mp4.
# Moviepy - Writing video /content/drive/MyDrive/aisf_project/videos/tqc_v3_ablation_constant_lr_3M_20251228_1522/tqc_v3_ablation_constant_lr_3M_20251228_1522_agent-step-0-to-step-2000.mp4
# Moviepy - Done !
# Moviepy - video ready /content/drive/MyDrive/aisf_project/videos/tqc_v3_ablation_constant_lr_3M_20251228_1522/tqc_v3_ablation_constant_lr_3M_20251228_1522_agent-step-0-to-step-2000.mp4
#         <video width="600" controls autoplay loop>
#             <source src="data:video/mp4;base64,..." type="video/mp4">
#         </video>

# %%
# Install dependencies if you restarted the runtime
# !apt-get install -y swig ffmpeg xvfb
# !pip install gymnasium[box2d] stable-baselines3 shimmy pyvirtualdisplay

import gymnasium as gym
import os
import torch.nn as nn
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import SubprocVecEnv, VecNormalize
from stable_baselines3.common.monitor import Monitor
from stable_baselines3.common.callbacks import EvalCallback, BaseCallback
from google.colab import drive
from pyvirtualdisplay import Display
from typing import Callable, List, Union

# --- COLAB SETUP ---
if not os.path.exists('/content/drive'):
    drive.mount('/content/drive')

try:
    virtual_display
except NameError:
    virtual_display = Display(visible=0, size=(1400, 900))
    virtual_display.start()

# --- CONFIGURATION ---
EXPERIMENT_NAME = "ppo_advanced_ablation_shared_net"
ENV_ID = "BipedalWalkerHardcore-v3"
TOTAL_TIMESTEPS = 3_000_000
NUM_CPU = 4
SEED = 42

# --- DIRECTORY SETUP ---
base_path = "/content/drive/MyDrive/aisf_project"
log_dir = f"{base_path}/logs/{EXPERIMENT_NAME}"
model_dir = f"{base_path}/models/{EXPERIMENT_NAME}"
video_dir = f"{base_path}/videos/{EXPERIMENT_NAME}"

os.makedirs(log_dir, exist_ok=True)
os.makedirs(model_dir, exist_ok=True)
os.makedirs(video_dir, exist_ok=True)

# --- REWARD SHAPING ---
class EncouragingWalkerWrapper(gym.RewardWrapper):
    def __init__(self, env):
        super().__init__(env)
    def reward(self, reward):
        return reward * 1.1

# --- LINEAR SCHEDULE ---
def linear_schedule(initial_value: float) -> Callable[[float], float]:
    def func(progress_remaining: float) -> float:
        return progress_remaining * initial_value
    return func

# --- MAKE ENV ---
def make_env(rank, seed=0, is_eval=False):
    def _init():
        env = gym.make(ENV_ID, render_mode="rgb_array")
        env = EncouragingWalkerWrapper(env)

        # Separate logs for train vs eval
        subdir = "eval" if is_eval else "train"
        log_file = os.path.join(log_dir, subdir, str(rank))
        os.makedirs(os.path.dirname(log_file), exist_ok=True)

        env = Monitor(env, log_file)
        env.reset(seed=seed + rank)
        return env
    return _init

# --- CALLBACK TO SYNC STATS ---
class SyncVecNormalizeCallback(BaseCallback):
    def __init__(self, train_env, eval_env):
        super().__init__()
        self.train_env = train_env
        self.eval_env = eval_env

    def _on_step(self) -> bool:
        return True

    def _on_event(self) -> bool:
        self.eval_env.obs_rms = self.train_env.obs_rms
        return True

def train():
    print(f"--- Starting Ablation: SHARED NETWORK (Coupled) ---")

    # 1. Training Environment
    env = SubprocVecEnv([make_env(i, seed=SEED) for i in range(NUM_CPU)])
    env = VecNormalize(env, norm_obs=True, norm_reward=True, clip_obs=10.)

    # 2. Evaluation Environment (Separate instance)
    eval_env = SubprocVecEnv([make_env(0, seed=SEED+1000, is_eval=True)])
    # norm_reward=False so we see the raw score, training=False to freeze stats
    eval_env = VecNormalize(eval_env, norm_obs=True, norm_reward=False, clip_obs=10., training=False)

    # 3. Callbacks
    sync_callback = SyncVecNormalizeCallback(env, eval_env)

    eval_callback = EvalCallback(
        eval_env,
        best_model_save_path=model_dir,
        log_path=os.path.join(log_dir, "eval"),
        eval_freq=max(50000 // NUM_CPU, 1),
        deterministic=True,
        render=False
    )

    # 4. Model Setup
    model = PPO(
        "MlpPolicy",
        env,
        verbose=1,
        seed=SEED,
        tensorboard_log=log_dir,
        use_sde=False,
        policy_kwargs=dict(
            # --- SHARED NETWORK ARCHITECTURE ---
            # By passing a simple list, SB3 creates a shared feature extractor
            # of [256, 256] before splitting into heads.
            net_arch=[256, 256],

            activation_fn=nn.Tanh,
            optimizer_kwargs=dict(eps=1e-5)
        ),
        learning_rate=linear_schedule(3e-4),
        n_steps=2048,
        batch_size=1024,
        n_epochs=10,
        gamma=0.99,
        gae_lambda=0.95,
        clip_range=0.2,
        ent_coef=0.001,
        vf_coef=0.5,
        max_grad_norm=0.5,
    )

    # 5. Learn
    model.learn(total_timesteps=TOTAL_TIMESTEPS, callback=[sync_callback, eval_callback])

    model.save(f"{model_dir}/final_model")
    env.save(f"{model_dir}/vecnormalize.pkl")
    print("Training finished.")

    env.close()
    eval_env.close()

if __name__ == "__main__":
    train()
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# swig is already the newest version (4.0.2-1ubuntu1).
# ffmpeg is already the newest version (7:4.4.2-0ubuntu0.22.04.1).
# xvfb is already the newest version (2:21.1.4-2ubuntu1.7~22.04.16).
# 0 upgraded, 0 newly installed, 0 to remove and 41 not upgraded.
# Requirement already satisfied: stable-baselines3 in /usr/local/lib/python3.12/dist-packages (2.7.1)
# Requirement already satisfied: shimmy in /usr/local/lib/python3.12/dist-packages (2.0.0)
# Requirement already satisfied: pyvirtualdisplay in /usr/local/lib/python3.12/dist-packages (3.0)
# Requirement already satisfied: gymnasium[box2d] in /usr/local/lib/python3.12/dist-packages (1.2.2)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (3.1.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.15.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (0.0.4)
# Requirement already satisfied: box2d-py==2.3.5 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.3.5)
# Requirement already satisfied: pygame>=2.1.3 in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (2.6.1)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.12/dist-packages (from gymnasium[box2d]) (4.4.1)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.9.0+cu126)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (2.2.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from stable-baselines3) (3.10.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.20.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch<3.0,>=2.3->stable-baselines3) (3.5.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->stable-baselines3) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->stable-baselines3) (2025.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->stable-baselines3) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch<3.0,>=2.3->stable-baselines3) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch<3.0,>=2.3->stable-baselines3) (3.0.3)
# --- Starting Ablation: SHARED NETWORK (Coupled) ---
# Using cuda device
# Logging to /content/drive/MyDrive/aisf_project/logs/ppo_advanced_ablation_shared_net/PPO_1
# /usr/local/lib/python3.12/dist-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# Streaming output truncated to the last 5000 lines.
# |    ep_rew_mean          | -80.1      |
# | time/                   |            |
# |    fps                  | 1239       |
# |    iterations           | 155        |
# |    time_elapsed         | 1024       |
# |    total_timesteps      | 1269760    |
# | train/                  |            |
# |    approx_kl            | 0.00740656 |
# |    clip_fraction        | 0.0865     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.84      |
# |    explained_variance   | 0.897      |
# |    learning_rate        | 0.000174   |
# |    loss                 | 0.0188     |
# |    n_updates            | 1540       |
# |    policy_gradient_loss | -0.0153    |
# |    std                  | 0.631      |
# |    value_loss           | 0.156      |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.3e+03     |
# |    ep_rew_mean          | -77.4       |
# | time/                   |             |
# |    fps                  | 1241        |
# |    iterations           | 156         |
# |    time_elapsed         | 1029        |
# |    total_timesteps      | 1277952     |
# | train/                  |             |
# |    approx_kl            | 0.008196862 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.83       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.000173    |
# |    loss                 | 0.00828     |
# |    n_updates            | 1550        |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.63        |
# |    value_loss           | 0.131       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.3e+03      |
# |    ep_rew_mean          | -75.9        |
# | time/                   |              |
# |    fps                  | 1243         |
# |    iterations           | 157          |
# |    time_elapsed         | 1034         |
# |    total_timesteps      | 1286144      |
# | train/                  |              |
# |    approx_kl            | 0.0076922113 |
# |    clip_fraction        | 0.0799       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.82        |
# |    explained_variance   | 0.936        |
# |    learning_rate        | 0.000172     |
# |    loss                 | -0.0224      |
# |    n_updates            | 1560         |
# |    policy_gradient_loss | -0.0176      |
# |    std                  | 0.628        |
# |    value_loss           | 0.0439       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.29e+03     |
# |    ep_rew_mean          | -73.2        |
# | time/                   |              |
# |    fps                  | 1245         |
# |    iterations           | 158          |
# |    time_elapsed         | 1039         |
# |    total_timesteps      | 1294336      |
# | train/                  |              |
# |    approx_kl            | 0.0086472165 |
# |    clip_fraction        | 0.0926       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.81        |
# |    explained_variance   | 0.885        |
# |    learning_rate        | 0.000171     |
# |    loss                 | -0.00392     |
# |    n_updates            | 1570         |
# |    policy_gradient_loss | -0.0189      |
# |    std                  | 0.626        |
# |    value_loss           | 0.0936       |
# ------------------------------------------
# Eval num_timesteps=1300000, episode_reward=-21.79 +/- 35.34
# Episode length: 2000.00 +/- 0.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 2e+03       |
# |    mean_reward          | -21.8       |
# | time/                   |             |
# |    total_timesteps      | 1300000     |
# | train/                  |             |
# |    approx_kl            | 0.009856577 |
# |    clip_fraction        | 0.0964      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.000171    |
# |    loss                 | 0.0014      |
# |    n_updates            | 1580        |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.626       |
# |    value_loss           | 0.103       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.31e+03 |
# |    ep_rew_mean     | -75.8    |
# | time/              |          |
# |    fps             | 1230     |
# |    iterations      | 159      |
# |    time_elapsed    | 1058     |
# |    total_timesteps | 1302528  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -75.1       |
# | time/                   |             |
# |    fps                  | 1232        |
# |    iterations           | 160         |
# |    time_elapsed         | 1063        |
# |    total_timesteps      | 1310720     |
# | train/                  |             |
# |    approx_kl            | 0.008514494 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.8        |
# |    explained_variance   | 0.901       |
# |    learning_rate        | 0.00017     |
# |    loss                 | -0.0216     |
# |    n_updates            | 1590        |
# |    policy_gradient_loss | -0.0172     |
# |    std                  | 0.624       |
# |    value_loss           | 0.0302      |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.35e+03   |
# |    ep_rew_mean          | -74.5      |
# | time/                   |            |
# |    fps                  | 1234       |
# |    iterations           | 161        |
# |    time_elapsed         | 1068       |
# |    total_timesteps      | 1318912    |
# | train/                  |            |
# |    approx_kl            | 0.00975282 |
# |    clip_fraction        | 0.11       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.78      |
# |    explained_variance   | 0.892      |
# |    learning_rate        | 0.000169   |
# |    loss                 | -0.0135    |
# |    n_updates            | 1600       |
# |    policy_gradient_loss | -0.0179    |
# |    std                  | 0.622      |
# |    value_loss           | 0.0544     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -73.1       |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 162         |
# |    time_elapsed         | 1073        |
# |    total_timesteps      | 1327104     |
# | train/                  |             |
# |    approx_kl            | 0.009577841 |
# |    clip_fraction        | 0.108       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.909       |
# |    learning_rate        | 0.000168    |
# |    loss                 | 0.00952     |
# |    n_updates            | 1610        |
# |    policy_gradient_loss | -0.0163     |
# |    std                  | 0.623       |
# |    value_loss           | 0.127       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -75         |
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 163         |
# |    time_elapsed         | 1078        |
# |    total_timesteps      | 1335296     |
# | train/                  |             |
# |    approx_kl            | 0.009715753 |
# |    clip_fraction        | 0.116       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.78       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.000167    |
# |    loss                 | -0.0158     |
# |    n_updates            | 1620        |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.623       |
# |    value_loss           | 0.0709      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.38e+03     |
# |    ep_rew_mean          | -74.5        |
# | time/                   |              |
# |    fps                  | 1239         |
# |    iterations           | 164          |
# |    time_elapsed         | 1083         |
# |    total_timesteps      | 1343488      |
# | train/                  |              |
# |    approx_kl            | 0.0086941905 |
# |    clip_fraction        | 0.0939       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.77        |
# |    explained_variance   | 0.952        |
# |    learning_rate        | 0.000166     |
# |    loss                 | -0.0152      |
# |    n_updates            | 1630         |
# |    policy_gradient_loss | -0.0147      |
# |    std                  | 0.619        |
# |    value_loss           | 0.042        |
# ------------------------------------------
# Eval num_timesteps=1350000, episode_reward=-68.22 +/- 34.57
# Episode length: 1084.20 +/- 788.41
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 1.08e+03     |
# |    mean_reward          | -68.2        |
# | time/                   |              |
# |    total_timesteps      | 1350000      |
# | train/                  |              |
# |    approx_kl            | 0.0093614925 |
# |    clip_fraction        | 0.1          |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.75        |
# |    explained_variance   | 0.93         |
# |    learning_rate        | 0.000166     |
# |    loss                 | -0.0231      |
# |    n_updates            | 1640         |
# |    policy_gradient_loss | -0.0181      |
# |    std                  | 0.616        |
# |    value_loss           | 0.033        |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.33e+03 |
# |    ep_rew_mean     | -73.2    |
# | time/              |          |
# |    fps             | 1233     |
# |    iterations      | 165      |
# |    time_elapsed    | 1096     |
# |    total_timesteps | 1351680  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.32e+03    |
# |    ep_rew_mean          | -73.6       |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 166         |
# |    time_elapsed         | 1101        |
# |    total_timesteps      | 1359872     |
# | train/                  |             |
# |    approx_kl            | 0.008413707 |
# |    clip_fraction        | 0.0766      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.892       |
# |    learning_rate        | 0.000165    |
# |    loss                 | 0.00342     |
# |    n_updates            | 1650        |
# |    policy_gradient_loss | -0.0165     |
# |    std                  | 0.614       |
# |    value_loss           | 0.108       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.32e+03    |
# |    ep_rew_mean          | -74.3       |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 167         |
# |    time_elapsed         | 1106        |
# |    total_timesteps      | 1368064     |
# | train/                  |             |
# |    approx_kl            | 0.010168602 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.906       |
# |    learning_rate        | 0.000164    |
# |    loss                 | -0.000994   |
# |    n_updates            | 1660        |
# |    policy_gradient_loss | -0.0193     |
# |    std                  | 0.615       |
# |    value_loss           | 0.0938      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -68.9       |
# | time/                   |             |
# |    fps                  | 1238        |
# |    iterations           | 168         |
# |    time_elapsed         | 1111        |
# |    total_timesteps      | 1376256     |
# | train/                  |             |
# |    approx_kl            | 0.006455441 |
# |    clip_fraction        | 0.0834      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.73       |
# |    explained_variance   | 0.9         |
# |    learning_rate        | 0.000163    |
# |    loss                 | -0.0184     |
# |    n_updates            | 1670        |
# |    policy_gradient_loss | -0.0141     |
# |    std                  | 0.613       |
# |    value_loss           | 0.0402      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.31e+03    |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 169         |
# |    time_elapsed         | 1116        |
# |    total_timesteps      | 1384448     |
# | train/                  |             |
# |    approx_kl            | 0.008107726 |
# |    clip_fraction        | 0.0945      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.71       |
# |    explained_variance   | 0.927       |
# |    learning_rate        | 0.000162    |
# |    loss                 | -0.00881    |
# |    n_updates            | 1680        |
# |    policy_gradient_loss | -0.0174     |
# |    std                  | 0.611       |
# |    value_loss           | 0.0767      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.3e+03     |
# |    ep_rew_mean          | -67.4       |
# | time/                   |             |
# |    fps                  | 1241        |
# |    iterations           | 170         |
# |    time_elapsed         | 1121        |
# |    total_timesteps      | 1392640     |
# | train/                  |             |
# |    approx_kl            | 0.009916838 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.000162    |
# |    loss                 | 0.0308      |
# |    n_updates            | 1690        |
# |    policy_gradient_loss | -0.0177     |
# |    std                  | 0.61        |
# |    value_loss           | 0.197       |
# -----------------------------------------
# Eval num_timesteps=1400000, episode_reward=-46.50 +/- 38.72
# Episode length: 1633.00 +/- 734.00
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.63e+03    |
# |    mean_reward          | -46.5       |
# | time/                   |             |
# |    total_timesteps      | 1400000     |
# | train/                  |             |
# |    approx_kl            | 0.009469475 |
# |    clip_fraction        | 0.101       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.905       |
# |    learning_rate        | 0.000161    |
# |    loss                 | 0.013       |
# |    n_updates            | 1700        |
# |    policy_gradient_loss | -0.0182     |
# |    std                  | 0.61        |
# |    value_loss           | 0.114       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.26e+03 |
# |    ep_rew_mean     | -69      |
# | time/              |          |
# |    fps             | 1231     |
# |    iterations      | 171      |
# |    time_elapsed    | 1137     |
# |    total_timesteps | 1400832  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.24e+03    |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 172         |
# |    time_elapsed         | 1142        |
# |    total_timesteps      | 1409024     |
# | train/                  |             |
# |    approx_kl            | 0.009955998 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.893       |
# |    learning_rate        | 0.00016     |
# |    loss                 | 0.0367      |
# |    n_updates            | 1710        |
# |    policy_gradient_loss | -0.0185     |
# |    std                  | 0.611       |
# |    value_loss           | 0.225       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.24e+03     |
# |    ep_rew_mean          | -69.3        |
# | time/                   |              |
# |    fps                  | 1235         |
# |    iterations           | 173          |
# |    time_elapsed         | 1147         |
# |    total_timesteps      | 1417216      |
# | train/                  |              |
# |    approx_kl            | 0.0081870835 |
# |    clip_fraction        | 0.0841       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.7         |
# |    explained_variance   | 0.882        |
# |    learning_rate        | 0.000159     |
# |    loss                 | 0.0122       |
# |    n_updates            | 1720         |
# |    policy_gradient_loss | -0.0161      |
# |    std                  | 0.61         |
# |    value_loss           | 0.144        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.22e+03    |
# |    ep_rew_mean          | -67.9       |
# | time/                   |             |
# |    fps                  | 1237        |
# |    iterations           | 174         |
# |    time_elapsed         | 1152        |
# |    total_timesteps      | 1425408     |
# | train/                  |             |
# |    approx_kl            | 0.009080137 |
# |    clip_fraction        | 0.0966      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.7        |
# |    explained_variance   | 0.894       |
# |    learning_rate        | 0.000158    |
# |    loss                 | 0.0233      |
# |    n_updates            | 1730        |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.609       |
# |    value_loss           | 0.159       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.21e+03     |
# |    ep_rew_mean          | -66          |
# | time/                   |              |
# |    fps                  | 1238         |
# |    iterations           | 175          |
# |    time_elapsed         | 1157         |
# |    total_timesteps      | 1433600      |
# | train/                  |              |
# |    approx_kl            | 0.0089848675 |
# |    clip_fraction        | 0.105        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.69        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.000157     |
# |    loss                 | 0.024        |
# |    n_updates            | 1740         |
# |    policy_gradient_loss | -0.0181      |
# |    std                  | 0.608        |
# |    value_loss           | 0.151        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | -65.8       |
# | time/                   |             |
# |    fps                  | 1240        |
# |    iterations           | 176         |
# |    time_elapsed         | 1162        |
# |    total_timesteps      | 1441792     |
# | train/                  |             |
# |    approx_kl            | 0.008709588 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.68       |
# |    explained_variance   | 0.923       |
# |    learning_rate        | 0.000157    |
# |    loss                 | 0.00223     |
# |    n_updates            | 1750        |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.607       |
# |    value_loss           | 0.0921      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.23e+03    |
# |    ep_rew_mean          | -65.5       |
# | time/                   |             |
# |    fps                  | 1242        |
# |    iterations           | 177         |
# |    time_elapsed         | 1167        |
# |    total_timesteps      | 1449984     |
# | train/                  |             |
# |    approx_kl            | 0.009597003 |
# |    clip_fraction        | 0.107       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.67       |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.000156    |
# |    loss                 | -0.0219     |
# |    n_updates            | 1760        |
# |    policy_gradient_loss | -0.0179     |
# |    std                  | 0.605       |
# |    value_loss           | 0.0368      |
# -----------------------------------------
# Eval num_timesteps=1450000, episode_reward=-31.91 +/- 87.88
# Episode length: 1920.20 +/- 159.60
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.92e+03   |
# |    mean_reward          | -31.9      |
# | time/                   |            |
# |    total_timesteps      | 1450000    |
# | train/                  |            |
# |    approx_kl            | 0.00897783 |
# |    clip_fraction        | 0.109      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.66      |
# |    explained_variance   | 0.894      |
# |    learning_rate        | 0.000155   |
# |    loss                 | -0.0023    |
# |    n_updates            | 1770       |
# |    policy_gradient_loss | -0.0162    |
# |    std                  | 0.604      |
# |    value_loss           | 0.0659     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.23e+03 |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    fps             | 1230     |
# |    iterations      | 178      |
# |    time_elapsed    | 1184     |
# |    total_timesteps | 1458176  |
# ---------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.21e+03   |
# |    ep_rew_mean          | -65.8      |
# | time/                   |            |
# |    fps                  | 1232       |
# |    iterations           | 179        |
# |    time_elapsed         | 1189       |
# |    total_timesteps      | 1466368    |
# | train/                  |            |
# |    approx_kl            | 0.00972542 |
# |    clip_fraction        | 0.0961     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.65      |
# |    explained_variance   | 0.944      |
# |    learning_rate        | 0.000154   |
# |    loss                 | -0.0133    |
# |    n_updates            | 1780       |
# |    policy_gradient_loss | -0.0174    |
# |    std                  | 0.602      |
# |    value_loss           | 0.0475     |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.25e+03    |
# |    ep_rew_mean          | -65.1       |
# | time/                   |             |
# |    fps                  | 1234        |
# |    iterations           | 180         |
# |    time_elapsed         | 1194        |
# |    total_timesteps      | 1474560     |
# | train/                  |             |
# |    approx_kl            | 0.009218454 |
# |    clip_fraction        | 0.103       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.64       |
# |    explained_variance   | 0.868       |
# |    learning_rate        | 0.000153    |
# |    loss                 | -0.00915    |
# |    n_updates            | 1790        |
# |    policy_gradient_loss | -0.019      |
# |    std                  | 0.601       |
# |    value_loss           | 0.0983      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -65.5       |
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 181         |
# |    time_elapsed         | 1199        |
# |    total_timesteps      | 1482752     |
# | train/                  |             |
# |    approx_kl            | 0.009315921 |
# |    clip_fraction        | 0.091       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.63       |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.000153    |
# |    loss                 | -0.0232     |
# |    n_updates            | 1800        |
# |    policy_gradient_loss | -0.018      |
# |    std                  | 0.599       |
# |    value_loss           | 0.0376      |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.28e+03     |
# |    ep_rew_mean          | -65.5        |
# | time/                   |              |
# |    fps                  | 1237         |
# |    iterations           | 182          |
# |    time_elapsed         | 1204         |
# |    total_timesteps      | 1490944      |
# | train/                  |              |
# |    approx_kl            | 0.0101151075 |
# |    clip_fraction        | 0.11         |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.62        |
# |    explained_variance   | 0.924        |
# |    learning_rate        | 0.000152     |
# |    loss                 | -0.0181      |
# |    n_updates            | 1810         |
# |    policy_gradient_loss | -0.0179      |
# |    std                  | 0.597        |
# |    value_loss           | 0.0431       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.26e+03    |
# |    ep_rew_mean          | -60.2       |
# | time/                   |             |
# |    fps                  | 1239        |
# |    iterations           | 183         |
# |    time_elapsed         | 1209        |
# |    total_timesteps      | 1499136     |
# | train/                  |             |
# |    approx_kl            | 0.008305533 |
# |    clip_fraction        | 0.0744      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.903       |
# |    learning_rate        | 0.000151    |
# |    loss                 | 6.76e-05    |
# |    n_updates            | 1820        |
# |    policy_gradient_loss | -0.0171     |
# |    std                  | 0.596       |
# |    value_loss           | 0.0844      |
# -----------------------------------------
# Eval num_timesteps=1500000, episode_reward=-84.52 +/- 61.66
# Episode length: 1801.00 +/- 398.00
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.8e+03    |
# |    mean_reward          | -84.5      |
# | time/                   |            |
# |    total_timesteps      | 1500000    |
# | train/                  |            |
# |    approx_kl            | 0.00840546 |
# |    clip_fraction        | 0.0792     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -3.6       |
# |    explained_variance   | 0.92       |
# |    learning_rate        | 0.00015    |
# |    loss                 | -0.00472   |
# |    n_updates            | 1830       |
# |    policy_gradient_loss | -0.0141    |
# |    std                  | 0.596      |
# |    value_loss           | 0.0672     |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.28e+03 |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    fps             | 1228     |
# |    iterations      | 184      |
# |    time_elapsed    | 1226     |
# |    total_timesteps | 1507328  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.3e+03     |
# |    ep_rew_mean          | -67         |
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 185         |
# |    time_elapsed         | 1231        |
# |    total_timesteps      | 1515520     |
# | train/                  |             |
# |    approx_kl            | 0.009371309 |
# |    clip_fraction        | 0.0874      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.61       |
# |    explained_variance   | 0.915       |
# |    learning_rate        | 0.000149    |
# |    loss                 | -0.0118     |
# |    n_updates            | 1840        |
# |    policy_gradient_loss | -0.0153     |
# |    std                  | 0.596       |
# |    value_loss           | 0.0758      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.28e+03    |
# |    ep_rew_mean          | -66.6       |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 186         |
# |    time_elapsed         | 1236        |
# |    total_timesteps      | 1523712     |
# | train/                  |             |
# |    approx_kl            | 0.008680265 |
# |    clip_fraction        | 0.0993      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.911       |
# |    learning_rate        | 0.000148    |
# |    loss                 | 0.0138      |
# |    n_updates            | 1850        |
# |    policy_gradient_loss | -0.0184     |
# |    std                  | 0.595       |
# |    value_loss           | 0.13        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.34e+03    |
# |    ep_rew_mean          | -67.3       |
# | time/                   |             |
# |    fps                  | 1233        |
# |    iterations           | 187         |
# |    time_elapsed         | 1241        |
# |    total_timesteps      | 1531904     |
# | train/                  |             |
# |    approx_kl            | 0.007954223 |
# |    clip_fraction        | 0.0843      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.6        |
# |    explained_variance   | 0.921       |
# |    learning_rate        | 0.000148    |
# |    loss                 | 0.00659     |
# |    n_updates            | 1860        |
# |    policy_gradient_loss | -0.0168     |
# |    std                  | 0.595       |
# |    value_loss           | 0.122       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.37e+03    |
# |    ep_rew_mean          | -66.2       |
# | time/                   |             |
# |    fps                  | 1235        |
# |    iterations           | 188         |
# |    time_elapsed         | 1246        |
# |    total_timesteps      | 1540096     |
# | train/                  |             |
# |    approx_kl            | 0.008715626 |
# |    clip_fraction        | 0.0893      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.59       |
# |    explained_variance   | 0.859       |
# |    learning_rate        | 0.000147    |
# |    loss                 | -0.00709    |
# |    n_updates            | 1870        |
# |    policy_gradient_loss | -0.0156     |
# |    std                  | 0.593       |
# |    value_loss           | 0.0658      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.38e+03    |
# |    ep_rew_mean          | -67.8       |
# | time/                   |             |
# |    fps                  | 1236        |
# |    iterations           | 189         |
# |    time_elapsed         | 1251        |
# |    total_timesteps      | 1548288     |
# | train/                  |             |
# |    approx_kl            | 0.007601192 |
# |    clip_fraction        | 0.0856      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.58       |
# |    explained_variance   | 0.88        |
# |    learning_rate        | 0.000146    |
# |    loss                 | 0.00282     |
# |    n_updates            | 1880        |
# |    policy_gradient_loss | -0.015      |
# |    std                  | 0.591       |
# |    value_loss           | 0.0692      |
# -----------------------------------------
# Eval num_timesteps=1550000, episode_reward=-3.05 +/- 90.68
# Episode length: 2000.00 +/- 0.00
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 2e+03        |
# |    mean_reward          | -3.05        |
# | time/                   |              |
# |    total_timesteps      | 1550000      |
# | train/                  |              |
# |    approx_kl            | 0.0068402975 |
# |    clip_fraction        | 0.0697       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.56        |
# |    explained_variance   | 0.922        |
# |    learning_rate        | 0.000145     |
# |    loss                 | -0.0175      |
# |    n_updates            | 1890         |
# |    policy_gradient_loss | -0.0164      |
# |    std                  | 0.588        |
# |    value_loss           | 0.0456       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.41e+03 |
# |    ep_rew_mean     | -66.1    |
# | time/              |          |
# |    fps             | 1225     |
# |    iterations      | 190      |
# |    time_elapsed    | 1269     |
# |    total_timesteps | 1556480  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.42e+03     |
# |    ep_rew_mean          | -65          |
# | time/                   |              |
# |    fps                  | 1227         |
# |    iterations           | 191          |
# |    time_elapsed         | 1274         |
# |    total_timesteps      | 1564672      |
# | train/                  |              |
# |    approx_kl            | 0.0076964763 |
# |    clip_fraction        | 0.0981       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -3.55        |
# |    explained_variance   | 0.927        |
# |    learning_rate        | 0.000144     |
# |    loss                 | -0.0195      |
# |    n_updates            | 1900         |
# |    policy_gradient_loss | -0.0168      |
# |    std                  | 0.588        |
# |    value_loss           | 0.0497       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.42e+03    |
# |    ep_rew_mean          | -67.4       |
# | time/                   |             |
# |    fps                  | 1228        |
# |    iterations           | 192         |
# |    time_elapsed         | 1279        |
# |    total_timesteps      | 1572864     |
# | train/                  |             |
# |    approx_kl            | 0.008188823 |
# |    clip_fraction        | 0.0772      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.949       |
# |    learning_rate        | 0.000144    |
# |    loss                 | -0.0165     |
# |    n_updates            | 1910        |
# |    policy_gradient_loss | -0.0151     |
# |    std                  | 0.587       |
# |    value_loss           | 0.049       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | -69         |
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 193         |
# |    time_elapsed         | 1285        |
# |    total_timesteps      | 1581056     |
# | train/                  |             |
# |    approx_kl            | 0.007537391 |
# |    clip_fraction        | 0.0935      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.55       |
# |    explained_variance   | 0.871       |
# |    learning_rate        | 0.000143    |
# |    loss                 | -0.0169     |
# |    n_updates            | 1920        |
# |    policy_gradient_loss | -0.0143     |
# |    std                  | 0.588       |
# |    value_loss           | 0.0248      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.48e+03    |
# |    ep_rew_mean          | -66.2       |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 194         |
# |    time_elapsed         | 1290        |
# |    total_timesteps      | 1589248     |
# | train/                  |             |
# |    approx_kl            | 0.008887792 |
# |    clip_fraction        | 0.0904      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -3.54       |
# |    explained_variance   | 0.91        |
# |    learning_rate        | 0.000142    |
# |    loss                 | -0.0157     |
# |    n_updates            | 1930        |
# |    policy_gradient_loss | -0.0178     |
# |    std                  | 0.585       |
# |    value_loss           | 0.0346      |
# -----------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 1.47e+03  |
# |    ep_rew_mean          | -66.3     |
# | time/                   |           |
# |    fps                  | 1233      |
# |    iterations           | 195       |
# |    time_elapsed         | 1295      |
# |    total_timesteps      | 1597440   |
# | train/                  |           |
# |    approx_kl            | 0.0084928 |
# |    clip_fraction        | 0.0827    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -3.53     |
# |    explained_variance   | 0.939     |
# |    learning_rate        | 0.000141  |
# |    loss                 | -0.0118   |
# |    n_updates            | 1940      |
# |    policy_gradient_loss | -0.0163   |
# |    std                  | 0.583     |
# |    value_loss           | 0.0529    |
# ---------------------------------------
# Eval num_timesteps=1600000, episode_reward=-36.13 +/- 85.54
# Episode length: 1404.80 +/- 737.13
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.4e+03     |
# |    mean_reward          | -36.1       |
# | time/                   |             |
# |    total_timesteps      | 1600000     |
# | train/                  |             |
# |    approx_kl            | 0.008832924 |
# |    clip_fraction        | 0.0967      |
# ...
# |    std                  | 0.508        |
# |    value_loss           | 0.112        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.44e+03     |
# |    ep_rew_mean          | -35.6        |
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 352          |
# |    time_elapsed         | 2345         |
# |    total_timesteps      | 2883584      |
# | train/                  |              |
# |    approx_kl            | 0.0059560654 |
# |    clip_fraction        | 0.0322       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 1.25e-05     |
# |    loss                 | 0.0482       |
# |    n_updates            | 3510         |
# |    policy_gradient_loss | -0.00694     |
# |    std                  | 0.508        |
# |    value_loss           | 0.148        |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 1.43e+03   |
# |    ep_rew_mean          | -36        |
# | time/                   |            |
# |    fps                  | 1230       |
# |    iterations           | 353        |
# |    time_elapsed         | 2350       |
# |    total_timesteps      | 2891776    |
# | train/                  |            |
# |    approx_kl            | 0.00412169 |
# |    clip_fraction        | 0.0244     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.95       |
# |    learning_rate        | 1.16e-05   |
# |    loss                 | 0.0184     |
# |    n_updates            | 3520       |
# |    policy_gradient_loss | -0.00621   |
# |    std                  | 0.508      |
# |    value_loss           | 0.0704     |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.45e+03     |
# |    ep_rew_mean          | -34.1        |
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 354          |
# |    time_elapsed         | 2355         |
# |    total_timesteps      | 2899968      |
# | train/                  |              |
# |    approx_kl            | 0.0049180905 |
# |    clip_fraction        | 0.0266       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.901        |
# |    learning_rate        | 1.08e-05     |
# |    loss                 | 0.0673       |
# |    n_updates            | 3530         |
# |    policy_gradient_loss | -0.00676     |
# |    std                  | 0.508        |
# |    value_loss           | 0.18         |
# ------------------------------------------
# Eval num_timesteps=2900000, episode_reward=-26.63 +/- 60.17
# Episode length: 981.60 +/- 837.45
# ------------------------------------------
# | eval/                   |              |
# |    mean_ep_length       | 982          |
# |    mean_reward          | -26.6        |
# | time/                   |              |
# |    total_timesteps      | 2900000      |
# | train/                  |              |
# |    approx_kl            | 0.0037147265 |
# |    clip_fraction        | 0.0105       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.937        |
# |    learning_rate        | 1e-05        |
# |    loss                 | 0.0204       |
# |    n_updates            | 3540         |
# |    policy_gradient_loss | -0.00498     |
# |    std                  | 0.508        |
# |    value_loss           | 0.0713       |
# ------------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.49e+03 |
# |    ep_rew_mean     | -31.7    |
# | time/              |          |
# |    fps             | 1228     |
# |    iterations      | 355      |
# |    time_elapsed    | 2366     |
# |    total_timesteps | 2908160  |
# ---------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.48e+03     |
# |    ep_rew_mean          | -29.3        |
# | time/                   |              |
# |    fps                  | 1229         |
# |    iterations           | 356          |
# |    time_elapsed         | 2372         |
# |    total_timesteps      | 2916352      |
# | train/                  |              |
# |    approx_kl            | 0.0039401217 |
# |    clip_fraction        | 0.0136       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.964        |
# |    learning_rate        | 9.18e-06     |
# |    loss                 | 0.00508      |
# |    n_updates            | 3550         |
# |    policy_gradient_loss | -0.0052      |
# |    std                  | 0.508        |
# |    value_loss           | 0.0381       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.46e+03     |
# |    ep_rew_mean          | -29.7        |
# | time/                   |              |
# |    fps                  | 1230         |
# |    iterations           | 357          |
# |    time_elapsed         | 2377         |
# |    total_timesteps      | 2924544      |
# | train/                  |              |
# |    approx_kl            | 0.0035526946 |
# |    clip_fraction        | 0.00845      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.932        |
# |    learning_rate        | 8.36e-06     |
# |    loss                 | 0.0623       |
# |    n_updates            | 3560         |
# |    policy_gradient_loss | -0.00464     |
# |    std                  | 0.508        |
# |    value_loss           | 0.146        |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | -33.8       |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 358         |
# |    time_elapsed         | 2382        |
# |    total_timesteps      | 2932736     |
# | train/                  |             |
# |    approx_kl            | 0.003999426 |
# |    clip_fraction        | 0.0111      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 7.55e-06    |
# |    loss                 | 0.0178      |
# |    n_updates            | 3570        |
# |    policy_gradient_loss | -0.00414    |
# |    std                  | 0.508       |
# |    value_loss           | 0.101       |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.45e+03    |
# |    ep_rew_mean          | -37.8       |
# | time/                   |             |
# |    fps                  | 1231        |
# |    iterations           | 359         |
# |    time_elapsed         | 2387        |
# |    total_timesteps      | 2940928     |
# | train/                  |             |
# |    approx_kl            | 0.004270756 |
# |    clip_fraction        | 0.0149      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.943       |
# |    learning_rate        | 6.73e-06    |
# |    loss                 | 0.0345      |
# |    n_updates            | 3580        |
# |    policy_gradient_loss | -0.00382    |
# |    std                  | 0.508       |
# |    value_loss           | 0.106       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.48e+03     |
# |    ep_rew_mean          | -37.4        |
# | time/                   |              |
# |    fps                  | 1232         |
# |    iterations           | 360          |
# |    time_elapsed         | 2392         |
# |    total_timesteps      | 2949120      |
# | train/                  |              |
# |    approx_kl            | 0.0026729563 |
# |    clip_fraction        | 0.00435      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 5.91e-06     |
# |    loss                 | 0.0264       |
# |    n_updates            | 3590         |
# |    policy_gradient_loss | -0.00351     |
# |    std                  | 0.508        |
# |    value_loss           | 0.0835       |
# ------------------------------------------
# Eval num_timesteps=2950000, episode_reward=-15.11 +/- 89.05
# Episode length: 1402.00 +/- 725.74
# -----------------------------------------
# | eval/                   |             |
# |    mean_ep_length       | 1.4e+03     |
# |    mean_reward          | -15.1       |
# | time/                   |             |
# |    total_timesteps      | 2950000     |
# | train/                  |             |
# |    approx_kl            | 0.002589026 |
# |    clip_fraction        | 0.0024      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.918       |
# |    learning_rate        | 5.09e-06    |
# |    loss                 | 0.0312      |
# |    n_updates            | 3600        |
# |    policy_gradient_loss | -0.00326    |
# |    std                  | 0.508       |
# |    value_loss           | 0.111       |
# -----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.51e+03 |
# |    ep_rew_mean     | -36.4    |
# | time/              |          |
# |    fps             | 1228     |
# |    iterations      | 361      |
# |    time_elapsed    | 2406     |
# |    total_timesteps | 2957312  |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.5e+03     |
# |    ep_rew_mean          | -41.1       |
# | time/                   |             |
# |    fps                  | 1229        |
# |    iterations           | 362         |
# |    time_elapsed         | 2411        |
# |    total_timesteps      | 2965504     |
# | train/                  |             |
# |    approx_kl            | 0.002772794 |
# |    clip_fraction        | 0.00421     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.934       |
# |    learning_rate        | 4.27e-06    |
# |    loss                 | 0.0135      |
# |    n_updates            | 3610        |
# |    policy_gradient_loss | -0.00302    |
# |    std                  | 0.508       |
# |    value_loss           | 0.0601      |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.49e+03    |
# |    ep_rew_mean          | -47.9       |
# | time/                   |             |
# |    fps                  | 1230        |
# |    iterations           | 363         |
# |    time_elapsed         | 2417        |
# |    total_timesteps      | 2973696     |
# | train/                  |             |
# |    approx_kl            | 0.001140896 |
# |    clip_fraction        | 0.000122    |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.907       |
# |    learning_rate        | 3.45e-06    |
# |    loss                 | 0.044       |
# |    n_updates            | 3620        |
# |    policy_gradient_loss | -0.00243    |
# |    std                  | 0.508       |
# |    value_loss           | 0.105       |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.48e+03     |
# |    ep_rew_mean          | -47.6        |
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 364          |
# |    time_elapsed         | 2422         |
# |    total_timesteps      | 2981888      |
# | train/                  |              |
# |    approx_kl            | 0.0007946902 |
# |    clip_fraction        | 3.66e-05     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 2.63e-06     |
# |    loss                 | 0.0451       |
# |    n_updates            | 3630         |
# |    policy_gradient_loss | -0.0019      |
# |    std                  | 0.508        |
# |    value_loss           | 0.106        |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 1.47e+03     |
# |    ep_rew_mean          | -47.2        |
# | time/                   |              |
# |    fps                  | 1231         |
# |    iterations           | 365          |
# |    time_elapsed         | 2427         |
# |    total_timesteps      | 2990080      |
# | train/                  |              |
# |    approx_kl            | 0.0003206424 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -2.96        |
# |    explained_variance   | 0.916        |
# |    learning_rate        | 1.81e-06     |
# |    loss                 | 0.023        |
# |    n_updates            | 3640         |
# |    policy_gradient_loss | -0.000983    |
# |    std                  | 0.508        |
# |    value_loss           | 0.0728       |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 1.48e+03    |
# |    ep_rew_mean          | -44.5       |
# | time/                   |             |
# |    fps                  | 1232        |
# |    iterations           | 366         |
# |    time_elapsed         | 2432        |
# |    total_timesteps      | 2998272     |
# | train/                  |             |
# |    approx_kl            | 5.35808e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -2.96       |
# |    explained_variance   | 0.952       |
# |    learning_rate        | 9.92e-07    |
# |    loss                 | 0.0467      |
# |    n_updates            | 3650        |
# |    policy_gradient_loss | -0.000485   |
# |    std                  | 0.508       |
# |    value_loss           | 0.0966      |
# -----------------------------------------
# Eval num_timesteps=3000000, episode_reward=50.15 +/- 89.38
# Episode length: 1915.40 +/- 169.20
# ----------------------------------------
# | eval/                   |            |
# |    mean_ep_length       | 1.92e+03   |
# |    mean_reward          | 50.1       |
# | time/                   |            |
# |    total_timesteps      | 3000000    |
# | train/                  |            |
# |    approx_kl            | 4.5087e-06 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -2.96      |
# |    explained_variance   | 0.878      |
# |    learning_rate        | 1.73e-07   |
# |    loss                 | 0.0691     |
# |    n_updates            | 3660       |
# |    policy_gradient_loss | -0.000141  |
# |    std                  | 0.508      |
# |    value_loss           | 0.106      |
# ----------------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 1.5e+03  |
# |    ep_rew_mean     | -45.2    |
# | time/              |          |
# |    fps             | 1226     |
# |    iterations      | 367      |
# |    time_elapsed    | 2450     |
# |    total_timesteps | 3006464  |
# ---------------------------------
# Training finished.
